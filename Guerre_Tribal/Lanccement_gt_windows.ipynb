# %%
# !pip install pywinauto
# !pip install schedule
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pywinauto in c:\users\zbook\appdata\roaming\python\python39\site-packages (0.6.8)
# Requirement already satisfied: pywin32 in c:\programdata\anaconda3\lib\site-packages (from pywinauto) (302)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from pywinauto) (1.16.0)
# Requirement already satisfied: comtypes in c:\programdata\anaconda3\lib\site-packages (from pywinauto) (1.1.10)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting schedule
#   Downloading schedule-1.2.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: schedule
# Successfully installed schedule-1.2.0

# %%
from pywinauto.application import Application
import psutil
import time
import random

def delay_with_random_seconds():
    # Génère un délai aléatoire entre 1 et 5 secondes
    random_seconds = random.randint(3, 10)
    
    # Pause l'exécution du programme pendant le délai aléatoire
    time.sleep(random_seconds)
    
#     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()


# Vérifier si Firefox est en cours d'exécution
firefox_running = False
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_running = True
        firefox_pid = process.pid
        break

# Fermer Firefox si c'est le cas
if firefox_running:
    process = psutil.Process(firefox_pid)
    process.terminate()
#     time.sleep(5)
# Ouvrir Firefox
time.sleep(2)

app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')


# Ouvrir Firefox
# app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Trouver le PID de Firefox
firefox_pid = None
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_pid = process.pid
        break

# Vérifier si Firefox est en cours d'exécution
if firefox_pid is None:
    print("Firefox n'est pas en cours d'exécution.")
else:
    # Attacher Pywinauto à la fenêtre Firefox
    app = Application(backend='uia').connect(process=firefox_pid)

    # Ouvrir une page web
#     firefox = app.window(title_re='.*Nouvel onglet*')
    firefox = app.window( class_name='MozillaWindowClass')

    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     time.sleep(5)

#     # Saisir les champs
#     zone1 = firefox.window(title='user')
#     zone1.type_keys('*test1')
#     zone1 = firefox.child_window(control_type="Edit", found_index=0, automation_id="user")
    zone1 = firefox.child_window(auto_id='user')

    zone1.type_keys('arion1')
    delay_with_random_seconds()

    zone2 = firefox.child_window(auto_id='password')
    zone2.type_keys('MiMa5158**')
    delay_with_random_seconds()
    # Cliquer sur le bouton
#     bouton = firefox.window(title='Connexion')
# #     bouton = firefox.child_window(auto_id='btn-login')
#     bouton = firefox.child_window(title='Connexion')
#     bouton.click()!
    bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
    bouton.invoke()
#     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
#     bouton.invoke()
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=place&target=3275{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    zone3 = firefox.child_window(auto_id='unit_input_spear')
    zone3.type_keys('10')
    delay_with_random_seconds()
    zone4 = firefox.child_window(auto_id='unit_input_sword')
    zone4.type_keys('10')   
    delay_with_random_seconds()

#     bouton = firefox.child_window(title='Attaque', control_type='Hyperlink') # id = target_attack
#     bouton.invoke()
    bouton = firefox.child_window(auto_id='target_attack')
#     bouton = firefox.child_window(title='Connexion')
    bouton.click() 
    delay_with_random_seconds()
    
    bouton = firefox.child_window(auto_id='troop_confirm_submit')
#     bouton = firefox.child_window(title='Connexion')
    bouton.click()     
    delay_with_random_seconds()
    
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=place&target=3172{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()   
    zone3 = firefox.child_window(auto_id='unit_input_spear')
    zone3.type_keys('20')
    delay_with_random_seconds()
    zone4 = firefox.child_window(auto_id='unit_input_sword')
    zone4.type_keys('0')   
    delay_with_random_seconds()

#     bouton = firefox.child_window(title='Attaque', control_type='Hyperlink') # id = target_attack
#     bouton.invoke()
    bouton = firefox.child_window(auto_id='target_attack')
#     bouton = firefox.child_window(title='Connexion')
    bouton.click() 
    delay_with_random_seconds()
    
    bouton = firefox.child_window(auto_id='troop_confirm_submit')
#     bouton = firefox.child_window(title='Connexion')
    bouton.click()     
    delay_with_random_seconds()    
    # Fermer Firefox
#     firefox.close()

# %%
#     Fermer Firefox
firefox.close()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20876\2359715767.py in <module>
#       1 #     Fermer Firefox
# ----> 2 firefox.close()
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     394
#     395             if need_to_resolve:
# --> 396                 ctrls = self.__resolve_control(self.criteria)
#     397                 return getattr(ctrls[-1], attr_name)
#     398
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     201             criteria[0]['process'] = self.app.process
#     202             del criteria[0]['app']
# --> 203         dialog = self.backend.generic_wrapper_class(findwindows.find_element(**criteria[0]))
#     204
#     205         ctrls = []
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'class_name': 'MozillaWindowClass', 'backend': 'uia', 'process': 1364}

# %%
from pywinauto.application import Application
import psutil
import time
import random

def delay_with_random_seconds():
    # Génère un délai aléatoire entre 1 et 5 secondes
    random_seconds = random.randint(3, 10)
    
    # Pause l'exécution du programme pendant le délai aléatoire
    time.sleep(random_seconds)
    
#     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()
def attaquer_village(village_depart, village_arrive, nombre_troupes):
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_arrive}"
    firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()   
    zone3 = firefox.child_window(auto_id='unit_input_spear')
    zone3.type_keys(str(nombre_troupes))
    delay_with_random_seconds()
    zone4 = firefox.child_window(auto_id='unit_input_sword')
    zone4.type_keys(str(nombre_troupes))
    delay_with_random_seconds()

    bouton = firefox.child_window(auto_id='target_attack')
    bouton.click() 
    delay_with_random_seconds()
    
    bouton = firefox.child_window(auto_id='troop_confirm_submit')
    bouton.click()     
    delay_with_random_seconds()

# Vérifier si Firefox est en cours d'exécution
firefox_running = False
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_running = True
        firefox_pid = process.pid
        break

# Fermer Firefox si c'est le cas
if firefox_running:
    process = psutil.Process(firefox_pid)
    process.terminate()
#     time.sleep(5)
# Ouvrir Firefox
time.sleep(2)

app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')


# Ouvrir Firefox
# app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Trouver le PID de Firefox
firefox_pid = None
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_pid = process.pid
        break

# Vérifier si Firefox est en cours d'exécution
if firefox_pid is None:
    print("Firefox n'est pas en cours d'exécution.")
else:
    # Attacher Pywinauto à la fenêtre Firefox
    app = Application(backend='uia').connect(process=firefox_pid)

    # Ouvrir une page web
#     firefox = app.window(title_re='.*Nouvel onglet*')
    firefox = app.window( class_name='MozillaWindowClass')

    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     time.sleep(5)

#     # Saisir les champs
#     zone1 = firefox.window(title='user')
#     zone1.type_keys('*test1')
#     zone1 = firefox.child_window(control_type="Edit", found_index=0, automation_id="user")
    zone1 = firefox.child_window(auto_id='user')

    zone1.type_keys('arion1')
    delay_with_random_seconds()

    zone2 = firefox.child_window(auto_id='password')
    zone2.type_keys('MiMa5158**')
    delay_with_random_seconds()
    # Cliquer sur le bouton
#     bouton = firefox.window(title='Connexion')
# #     bouton = firefox.child_window(auto_id='btn-login')
#     bouton = firefox.child_window(title='Connexion')
#     bouton.click()!
    bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
    bouton.invoke()
#     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
#     bouton.invoke()
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
#     firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
#     firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=place&target=3275{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     delay_with_random_seconds()
#     zone3 = firefox.child_window(auto_id='unit_input_spear')
#     zone3.type_keys('10')
#     delay_with_random_seconds()
#     zone4 = firefox.child_window(auto_id='unit_input_sword')
#     zone4.type_keys('10')   
#     delay_with_random_seconds()

# #     bouton = firefox.child_window(title='Attaque', control_type='Hyperlink') # id = target_attack
# #     bouton.invoke()
#     bouton = firefox.child_window(auto_id='target_attack')
# #     bouton = firefox.child_window(title='Connexion')
#     bouton.click() 
#     delay_with_random_seconds()
    
#     bouton = firefox.child_window(auto_id='troop_confirm_submit')
# #     bouton = firefox.child_window(title='Connexion')
#     bouton.click()     
#     delay_with_random_seconds()
    
    attaquer_village('3466', '3275', 20)
    attaquer_village('3466', '3172', 20)
#     firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
#     firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=place&target=3172{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     delay_with_random_seconds()   
#     zone3 = firefox.child_window(auto_id='unit_input_spear')
#     zone3.type_keys('20')
#     delay_with_random_seconds()
#     zone4 = firefox.child_window(auto_id='unit_input_sword')
#     zone4.type_keys('0')   
#     delay_with_random_seconds()

# #     bouton = firefox.child_window(title='Attaque', control_type='Hyperlink') # id = target_attack
# #     bouton.invoke()
#     bouton = firefox.child_window(auto_id='target_attack')
# #     bouton = firefox.child_window(title='Connexion')
#     bouton.click() 
#     delay_with_random_seconds()
    
#     bouton = firefox.child_window(auto_id='troop_confirm_submit')
# #     bouton = firefox.child_window(title='Connexion')
#     bouton.click()     
    delay_with_random_seconds()    
    # Fermer Firefox
#     firefox.close()

# %%
#     attaquer_village('3466', '3275', 15)
#     attaquer_village('3466', '3172', 15)

# %%
from pywinauto.application import Application
import psutil
import time
import random

def delay_with_random_seconds():
    # Génère un délai aléatoire entre 1 et 5 secondes
    random_seconds = random.randint(3, 10)
    
    # Pause l'exécution du programme pendant le délai aléatoire
    time.sleep(random_seconds)
    
#     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()
def attaquer_village(village_depart, village_arrive, nombre_troupes):
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_arrive}"
    firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()   
    zone3 = firefox.child_window(auto_id='unit_input_spear')
    zone3.type_keys(str(nombre_troupes))
    delay_with_random_seconds()
    zone4 = firefox.child_window(auto_id='unit_input_sword')
    zone4.type_keys(str(nombre_troupes))
    delay_with_random_seconds()

    bouton = firefox.child_window(auto_id='target_attack')
    bouton.click() 
    delay_with_random_seconds()
    
    bouton = firefox.child_window(auto_id='troop_confirm_submit')
    bouton.click()     
    delay_with_random_seconds()

# Vérifier si Firefox est en cours d'exécution
firefox_running = False
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_running = True
        firefox_pid = process.pid
        break

# Fermer Firefox si c'est le cas
if firefox_running:
    process = psutil.Process(firefox_pid)
    process.terminate()
#     time.sleep(5)
# Ouvrir Firefox
time.sleep(2)

app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')


# Ouvrir Firefox
# app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Trouver le PID de Firefox
firefox_pid = None
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_pid = process.pid
        break
print('firefox_pid : ' , firefox_pid)
# Vérifier si Firefox est en cours d'exécution
if firefox_pid is None:
    print("Firefox n'est pas en cours d'exécution.")
else:
    # Attacher Pywinauto à la fenêtre Firefox
    app = Application(backend='uia').connect(process=firefox_pid)
    print('app : ' , app)
    # Ouvrir une page web
#     firefox = app.window(title_re='.*Nouvel onglet*')
    firefox = app.window( class_name='MozillaWindowClass')
    print('firefox : ' , firefox)
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     time.sleep(5)

#     # Saisir les champs
#     zone1 = firefox.window(title='user')
#     zone1.type_keys('*test1')
#     zone1 = firefox.child_window(control_type="Edit", found_index=0, automation_id="user")
    zone1 = firefox.child_window(auto_id='user')

    zone1.type_keys('arion1')
    delay_with_random_seconds()

    zone2 = firefox.child_window(auto_id='password')
    zone2.type_keys('MiMa5158**')
    delay_with_random_seconds()
    # Cliquer sur le bouton
#     bouton = firefox.window(title='Connexion')
# #     bouton = firefox.child_window(auto_id='btn-login')
#     bouton = firefox.child_window(title='Connexion')
#     bouton.click()!
    bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
    bouton.invoke()
#     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
#     bouton.invoke()
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()

    
    attaquer_village('3466', '3275', 15)
    attaquer_village('3466', '3172', 15)
# Out:
# firefox_pid :  13576
# app :  <pywinauto.application.Application object at 0x000002B8CCDE1E80>
# firefox :  <pywinauto.application.WindowSpecification object at 0x000002B8CD112460>
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20876\1347322233.py in <module>
#     111
#     112
# --> 113     attaquer_village('3466', '3275', 15)
#     114     attaquer_village('3466', '3172', 15)
#
# ~\AppData\Local\Temp\ipykernel_20876\1347322233.py in attaquer_village(village_depart, village_arrive, nombre_troupes)
#      23     delay_with_random_seconds()
#      24     zone3 = firefox.child_window(auto_id='unit_input_spear')
# ---> 25     zone3.type_keys(str(nombre_troupes))
#      26     delay_with_random_seconds()
#      27     zone4 = firefox.child_window(auto_id='unit_input_sword')
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     377         if len(self.criteria) >= 2:  # FIXME - this is surprising
#     378
# --> 379             ctrls = self.__resolve_control(self.criteria)
#     380
#     381             try:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     201             criteria[0]['process'] = self.app.process
#     202             del criteria[0]['app']
# --> 203         dialog = self.backend.generic_wrapper_class(findwindows.find_element(**criteria[0]))
#     204
#     205         ctrls = []
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'class_name': 'MozillaWindowClass', 'backend': 'uia', 'process': 13576}

# %%
import schedule
import time
from pywinauto.application import Application
import psutil
import random

def delay_with_random_seconds():
    # Génère un délai aléatoire entre 1 et 5 secondes
    random_seconds = random.randint(3, 10)
    
    # Pause l'exécution du programme pendant le délai aléatoire
    time.sleep(random_seconds)

def attaquer_village(village_depart, village_arrive, nombre_troupes):
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_arrive}"
    firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()   
    zone3 = firefox.child_window(auto_id='unit_input_spear')
    zone3.type_keys(str(nombre_troupes))
    delay_with_random_seconds()
    zone4 = firefox.child_window(auto_id='unit_input_sword')
    zone4.type_keys(str(nombre_troupes))
    delay_with_random_seconds()

    bouton = firefox.child_window(auto_id='target_attack')
    bouton.click() 
    delay_with_random_seconds()
    
    bouton = firefox.child_window(auto_id='troop_confirm_submit')
    bouton.click()     
    delay_with_random_seconds()
def run_attack():

    # Ouvrir Firefox
    # app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

    # Trouver le PID de Firefox
    firefox_pid = None
    for process in psutil.process_iter():
        if process.name() == "firefox.exe":
            firefox_pid = process.pid
            break

    # Vérifier si Firefox est en cours d'exécution
    if firefox_pid is None:
        print("Firefox n'est pas en cours d'exécution.")
    else:
        # Attacher Pywinauto à la fenêtre Firefox
        app = Application(backend='uia').connect(process=firefox_pid)

        # Ouvrir une page web
    #     firefox = app.window(title_re='.*Nouvel onglet*')
        firefox = app.window( class_name='MozillaWindowClass')

        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    #     time.sleep(5)

    #     # Saisir les champs
    #     zone1 = firefox.window(title='user')
    #     zone1.type_keys('*test1')
    #     zone1 = firefox.child_window(control_type="Edit", found_index=0, automation_id="user")
        zone1 = firefox.child_window(auto_id='user')

        zone1.type_keys('arion1')
        delay_with_random_seconds()

        zone2 = firefox.child_window(auto_id='password')
        zone2.type_keys('MiMa5158**')
        delay_with_random_seconds()
        # Cliquer sur le bouton
    #     bouton = firefox.window(title='Connexion')
    # #     bouton = firefox.child_window(auto_id='btn-login')
    #     bouton = firefox.child_window(title='Connexion')
    #     bouton.click()!
        bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
        bouton.invoke()
    #     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
    #     bouton.invoke()
        delay_with_random_seconds()
        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()
        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()


        # Votre code pour attaquer les villages
        attaquer_village('3466', '3275', 15)
        attaquer_village('3466', '3172', 15)

# Fonction pour exécuter le code toutes les heures
def run_code():
    app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')
    time.sleep(2)

    run_attack()

    # Fermer Firefox
    firefox_pid = None
    for process in psutil.process_iter():
        if process.name() == "firefox.exe":
            firefox_pid = process.pid
            break

    if firefox_pid is not None:
        process = psutil.Process(firefox_pid)
        process.terminate()
import time
from datetime import datetime

while True:
    current_time = datetime.now().strftime("%H:%M")
    minutes = current_time.split(":")[1]
    
    if minutes == "00":
        print(f"L'heure actuelle est {current_time}")
        run_code()
    if minutes[-1] == "5":
        print(f"L'heure actuelle est {current_time}")        
        run_code()
    time.sleep(60)  # Attendre une minute

# %%
import schedule
import time
from datetime import datetime

def display_message(message):
    current_time = datetime.now().strftime("%H:%M:%S")
    print(f"[{current_time}] {message}")

# Fonction pour afficher un message toutes les heures
def hourly_message():
    display_message("Message toutes les heures")

# Fonction pour afficher un message à 23h
def eleven_pm_message():
    display_message("Message à 23h")

# Fonction pour afficher un message à 23h30
def eleven_thirty_pm_message():
    display_message("Message à 23h30")
# def run_code():
#     # Planifier l'affichage du message toutes les heures
#     schedule.every().hour.do(hourly_message)
    schedule.every().day.at("19:55").do(run_code, hour=19, minute=58)
    # Planifier l'affichage du message à 23h
    schedule.every().day.at("23:15").do(eleven_pm_message)

    # Planifier l'affichage du message à 23h30
    schedule.every().day.at("23:30").do(eleven_thirty_pm_message)

# # Boucle d'exécution pour exécuter les tâches planifiées
while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20876\1411843579.py in <module>
#      30 # # Boucle d'exécution pour exécuter les tâches planifiées
#      31 while True:
# ---> 32     schedule.run_pending()
#      33     time.sleep(1)
#
# ~\AppData\Roaming\Python\Python39\site-packages\schedule\__init__.py in run_pending()
#     820     :data:`default scheduler instance <default_scheduler>`.
#     821     """
# --> 822     default_scheduler.run_pending()
#     823
#     824
#
# ~\AppData\Roaming\Python\Python39\site-packages\schedule\__init__.py in run_pending(self)
#      98         runnable_jobs = (job for job in self.jobs if job.should_run)
#      99         for job in sorted(runnable_jobs):
# --> 100             self._run_job(job)
#     101
#     102     def run_all(self, delay_seconds: int = 0) -> None:
#
# ~\AppData\Roaming\Python\Python39\site-packages\schedule\__init__.py in _run_job(self, job)
#     170
#     171     def _run_job(self, job: "Job") -> None:
# --> 172         ret = job.run()
#     173         if isinstance(ret, CancelJob) or ret is CancelJob:
#     174             self.cancel_job(job)
#
# ~\AppData\Roaming\Python\Python39\site-packages\schedule\__init__.py in run(self)
#     691
#     692         logger.debug("Running job %s", self)
# --> 693         ret = self.job_func()
#     694         self.last_run = datetime.datetime.now()
#     695         self._schedule_next_run()
#
# TypeError: run_code() got an unexpected keyword argument 'hour'

# %%
import schedule
import time

def job():
    print("Fonction exécutée")

# Planifier l'exécution de la fonction toutes les 5 secondes
schedule.every(5).seconds.do(job)

# Boucle d'exécution pour exécuter les tâches planifiées
# while True:
#     schedule.run_pending()
#     time.sleep(1)
# Out:
# Every 5 seconds do job() (last run: [never], next run: 2023-05-18 23:13:26)

# %%
import time
from datetime import datetime

while True:
    current_time = datetime.now().strftime("%H:%M")
    minutes = current_time.split(":")[1]
    
    if minutes == "00":
        print(f"L'heure actuelle est {current_time}")
    if minutes[-1] == "5":
        print(f"L'heure actuelle est {current_time}")        
    
    time.sleep(60)  # Attendre une minute
# Out:
# L'heure actuelle est 23:55
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20876\3545865794.py in <module>
#      11         print(f"L'heure actuelle est {current_time}")
#      12
# ---> 13     time.sleep(60)  # Attendre une minute
#
# KeyboardInterrupt:

# %%
from pywinauto.application import Application
import psutil
import time
from datetime import datetime
import random

def fermer_firefox():
    for process_ff in psutil.process_iter(['name']):
        if process_ff.info['name'] == 'firefox.exe':
            process_ff.terminate()
            # Attprocess_ffendre que psutil se termine correctement
            process_ff.wait()
        
def delay_with_random_seconds():
    # Génère un délai aléatoire entre 1 et 5 secondes
    random_seconds = random.randint(3, 10)
    
    # Pause l'exécution du programme pendant le délai aléatoire
    time.sleep(random_seconds)
    
#     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()
def attaquer_village(village_depart, village_arrive, nombre_troupes):
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_arrive}"
    firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()   
    zone3 = firefox.child_window(auto_id='unit_input_spear')
    zone3.type_keys(str(nombre_troupes))
    delay_with_random_seconds()
    zone4 = firefox.child_window(auto_id='unit_input_sword')
    zone4.type_keys(str(nombre_troupes))
    delay_with_random_seconds()

    bouton = firefox.child_window(auto_id='target_attack')
    bouton.click() 
    delay_with_random_seconds()
    
    bouton = firefox.child_window(auto_id='troop_confirm_submit')
    bouton.click()     
    delay_with_random_seconds()

def main_a():
#     fermer_firefox()
#     # Vérifier si Firefox est en cours d'exécution
#     firefox_running = False
#     for process in psutil.process_iter():
#         if process.name() == "firefox.exe":
#             firefox_running = True
#             firefox_pid = process.pid
#             break

#     # Fermer Firefox si c'est le cas
#     if firefox_running:
#         process = psutil.Process(firefox_pid)
#         process.terminate()
#         # Attendre que psutil se termine correctement
#         process.wait()       
#     #     time.sleep(5)
#     # Ouvrir Firefox
#     time.sleep(2)

#     app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

    
    # Ouvrir Firefox
#     app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')
    time.sleep(2)
    # Trouver le PID de Firefox
    firefox_pid = None
    for process in psutil.process_iter():
        if process.name() == "firefox.exe":
            firefox_pid = process.pid
            break
    time.sleep(2)
#     # Vérifier si Firefox est en cours d'exécution
    if firefox_pid is None:
        print("Firefox n'est pas en cours d'exécution.")
#     else:
        app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

        # Attacher Pywinauto à la fenêtre Firefox
#         app = Application(backend='uia').connect(process=firefox_pid)

        # Ouvrir une page web
    #     firefox = app.window(title_re='.*Nouvel onglet*')
        firefox = app.window( class_name='MozillaWindowClass')

        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    #     time.sleep(5)

    #     # Saisir les champs
    #     zone1 = firefox.window(title='user')
    #     zone1.type_keys('*test1')
    #     zone1 = firefox.child_window(control_type="Edit", found_index=0, automation_id="user")
        zone1 = firefox.child_window(auto_id='user')

        zone1.type_keys('arion1')
        delay_with_random_seconds()

        zone2 = firefox.child_window(auto_id='password')
        zone2.type_keys('MiMa5158**')
        delay_with_random_seconds()
        # Cliquer sur le bouton
    #     bouton = firefox.window(title='Connexion')
    # #     bouton = firefox.child_window(auto_id='btn-login')
    #     bouton = firefox.child_window(title='Connexion')
    #     bouton.click()!
        bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
        bouton.invoke()
    #     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
    #     bouton.invoke()
        delay_with_random_seconds()
        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()
        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()


        attaquer_village('3466', '3275', 15)
        attaquer_village('3466', '3172', 15)
        #     Fermer Firefox
        firefox.close()

while True:
    current_time = datetime.now().strftime("%H:%M")
    minutes = current_time.split(":")[1]
#     firefox.close()
#     fermer_firefox()
    if minutes == "00":
        print(f"L'heure actuelle est {current_time}")
        main_a()
    if minutes[-1] == "9":
        print(f"L'heure actuelle est {current_time}")        
        main_a()
        #     Fermer Firefox
        firefox.close()
    time.sleep(55)  # Attendre une minute
# Out:
# L'heure actuelle est 01:19
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20876\986220075.py in <module>
#     154         firefox = app.window( class_name='MozillaWindowClass')
#     155
# --> 156         firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
#     157         firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     158     #     time.sleep(5)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     394
#     395             if need_to_resolve:
# --> 396                 ctrls = self.__resolve_control(self.criteria)
#     397                 return getattr(ctrls[-1], attr_name)
#     398
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     201             criteria[0]['process'] = self.app.process
#     202             del criteria[0]['app']
# --> 203         dialog = self.backend.generic_wrapper_class(findwindows.find_element(**criteria[0]))
#     204
#     205         ctrls = []
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'class_name': 'MozillaWindowClass', 'backend': 'uia', 'process': 3120}

# %%
#     Fermer Firefox
firefox.close()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20876\2359715767.py in <module>
#       1 #     Fermer Firefox
# ----> 2 firefox.close()
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     394
#     395             if need_to_resolve:
# --> 396                 ctrls = self.__resolve_control(self.criteria)
#     397                 return getattr(ctrls[-1], attr_name)
#     398
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     201             criteria[0]['process'] = self.app.process
#     202             del criteria[0]['app']
# --> 203         dialog = self.backend.generic_wrapper_class(findwindows.find_element(**criteria[0]))
#     204
#     205         ctrls = []
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'class_name': 'MozillaWindowClass', 'backend': 'uia', 'process': 7596}

# %%
from pywinauto.application import Application
import psutil
import time
import random

def delay_with_random_seconds():
    # Génère un délai aléatoire entre 1 et 5 secondes
    random_seconds = random.randint(3, 10)
    
    # Pause l'exécution du programme pendant le délai aléatoire
    time.sleep(random_seconds)
    
#     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()
def attaquer_village(village_depart, village_arrive, nombre_troupes):
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_arrive}"
    firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()   
    zone3 = firefox.child_window(auto_id='unit_input_spear')
    zone3.type_keys(str(nombre_troupes))
    delay_with_random_seconds()
    zone4 = firefox.child_window(auto_id='unit_input_sword')
    zone4.type_keys(str(nombre_troupes))
    delay_with_random_seconds()

    bouton = firefox.child_window(auto_id='target_attack')
    bouton.click() 
    delay_with_random_seconds()
    
    bouton = firefox.child_window(auto_id='troop_confirm_submit')
    bouton.click()     
    delay_with_random_seconds()

# Vérifier si Firefox est en cours d'exécution
firefox_running = False
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_running = True
        firefox_pid = process.pid
        break

# Fermer Firefox si c'est le cas
if firefox_running:
    process = psutil.Process(firefox_pid)
    process.terminate()
#     time.sleep(5)
# Ouvrir Firefox
time.sleep(2)

app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')


# Ouvrir Firefox
# app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Trouver le PID de Firefox
firefox_pid = None
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_pid = process.pid
        break

# Vérifier si Firefox est en cours d'exécution
if firefox_pid is None:
    print("Firefox n'est pas en cours d'exécution.")
else:
    # Attacher Pywinauto à la fenêtre Firefox
    app = Application(backend='uia').connect(process=firefox_pid)

    # Ouvrir une page web
#     firefox = app.window(title_re='.*Nouvel onglet*')
    firefox = app.window( class_name='MozillaWindowClass')

    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     time.sleep(5)

#     # Saisir les champs
#     zone1 = firefox.window(title='user')
#     zone1.type_keys('*test1')
#     zone1 = firefox.child_window(control_type="Edit", found_index=0, automation_id="user")
    zone1 = firefox.child_window(auto_id='user')

    zone1.type_keys('arion1')
    delay_with_random_seconds()

    zone2 = firefox.child_window(auto_id='password')
    zone2.type_keys('MiMa5158**')
    delay_with_random_seconds()
    # Cliquer sur le bouton
#     bouton = firefox.window(title='Connexion')
# #     bouton = firefox.child_window(auto_id='btn-login')
#     bouton = firefox.child_window(title='Connexion')
#     bouton.click()!
    bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
    bouton.invoke()
#     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
#     bouton.invoke()
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    
    attaquer_village('3466', '3275', 20)
    attaquer_village('3466', '3172', 20)
    delay_with_random_seconds()    
    # Fermer Firefox
#     firefox.close()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20876\3400333400.py in <module>
#     111
#     112     attaquer_village('3466', '3275', 20)
# --> 113     attaquer_village('3466', '3172', 20)
#     114     delay_with_random_seconds()
#     115     # Fermer Firefox
#
# ~\AppData\Local\Temp\ipykernel_20876\3400333400.py in attaquer_village(village_depart, village_arrive, nombre_troupes)
#      34
#      35     bouton = firefox.child_window(auto_id='troop_confirm_submit')
# ---> 36     bouton.click()
#      37     delay_with_random_seconds()
#      38
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     377         if len(self.criteria) >= 2:  # FIXME - this is surprising
#     378
# --> 379             ctrls = self.__resolve_control(self.criteria)
#     380
#     381             try:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     220                 if 'backend' not in ctrl_criteria:
#     221                     ctrl_criteria['backend'] = self.backend.name
# --> 222                 ctrl = self.backend.generic_wrapper_class(findwindows.find_element(**ctrl_criteria))
#     223                 previous_parent = ctrl.element_info
#     224                 ctrls.append(ctrl)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'auto_id': 'troop_confirm_submit', 'top_level_only': False, 'parent': <uia_element_info.UIAElementInfo - 'Village de arion1 (556|484) - Guerre Tribale - Monde 81 — Mozilla Firefox', MozillaWindowClass, 28772190>, 'backend': 'uia'}

# %%
from pywinauto.application import Application
import psutil
import time
import random

def delay_with_random_seconds():
    # Génère un délai aléatoire entre 1 et 5 secondes
    random_seconds = random.randint(3, 10)
    
    # Pause l'exécution du programme pendant le délai aléatoire
    time.sleep(random_seconds)
    
#     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()
def attaquer_village(village_depart, village_arrive, nombre_troupes):
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_arrive}"
    firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()   
    zone3 = firefox.child_window(auto_id='unit_input_spear')
    zone3.type_keys(str(nombre_troupes))
    delay_with_random_seconds()
    zone4 = firefox.child_window(auto_id='unit_input_sword')
    zone4.type_keys(str(nombre_troupes))
    delay_with_random_seconds()

    bouton = firefox.child_window(auto_id='target_attack')
    bouton.click() 
    delay_with_random_seconds()
    
    bouton = firefox.child_window(auto_id='troop_confirm_submit')
    bouton.click()     
    delay_with_random_seconds()
def lancement():
    # Vérifier si Firefox est en cours d'exécution
    firefox_running = False
    for process in psutil.process_iter():
        if process.name() == "firefox.exe":
            firefox_running = True
            firefox_pid = process.pid
            break

    # Fermer Firefox si c'est le cas
    if firefox_running:
        process = psutil.Process(firefox_pid)
        process.terminate()
    #     time.sleep(5)
    # Ouvrir Firefox
    time.sleep(2)

    app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')


    # Ouvrir Firefox
    # app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

    # Trouver le PID de Firefox
    firefox_pid = None
    for process in psutil.process_iter():
        if process.name() == "firefox.exe":
            firefox_pid = process.pid
            break

    # Vérifier si Firefox est en cours d'exécution
    if firefox_pid is None:
        print("Firefox n'est pas en cours d'exécution.")
    else:
        # Attacher Pywinauto à la fenêtre Firefox
        app = Application(backend='uia').connect(process=firefox_pid)

        # Ouvrir une page web
    #     firefox = app.window(title_re='.*Nouvel onglet*')
        firefox = app.window( class_name='MozillaWindowClass')

        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    #     time.sleep(5)

    #     # Saisir les champs
    #     zone1 = firefox.window(title='user')
    #     zone1.type_keys('*test1')
    #     zone1 = firefox.child_window(control_type="Edit", found_index=0, automation_id="user")
        zone1 = firefox.child_window(auto_id='user')

        zone1.type_keys('arion1')
        delay_with_random_seconds()

        zone2 = firefox.child_window(auto_id='password')
        zone2.type_keys('MiMa5158**')
        delay_with_random_seconds()
        # Cliquer sur le bouton
    #     bouton = firefox.window(title='Connexion')
    # #     bouton = firefox.child_window(auto_id='btn-login')
    #     bouton = firefox.child_window(title='Connexion')
    #     bouton.click()!
        bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
        bouton.invoke()
    #     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
    #     bouton.invoke()
        delay_with_random_seconds()
        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()
        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()

        attaquer_village('3466', '3275', 20)
        attaquer_village('3466', '3172', 20)
        delay_with_random_seconds()    
        # Fermer Firefox
    #     firefox.close()
lancement()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20876\4274666477.py in <module>
#     115         # Fermer Firefox
#     116     #     firefox.close()
# --> 117 lancement()
#
# ~\AppData\Local\Temp\ipykernel_20876\4274666477.py in lancement()
#     106         firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     107         delay_with_random_seconds()
# --> 108         firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
#     109         firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     110         delay_with_random_seconds()
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     394
#     395             if need_to_resolve:
# --> 396                 ctrls = self.__resolve_control(self.criteria)
#     397                 return getattr(ctrls[-1], attr_name)
#     398
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     201             criteria[0]['process'] = self.app.process
#     202             del criteria[0]['app']
# --> 203         dialog = self.backend.generic_wrapper_class(findwindows.find_element(**criteria[0]))
#     204
#     205         ctrls = []
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'class_name': 'MozillaWindowClass', 'backend': 'uia', 'process': 11672}

# %%
from pywinauto.application import Application
import psutil
import time
import random

def delay_with_random_seconds():
    # Génère un délai aléatoire entre 1 et 5 secondes
    random_seconds = random.randint(3, 10)
    
    # Pause l'exécution du programme pendant le délai aléatoire
    time.sleep(random_seconds)
    
#     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()
def attaquer_village(village_depart, village_arrive, nombre_troupes):
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_arrive}"
    firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()   
    zone3 = firefox.child_window(auto_id='unit_input_spear')
    zone3.type_keys(str(nombre_troupes))
    delay_with_random_seconds()
    zone4 = firefox.child_window(auto_id='unit_input_sword')
    zone4.type_keys(str(nombre_troupes))
    delay_with_random_seconds()

    bouton = firefox.child_window(auto_id='target_attack')
    bouton.click() 
    delay_with_random_seconds()
    
    bouton = firefox.child_window(auto_id='troop_confirm_submit')
    bouton.click()     
    delay_with_random_seconds()
def lancement():
    # Vérifier si Firefox est en cours d'exécution
    firefox_running = False
    for process in psutil.process_iter():
        if process.name() == "firefox.exe":
            firefox_running = True
            firefox_pid = process.pid
            break

    # Fermer Firefox si c'est le cas
    if firefox_running:
        process = psutil.Process(firefox_pid)
        process.kill()
        
    # Vérifier si Firefox est en cours d'exécution
    firefox_running = False
    for process in psutil.process_iter():
        if process.name() == "firefox.exe":
            firefox_running = True
            firefox_pid = process.pid
            break

    # Fermer Firefox si c'est le cas
    if firefox_running:
        process = psutil.Process(firefox_pid)
        process.terminate()
    #     time.sleep(5)
    # Ouvrir Firefox
    time.sleep(2)

    app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')
    time.sleep(2)

    # Ouvrir Firefox
    # app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

    # Trouver le PID de Firefox
    firefox_pid = None
    for process in psutil.process_iter():
        if process.name() == "firefox.exe":
            firefox_pid = process.pid
            break

    # Vérifier si Firefox est en cours d'exécution
    if firefox_pid is None:
        print("Firefox n'est pas en cours d'exécution.")
    else:
        # Attacher Pywinauto à la fenêtre Firefox
        app = Application(backend='uia').connect(process=firefox_pid)

        # Ouvrir une page web
    #     firefox = app.window(title_re='.*Nouvel onglet*')
        firefox = app.window( class_name='MozillaWindowClass')
        time.sleep(2)
        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    #     time.sleep(5)

    #     # Saisir les champs
    #     zone1 = firefox.window(title='user')
    #     zone1.type_keys('*test1')
    #     zone1 = firefox.child_window(control_type="Edit", found_index=0, automation_id="user")
        zone1 = firefox.child_window(auto_id='user')

        zone1.type_keys('arion1')
        delay_with_random_seconds()

        zone2 = firefox.child_window(auto_id='password')
        zone2.type_keys('MiMa5158**')
        delay_with_random_seconds()
        # Cliquer sur le bouton
    #     bouton = firefox.window(title='Connexion')
    # #     bouton = firefox.child_window(auto_id='btn-login')
    #     bouton = firefox.child_window(title='Connexion')
    #     bouton.click()!
        bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
        bouton.invoke()
    #     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
    #     bouton.invoke()
        delay_with_random_seconds()
        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()
        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()

        attaquer_village('3466', '3275', 20)
        attaquer_village('3466', '3172', 20)
        delay_with_random_seconds()    
        # Fermer Firefox
    #     firefox.close()

while True:
    current_time = datetime.now().strftime("%H:%M")
    minutes = current_time.split(":")[1]
#     firefox.close()
#     fermer_firefox()
    if minutes == "00":
        print(f"L'heure actuelle est {current_time}")
        lancement()
    if minutes[-1] == "2":
        print(f"L'heure actuelle est {current_time}")        
        lancement()
    if minutes[-1] == "4":
        print(f"L'heure actuelle est {current_time}")        
        lancement()
    if minutes[-1] == "6":
        print(f"L'heure actuelle est {current_time}")        
        lancement()
    if minutes[-1] == "8":
        print(f"L'heure actuelle est {current_time}")        
        lancement()
        #     Fermer Firefox
#         firefox.close()
    time.sleep(55)  # Attendre une minute
# Out:
# L'heure actuelle est 23:48
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20876\1625372770.py in <module>
#     148     if minutes[-1] == "8":
#     149         print(f"L'heure actuelle est {current_time}")
# --> 150         lancement()
#     151         #     Fermer Firefox
#     152 #         firefox.close()
#
# ~\AppData\Local\Temp\ipykernel_20876\1625372770.py in lancement()
#     123         delay_with_random_seconds()
#     124
# --> 125         attaquer_village('3466', '3275', 20)
#     126         attaquer_village('3466', '3172', 20)
#     127         delay_with_random_seconds()
#
# ~\AppData\Local\Temp\ipykernel_20876\1625372770.py in attaquer_village(village_depart, village_arrive, nombre_troupes)
#      18 #         proc.kill()
#      19 def attaquer_village(village_depart, village_arrive, nombre_troupes):
# ---> 20     firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
#      21     url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_arrive}"
#      22     firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     394
#     395             if need_to_resolve:
# --> 396                 ctrls = self.__resolve_control(self.criteria)
#     397                 return getattr(ctrls[-1], attr_name)
#     398
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     201             criteria[0]['process'] = self.app.process
#     202             del criteria[0]['app']
# --> 203         dialog = self.backend.generic_wrapper_class(findwindows.find_element(**criteria[0]))
#     204
#     205         ctrls = []
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'class_name': 'MozillaWindowClass', 'backend': 'uia', 'process': 15108}
