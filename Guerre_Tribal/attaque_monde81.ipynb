# %%
from pywinauto.application import Application
import psutil
import time
import random
import requests
import csv
import datetime
import fileinput

def delay_with_random_seconds():
#     # Génère un délai aléatoire entre 1 et 5 secondes
#     random_seconds = random.randint(2, 4)
# #     print(random_seconds)
    
#     # Pause l'exécution du programme pendant le délai aléatoire
#     time.sleep(random_seconds)
    random_milliseconds = random.randint(1000, 3000)  # Générer un nombre aléatoire en millisecondes entre 2000 et 4000
    print('\n', datetime.datetime.now(),' - random_milliseconds \n...')   
    print(random_milliseconds)
    print('\n', datetime.datetime.now(),' - random_milliseconds / 1000 \n...')   
    print(random_milliseconds / 1000)
    time.sleep(random_milliseconds / 1000)  # Utiliser la valeur en millisecondes dans time.sleep()
 #     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()

def attaquer_village(troupes_file):
    # Réafficher la fenêtre de navigateur
#     firefox.activate()
    firefox.set_focus()

    lines = []

    # Lire le fichier et stocker les lignes dans une liste
    with open(troupes_file, 'r') as file:
        lines = file.readlines()

    # Exclure la première ligne (en-têtes)
    headers = lines[0].strip().split(',')
    lines = lines[1:]

    # Trier les lignes par heure_attaque la plus ancienne
    lines = sorted(lines, key=lambda x: datetime.datetime.strptime(x.strip().split(',')[headers.index('heure_attaque')], "%Y-%m-%d %H:%M:%S"))

    # Parcourir les lignes triées
    for i, line in enumerate(lines):
        data = line.strip().split(',')
        village_depart = data[headers.index('village_depart')]
        village_attaquer = data[headers.index('village_attaquer')]

        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_attaquer}"
        firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()

        # Saisir les champs pour chaque type de troupe
        for header in headers:
            if header not in ['heure_attaque', 'village_depart', 'village_attaquer']:
                value = int(data[headers.index(header)])
                if value > 0:
                    zone = firefox.child_window(auto_id=header)
                    zone.type_keys(str(value))
                    delay_with_random_seconds()

        # Mettre à jour la colonne heure_attaque avec l'heure actuelle
        heure_attaque_index = headers.index('heure_attaque')
        heure_attaque = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        data[heure_attaque_index] = heure_attaque

        # Modifier la ligne dans la liste
        lines[i] = ','.join(data) + '\n'

        bouton = firefox.child_window(auto_id='target_attack')
        bouton.click()
        delay_with_random_seconds()

        bouton = firefox.child_window(auto_id='troop_confirm_submit')
        bouton.click()
        delay_with_random_seconds()

    # Réécrire le fichier avec les lignes modifiées
    with open(troupes_file, 'w') as file:
        file.write(','.join(headers) + '\n')  # Réécrire les en-têtes
        file.writelines(lines)  # Réécrire les lignes modifiées


# Vérifier si Firefox est en cours d'exécution
firefox_running = False
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_running = True
        firefox_pid = process.pid
        break

# Fermer Firefox si c'est le cas
if firefox_running:
    process = psutil.Process(firefox_pid)
    process.terminate()
#     time.sleep(5)
# Ouvrir Firefox
time.sleep(2)

app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Ouvrir Firefox
# app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Trouver le PID de Firefox
firefox_pid = None
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_pid = process.pid
        break

# Vérifier si Firefox est en cours d'exécution
if firefox_pid is None:
    print("Firefox n'est pas en cours d'exécution.")
else:
    # Attacher Pywinauto à la fenêtre Firefox
    app = Application(backend='uia').connect(process=firefox_pid)

    # Ouvrir une page web
#     firefox = app.window(title_re='.*Nouvel onglet*')
    firefox = app.window( class_name='MozillaWindowClass')

    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     time.sleep(5)

#     # Saisir les champs
#     zone1 = firefox.window(title='user')
#     zone1.type_keys('*test1')
#     zone1 = firefox.child_window(control_type="Edit", found_index=0,  automation_id="user")
    zone1 = firefox.child_window(auto_id='user')

    zone1.type_keys('arion1')
    delay_with_random_seconds()
 
    zone2 = firefox.child_window(auto_id='password')
    zone2.type_keys('MiMa5158**')
    delay_with_random_seconds()
    # Cliquer sur le bouton
#     bouton = firefox.window(title='Connexion')
# #     bouton = firefox.child_window(auto_id='btn-login')
#     bouton = firefox.child_window(title='Connexion')
#     bouton.click()!
    bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
    bouton.invoke()
#     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
#     bouton.invoke()
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    
#     attaquer_village('3466', '3275', 'data/village.txt')
#     attaquer_village('3466', '3172', 'data/village.txt')
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages_M81.csv")
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages_M81.csv")
    delay_with_random_seconds()    
    # Fermer Firefox 
#     firefox.close()
# Out:
#  2023-07-07 01:03:23.421175  - random_milliseconds
# ...
# 1498
#
#  2023-07-07 01:03:23.421175  - random_milliseconds / 1000
# ...
# 1.498
#
#  2023-07-07 01:03:26.270978  - random_milliseconds
# ...
# 1286
#
#  2023-07-07 01:03:26.270978  - random_milliseconds / 1000
# ...
# 1.286
#
#  2023-07-07 01:03:28.516452  - random_milliseconds
# ...
# 1508
#
#  2023-07-07 01:03:28.516452  - random_milliseconds / 1000
# ...
# 1.508
#
#  2023-07-07 01:03:31.856935  - random_milliseconds
# ...
# 2268
#
#  2023-07-07 01:03:31.856935  - random_milliseconds / 1000
# ...
# 2.268
#
#  2023-07-07 01:03:36.406897  - random_milliseconds
# ...
# 1023
#
#  2023-07-07 01:03:36.406897  - random_milliseconds / 1000
# ...
# 1.023
#
#  2023-07-07 01:03:40.411291  - random_milliseconds
# ...
# 1524
#
#  2023-07-07 01:03:40.411291  - random_milliseconds / 1000
# ...
# 1.524
#
#  2023-07-07 01:03:43.689686  - random_milliseconds
# ...
# 1266
#
#  2023-07-07 01:03:43.689686  - random_milliseconds / 1000
# ...
# 1.266
#
#  2023-07-07 01:03:46.462774  - random_milliseconds
# ...
# 1799
#
#  2023-07-07 01:03:46.462774  - random_milliseconds / 1000
# ...
# 1.799
#
#  2023-07-07 01:03:49.906179  - random_milliseconds
# ...
# 1141
#
#  2023-07-07 01:03:49.906179  - random_milliseconds / 1000
# ...
# 1.141
#
#  2023-07-07 01:03:52.554159  - random_milliseconds
# ...
# 2665
#
#  2023-07-07 01:03:52.554159  - random_milliseconds / 1000
# ...
# 2.665
#
#  2023-07-07 01:03:57.670513  - random_milliseconds
# ...
# 2408
#
#  2023-07-07 01:03:57.670513  - random_milliseconds / 1000
# ...
# 2.408
#
#  2023-07-07 01:04:01.556004  - random_milliseconds
# ...
# 2177
#
#  2023-07-07 01:04:01.556004  - random_milliseconds / 1000
# ...
# 2.177
#
#  2023-07-07 01:04:05.350032  - random_milliseconds
# ...
# 2196
#
#  2023-07-07 01:04:05.350032  - random_milliseconds / 1000
# ...
# 2.196
#
#  2023-07-07 01:04:09.080578  - random_milliseconds
# ...
# 2072
#
#  2023-07-07 01:04:09.080578  - random_milliseconds / 1000
# ...
# 2.072
#
#  2023-07-07 01:04:12.558014  - random_milliseconds
# ...
# 1004
#
#  2023-07-07 01:04:12.558014  - random_milliseconds / 1000
# ...
# 1.004
#
#  2023-07-07 01:04:15.627356  - random_milliseconds
# ...
# 1293
#
#  2023-07-07 01:04:15.627356  - random_milliseconds / 1000
# ...
# 1.293
#
#  2023-07-07 01:04:18.476607  - random_milliseconds
# ...
# 2007
#
#  2023-07-07 01:04:18.476607  - random_milliseconds / 1000
# ...
# 2.007
#
#  2023-07-07 01:04:22.129235  - random_milliseconds
# ...
# 1379
#
#  2023-07-07 01:04:22.129235  - random_milliseconds / 1000
# ...
# 1.379
#
#  2023-07-07 01:04:25.235779  - random_milliseconds
# ...
# 2726
#
#  2023-07-07 01:04:25.235779  - random_milliseconds / 1000
# ...
# 2.726
#
#  2023-07-07 01:04:29.512958  - random_milliseconds
# ...
# 2749
#
#  2023-07-07 01:04:29.512958  - random_milliseconds / 1000
# ...
# 2.749
#
#  2023-07-07 01:04:34.252196  - random_milliseconds
# ...
# 2693
#
#  2023-07-07 01:04:34.252196  - random_milliseconds / 1000
# ...
# 2.693
#
#  2023-07-07 01:04:38.689103  - random_milliseconds
# ...
# 1284
#
#  2023-07-07 01:04:38.689103  - random_milliseconds / 1000
# ...
# 1.284
#
#  2023-07-07 01:04:41.699457  - random_milliseconds
# ...
# 2621
#
#  2023-07-07 01:04:41.699457  - random_milliseconds / 1000
# ...
# 2.621
#
#  2023-07-07 01:04:46.113981  - random_milliseconds
# ...
# 2812
#
#  2023-07-07 01:04:46.113981  - random_milliseconds / 1000
# ...
# 2.812
#
#  2023-07-07 01:04:50.226012  - random_milliseconds
# ...
# 1345
#
#  2023-07-07 01:04:50.226012  - random_milliseconds / 1000
# ...
# 1.345
#
#  2023-07-07 01:04:53.910812  - random_milliseconds
# ...
# 2773
#
#  2023-07-07 01:04:53.910812  - random_milliseconds / 1000
# ...
# 2.773
#
#  2023-07-07 01:04:58.433319  - random_milliseconds
# ...
# 1687
#
#  2023-07-07 01:04:58.433319  - random_milliseconds / 1000
# ...
# 1.687
#
#  2023-07-07 01:05:02.350020  - random_milliseconds
# ...
# 2554
#
#  2023-07-07 01:05:02.350020  - random_milliseconds / 1000
# ...
# 2.554
#
#  2023-07-07 01:05:06.424884  - random_milliseconds
# ...
# 1953
#
#  2023-07-07 01:05:06.424884  - random_milliseconds / 1000
# ...
# 1.953
#
#  2023-07-07 01:05:09.834359  - random_milliseconds
# ...
# 2066
#
#  2023-07-07 01:05:09.834359  - random_milliseconds / 1000
# ...
# 2.066
#
#  2023-07-07 01:05:14.289857  - random_milliseconds
# ...
# 1176
#
#  2023-07-07 01:05:14.289857  - random_milliseconds / 1000
# ...
# 1.176
#
#  2023-07-07 01:05:17.162780  - random_milliseconds
# ...
# 2703
#
#  2023-07-07 01:05:17.162780  - random_milliseconds / 1000
# ...
# 2.703
#
#  2023-07-07 01:05:21.537246  - random_milliseconds
# ...
# 1857
#
#  2023-07-07 01:05:21.537246  - random_milliseconds / 1000
# ...
# 1.857
#
#  2023-07-07 01:05:25.164391  - random_milliseconds
# ...
# 2610
#
#  2023-07-07 01:05:25.164391  - random_milliseconds / 1000
# ...
# 2.61
#
#  2023-07-07 01:05:29.288296  - random_milliseconds
# ...
# 1186
#
#  2023-07-07 01:05:29.288296  - random_milliseconds / 1000
# ...
# 1.186
#
#  2023-07-07 01:05:32.911318  - random_milliseconds
# ...
# 1088
#
#  2023-07-07 01:05:32.911318  - random_milliseconds / 1000
# ...
# 1.088
#
#  2023-07-07 01:05:35.891757  - random_milliseconds
# ...
# 1363
#
#  2023-07-07 01:05:35.891757  - random_milliseconds / 1000
# ...
# 1.363
#
#  2023-07-07 01:05:38.887599  - random_milliseconds
# ...
# 1946
#
#  2023-07-07 01:05:38.887599  - random_milliseconds / 1000
# ...
# 1.946
#
#  2023-07-07 01:05:42.648005  - random_milliseconds
# ...
# 1389
#
#  2023-07-07 01:05:42.648005  - random_milliseconds / 1000
# ...
# 1.389
#
#  2023-07-07 01:05:45.653382  - random_milliseconds
# ...
# 2099
#
#  2023-07-07 01:05:45.653382  - random_milliseconds / 1000
# ...
# 2.099
#
#  2023-07-07 01:05:50.122407  - random_milliseconds
# ...
# 2909
#
#  2023-07-07 01:05:50.122407  - random_milliseconds / 1000
# ...
# 2.909
#
#  2023-07-07 01:05:54.656142  - random_milliseconds
# ...
# 2279
#
#  2023-07-07 01:05:54.656142  - random_milliseconds / 1000
# ...
# 2.279
#
#  2023-07-07 01:05:58.792078  - random_milliseconds
# ...
# 1158
#
#  2023-07-07 01:05:58.792078  - random_milliseconds / 1000
# ...
# 1.158
#
#  2023-07-07 01:06:01.823645  - random_milliseconds
# ...
# 1878
#
#  2023-07-07 01:06:01.823645  - random_milliseconds / 1000
# ...
# 1.878
#
#  2023-07-07 01:06:05.195058  - random_milliseconds
# ...
# 1359
#
#  2023-07-07 01:06:05.195058  - random_milliseconds / 1000
# ...
# 1.359
#
#  2023-07-07 01:06:08.949420  - random_milliseconds
# ...
# 2239
#
#  2023-07-07 01:06:08.949420  - random_milliseconds / 1000
# ...
# 2.239
#
#  2023-07-07 01:06:12.858859  - random_milliseconds
# ...
# 1100
#
#  2023-07-07 01:06:12.858859  - random_milliseconds / 1000
# ...
# 1.1
#
#  2023-07-07 01:06:15.822400  - random_milliseconds
# ...
# 1010
#
#  2023-07-07 01:06:15.822400  - random_milliseconds / 1000
# ...
# 1.01
#
#  2023-07-07 01:06:18.673858  - random_milliseconds
# ...
# 2294
#
#  2023-07-07 01:06:18.673858  - random_milliseconds / 1000
# ...
# 2.294
#
#  2023-07-07 01:06:23.040514  - random_milliseconds
# ...
# 1016
#
#  2023-07-07 01:06:23.040514  - random_milliseconds / 1000
# ...
# 1.016
#
#  2023-07-07 01:06:26.246858  - random_milliseconds
# ...
# 2495
#
#  2023-07-07 01:06:26.246858  - random_milliseconds / 1000
# ...
# 2.495
#
#  2023-07-07 01:06:30.470000  - random_milliseconds
# ...
# 2862
#
#  2023-07-07 01:06:30.470000  - random_milliseconds / 1000
# ...
# 2.862
#
#  2023-07-07 01:06:35.185472  - random_milliseconds
# ...
# 1674
#
#  2023-07-07 01:06:35.185472  - random_milliseconds / 1000
# ...
# 1.674
#
#  2023-07-07 01:06:38.799840  - random_milliseconds
# ...
# 2205
#
#  2023-07-07 01:06:38.799840  - random_milliseconds / 1000
# ...
# 2.205
#
#  2023-07-07 01:06:42.361834  - random_milliseconds
# ...
# 1928
#
#  2023-07-07 01:06:42.361834  - random_milliseconds / 1000
# ...
# 1.928
#
#  2023-07-07 01:06:46.611218  - random_milliseconds
# ...
# 1679
#
#  2023-07-07 01:06:46.611218  - random_milliseconds / 1000
# ...
# 1.679
#
#  2023-07-07 01:06:50.091510  - random_milliseconds
# ...
# 2549
#
#  2023-07-07 01:06:50.091510  - random_milliseconds / 1000
# ...
# 2.549
#
#  2023-07-07 01:06:54.586662  - random_milliseconds
# ...
# 1705
#
#  2023-07-07 01:06:54.586662  - random_milliseconds / 1000
# ...
# 1.705
#
#  2023-07-07 01:06:57.985680  - random_milliseconds
# ...
# 1409
#
#  2023-07-07 01:06:57.985680  - random_milliseconds / 1000
# ...
# 1.409
#
#  2023-07-07 01:07:00.754231  - random_milliseconds
# ...
# 2189
#
#  2023-07-07 01:07:00.754231  - random_milliseconds / 1000
# ...
# 2.189
#
#  2023-07-07 01:07:05.415406  - random_milliseconds
# ...
# 1057
#
#  2023-07-07 01:07:05.415406  - random_milliseconds / 1000
# ...
# 1.057
#
#  2023-07-07 01:07:08.396606  - random_milliseconds
# ...
# 1343
#
#  2023-07-07 01:07:08.397084  - random_milliseconds / 1000
# ...
# 1.343
#
#  2023-07-07 01:07:11.730363  - random_milliseconds
# ...
# 2508
#
#  2023-07-07 01:07:11.730363  - random_milliseconds / 1000
# ...
# 2.508
#  2023-07-07 01:07:15.999562  - random_milliseconds
# ...
# 1362
#
#  2023-07-07 01:07:15.999562  - random_milliseconds / 1000
# ...
# 1.362
#
#  2023-07-07 01:07:18.842191  - random_milliseconds
# ...
# 2425
#
#  2023-07-07 01:07:18.842191  - random_milliseconds / 1000
# ...
# 2.425
#
#  2023-07-07 01:07:23.655771  - random_milliseconds
# ...
# 1036
#
#  2023-07-07 01:07:23.655771  - random_milliseconds / 1000
# ...
# 1.036
#
#  2023-07-07 01:07:26.563115  - random_milliseconds
# ...
# 1441
#
#  2023-07-07 01:07:26.563115  - random_milliseconds / 1000
# ...
# 1.441
#
#  2023-07-07 01:07:29.710316  - random_milliseconds
# ...
# 2970
#
#  2023-07-07 01:07:29.710316  - random_milliseconds / 1000
# ...
# 2.97
#
#  2023-07-07 01:07:34.627644  - random_milliseconds
# ...
# 2346
#
#  2023-07-07 01:07:34.628641  - random_milliseconds / 1000
# ...
# 2.346
#
#  2023-07-07 01:07:39.203459  - random_milliseconds
# ...
# 2131
#
#  2023-07-07 01:07:39.203459  - random_milliseconds / 1000
# ...
# 2.131
#
#  2023-07-07 01:07:43.736255  - random_milliseconds
# ...
# 2779
#
#  2023-07-07 01:07:43.736255  - random_milliseconds / 1000
# ...
# 2.779
#
#  2023-07-07 01:07:48.198396  - random_milliseconds
# ...
# 1500
#
#  2023-07-07 01:07:48.198396  - random_milliseconds / 1000
# ...
# 1.5
#
#  2023-07-07 01:07:51.594319  - random_milliseconds
# ...
# 2150
#
#  2023-07-07 01:07:51.594319  - random_milliseconds / 1000
# ...
# 2.15
#
#  2023-07-07 01:07:55.747942  - random_milliseconds
# ...
# 2165
#
#  2023-07-07 01:07:55.747942  - random_milliseconds / 1000
# ...
# 2.165
#
#  2023-07-07 01:07:59.485966  - random_milliseconds
# ...
# 1138
#
#  2023-07-07 01:07:59.485966  - random_milliseconds / 1000
# ...
# 1.138
#
#  2023-07-07 01:08:02.745058  - random_milliseconds
# ...
# 1016
#
#  2023-07-07 01:08:02.745058  - random_milliseconds / 1000
# ...
# 1.016
#
#  2023-07-07 01:08:05.487895  - random_milliseconds
# ...
# 1515
#
#  2023-07-07 01:08:05.487895  - random_milliseconds / 1000
# ...
# 1.515
#
#  2023-07-07 01:08:09.047099  - random_milliseconds
# ...
# 1353
#
#  2023-07-07 01:08:09.047099  - random_milliseconds / 1000
# ...
# 1.353
#
#  2023-07-07 01:08:12.453408  - random_milliseconds
# ...
# 1462
#
#  2023-07-07 01:08:12.453408  - random_milliseconds / 1000
# ...
# 1.462
#
#  2023-07-07 01:08:15.441692  - random_milliseconds
# ...
# 1743
#
#  2023-07-07 01:08:15.441692  - random_milliseconds / 1000
# ...
# 1.743
#
#  2023-07-07 01:08:19.289442  - random_milliseconds
# ...
# 2742
#
#  2023-07-07 01:08:19.289442  - random_milliseconds / 1000
# ...
# 2.742
#
#  2023-07-07 01:08:24.053087  - random_milliseconds
# ...
# 2140
#
#  2023-07-07 01:08:24.054133  - random_milliseconds / 1000
# ...
# 2.14
#
#  2023-07-07 01:08:28.234652  - random_milliseconds
# ...
# 1612
#
#  2023-07-07 01:08:28.234652  - random_milliseconds / 1000
# ...
# 1.612
#
#  2023-07-07 01:08:31.872891  - random_milliseconds
# ...
# 1355
#
#  2023-07-07 01:08:31.872891  - random_milliseconds / 1000
# ...
# 1.355
#
#  2023-07-07 01:08:34.541894  - random_milliseconds
# ...
# 2817
#
#  2023-07-07 01:08:34.542892  - random_milliseconds / 1000
# ...
# 2.817
#
#  2023-07-07 01:08:39.783516  - random_milliseconds
# ...
# 1670
#
#  2023-07-07 01:08:39.783516  - random_milliseconds / 1000
# ...
# 1.67
#
#  2023-07-07 01:08:43.412662  - random_milliseconds
# ...
# 1300
#
#  2023-07-07 01:08:43.412662  - random_milliseconds / 1000
# ...
# 1.3
#
#  2023-07-07 01:08:46.610627  - random_milliseconds
# ...
# 1453
#
#  2023-07-07 01:08:46.610627  - random_milliseconds / 1000
# ...
# 1.453
#
#  2023-07-07 01:08:50.352296  - random_milliseconds
# ...
# 2078
#
#  2023-07-07 01:08:50.353294  - random_milliseconds / 1000
# ...
# 2.078
#
#  2023-07-07 01:08:53.818018  - random_milliseconds
# ...
# 1181
#
#  2023-07-07 01:08:53.818018  - random_milliseconds / 1000
# ...
# 1.181
#
#  2023-07-07 01:08:57.341073  - random_milliseconds
# ...
# 1672
#
#  2023-07-07 01:08:57.341073  - random_milliseconds / 1000
# ...
# 1.672
#
#  2023-07-07 01:09:00.961016  - random_milliseconds
# ...
# 1717
#
#  2023-07-07 01:09:00.961016  - random_milliseconds / 1000
# ...
# 1.717
#
#  2023-07-07 01:09:04.648430  - random_milliseconds
# ...
# 1501
#
#  2023-07-07 01:09:04.648430  - random_milliseconds / 1000
# ...
# 1.501
#
#  2023-07-07 01:09:07.991304  - random_milliseconds
# ...
# 2012
#
#  2023-07-07 01:09:07.991304  - random_milliseconds / 1000
# ...
# 2.012
#
#  2023-07-07 01:09:11.450771  - random_milliseconds
# ...
# 2829
#
#  2023-07-07 01:09:11.450771  - random_milliseconds / 1000
# ...
# 2.829
#
#  2023-07-07 01:09:16.679133  - random_milliseconds
# ...
# 1623
#
#  2023-07-07 01:09:16.679133  - random_milliseconds / 1000
# ...
# 1.623
#
#  2023-07-07 01:09:20.349043  - random_milliseconds
# ...
# 2015
#
#  2023-07-07 01:09:20.349043  - random_milliseconds / 1000
# ...
# 2.015
#
#  2023-07-07 01:09:24.314205  - random_milliseconds
# ...
# 2794
#
#  2023-07-07 01:09:24.314205  - random_milliseconds / 1000
# ...
# 2.794
#
#  2023-07-07 01:09:29.212014  - random_milliseconds
# ...
# 2027
#
#  2023-07-07 01:09:29.212014  - random_milliseconds / 1000
# ...
# 2.027
#
#  2023-07-07 01:09:32.743585  - random_milliseconds
# ...
# 2285
#
#  2023-07-07 01:09:32.744582  - random_milliseconds / 1000
# ...
# 2.285
#
#  2023-07-07 01:09:37.459613  - random_milliseconds
# ...
# 2621
#
#  2023-07-07 01:09:37.459613  - random_milliseconds / 1000
# ...
# 2.621
#
#  2023-07-07 01:09:42.083182  - random_milliseconds
# ...
# 2040
#
#  2023-07-07 01:09:42.083182  - random_milliseconds / 1000
# ...
# 2.04
#
#  2023-07-07 01:09:46.203090  - random_milliseconds
# ...
# 1259
#
#  2023-07-07 01:09:46.204087  - random_milliseconds / 1000
# ...
# 1.259
#
#  2023-07-07 01:09:49.542356  - random_milliseconds
# ...
# 1876
#
#  2023-07-07 01:09:49.543353  - random_milliseconds / 1000
# ...
# 1.876
#
#  2023-07-07 01:09:52.913973  - random_milliseconds
# ...
# 2391
#
#  2023-07-07 01:09:52.913973  - random_milliseconds / 1000
# ...
# 2.391
#
#  2023-07-07 01:09:57.665418  - random_milliseconds
# ...
# 1574
#
#  2023-07-07 01:09:57.665418  - random_milliseconds / 1000
# ...
# 1.574
#
#  2023-07-07 01:10:01.339125  - random_milliseconds
# ...
# 1094
#
#  2023-07-07 01:10:01.339125  - random_milliseconds / 1000
# ...
# 1.094
#
#  2023-07-07 01:10:05.214838  - random_milliseconds
# ...
# 2844
#
#  2023-07-07 01:10:05.214838  - random_milliseconds / 1000
# ...
# 2.844
#
#  2023-07-07 01:10:09.993692  - random_milliseconds
# ...
# 2119
#
#  2023-07-07 01:10:09.993692  - random_milliseconds / 1000
# ...
# 2.119
#
#  2023-07-07 01:10:13.513595  - random_milliseconds
# ...
# 2609
#
#  2023-07-07 01:10:13.513595  - random_milliseconds / 1000
# ...
# 2.609
#
#  2023-07-07 01:10:18.524573  - random_milliseconds
# ...
# 1582
#
#  2023-07-07 01:10:18.524573  - random_milliseconds / 1000
# ...
# 1.582
#
#  2023-07-07 01:10:22.295996  - random_milliseconds
# ...
# 1650
#
#  2023-07-07 01:10:22.295996  - random_milliseconds / 1000
# ...
# 1.65
#
#  2023-07-07 01:10:26.027381  - random_milliseconds
# ...
# 1763
#
#  2023-07-07 01:10:26.027381  - random_milliseconds / 1000
# ...
# 1.763
#
#  2023-07-07 01:10:29.975498  - random_milliseconds
# ...
# 2457
#
#  2023-07-07 01:10:29.976498  - random_milliseconds / 1000
# ...
# 2.457
#
#  2023-07-07 01:10:33.978455  - random_milliseconds
# ...
# 1652
#
#  2023-07-07 01:10:33.978455  - random_milliseconds / 1000
# ...
# 1.652
#
#  2023-07-07 01:10:38.062419  - random_milliseconds
# ...
# 1114
#
#  2023-07-07 01:10:38.062419  - random_milliseconds / 1000
# ...
# 1.114
#
#  2023-07-07 01:10:41.268594  - random_milliseconds
# ...
# 1346
#
#  2023-07-07 01:10:41.268594  - random_milliseconds / 1000
# ...
# 1.346
#
#  2023-07-07 01:10:44.616729  - random_milliseconds
# ...
# 1226
#
#  2023-07-07 01:10:44.616729  - random_milliseconds / 1000
# ...
# 1.226
#
#  2023-07-07 01:10:48.128453  - random_milliseconds
# ...
# 2975
#
#  2023-07-07 01:10:48.128453  - random_milliseconds / 1000
# ...
# 2.975
#
#  2023-07-07 01:10:52.706975  - random_milliseconds
# ...
# 1029
#
#  2023-07-07 01:10:52.706975  - random_milliseconds / 1000
# ...
# 1.029
#
#  2023-07-07 01:10:56.274251  - random_milliseconds
# ...
# 1651
#
#  2023-07-07 01:10:56.274251  - random_milliseconds / 1000
# ...
# 1.651
#
#  2023-07-07 01:10:59.950408  - random_milliseconds
# ...
# 2888
#
#  2023-07-07 01:10:59.950408  - random_milliseconds / 1000
# ...
# 2.888
#
#  2023-07-07 01:11:04.942187  - random_milliseconds
# ...
# 1181
#
#  2023-07-07 01:11:04.942187  - random_milliseconds / 1000
# ...
# 1.181
#
#  2023-07-07 01:11:08.353056  - random_milliseconds
# ...
# 2130
#
#  2023-07-07 01:11:08.353056  - random_milliseconds / 1000
# ...
# 2.13
#
#  2023-07-07 01:11:12.057465  - random_milliseconds
# ...
# 2929
#
#  2023-07-07 01:11:12.057465  - random_milliseconds / 1000
# ...
# 2.929
#
#  2023-07-07 01:11:17.299733  - random_milliseconds
# ...
# 2551
#
#  2023-07-07 01:11:17.299733  - random_milliseconds / 1000
# ...
# 2.551
#  2023-07-07 01:11:22.496668  - random_milliseconds
# ...
# 2896
#
#  2023-07-07 01:11:22.496668  - random_milliseconds / 1000
# ...
# 2.896
#
#  2023-07-07 01:11:27.633788  - random_milliseconds
# ...
# 2010
#
#  2023-07-07 01:11:27.633788  - random_milliseconds / 1000
# ...
# 2.01
#
#  2023-07-07 01:11:31.662225  - random_milliseconds
# ...
# 1338
#
#  2023-07-07 01:11:31.662225  - random_milliseconds / 1000
# ...
# 1.338
#
#  2023-07-07 01:11:34.562159  - random_milliseconds
# ...
# 1606
#
#  2023-07-07 01:11:34.562159  - random_milliseconds / 1000
# ...
# 1.606
#
#  2023-07-07 01:11:38.675488  - random_milliseconds
# ...
# 2386
#
#  2023-07-07 01:11:38.675488  - random_milliseconds / 1000
# ...
# 2.386
#
#  2023-07-07 01:11:43.264405  - random_milliseconds
# ...
# 1561
#
#  2023-07-07 01:11:43.264405  - random_milliseconds / 1000
# ...
# 1.561
#
#  2023-07-07 01:11:46.853145  - random_milliseconds
# ...
# 2413
#
#  2023-07-07 01:11:46.853145  - random_milliseconds / 1000
# ...
# 2.413
#
#  2023-07-07 01:11:51.470493  - random_milliseconds
# ...
# 2878
#
#  2023-07-07 01:11:51.470493  - random_milliseconds / 1000
# ...
# 2.878
#
#  2023-07-07 01:11:55.831046  - random_milliseconds
# ...
# 2719
#
#  2023-07-07 01:11:55.831046  - random_milliseconds / 1000
# ...
# 2.719
#
#  2023-07-07 01:12:01.009588  - random_milliseconds
# ...
# 2674
#
#  2023-07-07 01:12:01.009588  - random_milliseconds / 1000
# ...
# 2.674
#
#  2023-07-07 01:12:05.831855  - random_milliseconds
# ...
# 1970
#
#  2023-07-07 01:12:05.831855  - random_milliseconds / 1000
# ...
# 1.97
#
#  2023-07-07 01:12:10.090698  - random_milliseconds
# ...
# 1380
#
#  2023-07-07 01:12:10.090698  - random_milliseconds / 1000
# ...
# 1.38
#
#  2023-07-07 01:12:13.787883  - random_milliseconds
# ...
# 2072
#
#  2023-07-07 01:12:13.787883  - random_milliseconds / 1000
# ...
# 2.072
#
#  2023-07-07 01:12:17.265992  - random_milliseconds
# ...
# 2130
#
#  2023-07-07 01:12:17.265992  - random_milliseconds / 1000
# ...
# 2.13
#
#  2023-07-07 01:12:21.691680  - random_milliseconds
# ...
# 1584
#
#  2023-07-07 01:12:21.692677  - random_milliseconds / 1000
# ...
# 1.584
#
#  2023-07-07 01:12:25.459537  - random_milliseconds
# ...
# 1886
#
#  2023-07-07 01:12:25.459537  - random_milliseconds / 1000
# ...
# 1.886
#
#  2023-07-07 01:12:30.278762  - random_milliseconds
# ...
# 1374
#
#  2023-07-07 01:12:30.278762  - random_milliseconds / 1000
# ...
# 1.374
#
#  2023-07-07 01:12:33.795570  - random_milliseconds
# ...
# 1906
#
#  2023-07-07 01:12:33.795570  - random_milliseconds / 1000
# ...
# 1.906
#
#  2023-07-07 01:12:37.186383  - random_milliseconds
# ...
# 1503
#
#  2023-07-07 01:12:37.186383  - random_milliseconds / 1000
# ...
# 1.503
#
#  2023-07-07 01:12:41.092090  - random_milliseconds
# ...
# 2604
#
#  2023-07-07 01:12:41.092090  - random_milliseconds / 1000
# ...
# 2.604
#
#  2023-07-07 01:12:45.940487  - random_milliseconds
# ...
# 2568
#
#  2023-07-07 01:12:45.940487  - random_milliseconds / 1000
# ...
# 2.568
#
#  2023-07-07 01:12:50.637356  - random_milliseconds
# ...
# 2624
#
#  2023-07-07 01:12:50.637356  - random_milliseconds / 1000
# ...
# 2.624
#
#  2023-07-07 01:12:55.546214  - random_milliseconds
# ...
# 2971
#
#  2023-07-07 01:12:55.546214  - random_milliseconds / 1000
# ...
# 2.971
#
#  2023-07-07 01:13:00.079264  - random_milliseconds
# ...
# 2970
#
#  2023-07-07 01:13:00.079264  - random_milliseconds / 1000
# ...
# 2.97
#
#  2023-07-07 01:13:05.403308  - random_milliseconds
# ...
# 2552
#
#  2023-07-07 01:13:05.404305  - random_milliseconds / 1000
# ...
# 2.552
#
#  2023-07-07 01:13:10.145161  - random_milliseconds
# ...
# 2394
#
#  2023-07-07 01:13:10.145161  - random_milliseconds / 1000
# ...
# 2.394
#
#  2023-07-07 01:13:14.852548  - random_milliseconds
# ...
# 2249
#
#  2023-07-07 01:13:14.852548  - random_milliseconds / 1000
# ...
# 2.249
#
#  2023-07-07 01:13:19.411194  - random_milliseconds
# ...
# 1600
#
#  2023-07-07 01:13:19.411194  - random_milliseconds / 1000
# ...
# 1.6
#
#  2023-07-07 01:13:22.395324  - random_milliseconds
# ...
# 2170
#
#  2023-07-07 01:13:22.395324  - random_milliseconds / 1000
# ...
# 2.17
#
#  2023-07-07 01:13:26.980636  - random_milliseconds
# ...
# 2469
#
#  2023-07-07 01:13:26.980636  - random_milliseconds / 1000
# ...
# 2.469
#
#  2023-07-07 01:13:31.888860  - random_milliseconds
# ...
# 1351
#
#  2023-07-07 01:13:31.888860  - random_milliseconds / 1000
# ...
# 1.351
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11932\1883151344.py in <module>
#     162 #     attaquer_village('3466', '3275', 'data/village.txt')
#     163 #     attaquer_village('3466', '3172', 'data/village.txt')
# --> 164     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages_M81.csv")
#     165     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages_M81.csv")
#     166     delay_with_random_seconds()
#
# ~\AppData\Local\Temp\ipykernel_11932\1883151344.py in attaquer_village(troupes_file)
#      63                 if value > 0:
#      64                     zone = firefox.child_window(auto_id=header)
# ---> 65                     zone.type_keys(str(value))
#      66                     delay_with_random_seconds()
#      67
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     377         if len(self.criteria) >= 2:  # FIXME - this is surprising
#     378
# --> 379             ctrls = self.__resolve_control(self.criteria)
#     380
#     381             try:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     201             criteria[0]['process'] = self.app.process
#     202             del criteria[0]['app']
# --> 203         dialog = self.backend.generic_wrapper_class(findwindows.find_element(**criteria[0]))
#     204
#     205         ctrls = []
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'class_name': 'MozillaWindowClass', 'backend': 'uia', 'process': 17540}
