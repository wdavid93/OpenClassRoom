# %%
from pywinauto.application import Application
import psutil
import time
import random
import requests
import csv
import datetime
import fileinput

def delay_with_random_seconds():
#     # Génère un délai aléatoire entre 1 et 5 secondes
#     random_seconds = random.randint(2, 4)
# #     print(random_seconds)
    
#     # Pause l'exécution du programme pendant le délai aléatoire
#     time.sleep(random_seconds)
    random_milliseconds = random.randint(1000, 3000)  # Générer un nombre aléatoire en millisecondes entre 2000 et 4000
    print('\n', datetime.datetime.now(),' - random_milliseconds \n...')   
    print(random_milliseconds)
    print('\n', datetime.datetime.now(),' - random_milliseconds / 1000 \n...')   
    print(random_milliseconds / 1000)
    time.sleep(random_milliseconds / 1000)  # Utiliser la valeur en millisecondes dans time.sleep()
 #     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()

def attaquer_village(troupes_file):
    # Réafficher la fenêtre de navigateur
#     firefox.activate()
    firefox.set_focus()

    lines = []

    # Lire le fichier et stocker les lignes dans une liste
    with open(troupes_file, 'r') as file:
        lines = file.readlines()

    # Exclure la première ligne (en-têtes)
    headers = lines[0].strip().split(',')
    lines = lines[1:]

    # Trier les lignes par heure_attaque la plus ancienne
    lines = sorted(lines, key=lambda x: datetime.datetime.strptime(x.strip().split(',')[headers.index('heure_attaque')], "%Y-%m-%d %H:%M:%S"))

    # Parcourir les lignes triées
    for i, line in enumerate(lines):
        data = line.strip().split(',')
        village_depart = data[headers.index('village_depart')]
        village_attaquer = data[headers.index('village_attaquer')]

        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        url = f"https://fr82.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_attaquer}"
        firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()

        # Saisir les champs pour chaque type de troupe
        for header in headers:
            if header not in ['heure_attaque', 'village_depart', 'village_attaquer']:
                value = int(data[headers.index(header)])
                if value > 0:
                    zone = firefox.child_window(auto_id=header)
                    zone.type_keys(str(value))
                    delay_with_random_seconds()

        # Mettre à jour la colonne heure_attaque avec l'heure actuelle
        heure_attaque_index = headers.index('heure_attaque')
        heure_attaque = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        data[heure_attaque_index] = heure_attaque

        # Modifier la ligne dans la liste
        lines[i] = ','.join(data) + '\n'

        bouton = firefox.child_window(auto_id='target_attack')
        bouton.click()
        delay_with_random_seconds()

        bouton = firefox.child_window(auto_id='troop_confirm_submit')
        bouton.click()
        delay_with_random_seconds()

    # Réécrire le fichier avec les lignes modifiées
    with open(troupes_file, 'w') as file:
        file.write(','.join(headers) + '\n')  # Réécrire les en-têtes
        file.writelines(lines)  # Réécrire les lignes modifiées


# Vérifier si Firefox est en cours d'exécution
firefox_running = False
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_running = True
        firefox_pid = process.pid
        break

# Fermer Firefox si c'est le cas
if firefox_running:
    process = psutil.Process(firefox_pid)
    process.terminate()
#     time.sleep(5)
# Ouvrir Firefox
time.sleep(2)

app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Ouvrir Firefox
# app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Trouver le PID de Firefox
firefox_pid = None
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_pid = process.pid
        break

# Vérifier si Firefox est en cours d'exécution
if firefox_pid is None:
    print("Firefox n'est pas en cours d'exécution.")
else:
    # Attacher Pywinauto à la fenêtre Firefox
    app = Application(backend='uia').connect(process=firefox_pid)

    # Ouvrir une page web
#     firefox = app.window(title_re='.*Nouvel onglet*')
    firefox = app.window( class_name='MozillaWindowClass')

    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     time.sleep(5)

#     # Saisir les champs
#     zone1 = firefox.window(title='user')
#     zone1.type_keys('*test1')
#     zone1 = firefox.child_window(control_type="Edit", found_index=0,  automation_id="user")
    zone1 = firefox.child_window(auto_id='user')

    zone1.type_keys('arion1')
    delay_with_random_seconds()

    zone2 = firefox.child_window(auto_id='password')
    zone2.type_keys('MiMa5158**')
    delay_with_random_seconds()
    # Cliquer sur le bouton
#     bouton = firefox.window(title='Connexion')
# #     bouton = firefox.child_window(auto_id='btn-login')
#     bouton = firefox.child_window(title='Connexion')
#     bouton.click()!
    bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
    bouton.invoke()
#     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
#     bouton.invoke()
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr/page/play/fr82{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr82.guerretribale.fr/game.php?village=2251&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    
#     attaquer_village('3466', '3275', 'data/village.txt')
#     attaquer_village('3466', '3172', 'data/village.txt')
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages_M82.csv")
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages_M82.csv")
    delay_with_random_seconds()    
    # Fermer Firefox 
#     firefox.close()
# Out:
#  2023-07-06 21:10:28.797845  - random_milliseconds
# ...
# 2470
#
#  2023-07-06 21:10:28.797845  - random_milliseconds / 1000
# ...
# 2.47
#
#  2023-07-06 21:10:32.082540  - random_milliseconds
# ...
# 2128
#
#  2023-07-06 21:10:32.082540  - random_milliseconds / 1000
# ...
# 2.128
#
#  2023-07-06 21:10:34.789246  - random_milliseconds
# ...
# 1169
#
#  2023-07-06 21:10:34.789246  - random_milliseconds / 1000
# ...
# 1.169
#
#  2023-07-06 21:10:37.385958  - random_milliseconds
# ...
# 1280
#
#  2023-07-06 21:10:37.385958  - random_milliseconds / 1000
# ...
# 1.28
#
#  2023-07-06 21:10:40.510778  - random_milliseconds
# ...
# 2310
#
#  2023-07-06 21:10:40.510778  - random_milliseconds / 1000
# ...
# 2.31
#
#  2023-07-06 21:10:45.010285  - random_milliseconds
# ...
# 2889
#
#  2023-07-06 21:10:45.010285  - random_milliseconds / 1000
# ...
# 2.889
#
#  2023-07-06 21:10:48.963472  - random_milliseconds
# ...
# 1568
#
#  2023-07-06 21:10:48.963472  - random_milliseconds / 1000
# ...
# 1.568
#
#  2023-07-06 21:10:52.250543  - random_milliseconds
# ...
# 2437
#
#  2023-07-06 21:10:52.250543  - random_milliseconds / 1000
# ...
# 2.437
#
#  2023-07-06 21:10:55.850313  - random_milliseconds
# ...
# 2356
#
#  2023-07-06 21:10:55.850313  - random_milliseconds / 1000
# ...
# 2.356
#
#  2023-07-06 21:10:59.224114  - random_milliseconds
# ...
# 2688
#
#  2023-07-06 21:10:59.224114  - random_milliseconds / 1000
# ...
# 2.688
#
#  2023-07-06 21:11:03.792359  - random_milliseconds
# ...
# 1034
#
#  2023-07-06 21:11:03.792359  - random_milliseconds / 1000
# ...
# 1.034
#
#  2023-07-06 21:11:05.950001  - random_milliseconds
# ...
# 1350
#
#  2023-07-06 21:11:05.950001  - random_milliseconds / 1000
# ...
# 1.35
#
#  2023-07-06 21:11:08.439355  - random_milliseconds
# ...
# 1310
#
#  2023-07-06 21:11:08.439355  - random_milliseconds / 1000
# ...
# 1.31
#
#  2023-07-06 21:11:10.835199  - random_milliseconds
# ...
# 1069
#
#  2023-07-06 21:11:10.835199  - random_milliseconds / 1000
# ...
# 1.069
#
#  2023-07-06 21:11:12.987273  - random_milliseconds
# ...
# 2075
#
#  2023-07-06 21:11:12.987273  - random_milliseconds / 1000
# ...
# 2.075
#
#  2023-07-06 21:11:17.007347  - random_milliseconds
# ...
# 1847
#
#  2023-07-06 21:11:17.007347  - random_milliseconds / 1000
# ...
# 1.847
#
#  2023-07-06 21:11:20.086033  - random_milliseconds
# ...
# 1190
#
#  2023-07-06 21:11:20.086033  - random_milliseconds / 1000
# ...
# 1.19
#
#  2023-07-06 21:11:22.450548  - random_milliseconds
# ...
# 1248
#
#  2023-07-06 21:11:22.450548  - random_milliseconds / 1000
# ...
# 1.248
#
#  2023-07-06 21:11:24.899662  - random_milliseconds
# ...
# 1391
#
#  2023-07-06 21:11:24.899662  - random_milliseconds / 1000
# ...
# 1.391
#
#  2023-07-06 21:11:27.352101  - random_milliseconds
# ...
# 1587
#
#  2023-07-06 21:11:27.352101  - random_milliseconds / 1000
# ...
# 1.587
#
#  2023-07-06 21:11:31.107818  - random_milliseconds
# ...
# 2003
#
#  2023-07-06 21:11:31.107818  - random_milliseconds / 1000
# ...
# 2.003
#
#  2023-07-06 21:11:34.120246  - random_milliseconds
# ...
# 2576
#
#  2023-07-06 21:11:34.120246  - random_milliseconds / 1000
# ...
# 2.576
#
#  2023-07-06 21:11:37.811498  - random_milliseconds
# ...
# 1362
#
#  2023-07-06 21:11:37.811498  - random_milliseconds / 1000
# ...
# 1.362
#
#  2023-07-06 21:11:40.322360  - random_milliseconds
# ...
# 1963
#
#  2023-07-06 21:11:40.322360  - random_milliseconds / 1000
# ...
# 1.963
#
#  2023-07-06 21:11:43.230951  - random_milliseconds
# ...
# 1258
#
#  2023-07-06 21:11:43.230951  - random_milliseconds / 1000
# ...
# 1.258
#
#  2023-07-06 21:11:46.598772  - random_milliseconds
# ...
# 1735
#
#  2023-07-06 21:11:46.598772  - random_milliseconds / 1000
# ...
# 1.735
#
#  2023-07-06 21:11:49.447763  - random_milliseconds
# ...
# 2670
#
#  2023-07-06 21:11:49.447763  - random_milliseconds / 1000
# ...
# 2.67
#
#  2023-07-06 21:11:53.240977  - random_milliseconds
# ...
# 2135
#
#  2023-07-06 21:11:53.240977  - random_milliseconds / 1000
# ...
# 2.135
#
#  2023-07-06 21:11:56.505298  - random_milliseconds
# ...
# 2483
#
#  2023-07-06 21:11:56.505298  - random_milliseconds / 1000
# ...
# 2.483
#
#  2023-07-06 21:11:59.966019  - random_milliseconds
# ...
# 2854
#
#  2023-07-06 21:11:59.966019  - random_milliseconds / 1000
# ...
# 2.854
#
#  2023-07-06 21:12:04.925247  - random_milliseconds
# ...
# 2347
#
#  2023-07-06 21:12:04.925247  - random_milliseconds / 1000
# ...
# 2.347
#
#  2023-07-06 21:12:08.645584  - random_milliseconds
# ...
# 2381
#
#  2023-07-06 21:12:08.645584  - random_milliseconds / 1000
# ...
# 2.381
#
#  2023-07-06 21:12:12.143602  - random_milliseconds
# ...
# 1000
#
#  2023-07-06 21:12:12.143602  - random_milliseconds / 1000
# ...
# 1.0
#
#  2023-07-06 21:12:14.196616  - random_milliseconds
# ...
# 2650
#
#  2023-07-06 21:12:14.196616  - random_milliseconds / 1000
# ...
# 2.65
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3004\3222848290.py in <module>
#     162 #     attaquer_village('3466', '3275', 'data/village.txt')
#     163 #     attaquer_village('3466', '3172', 'data/village.txt')
# --> 164     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages_M82.csv")
#     165     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages_M82.csv")
#     166     delay_with_random_seconds()
#
# ~\AppData\Local\Temp\ipykernel_3004\3222848290.py in attaquer_village(troupes_file)
#      79
#      80         bouton = firefox.child_window(auto_id='troop_confirm_submit')
# ---> 81         bouton.click()
#      82         delay_with_random_seconds()
#      83
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     377         if len(self.criteria) >= 2:  # FIXME - this is surprising
#     378
# --> 379             ctrls = self.__resolve_control(self.criteria)
#     380
#     381             try:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     220                 if 'backend' not in ctrl_criteria:
#     221                     ctrl_criteria['backend'] = self.backend.name
# --> 222                 ctrl = self.backend.generic_wrapper_class(findwindows.find_element(**ctrl_criteria))
#     223                 previous_parent = ctrl.element_info
#     224                 ctrls.append(ctrl)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'auto_id': 'troop_confirm_submit', 'top_level_only': False, 'parent': <uia_element_info.UIAElementInfo - 'M82-----1 (538|528) - Guerre Tribale - Monde 82 — Mozilla Firefox', MozillaWindowClass, 6949016>, 'backend': 'uia'}
