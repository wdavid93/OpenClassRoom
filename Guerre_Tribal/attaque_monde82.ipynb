# %%
from pywinauto.application import Application
import psutil
import time
import random
import requests
import csv
import datetime
import fileinput

def delay_with_random_seconds():
#     # Génère un délai aléatoire entre 1 et 5 secondes
#     random_seconds = random.randint(2, 3)
# #     print(random_seconds)
    
#     # Pause l'exécution du programme pendant le délai aléatoire
#     time.sleep(random_seconds)
    random_milliseconds = random.randint(1100, 2100)  # Générer un nombre aléatoire en millisecondes entre 2000 et 4000
    print('\n', datetime.datetime.now(),' - random_milliseconds \n...')   
    print(random_milliseconds)
    print('\n', datetime.datetime.now(),' - random_milliseconds / 1000 \n...')   
    print(random_milliseconds / 1000)
    time.sleep(random_milliseconds / 1000)  # Utiliser la valeur en millisecondes dans time.sleep()
 #     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()

def attaquer_village(troupes_file):
    # Réafficher la fenêtre de navigateur
#     firefox.activate()
    firefox.set_focus()

    lines = []

    # Lire le fichier et stocker les lignes dans une liste
    with open(troupes_file, 'r') as file:
        lines = file.readlines()

    # Exclure la première ligne (en-têtes)
    headers = lines[0].strip().split(',')
    lines = lines[1:]

    # Trier les lignes par heure_attaque la plus ancienne
    lines = sorted(lines, key=lambda x: datetime.datetime.strptime(x.strip().split(',')[headers.index('heure_attaque')], "%Y-%m-%d %H:%M:%S"))

    # Parcourir les lignes triées
    for i, line in enumerate(lines):
        data = line.strip().split(',')
        village_depart = data[headers.index('village_depart')]
        village_attaquer = data[headers.index('village_attaquer')]

        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        url = f"https://fr82.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_attaquer}"
        firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()

        # Saisir les champs pour chaque type de troupe
        for header in headers:
            if header not in ['heure_attaque', 'village_depart', 'village_attaquer']:
                value = int(data[headers.index(header)])
                if value > 0:
                    zone = firefox.child_window(auto_id=header)
                    zone.type_keys(str(value))
                    delay_with_random_seconds()

        # Mettre à jour la colonne heure_attaque avec l'heure actuelle
        heure_attaque_index = headers.index('heure_attaque')
        heure_attaque = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        data[heure_attaque_index] = heure_attaque

        # Modifier la ligne dans la liste
        lines[i] = ','.join(data) + '\n'

        bouton = firefox.child_window(auto_id='target_attack')
        bouton.click()
        delay_with_random_seconds()

        bouton = firefox.child_window(auto_id='troop_confirm_submit')
        bouton.click()
        delay_with_random_seconds()

    # Réécrire le fichier avec les lignes modifiées
    with open(troupes_file, 'w') as file:
        file.write(','.join(headers) + '\n')  # Réécrire les en-têtes
        file.writelines(lines)  # Réécrire les lignes modifiées


# Vérifier si Firefox est en cours d'exécution
firefox_running = False
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_running = True
        firefox_pid = process.pid
        break

# Fermer Firefox si c'est le cas
if firefox_running:
    process = psutil.Process(firefox_pid)
    process.terminate()
#     time.sleep(5)
# Ouvrir Firefox
time.sleep(2)

app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Ouvrir Firefox
# app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Trouver le PID de Firefox
firefox_pid = None
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_pid = process.pid
        break

# Vérifier si Firefox est en cours d'exécution
if firefox_pid is None:
    print("Firefox n'est pas en cours d'exécution.")
else:
    # Attacher Pywinauto à la fenêtre Firefox
    app = Application(backend='uia').connect(process=firefox_pid)

    # Ouvrir une page web
#     firefox = app.window(title_re='.*Nouvel onglet*')
    firefox = app.window( class_name='MozillaWindowClass')

    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     time.sleep(5)

#     # Saisir les champs
#     zone1 = firefox.window(title='user')
#     zone1.type_keys('*test1')
#     zone1 = firefox.child_window(control_type="Edit", found_index=0,  automation_id="user")
    zone1 = firefox.child_window(auto_id='user')

    zone1.type_keys('arion1')
    delay_with_random_seconds()

    zone2 = firefox.child_window(auto_id='password')
    zone2.type_keys('MiMa5158**')
    delay_with_random_seconds()
    # Cliquer sur le bouton
#     bouton = firefox.window(title='Connexion')
# #     bouton = firefox.child_window(auto_id='btn-login')
#     bouton = firefox.child_window(title='Connexion')
#     bouton.click()!
    bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
    bouton.invoke()
#     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
#     bouton.invoke()
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr/page/play/fr82{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr82.guerretribale.fr/game.php?village=2251&screen=map#538;528{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    
#     attaquer_village('3466', '3275', 'data/village.txt')
#     attaquer_village('3466', '3172', 'data/village.txt')
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages_M82.csv")
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages_M82.csv")
    delay_with_random_seconds()    
    # Fermer Firefox 
#     firefox.close()
# Out:
#  2023-07-29 07:30:17.389419  - random_milliseconds
# ...
# 1631
#
#  2023-07-29 07:30:17.389419  - random_milliseconds / 1000
# ...
# 1.631
#
#  2023-07-29 07:30:19.728992  - random_milliseconds
# ...
# 1745
#
#  2023-07-29 07:30:19.728992  - random_milliseconds / 1000
# ...
# 1.745
#
#  2023-07-29 07:30:22.121878  - random_milliseconds
# ...
# 1233
#
#  2023-07-29 07:30:22.121878  - random_milliseconds / 1000
# ...
# 1.233
#
#  2023-07-29 07:30:24.495095  - random_milliseconds
# ...
# 1438
#
#  2023-07-29 07:30:24.495095  - random_milliseconds / 1000
# ...
# 1.438
#
#  2023-07-29 07:30:27.491192  - random_milliseconds
# ...
# 2001
#
#  2023-07-29 07:30:27.491304  - random_milliseconds / 1000
# ...
# 2.001
#
#  2023-07-29 07:30:31.208276  - random_milliseconds
# ...
# 1325
#
#  2023-07-29 07:30:31.208276  - random_milliseconds / 1000
# ...
# 1.325
#
#  2023-07-29 07:30:33.474367  - random_milliseconds
# ...
# 1253
#
#  2023-07-29 07:30:33.474367  - random_milliseconds / 1000
# ...
# 1.253
#
#  2023-07-29 07:30:35.804641  - random_milliseconds
# ...
# 1956
#
#  2023-07-29 07:30:35.804641  - random_milliseconds / 1000
# ...
# 1.956
#
#  2023-07-29 07:30:38.692811  - random_milliseconds
# ...
# 1207
#
#  2023-07-29 07:30:38.692811  - random_milliseconds / 1000
# ...
# 1.207
#
#  2023-07-29 07:30:41.442173  - random_milliseconds
# ...
# 1333
#
#  2023-07-29 07:30:41.442173  - random_milliseconds / 1000
# ...
# 1.333
#
#  2023-07-29 07:30:43.795611  - random_milliseconds
# ...
# 1479
#
#  2023-07-29 07:30:43.795611  - random_milliseconds / 1000
# ...
# 1.479
#
#  2023-07-29 07:30:46.406547  - random_milliseconds
# ...
# 1446
#
#  2023-07-29 07:30:46.407543  - random_milliseconds / 1000
# ...
# 1.446
#
#  2023-07-29 07:30:48.783155  - random_milliseconds
# ...
# 1697
#
#  2023-07-29 07:30:48.784152  - random_milliseconds / 1000
# ...
# 1.697
#
#  2023-07-29 07:30:51.962966  - random_milliseconds
# ...
# 1236
#
#  2023-07-29 07:30:51.962966  - random_milliseconds / 1000
# ...
# 1.236
#
#  2023-07-29 07:30:54.304544  - random_milliseconds
# ...
# 1983
#
#  2023-07-29 07:30:54.304544  - random_milliseconds / 1000
# ...
# 1.983
#
#  2023-07-29 07:30:57.436099  - random_milliseconds
# ...
# 1755
#
#  2023-07-29 07:30:57.436099  - random_milliseconds / 1000
# ...
# 1.755
#
#  2023-07-29 07:31:00.533157  - random_milliseconds
# ...
# 1835
#
#  2023-07-29 07:31:00.533157  - random_milliseconds / 1000
# ...
# 1.835
#
#  2023-07-29 07:31:03.949842  - random_milliseconds
# ...
# 1744
#
#  2023-07-29 07:31:03.949842  - random_milliseconds / 1000
# ...
# 1.744
#
#  2023-07-29 07:31:06.802980  - random_milliseconds
# ...
# 1577
#
#  2023-07-29 07:31:06.802980  - random_milliseconds / 1000
# ...
# 1.577
#
#  2023-07-29 07:31:09.480098  - random_milliseconds
# ...
# 1328
#
#  2023-07-29 07:31:09.480098  - random_milliseconds / 1000
# ...
# 1.328
#
#  2023-07-29 07:31:11.731535  - random_milliseconds
# ...
# 1151
#
#  2023-07-29 07:31:11.731535  - random_milliseconds / 1000
# ...
# 1.151
#
#  2023-07-29 07:31:14.278044  - random_milliseconds
# ...
# 1741
#
#  2023-07-29 07:31:14.278044  - random_milliseconds / 1000
# ...
# 1.741
#
#  2023-07-29 07:31:17.053339  - random_milliseconds
# ...
# 1495
#
#  2023-07-29 07:31:17.053339  - random_milliseconds / 1000
# ...
# 1.495
#
#  2023-07-29 07:31:19.707714  - random_milliseconds
# ...
# 1159
#
#  2023-07-29 07:31:19.707714  - random_milliseconds / 1000
# ...
# 1.159
#
#  2023-07-29 07:31:21.834496  - random_milliseconds
# ...
# 1593
#
#  2023-07-29 07:31:21.834496  - random_milliseconds / 1000
# ...
# 1.593
#
#  2023-07-29 07:31:24.797005  - random_milliseconds
# ...
# 1947
#
#  2023-07-29 07:31:24.797005  - random_milliseconds / 1000
# ...
# 1.947
#
#  2023-07-29 07:31:27.749432  - random_milliseconds
# ...
# 1950
#
#  2023-07-29 07:31:27.749432  - random_milliseconds / 1000
# ...
# 1.95
#
#  2023-07-29 07:31:30.777218  - random_milliseconds
# ...
# 1452
#
#  2023-07-29 07:31:30.777218  - random_milliseconds / 1000
# ...
# 1.452
#
#  2023-07-29 07:31:33.185828  - random_milliseconds
# ...
# 1178
#
#  2023-07-29 07:31:33.186062  - random_milliseconds / 1000
# ...
# 1.178
#
#  2023-07-29 07:31:35.859869  - random_milliseconds
# ...
# 1809
#
#  2023-07-29 07:31:35.860865  - random_milliseconds / 1000
# ...
# 1.809
#
#  2023-07-29 07:31:38.706652  - random_milliseconds
# ...
# 1329
#
#  2023-07-29 07:31:38.706652  - random_milliseconds / 1000
# ...
# 1.329
#
#  2023-07-29 07:31:41.166367  - random_milliseconds
# ...
# 1283
#
#  2023-07-29 07:31:41.166367  - random_milliseconds / 1000
# ...
# 1.283
#
#  2023-07-29 07:31:43.408461  - random_milliseconds
# ...
# 1357
#
#  2023-07-29 07:31:43.408461  - random_milliseconds / 1000
# ...
# 1.357
#
#  2023-07-29 07:31:46.183565  - random_milliseconds
# ...
# 2070
#
#  2023-07-29 07:31:46.183565  - random_milliseconds / 1000
# ...
# 2.07
#
#  2023-07-29 07:31:49.392202  - random_milliseconds
# ...
# 1410
#
#  2023-07-29 07:31:49.392202  - random_milliseconds / 1000
# ...
# 1.41
#
#  2023-07-29 07:31:52.007449  - random_milliseconds
# ...
# 1152
#
#  2023-07-29 07:31:52.007449  - random_milliseconds / 1000
# ...
# 1.152
#
#  2023-07-29 07:31:54.106169  - random_milliseconds
# ...
# 1674
#
#  2023-07-29 07:31:54.106169  - random_milliseconds / 1000
# ...
# 1.674
#
#  2023-07-29 07:31:57.193364  - random_milliseconds
# ...
# 2080
#
#  2023-07-29 07:31:57.194397  - random_milliseconds / 1000
# ...
# 2.08
#
#  2023-07-29 07:32:00.678448  - random_milliseconds
# ...
# 2036
#
#  2023-07-29 07:32:00.678448  - random_milliseconds / 1000
# ...
# 2.036
#
#  2023-07-29 07:32:03.898096  - random_milliseconds
# ...
# 1535
#
#  2023-07-29 07:32:03.898096  - random_milliseconds / 1000
# ...
# 1.535
#
#  2023-07-29 07:32:06.417348  - random_milliseconds
# ...
# 1154
#
#  2023-07-29 07:32:06.417348  - random_milliseconds / 1000
# ...
# 1.154
#
#  2023-07-29 07:32:09.071328  - random_milliseconds
# ...
# 1332
#
#  2023-07-29 07:32:09.071328  - random_milliseconds / 1000
# ...
# 1.332
#
#  2023-07-29 07:32:11.576194  - random_milliseconds
# ...
# 2019
#
#  2023-07-29 07:32:11.576194  - random_milliseconds / 1000
# ...
# 2.019
#
#  2023-07-29 07:32:14.835478  - random_milliseconds
# ...
# 1402
#
#  2023-07-29 07:32:14.835478  - random_milliseconds / 1000
# ...
# 1.402
#
#  2023-07-29 07:32:17.123379  - random_milliseconds
# ...
# 1264
#
#  2023-07-29 07:32:17.123379  - random_milliseconds / 1000
# ...
# 1.264
#
#  2023-07-29 07:32:19.836472  - random_milliseconds
# ...
# 1924
#
#  2023-07-29 07:32:19.836472  - random_milliseconds / 1000
# ...
# 1.924
#
#  2023-07-29 07:32:22.952341  - random_milliseconds
# ...
# 1351
#
#  2023-07-29 07:32:22.952341  - random_milliseconds / 1000
# ...
# 1.351
#
#  2023-07-29 07:32:25.511096  - random_milliseconds
# ...
# 1633
#
#  2023-07-29 07:32:25.511096  - random_milliseconds / 1000
# ...
# 1.633
#
#  2023-07-29 07:32:28.078227  - random_milliseconds
# ...
# 1896
#
#  2023-07-29 07:32:28.078227  - random_milliseconds / 1000
# ...
# 1.896
#
#  2023-07-29 07:32:31.423614  - random_milliseconds
# ...
# 1704
#
#  2023-07-29 07:32:31.423614  - random_milliseconds / 1000
# ...
# 1.704
#
#  2023-07-29 07:32:34.269806  - random_milliseconds
# ...
# 1738
#
#  2023-07-29 07:32:34.269806  - random_milliseconds / 1000
# ...
# 1.738
#
#  2023-07-29 07:32:37.146919  - random_milliseconds
# ...
# 1551
#
#  2023-07-29 07:32:37.146919  - random_milliseconds / 1000
# ...
# 1.551
#
#  2023-07-29 07:32:39.664995  - random_milliseconds
# ...
# 2026
#
#  2023-07-29 07:32:39.664995  - random_milliseconds / 1000
# ...
# 2.026
#
#  2023-07-29 07:32:43.268653  - random_milliseconds
# ...
# 1264
#
#  2023-07-29 07:32:43.268919  - random_milliseconds / 1000
# ...
# 1.264
#
#  2023-07-29 07:32:45.722824  - random_milliseconds
# ...
# 1652
#
#  2023-07-29 07:32:45.722824  - random_milliseconds / 1000
# ...
# 1.652
#
#  2023-07-29 07:32:48.621886  - random_milliseconds
# ...
# 1895
#
#  2023-07-29 07:32:48.621886  - random_milliseconds / 1000
# ...
# 1.895
#
#  2023-07-29 07:32:51.411676  - random_milliseconds
# ...
# 1957
#
#  2023-07-29 07:32:51.411676  - random_milliseconds / 1000
# ...
# 1.957
#
#  2023-07-29 07:32:55.111535  - random_milliseconds
# ...
# 1324
#
#  2023-07-29 07:32:55.111535  - random_milliseconds / 1000
# ...
# 1.324
#
#  2023-07-29 07:32:57.958163  - random_milliseconds
# ...
# 1273
#
#  2023-07-29 07:32:57.958163  - random_milliseconds / 1000
# ...
# 1.273
#
#  2023-07-29 07:33:00.445146  - random_milliseconds
# ...
# 1231
#
#  2023-07-29 07:33:00.445146  - random_milliseconds / 1000
# ...
# 1.231
#
#  2023-07-29 07:33:02.563449  - random_milliseconds
# ...
# 1865
#
#  2023-07-29 07:33:02.563449  - random_milliseconds / 1000
# ...
# 1.865
#
#  2023-07-29 07:33:06.074228  - random_milliseconds
# ...
# 1297
#
#  2023-07-29 07:33:06.074228  - random_milliseconds / 1000
# ...
# 1.297
#
#  2023-07-29 07:33:08.587748  - random_milliseconds
# ...
# 1552
#
#  2023-07-29 07:33:08.587748  - random_milliseconds / 1000
# ...
# 1.552
#  2023-07-29 07:33:11.401853  - random_milliseconds
# ...
# 1403
#
#  2023-07-29 07:33:11.401853  - random_milliseconds / 1000
# ...
# 1.403
#
#  2023-07-29 07:33:13.768394  - random_milliseconds
# ...
# 1883
#
#  2023-07-29 07:33:13.768394  - random_milliseconds / 1000
# ...
# 1.883
#
#  2023-07-29 07:33:17.224618  - random_milliseconds
# ...
# 1667
#
#  2023-07-29 07:33:17.225614  - random_milliseconds / 1000
# ...
# 1.667
#
#  2023-07-29 07:33:20.117709  - random_milliseconds
# ...
# 1897
#
#  2023-07-29 07:33:20.117709  - random_milliseconds / 1000
# ...
# 1.897
#
#  2023-07-29 07:33:23.228286  - random_milliseconds
# ...
# 1568
#
#  2023-07-29 07:33:23.228286  - random_milliseconds / 1000
# ...
# 1.568
#
#  2023-07-29 07:33:25.678475  - random_milliseconds
# ...
# 1386
#
#  2023-07-29 07:33:25.678475  - random_milliseconds / 1000
# ...
# 1.386
#
#  2023-07-29 07:33:28.545347  - random_milliseconds
# ...
# 1625
#
#  2023-07-29 07:33:28.545347  - random_milliseconds / 1000
# ...
# 1.625
#
#  2023-07-29 07:33:31.347564  - random_milliseconds
# ...
# 1336
#
#  2023-07-29 07:33:31.347564  - random_milliseconds / 1000
# ...
# 1.336
#
#  2023-07-29 07:33:33.969341  - random_milliseconds
# ...
# 1519
#
#  2023-07-29 07:33:33.969341  - random_milliseconds / 1000
# ...
# 1.519
#
#  2023-07-29 07:33:36.452190  - random_milliseconds
# ...
# 1851
#
#  2023-07-29 07:33:36.452190  - random_milliseconds / 1000
# ...
# 1.851
#
#  2023-07-29 07:33:39.773726  - random_milliseconds
# ...
# 1939
#
#  2023-07-29 07:33:39.773726  - random_milliseconds / 1000
# ...
# 1.939
#
#  2023-07-29 07:33:42.972044  - random_milliseconds
# ...
# 1881
#
#  2023-07-29 07:33:42.972044  - random_milliseconds / 1000
# ...
# 1.881
#
#  2023-07-29 07:33:46.198190  - random_milliseconds
# ...
# 1130
#
#  2023-07-29 07:33:46.198190  - random_milliseconds / 1000
# ...
# 1.13
#
#  2023-07-29 07:33:48.620067  - random_milliseconds
# ...
# 1702
#
#  2023-07-29 07:33:48.620067  - random_milliseconds / 1000
# ...
# 1.702
#
#  2023-07-29 07:33:51.854702  - random_milliseconds
# ...
# 1789
#
#  2023-07-29 07:33:51.854702  - random_milliseconds / 1000
# ...
# 1.789
#
#  2023-07-29 07:33:54.830974  - random_milliseconds
# ...
# 1108
#
#  2023-07-29 07:33:54.830974  - random_milliseconds / 1000
# ...
# 1.108
#
#  2023-07-29 07:33:57.216552  - random_milliseconds
# ...
# 1299
#
#  2023-07-29 07:33:57.216552  - random_milliseconds / 1000
# ...
# 1.299
#
#  2023-07-29 07:33:59.401378  - random_milliseconds
# ...
# 1443
#
#  2023-07-29 07:33:59.401378  - random_milliseconds / 1000
# ...
# 1.443
#
#  2023-07-29 07:34:02.467873  - random_milliseconds
# ...
# 1233
#
#  2023-07-29 07:34:02.467873  - random_milliseconds / 1000
# ...
# 1.233
#
#  2023-07-29 07:34:05.035161  - random_milliseconds
# ...
# 1176
#
#  2023-07-29 07:34:05.035161  - random_milliseconds / 1000
# ...
# 1.176
#
#  2023-07-29 07:34:07.541378  - random_milliseconds
# ...
# 1640
#
#  2023-07-29 07:34:07.542382  - random_milliseconds / 1000
# ...
# 1.64
#
#  2023-07-29 07:34:10.101882  - random_milliseconds
# ...
# 1671
#
#  2023-07-29 07:34:10.101882  - random_milliseconds / 1000
# ...
# 1.671
#
#  2023-07-29 07:34:13.427184  - random_milliseconds
# ...
# 1941
#
#  2023-07-29 07:34:13.427184  - random_milliseconds / 1000
# ...
# 1.941
#
#  2023-07-29 07:34:16.648645  - random_milliseconds
# ...
# 1754
#
#  2023-07-29 07:34:16.648645  - random_milliseconds / 1000
# ...
# 1.754
#
#  2023-07-29 07:34:19.715828  - random_milliseconds
# ...
# 1694
#
#  2023-07-29 07:34:19.715828  - random_milliseconds / 1000
# ...
# 1.694
#
#  2023-07-29 07:34:22.402304  - random_milliseconds
# ...
# 1771
#
#  2023-07-29 07:34:22.402304  - random_milliseconds / 1000
# ...
# 1.771
#
#  2023-07-29 07:34:25.821658  - random_milliseconds
# ...
# 1397
#
#  2023-07-29 07:34:25.821658  - random_milliseconds / 1000
# ...
# 1.397
#
#  2023-07-29 07:34:29.280268  - random_milliseconds
# ...
# 1722
#
#  2023-07-29 07:34:29.281264  - random_milliseconds / 1000
# ...
# 1.722
#
#  2023-07-29 07:34:32.778699  - random_milliseconds
# ...
# 1541
#
#  2023-07-29 07:34:32.778699  - random_milliseconds / 1000
# ...
# 1.541
#
#  2023-07-29 07:34:36.370086  - random_milliseconds
# ...
# 1149
#
#  2023-07-29 07:34:36.370086  - random_milliseconds / 1000
# ...
# 1.149
#
#  2023-07-29 07:34:39.149279  - random_milliseconds
# ...
# 1138
#
#  2023-07-29 07:34:39.150316  - random_milliseconds / 1000
# ...
# 1.138
#
#  2023-07-29 07:34:42.475608  - random_milliseconds
# ...
# 1889
#
#  2023-07-29 07:34:42.475608  - random_milliseconds / 1000
# ...
# 1.889
#
#  2023-07-29 07:34:47.051150  - random_milliseconds
# ...
# 1461
#
#  2023-07-29 07:34:47.051150  - random_milliseconds / 1000
# ...
# 1.461
#
#  2023-07-29 07:34:50.210158  - random_milliseconds
# ...
# 1486
#
#  2023-07-29 07:34:50.210158  - random_milliseconds / 1000
# ...
# 1.486
#
#  2023-07-29 07:34:53.335497  - random_milliseconds
# ...
# 1973
#
#  2023-07-29 07:34:53.336490  - random_milliseconds / 1000
# ...
# 1.973
#
#  2023-07-29 07:34:57.764186  - random_milliseconds
# ...
# 1217
#
#  2023-07-29 07:34:57.764186  - random_milliseconds / 1000
# ...
# 1.217
#
#  2023-07-29 07:35:01.334245  - random_milliseconds
# ...
# 1182
#
#  2023-07-29 07:35:01.334245  - random_milliseconds / 1000
# ...
# 1.182
#
#  2023-07-29 07:35:04.449105  - random_milliseconds
# ...
# 1529
#
#  2023-07-29 07:35:04.449105  - random_milliseconds / 1000
# ...
# 1.529
#
#  2023-07-29 07:35:07.594476  - random_milliseconds
# ...
# 1777
#
#  2023-07-29 07:35:07.594476  - random_milliseconds / 1000
# ...
# 1.777
#
#  2023-07-29 07:35:11.983768  - random_milliseconds
# ...
# 1589
#
#  2023-07-29 07:35:11.983768  - random_milliseconds / 1000
# ...
# 1.589
#
#  2023-07-29 07:35:15.972812  - random_milliseconds
# ...
# 1204
#
#  2023-07-29 07:35:15.972812  - random_milliseconds / 1000
# ...
# 1.204
#
#  2023-07-29 07:35:19.386568  - random_milliseconds
# ...
# 1327
#
#  2023-07-29 07:35:19.386568  - random_milliseconds / 1000
# ...
# 1.327
#
#  2023-07-29 07:35:22.406223  - random_milliseconds
# ...
# 1930
#
#  2023-07-29 07:35:22.406223  - random_milliseconds / 1000
# ...
# 1.93
#
#  2023-07-29 07:35:26.592729  - random_milliseconds
# ...
# 1589
#
#  2023-07-29 07:35:26.592729  - random_milliseconds / 1000
# ...
# 1.589
#
#  2023-07-29 07:35:30.860080  - random_milliseconds
# ...
# 1193
#
#  2023-07-29 07:35:30.860080  - random_milliseconds / 1000
# ...
# 1.193
#
#  2023-07-29 07:35:33.889974  - random_milliseconds
# ...
# 1535
#
#  2023-07-29 07:35:33.889974  - random_milliseconds / 1000
# ...
# 1.535
#
#  2023-07-29 07:35:35.438741  - random_milliseconds
# ...
# 1345
#
#  2023-07-29 07:35:35.440823  - random_milliseconds / 1000
# ...
# 1.345
