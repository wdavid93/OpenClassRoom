# %%
from pywinauto.application import Application
import psutil
import time
import random
import requests
import csv
import datetime
import fileinput

def delay_with_random_seconds():
#     # Génère un délai aléatoire entre 1 et 5 secondes
#     random_seconds = random.randint(2, 4)
# #     print(random_seconds)
    
#     # Pause l'exécution du programme pendant le délai aléatoire
#     time.sleep(random_seconds)
    random_milliseconds = random.randint(2000, 4000)  # Générer un nombre aléatoire en millisecondes entre 2000 et 4000
    print('\n', datetime.datetime.now(),' - random_milliseconds \n...')   
    print(random_milliseconds)
    print('\n', datetime.datetime.now(),' - random_milliseconds / 1000 \n...')   
    print(random_milliseconds / 1000)
    time.sleep(random_milliseconds / 1000)  # Utiliser la valeur en millisecondes dans time.sleep()
 #     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()

def attaquer_village(troupes_file):
    lines = []

    # Lire le fichier et stocker les lignes dans une liste
    with open(troupes_file, 'r') as file:
        lines = file.readlines()

    # Exclure la première ligne (en-têtes)
    headers = lines[0].strip().split(',')
    lines = lines[1:]

    # Trier les lignes par heure_attaque la plus ancienne
    lines = sorted(lines, key=lambda x: datetime.datetime.strptime(x.strip().split(',')[headers.index('heure_attaque')], "%Y-%m-%d %H:%M:%S"))

    # Parcourir les lignes triées
    for i, line in enumerate(lines):
        data = line.strip().split(',')
        village_depart = data[headers.index('village_depart')]
        village_attaquer = data[headers.index('village_attaquer')]

        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_attaquer}"
        firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()

        # Saisir les champs pour chaque type de troupe
        for header in headers:
            if header not in ['heure_attaque', 'village_depart', 'village_attaquer']:
                value = int(data[headers.index(header)])
                if value > 0:
                    zone = firefox.child_window(auto_id=header)
                    zone.type_keys(str(value))
                    delay_with_random_seconds()

        # Mettre à jour la colonne heure_attaque avec l'heure actuelle
        heure_attaque_index = headers.index('heure_attaque')
        heure_attaque = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        data[heure_attaque_index] = heure_attaque

        # Modifier la ligne dans la liste
        lines[i] = ','.join(data) + '\n'

        bouton = firefox.child_window(auto_id='target_attack')
        bouton.click()
        delay_with_random_seconds()

        bouton = firefox.child_window(auto_id='troop_confirm_submit')
        bouton.click()
        delay_with_random_seconds()

    # Réécrire le fichier avec les lignes modifiées
    with open(troupes_file, 'w') as file:
        file.write(','.join(headers) + '\n')  # Réécrire les en-têtes
        file.writelines(lines)  # Réécrire les lignes modifiées


# Vérifier si Firefox est en cours d'exécution
firefox_running = False
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_running = True
        firefox_pid = process.pid
        break

# Fermer Firefox si c'est le cas
if firefox_running:
    process = psutil.Process(firefox_pid)
    process.terminate()
#     time.sleep(5)
# Ouvrir Firefox
time.sleep(2)

app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Ouvrir Firefox
# app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Trouver le PID de Firefox
firefox_pid = None
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_pid = process.pid
        break

# Vérifier si Firefox est en cours d'exécution
if firefox_pid is None:
    print("Firefox n'est pas en cours d'exécution.")
else:
    # Attacher Pywinauto à la fenêtre Firefox
    app = Application(backend='uia').connect(process=firefox_pid)

    # Ouvrir une page web
#     firefox = app.window(title_re='.*Nouvel onglet*')
    firefox = app.window( class_name='MozillaWindowClass')

    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     time.sleep(5)

#     # Saisir les champs
#     zone1 = firefox.window(title='user')
#     zone1.type_keys('*test1')
#     zone1 = firefox.child_window(control_type="Edit", found_index=0, automation_id="user")
    zone1 = firefox.child_window(auto_id='user')

    zone1.type_keys('arion1')
    delay_with_random_seconds()

    zone2 = firefox.child_window(auto_id='password')
    zone2.type_keys('MiMa5158**')
    delay_with_random_seconds()
    # Cliquer sur le bouton
#     bouton = firefox.window(title='Connexion')
# #     bouton = firefox.child_window(auto_id='btn-login')
#     bouton = firefox.child_window(title='Connexion')
#     bouton.click()!
    bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
    bouton.invoke()
#     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
#     bouton.invoke()
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    
#     attaquer_village('3466', '3275', 'data/village.txt')
#     attaquer_village('3466', '3172', 'data/village.txt')
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
    delay_with_random_seconds()    
    # Fermer Firefox 
#     firefox.close()
# Out:
#  2023-06-06 19:32:08.249578  - random_milliseconds
# ...
# 2956
#
#  2023-06-06 19:32:08.249578  - random_milliseconds / 1000
# ...
# 2.956
#
#  2023-06-06 19:32:11.863401  - random_milliseconds
# ...
# 3947
#
#  2023-06-06 19:32:11.863401  - random_milliseconds / 1000
# ...
# 3.947
#
#  2023-06-06 19:32:16.280774  - random_milliseconds
# ...
# 2104
#
#  2023-06-06 19:32:16.281773  - random_milliseconds / 1000
# ...
# 2.104
#
#  2023-06-06 19:32:19.665726  - random_milliseconds
# ...
# 3803
#
#  2023-06-06 19:32:19.665726  - random_milliseconds / 1000
# ...
# 3.803
#
#  2023-06-06 19:32:25.150216  - random_milliseconds
# ...
# 2435
#
#  2023-06-06 19:32:25.150216  - random_milliseconds / 1000
# ...
# 2.435
#
#  2023-06-06 19:32:29.390141  - random_milliseconds
# ...
# 3315
#
#  2023-06-06 19:32:29.390141  - random_milliseconds / 1000
# ...
# 3.315
#
#  2023-06-06 19:32:33.770988  - random_milliseconds
# ...
# 3248
#
#  2023-06-06 19:32:33.770988  - random_milliseconds / 1000
# ...
# 3.248
#
#  2023-06-06 19:32:38.057347  - random_milliseconds
# ...
# 3458
#
#  2023-06-06 19:32:38.057347  - random_milliseconds / 1000
# ...
# 3.458
#
#  2023-06-06 19:32:43.163290  - random_milliseconds
# ...
# 2583
#
#  2023-06-06 19:32:43.163290  - random_milliseconds / 1000
# ...
# 2.583
#
#  2023-06-06 19:32:46.522050  - random_milliseconds
# ...
# 3748
#
#  2023-06-06 19:32:46.522050  - random_milliseconds / 1000
# ...
# 3.748
#
#  2023-06-06 19:32:52.057809  - random_milliseconds
# ...
# 3777
#
#  2023-06-06 19:32:52.057809  - random_milliseconds / 1000
# ...
# 3.777
#
#  2023-06-06 19:32:56.901108  - random_milliseconds
# ...
# 2441
#
#  2023-06-06 19:32:56.901108  - random_milliseconds / 1000
# ...
# 2.441
#
#  2023-06-06 19:33:00.415697  - random_milliseconds
# ...
# 3374
#
#  2023-06-06 19:33:00.415697  - random_milliseconds / 1000
# ...
# 3.374
#
#  2023-06-06 19:33:04.790467  - random_milliseconds
# ...
# 3463
#
#  2023-06-06 19:33:04.790467  - random_milliseconds / 1000
# ...
# 3.463
#
#  2023-06-06 19:33:08.988891  - random_milliseconds
# ...
# 2162
#
#  2023-06-06 19:33:08.988891  - random_milliseconds / 1000
# ...
# 2.162
#
#  2023-06-06 19:33:12.915187  - random_milliseconds
# ...
# 2210
#
#  2023-06-06 19:33:12.915187  - random_milliseconds / 1000
# ...
# 2.21
#
#  2023-06-06 19:33:16.082073  - random_milliseconds
# ...
# 3536
#
#  2023-06-06 19:33:16.082073  - random_milliseconds / 1000
# ...
# 3.536
#
#  2023-06-06 19:33:20.637994  - random_milliseconds
# ...
# 2833
#
#  2023-06-06 19:33:20.637994  - random_milliseconds / 1000
# ...
# 2.833
#
#  2023-06-06 19:33:24.480186  - random_milliseconds
# ...
# 3937
#
#  2023-06-06 19:33:24.480186  - random_milliseconds / 1000
# ...
# 3.937
#
#  2023-06-06 19:33:29.196907  - random_milliseconds
# ...
# 3555
#
#  2023-06-06 19:33:29.196907  - random_milliseconds / 1000
# ...
# 3.555
#
#  2023-06-06 19:33:34.517511  - random_milliseconds
# ...
# 3467
#
#  2023-06-06 19:33:34.518511  - random_milliseconds / 1000
# ...
# 3.467
#
#  2023-06-06 19:33:38.957317  - random_milliseconds
# ...
# 3513
#
#  2023-06-06 19:33:38.957317  - random_milliseconds / 1000
# ...
# 3.513
#
#  2023-06-06 19:33:43.464091  - random_milliseconds
# ...
# 2539
#
#  2023-06-06 19:33:43.464091  - random_milliseconds / 1000
# ...
# 2.539
#
#  2023-06-06 19:33:47.021279  - random_milliseconds
# ...
# 2431
#
#  2023-06-06 19:33:47.021279  - random_milliseconds / 1000
# ...
# 2.431
#
#  2023-06-06 19:33:50.278900  - random_milliseconds
# ...
# 2862
#
#  2023-06-06 19:33:50.278900  - random_milliseconds / 1000
# ...
# 2.862
#
#  2023-06-06 19:33:54.941859  - random_milliseconds
# ...
# 2221
#
#  2023-06-06 19:33:54.941859  - random_milliseconds / 1000
# ...
# 2.221
#
#  2023-06-06 19:33:58.147681  - random_milliseconds
# ...
# 2559
#
#  2023-06-06 19:33:58.147681  - random_milliseconds / 1000
# ...
# 2.559
#
#  2023-06-06 19:34:01.702644  - random_milliseconds
# ...
# 2233
#
#  2023-06-06 19:34:01.702644  - random_milliseconds / 1000
# ...
# 2.233
#
#  2023-06-06 19:34:05.208579  - random_milliseconds
# ...
# 3782
#
#  2023-06-06 19:34:05.209587  - random_milliseconds / 1000
# ...
# 3.782
#
#  2023-06-06 19:34:09.823034  - random_milliseconds
# ...
# 3432
#
#  2023-06-06 19:34:09.824033  - random_milliseconds / 1000
# ...
# 3.432
#
#  2023-06-06 19:34:15.020531  - random_milliseconds
# ...
# 2467
#
#  2023-06-06 19:34:15.020531  - random_milliseconds / 1000
# ...
# 2.467
#
#  2023-06-06 19:34:18.472846  - random_milliseconds
# ...
# 3063
#
#  2023-06-06 19:34:18.472846  - random_milliseconds / 1000
# ...
# 3.063
#
#  2023-06-06 19:34:22.595390  - random_milliseconds
# ...
# 3498
#
#  2023-06-06 19:34:22.595390  - random_milliseconds / 1000
# ...
# 3.498
#
#  2023-06-06 19:34:27.071782  - random_milliseconds
# ...
# 2231
#
#  2023-06-06 19:34:27.071782  - random_milliseconds / 1000
# ...
# 2.231
#
#  2023-06-06 19:34:30.053899  - random_milliseconds
# ...
# 2045
#
#  2023-06-06 19:34:30.053899  - random_milliseconds / 1000
# ...
# 2.045
#
#  2023-06-06 19:34:33.878358  - random_milliseconds
# ...
# 3467
#
#  2023-06-06 19:34:33.878358  - random_milliseconds / 1000
# ...
# 3.467
#
#  2023-06-06 19:34:38.386157  - random_milliseconds
# ...
# 3454
#
#  2023-06-06 19:34:38.386157  - random_milliseconds / 1000
# ...
# 3.454
#
#  2023-06-06 19:34:42.860671  - random_milliseconds
# ...
# 2520
#
#  2023-06-06 19:34:42.860671  - random_milliseconds / 1000
# ...
# 2.52
#
#  2023-06-06 19:34:46.400935  - random_milliseconds
# ...
# 2012
#
#  2023-06-06 19:34:46.400935  - random_milliseconds / 1000
# ...
# 2.012
#
#  2023-06-06 19:34:49.145034  - random_milliseconds
# ...
# 3165
#
#  2023-06-06 19:34:49.145034  - random_milliseconds / 1000
# ...
# 3.165
#
#  2023-06-06 19:34:54.115116  - random_milliseconds
# ...
# 3693
#
#  2023-06-06 19:34:54.115116  - random_milliseconds / 1000
# ...
# 3.693
#
#  2023-06-06 19:34:58.826731  - random_milliseconds
# ...
# 2786
#
#  2023-06-06 19:34:58.826731  - random_milliseconds / 1000
# ...
# 2.786
#
#  2023-06-06 19:35:02.639968  - random_milliseconds
# ...
# 3362
#
#  2023-06-06 19:35:02.639968  - random_milliseconds / 1000
# ...
# 3.362
#
#  2023-06-06 19:35:07.093211  - random_milliseconds
# ...
# 3843
#
#  2023-06-06 19:35:07.093211  - random_milliseconds / 1000
# ...
# 3.843
#
#  2023-06-06 19:35:11.981830  - random_milliseconds
# ...
# 2216
#
#  2023-06-06 19:35:11.981830  - random_milliseconds / 1000
# ...
# 2.216
#
#  2023-06-06 19:35:15.991041  - random_milliseconds
# ...
# 2410
#
#  2023-06-06 19:35:15.991041  - random_milliseconds / 1000
# ...
# 2.41
#
#  2023-06-06 19:35:19.398872  - random_milliseconds
# ...
# 3341
#
#  2023-06-06 19:35:19.398872  - random_milliseconds / 1000
# ...
# 3.341
#
#  2023-06-06 19:35:23.759021  - random_milliseconds
# ...
# 2694
#
#  2023-06-06 19:35:23.759021  - random_milliseconds / 1000
# ...
# 2.694
#
#  2023-06-06 19:35:27.515804  - random_milliseconds
# ...
# 2811
#
#  2023-06-06 19:35:27.515804  - random_milliseconds / 1000
# ...
# 2.811
#
#  2023-06-06 19:35:31.112268  - random_milliseconds
# ...
# 2031
#
#  2023-06-06 19:35:31.112268  - random_milliseconds / 1000
# ...
# 2.031
#
#  2023-06-06 19:35:34.912617  - random_milliseconds
# ...
# 3309
#
#  2023-06-06 19:35:34.912617  - random_milliseconds / 1000
# ...
# 3.309
#
#  2023-06-06 19:35:39.270741  - random_milliseconds
# ...
# 2479
#
#  2023-06-06 19:35:39.270741  - random_milliseconds / 1000
# ...
# 2.479
#
#  2023-06-06 19:35:42.906580  - random_milliseconds
# ...
# 3794
#
#  2023-06-06 19:35:42.906580  - random_milliseconds / 1000
# ...
# 3.794
#
#  2023-06-06 19:35:47.773243  - random_milliseconds
# ...
# 2071
#
#  2023-06-06 19:35:47.773243  - random_milliseconds / 1000
# ...
# 2.071
#
#  2023-06-06 19:35:50.589461  - random_milliseconds
# ...
# 2151
#
#  2023-06-06 19:35:50.589461  - random_milliseconds / 1000
# ...
# 2.151
#
#  2023-06-06 19:35:54.489603  - random_milliseconds
# ...
# 3435
#
#  2023-06-06 19:35:54.489603  - random_milliseconds / 1000
# ...
# 3.435
#
#  2023-06-06 19:35:59.172326  - random_milliseconds
# ...
# 3553
#
#  2023-06-06 19:35:59.172326  - random_milliseconds / 1000
# ...
# 3.553
#
#  2023-06-06 19:36:03.866572  - random_milliseconds
# ...
# 2330
#
#  2023-06-06 19:36:03.866572  - random_milliseconds / 1000
# ...
# 2.33
#
#  2023-06-06 19:36:07.373174  - random_milliseconds
# ...
# 2201
#
#  2023-06-06 19:36:07.373174  - random_milliseconds / 1000
# ...
# 2.201
#
#  2023-06-06 19:36:10.421666  - random_milliseconds
# ...
# 3324
#
#  2023-06-06 19:36:10.421666  - random_milliseconds / 1000
# ...
# 3.324
#
#  2023-06-06 19:36:15.539541  - random_milliseconds
# ...
# 2943
#
#  2023-06-06 19:36:15.539541  - random_milliseconds / 1000
# ...
# 2.943
#
#  2023-06-06 19:36:19.805037  - random_milliseconds
# ...
# 2410
#
#  2023-06-06 19:36:19.805037  - random_milliseconds / 1000
# ...
# 2.41
#
#  2023-06-06 19:36:23.343700  - random_milliseconds
# ...
# 2372
#
#  2023-06-06 19:36:23.343700  - random_milliseconds / 1000
# ...
# 2.372
#  2023-06-06 19:36:26.852789  - random_milliseconds
# ...
# 3057
#
#  2023-06-06 19:36:26.852789  - random_milliseconds / 1000
# ...
# 3.057
#
#  2023-06-06 19:36:30.665245  - random_milliseconds
# ...
# 3078
#
#  2023-06-06 19:36:30.665245  - random_milliseconds / 1000
# ...
# 3.078
#
#  2023-06-06 19:36:35.521240  - random_milliseconds
# ...
# 2575
#
#  2023-06-06 19:36:35.521240  - random_milliseconds / 1000
# ...
# 2.575
#
#  2023-06-06 19:36:39.255509  - random_milliseconds
# ...
# 3412
#
#  2023-06-06 19:36:39.255509  - random_milliseconds / 1000
# ...
# 3.412
#
#  2023-06-06 19:36:43.755321  - random_milliseconds
# ...
# 2853
#
#  2023-06-06 19:36:43.755321  - random_milliseconds / 1000
# ...
# 2.853
#
#  2023-06-06 19:36:47.788780  - random_milliseconds
# ...
# 3225
#
#  2023-06-06 19:36:47.788780  - random_milliseconds / 1000
# ...
# 3.225
#
#  2023-06-06 19:36:51.814996  - random_milliseconds
# ...
# 2584
#
#  2023-06-06 19:36:51.814996  - random_milliseconds / 1000
# ...
# 2.584
#
#  2023-06-06 19:36:56.179241  - random_milliseconds
# ...
# 2226
#
#  2023-06-06 19:36:56.179241  - random_milliseconds / 1000
# ...
# 2.226
#
#  2023-06-06 19:36:59.579169  - random_milliseconds
# ...
# 2193
#
#  2023-06-06 19:36:59.579169  - random_milliseconds / 1000
# ...
# 2.193
#
#  2023-06-06 19:37:02.974000  - random_milliseconds
# ...
# 3510
#
#  2023-06-06 19:37:02.974000  - random_milliseconds / 1000
# ...
# 3.51
#
#  2023-06-06 19:37:07.569599  - random_milliseconds
# ...
# 2498
#
#  2023-06-06 19:37:07.570597  - random_milliseconds / 1000
# ...
# 2.498
#
#  2023-06-06 19:37:10.874542  - random_milliseconds
# ...
# 3387
#
#  2023-06-06 19:37:10.875540  - random_milliseconds / 1000
# ...
# 3.387
#
#  2023-06-06 19:37:16.058284  - random_milliseconds
# ...
# 2708
#
#  2023-06-06 19:37:16.059278  - random_milliseconds / 1000
# ...
# 2.708
#
#  2023-06-06 19:37:20.164879  - random_milliseconds
# ...
# 2269
#
#  2023-06-06 19:37:20.164879  - random_milliseconds / 1000
# ...
# 2.269
#
#  2023-06-06 19:37:23.591533  - random_milliseconds
# ...
# 2478
#
#  2023-06-06 19:37:23.591533  - random_milliseconds / 1000
# ...
# 2.478
#
#  2023-06-06 19:37:27.212491  - random_milliseconds
# ...
# 3770
#
#  2023-06-06 19:37:27.212491  - random_milliseconds / 1000
# ...
# 3.77
#
#  2023-06-06 19:37:31.732307  - random_milliseconds
# ...
# 2150
#
#  2023-06-06 19:37:31.732307  - random_milliseconds / 1000
# ...
# 2.15
#
#  2023-06-06 19:37:35.674906  - random_milliseconds
# ...
# 2292
#
#  2023-06-06 19:37:35.674906  - random_milliseconds / 1000
# ...
# 2.292
#
#  2023-06-06 19:37:39.099093  - random_milliseconds
# ...
# 3652
#
#  2023-06-06 19:37:39.099093  - random_milliseconds / 1000
# ...
# 3.652
#
#  2023-06-06 19:37:43.886027  - random_milliseconds
# ...
# 2955
#
#  2023-06-06 19:37:43.886027  - random_milliseconds / 1000
# ...
# 2.955
#
#  2023-06-06 19:37:47.961811  - random_milliseconds
# ...
# 2579
#
#  2023-06-06 19:37:47.961811  - random_milliseconds / 1000
# ...
# 2.579
#
#  2023-06-06 19:37:51.367717  - random_milliseconds
# ...
# 3317
#
#  2023-06-06 19:37:51.367717  - random_milliseconds / 1000
# ...
# 3.317
#
#  2023-06-06 19:37:56.439538  - random_milliseconds
# ...
# 3679
#
#  2023-06-06 19:37:56.439538  - random_milliseconds / 1000
# ...
# 3.679
#
#  2023-06-06 19:38:01.288155  - random_milliseconds
# ...
# 3162
#
#  2023-06-06 19:38:01.288155  - random_milliseconds / 1000
# ...
# 3.162
#
#  2023-06-06 19:38:05.571980  - random_milliseconds
# ...
# 2085
#
#  2023-06-06 19:38:05.571980  - random_milliseconds / 1000
# ...
# 2.085
#
#  2023-06-06 19:38:08.874536  - random_milliseconds
# ...
# 2212
#
#  2023-06-06 19:38:08.875528  - random_milliseconds / 1000
# ...
# 2.212
#
#  2023-06-06 19:38:11.892275  - random_milliseconds
# ...
# 3599
#
#  2023-06-06 19:38:11.892275  - random_milliseconds / 1000
# ...
# 3.599
#
#  2023-06-06 19:38:17.292606  - random_milliseconds
# ...
# 3389
#
#  2023-06-06 19:38:17.292606  - random_milliseconds / 1000
# ...
# 3.389
#
#  2023-06-06 19:38:22.342136  - random_milliseconds
# ...
# 3488
#
#  2023-06-06 19:38:22.342136  - random_milliseconds / 1000
# ...
# 3.488
#
#  2023-06-06 19:38:26.974816  - random_milliseconds
# ...
# 3640
#
#  2023-06-06 19:38:26.974816  - random_milliseconds / 1000
# ...
# 3.64
#
#  2023-06-06 19:38:31.766743  - random_milliseconds
# ...
# 2402
#
#  2023-06-06 19:38:31.766743  - random_milliseconds / 1000
# ...
# 2.402
#
#  2023-06-06 19:38:34.891231  - random_milliseconds
# ...
# 3315
#
#  2023-06-06 19:38:34.891231  - random_milliseconds / 1000
# ...
# 3.315
#
#  2023-06-06 19:38:39.979043  - random_milliseconds
# ...
# 3770
#
#  2023-06-06 19:38:39.980041  - random_milliseconds / 1000
# ...
# 3.77
#
#  2023-06-06 19:38:44.966714  - random_milliseconds
# ...
# 3853
#
#  2023-06-06 19:38:44.966714  - random_milliseconds / 1000
# ...
# 3.853
#
#  2023-06-06 19:38:50.077824  - random_milliseconds
# ...
# 3116
#
#  2023-06-06 19:38:50.077824  - random_milliseconds / 1000
# ...
# 3.116
#
#  2023-06-06 19:38:54.474206  - random_milliseconds
# ...
# 2630
#
#  2023-06-06 19:38:54.474206  - random_milliseconds / 1000
# ...
# 2.63
#
#  2023-06-06 19:38:57.918391  - random_milliseconds
# ...
# 3247
#
#  2023-06-06 19:38:57.918391  - random_milliseconds / 1000
# ...
# 3.247
#
#  2023-06-06 19:39:02.948242  - random_milliseconds
# ...
# 2896
#
#  2023-06-06 19:39:02.948242  - random_milliseconds / 1000
# ...
# 2.896
#
#  2023-06-06 19:39:07.048441  - random_milliseconds
# ...
# 2828
#
#  2023-06-06 19:39:07.048441  - random_milliseconds / 1000
# ...
# 2.828
#
#  2023-06-06 19:39:11.269765  - random_milliseconds
# ...
# 3909
#
#  2023-06-06 19:39:11.269765  - random_milliseconds / 1000
# ...
# 3.909
#
#  2023-06-06 19:39:16.536094  - random_milliseconds
# ...
# 3052
#
#  2023-06-06 19:39:16.537075  - random_milliseconds / 1000
# ...
# 3.052
#
#  2023-06-06 19:39:20.455800  - random_milliseconds
# ...
# 3063
#
#  2023-06-06 19:39:20.455800  - random_milliseconds / 1000
# ...
# 3.063
#
#  2023-06-06 19:39:25.295308  - random_milliseconds
# ...
# 2643
#
#  2023-06-06 19:39:25.295308  - random_milliseconds / 1000
# ...
# 2.643
#
#  2023-06-06 19:39:29.501048  - random_milliseconds
# ...
# 2013
#
#  2023-06-06 19:39:29.501048  - random_milliseconds / 1000
# ...
# 2.013
#
#  2023-06-06 19:39:32.717934  - random_milliseconds
# ...
# 2583
#
#  2023-06-06 19:39:32.717934  - random_milliseconds / 1000
# ...
# 2.583
#
#  2023-06-06 19:39:36.563259  - random_milliseconds
# ...
# 2539
#
#  2023-06-06 19:39:36.563259  - random_milliseconds / 1000
# ...
# 2.539
#
#  2023-06-06 19:39:39.863797  - random_milliseconds
# ...
# 2926
#
#  2023-06-06 19:39:39.863797  - random_milliseconds / 1000
# ...
# 2.926
#
#  2023-06-06 19:39:44.561179  - random_milliseconds
# ...
# 2040
#
#  2023-06-06 19:39:44.561179  - random_milliseconds / 1000
# ...
# 2.04
#
#  2023-06-06 19:39:47.727001  - random_milliseconds
# ...
# 3327
#
#  2023-06-06 19:39:47.727001  - random_milliseconds / 1000
# ...
# 3.327
#
#  2023-06-06 19:39:52.249148  - random_milliseconds
# ...
# 2940
#
#  2023-06-06 19:39:52.249148  - random_milliseconds / 1000
# ...
# 2.94
#
#  2023-06-06 19:39:56.350714  - random_milliseconds
# ...
# 2606
#
#  2023-06-06 19:39:56.350714  - random_milliseconds / 1000
# ...
# 2.606
#
#  2023-06-06 19:39:59.727395  - random_milliseconds
# ...
# 3324
#
#  2023-06-06 19:39:59.727395  - random_milliseconds / 1000
# ...
# 3.324
#
#  2023-06-06 19:40:04.837464  - random_milliseconds
# ...
# 2184
#
#  2023-06-06 19:40:04.837464  - random_milliseconds / 1000
# ...
# 2.184
#
#  2023-06-06 19:40:08.226076  - random_milliseconds
# ...
# 3369
#
#  2023-06-06 19:40:08.226076  - random_milliseconds / 1000
# ...
# 3.369
#
#  2023-06-06 19:40:12.848934  - random_milliseconds
# ...
# 2746
#
#  2023-06-06 19:40:12.848934  - random_milliseconds / 1000
# ...
# 2.746
#
#  2023-06-06 19:40:16.853863  - random_milliseconds
# ...
# 3693
#
#  2023-06-06 19:40:16.853863  - random_milliseconds / 1000
# ...
# 3.693
#
#  2023-06-06 19:40:21.759068  - random_milliseconds
# ...
# 2648
#
#  2023-06-06 19:40:21.759068  - random_milliseconds / 1000
# ...
# 2.648
#
#  2023-06-06 19:40:26.184830  - random_milliseconds
# ...
# 3039
#
#  2023-06-06 19:40:26.184830  - random_milliseconds / 1000
# ...
# 3.039
#
#  2023-06-06 19:40:30.405307  - random_milliseconds
# ...
# 3589
#
#  2023-06-06 19:40:30.405307  - random_milliseconds / 1000
# ...
# 3.589
#
#  2023-06-06 19:40:35.155005  - random_milliseconds
# ...
# 2502
#
#  2023-06-06 19:40:35.155005  - random_milliseconds / 1000
# ...
# 2.502
#
#  2023-06-06 19:40:38.904573  - random_milliseconds
# ...
# 3654
#
#  2023-06-06 19:40:38.904573  - random_milliseconds / 1000
# ...
# 3.654
#
#  2023-06-06 19:40:43.307009  - random_milliseconds
# ...
# 2812
#
#  2023-06-06 19:40:43.307009  - random_milliseconds / 1000
# ...
# 2.812
#
#  2023-06-06 19:40:47.919604  - random_milliseconds
# ...
# 3650
#
#  2023-06-06 19:40:47.919604  - random_milliseconds / 1000
# ...
# 3.65
#  2023-06-06 19:40:52.781879  - random_milliseconds
# ...
# 3457
#
#  2023-06-06 19:40:52.781879  - random_milliseconds / 1000
# ...
# 3.457
#
#  2023-06-06 19:40:57.442657  - random_milliseconds
# ...
# 2873
#
#  2023-06-06 19:40:57.442657  - random_milliseconds / 1000
# ...
# 2.873
#
#  2023-06-06 19:41:01.499767  - random_milliseconds
# ...
# 2308
#
#  2023-06-06 19:41:01.500752  - random_milliseconds / 1000
# ...
# 2.308
#
#  2023-06-06 19:41:04.625796  - random_milliseconds
# ...
# 3083
#
#  2023-06-06 19:41:04.625796  - random_milliseconds / 1000
# ...
# 3.083
#
#  2023-06-06 19:41:09.490679  - random_milliseconds
# ...
# 2276
#
#  2023-06-06 19:41:09.490679  - random_milliseconds / 1000
# ...
# 2.276
#
#  2023-06-06 19:41:12.977546  - random_milliseconds
# ...
# 3920
#
#  2023-06-06 19:41:12.977546  - random_milliseconds / 1000
# ...
# 3.92
#
#  2023-06-06 19:41:18.267756  - random_milliseconds
# ...
# 3333
#
#  2023-06-06 19:41:18.267756  - random_milliseconds / 1000
# ...
# 3.333
#
#  2023-06-06 19:41:23.369201  - random_milliseconds
# ...
# 3848
#
#  2023-06-06 19:41:23.369201  - random_milliseconds / 1000
# ...
# 3.848
#
#  2023-06-06 19:41:28.075286  - random_milliseconds
# ...
# 2986
#
#  2023-06-06 19:41:28.075286  - random_milliseconds / 1000
# ...
# 2.986
#
#  2023-06-06 19:41:32.851721  - random_milliseconds
# ...
# 3223
#
#  2023-06-06 19:41:32.851721  - random_milliseconds / 1000
# ...
# 3.223
#
#  2023-06-06 19:41:37.320608  - random_milliseconds
# ...
# 3428
#
#  2023-06-06 19:41:37.320608  - random_milliseconds / 1000
# ...
# 3.428
#
#  2023-06-06 19:41:42.011246  - random_milliseconds
# ...
# 2405
#
#  2023-06-06 19:41:42.011246  - random_milliseconds / 1000
# ...
# 2.405
#
#  2023-06-06 19:41:45.356126  - random_milliseconds
# ...
# 2141
#
#  2023-06-06 19:41:45.356126  - random_milliseconds / 1000
# ...
# 2.141
#
#  2023-06-06 19:41:48.222552  - random_milliseconds
# ...
# 2185
#
#  2023-06-06 19:41:48.222552  - random_milliseconds / 1000
# ...
# 2.185
#
#  2023-06-06 19:41:52.215860  - random_milliseconds
# ...
# 2095
#
#  2023-06-06 19:41:52.215860  - random_milliseconds / 1000
# ...
# 2.095
#
#  2023-06-06 19:41:55.561205  - random_milliseconds
# ...
# 3731
#
#  2023-06-06 19:41:55.561205  - random_milliseconds / 1000
# ...
# 3.731
#
#  2023-06-06 19:42:00.519100  - random_milliseconds
# ...
# 3530
#
#  2023-06-06 19:42:00.519100  - random_milliseconds / 1000
# ...
# 3.53
#
#  2023-06-06 19:42:05.273745  - random_milliseconds
# ...
# 2681
#
#  2023-06-06 19:42:05.273745  - random_milliseconds / 1000
# ...
# 2.681
#
#  2023-06-06 19:42:08.701355  - random_milliseconds
# ...
# 3305
#
#  2023-06-06 19:42:08.701355  - random_milliseconds / 1000
# ...
# 3.305
#
#  2023-06-06 19:42:13.790139  - random_milliseconds
# ...
# 3763
#
#  2023-06-06 19:42:13.790139  - random_milliseconds / 1000
# ...
# 3.763
#
#  2023-06-06 19:42:18.880586  - random_milliseconds
# ...
# 2239
#
#  2023-06-06 19:42:18.880586  - random_milliseconds / 1000
# ...
# 2.239
#
#  2023-06-06 19:42:22.894840  - random_milliseconds
# ...
# 3781
#
#  2023-06-06 19:42:22.894840  - random_milliseconds / 1000
# ...
# 3.781
#
#  2023-06-06 19:42:27.988333  - random_milliseconds
# ...
# 3104
#
#  2023-06-06 19:42:27.988333  - random_milliseconds / 1000
# ...
# 3.104
#
#  2023-06-06 19:42:31.925478  - random_milliseconds
# ...
# 3837
#
#  2023-06-06 19:42:31.925478  - random_milliseconds / 1000
# ...
# 3.837
#
#  2023-06-06 19:42:37.531016  - random_milliseconds
# ...
# 2592
#
#  2023-06-06 19:42:37.531016  - random_milliseconds / 1000
# ...
# 2.592
#
#  2023-06-06 19:42:41.458001  - random_milliseconds
# ...
# 2812
#
#  2023-06-06 19:42:41.458001  - random_milliseconds / 1000
# ...
# 2.812
#
#  2023-06-06 19:42:45.484007  - random_milliseconds
# ...
# 2155
#
#  2023-06-06 19:42:45.484007  - random_milliseconds / 1000
# ...
# 2.155
#
#  2023-06-06 19:42:48.858354  - random_milliseconds
# ...
# 2674
#
#  2023-06-06 19:42:48.859366  - random_milliseconds / 1000
# ...
# 2.674
#
#  2023-06-06 19:42:52.345990  - random_milliseconds
# ...
# 3692
#
#  2023-06-06 19:42:52.345990  - random_milliseconds / 1000
# ...
# 3.692
#
#  2023-06-06 19:42:57.854780  - random_milliseconds
# ...
# 2613
#
#  2023-06-06 19:42:57.854780  - random_milliseconds / 1000
# ...
# 2.613
#
#  2023-06-06 19:43:01.721806  - random_milliseconds
# ...
# 2999
#
#  2023-06-06 19:43:01.721806  - random_milliseconds / 1000
# ...
# 2.999
#
#  2023-06-06 19:43:06.001317  - random_milliseconds
# ...
# 2893
#
#  2023-06-06 19:43:06.002315  - random_milliseconds / 1000
# ...
# 2.893
#
#  2023-06-06 19:43:10.194987  - random_milliseconds
# ...
# 2204
#
#  2023-06-06 19:43:10.194987  - random_milliseconds / 1000
# ...
# 2.204
#
#  2023-06-06 19:43:13.171251  - random_milliseconds
# ...
# 3152
#
#  2023-06-06 19:43:13.172249  - random_milliseconds / 1000
# ...
# 3.152
#
#  2023-06-06 19:43:18.102881  - random_milliseconds
# ...
# 2061
#
#  2023-06-06 19:43:18.102881  - random_milliseconds / 1000
# ...
# 2.061
#
#  2023-06-06 19:43:22.031307  - random_milliseconds
# ...
# 2938
#
#  2023-06-06 19:43:22.031307  - random_milliseconds / 1000
# ...
# 2.938
#
#  2023-06-06 19:43:26.345059  - random_milliseconds
# ...
# 2784
#
#  2023-06-06 19:43:26.345059  - random_milliseconds / 1000
# ...
# 2.784
#
#  2023-06-06 19:43:30.483167  - random_milliseconds
# ...
# 2444
#
#  2023-06-06 19:43:30.483167  - random_milliseconds / 1000
# ...
# 2.444
#
#  2023-06-06 19:43:33.711846  - random_milliseconds
# ...
# 3728
#
#  2023-06-06 19:43:33.711846  - random_milliseconds / 1000
# ...
# 3.728
#
#  2023-06-06 19:43:39.232854  - random_milliseconds
# ...
# 3819
#
#  2023-06-06 19:43:39.232854  - random_milliseconds / 1000
# ...
# 3.819
#
#  2023-06-06 19:43:44.338290  - random_milliseconds
# ...
# 2306
#
#  2023-06-06 19:43:44.338290  - random_milliseconds / 1000
# ...
# 2.306
#
#  2023-06-06 19:43:47.987145  - random_milliseconds
# ...
# 3887
#
#  2023-06-06 19:43:47.987145  - random_milliseconds / 1000
# ...
# 3.887
#
#  2023-06-06 19:43:53.277618  - random_milliseconds
# ...
# 3905
#
#  2023-06-06 19:43:53.278624  - random_milliseconds / 1000
# ...
# 3.905
#
#  2023-06-06 19:43:57.964285  - random_milliseconds
# ...
# 2327
#
#  2023-06-06 19:43:57.964285  - random_milliseconds / 1000
# ...
# 2.327
#
#  2023-06-06 19:44:02.099500  - random_milliseconds
# ...
# 3933
#
#  2023-06-06 19:44:02.100499  - random_milliseconds / 1000
# ...
# 3.933
#
#  2023-06-06 19:44:07.441307  - random_milliseconds
# ...
# 3907
#
#  2023-06-06 19:44:07.441307  - random_milliseconds / 1000
# ...
# 3.907
#
#  2023-06-06 19:44:12.783027  - random_milliseconds
# ...
# 3551
#
#  2023-06-06 19:44:12.783027  - random_milliseconds / 1000
# ...
# 3.551
#
#  2023-06-06 19:44:17.991219  - random_milliseconds
# ...
# 2776
#
#  2023-06-06 19:44:17.991219  - random_milliseconds / 1000
# ...
# 2.776
#
#  2023-06-06 19:44:21.526531  - random_milliseconds
# ...
# 3015
#
#  2023-06-06 19:44:21.526531  - random_milliseconds / 1000
# ...
# 3.015
#
#  2023-06-06 19:44:26.290724  - random_milliseconds
# ...
# 2607
#
#  2023-06-06 19:44:26.290724  - random_milliseconds / 1000
# ...
# 2.607
#
#  2023-06-06 19:44:30.375003  - random_milliseconds
# ...
# 2939
#
#  2023-06-06 19:44:30.375003  - random_milliseconds / 1000
# ...
# 2.939
#
#  2023-06-06 19:44:34.577592  - random_milliseconds
# ...
# 2296
#
#  2023-06-06 19:44:34.577592  - random_milliseconds / 1000
# ...
# 2.296
#
#  2023-06-06 19:44:38.143526  - random_milliseconds
# ...
# 2459
#
#  2023-06-06 19:44:38.143526  - random_milliseconds / 1000
# ...
# 2.459
#
#  2023-06-06 19:44:41.388568  - random_milliseconds
# ...
# 3274
#
#  2023-06-06 19:44:41.389565  - random_milliseconds / 1000
# ...
# 3.274
#
#  2023-06-06 19:44:46.448340  - random_milliseconds
# ...
# 3788
#
#  2023-06-06 19:44:46.448340  - random_milliseconds / 1000
# ...
# 3.788
#
#  2023-06-06 19:44:51.532098  - random_milliseconds
# ...
# 2485
#
#  2023-06-06 19:44:51.532098  - random_milliseconds / 1000
# ...
# 2.485
#
#  2023-06-06 19:44:55.318316  - random_milliseconds
# ...
# 2953
#
#  2023-06-06 19:44:55.318316  - random_milliseconds / 1000
# ...
# 2.953
#
#  2023-06-06 19:44:59.583792  - random_milliseconds
# ...
# 2986
#
#  2023-06-06 19:44:59.584782  - random_milliseconds / 1000
# ...
# 2.986
#
#  2023-06-06 19:45:03.382285  - random_milliseconds
# ...
# 3321
#
#  2023-06-06 19:45:03.382285  - random_milliseconds / 1000
# ...
# 3.321
#
#  2023-06-06 19:45:08.466955  - random_milliseconds
# ...
# 3500
#
#  2023-06-06 19:45:08.466955  - random_milliseconds / 1000
# ...
# 3.5
#
#  2023-06-06 19:45:13.228947  - random_milliseconds
# ...
# 3250
#
#  2023-06-06 19:45:13.228947  - random_milliseconds / 1000
# ...
# 3.25
#
#  2023-06-06 19:45:18.326615  - random_milliseconds
# ...
# 3703
#
#  2023-06-06 19:45:18.326615  - random_milliseconds / 1000
# ...
# 3.703
#
#  2023-06-06 19:45:23.420326  - random_milliseconds
# ...
# 2008
#
#  2023-06-06 19:45:23.420326  - random_milliseconds / 1000
# ...
# 2.008
#  2023-06-06 19:45:26.179360  - random_milliseconds
# ...
# 2441
#
#  2023-06-06 19:45:26.179360  - random_milliseconds / 1000
# ...
# 2.441
#
#  2023-06-06 19:45:30.381730  - random_milliseconds
# ...
# 3924
#
#  2023-06-06 19:45:30.381730  - random_milliseconds / 1000
# ...
# 3.924
#
#  2023-06-06 19:45:35.808684  - random_milliseconds
# ...
# 3988
#
#  2023-06-06 19:45:35.808684  - random_milliseconds / 1000
# ...
# 3.988
#
#  2023-06-06 19:45:41.231627  - random_milliseconds
# ...
# 2131
#
#  2023-06-06 19:45:41.231627  - random_milliseconds / 1000
# ...
# 2.131
#
#  2023-06-06 19:45:44.803033  - random_milliseconds
# ...
# 3022
#
#  2023-06-06 19:45:44.803033  - random_milliseconds / 1000
# ...
# 3.022
#
#  2023-06-06 19:45:48.646228  - random_milliseconds
# ...
# 3548
#
#  2023-06-06 19:45:48.646228  - random_milliseconds / 1000
# ...
# 3.548
#
#  2023-06-06 19:45:53.986741  - random_milliseconds
# ...
# 2036
#
#  2023-06-06 19:45:53.986741  - random_milliseconds / 1000
# ...
# 2.036
#
#  2023-06-06 19:45:57.333412  - random_milliseconds
# ...
# 3343
#
#  2023-06-06 19:45:57.333412  - random_milliseconds / 1000
# ...
# 3.343
#
#  2023-06-06 19:46:02.015388  - random_milliseconds
# ...
# 2710
#
#  2023-06-06 19:46:02.015388  - random_milliseconds / 1000
# ...
# 2.71
#
#  2023-06-06 19:46:06.511513  - random_milliseconds
# ...
# 2411
#
#  2023-06-06 19:46:06.511513  - random_milliseconds / 1000
# ...
# 2.411
#
#  2023-06-06 19:46:09.702144  - random_milliseconds
# ...
# 2679
#
#  2023-06-06 19:46:09.702144  - random_milliseconds / 1000
# ...
# 2.679
#
#  2023-06-06 19:46:14.177225  - random_milliseconds
# ...
# 2435
#
#  2023-06-06 19:46:14.177225  - random_milliseconds / 1000
# ...
# 2.435
#
#  2023-06-06 19:46:17.996921  - random_milliseconds
# ...
# 3545
#
#  2023-06-06 19:46:17.996921  - random_milliseconds / 1000
# ...
# 3.545
#
#  2023-06-06 19:46:23.001218  - random_milliseconds
# ...
# 2182
#
#  2023-06-06 19:46:23.001218  - random_milliseconds / 1000
# ...
# 2.182
#
#  2023-06-06 19:46:26.568876  - random_milliseconds
# ...
# 2386
#
#  2023-06-06 19:46:26.568876  - random_milliseconds / 1000
# ...
# 2.386
#
#  2023-06-06 19:46:29.749345  - random_milliseconds
# ...
# 3445
#
#  2023-06-06 19:46:29.749345  - random_milliseconds / 1000
# ...
# 3.445
#
#  2023-06-06 19:46:34.980671  - random_milliseconds
# ...
# 3762
#
#  2023-06-06 19:46:34.980671  - random_milliseconds / 1000
# ...
# 3.762
#
#  2023-06-06 19:46:40.244039  - random_milliseconds
# ...
# 2541
#
#  2023-06-06 19:46:40.244039  - random_milliseconds / 1000
# ...
# 2.541
#
#  2023-06-06 19:46:44.223602  - random_milliseconds
# ...
# 3305
#
#  2023-06-06 19:46:44.223602  - random_milliseconds / 1000
# ...
# 3.305
#
#  2023-06-06 19:46:48.960057  - random_milliseconds
# ...
# 2368
#
#  2023-06-06 19:46:48.960057  - random_milliseconds / 1000
# ...
# 2.368
#
#  2023-06-06 19:46:52.104271  - random_milliseconds
# ...
# 3094
#
#  2023-06-06 19:46:52.104271  - random_milliseconds / 1000
# ...
# 3.094
#
#  2023-06-06 19:46:56.967014  - random_milliseconds
# ...
# 2299
#
#  2023-06-06 19:46:56.967014  - random_milliseconds / 1000
# ...
# 2.299
#
#  2023-06-06 19:47:00.944609  - random_milliseconds
# ...
# 3957
#
#  2023-06-06 19:47:00.944609  - random_milliseconds / 1000
# ...
# 3.957
#
#  2023-06-06 19:47:06.270559  - random_milliseconds
# ...
# 3029
#
#  2023-06-06 19:47:06.270559  - random_milliseconds / 1000
# ...
# 3.029
#
#  2023-06-06 19:47:10.745473  - random_milliseconds
# ...
# 2309
#
#  2023-06-06 19:47:10.745473  - random_milliseconds / 1000
# ...
# 2.309
#
#  2023-06-06 19:47:13.844363  - random_milliseconds
# ...
# 2727
#
#  2023-06-06 19:47:13.844363  - random_milliseconds / 1000
# ...
# 2.727
#
#  2023-06-06 19:47:18.335800  - random_milliseconds
# ...
# 2428
#
#  2023-06-06 19:47:18.335800  - random_milliseconds / 1000
# ...
# 2.428
#
#  2023-06-06 19:47:22.086588  - random_milliseconds
# ...
# 3547
#
#  2023-06-06 19:47:22.086588  - random_milliseconds / 1000
# ...
# 3.547
#
#  2023-06-06 19:47:27.146081  - random_milliseconds
# ...
# 2116
#
#  2023-06-06 19:47:27.146081  - random_milliseconds / 1000
# ...
# 2.116
#
#  2023-06-06 19:47:30.593517  - random_milliseconds
# ...
# 3149
#
#  2023-06-06 19:47:30.593517  - random_milliseconds / 1000
# ...
# 3.149
#
#  2023-06-06 19:47:34.498133  - random_milliseconds
# ...
# 2442
#
#  2023-06-06 19:47:34.498133  - random_milliseconds / 1000
# ...
# 2.442
#
#  2023-06-06 19:47:38.732148  - random_milliseconds
# ...
# 3554
#
#  2023-06-06 19:47:38.732148  - random_milliseconds / 1000
# ...
# 3.554
#
#  2023-06-06 19:47:43.769697  - random_milliseconds
# ...
# 3340
#
#  2023-06-06 19:47:43.769697  - random_milliseconds / 1000
# ...
# 3.34
#
#  2023-06-06 19:47:48.451950  - random_milliseconds
# ...
# 2387
#
#  2023-06-06 19:47:48.451950  - random_milliseconds / 1000
# ...
# 2.387
#
#  2023-06-06 19:47:52.646453  - random_milliseconds
# ...
# 2190
#
#  2023-06-06 19:47:52.646453  - random_milliseconds / 1000
# ...
# 2.19
#
#  2023-06-06 19:47:55.637298  - random_milliseconds
# ...
# 2198
#
#  2023-06-06 19:47:55.637298  - random_milliseconds / 1000
# ...
# 2.198
#
#  2023-06-06 19:47:59.649932  - random_milliseconds
# ...
# 3852
#
#  2023-06-06 19:47:59.649932  - random_milliseconds / 1000
# ...
# 3.852
#
#  2023-06-06 19:48:04.904742  - random_milliseconds
# ...
# 3238
#
#  2023-06-06 19:48:04.904742  - random_milliseconds / 1000
# ...
# 3.238
#
#  2023-06-06 19:48:09.511340  - random_milliseconds
# ...
# 2964
#
#  2023-06-06 19:48:09.512305  - random_milliseconds / 1000
# ...
# 2.964
#
#  2023-06-06 19:48:13.856778  - random_milliseconds
# ...
# 3805
#
#  2023-06-06 19:48:13.856778  - random_milliseconds / 1000
# ...
# 3.805
#
#  2023-06-06 19:48:18.399584  - random_milliseconds
# ...
# 3412
#
#  2023-06-06 19:48:18.399584  - random_milliseconds / 1000
# ...
# 3.412
#
#  2023-06-06 19:48:23.556318  - random_milliseconds
# ...
# 2953
#
#  2023-06-06 19:48:23.556318  - random_milliseconds / 1000
# ...
# 2.953
#
#  2023-06-06 19:48:27.953808  - random_milliseconds
# ...
# 2092
#
#  2023-06-06 19:48:27.953808  - random_milliseconds / 1000
# ...
# 2.092
#
#  2023-06-06 19:48:31.505789  - random_milliseconds
# ...
# 3808
#
#  2023-06-06 19:48:31.505789  - random_milliseconds / 1000
# ...
# 3.808
#
#  2023-06-06 19:48:36.765488  - random_milliseconds
# ...
# 3337
#
#  2023-06-06 19:48:36.765488  - random_milliseconds / 1000
# ...
# 3.337
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22416\3447074465.py in <module>
#     158 #     attaquer_village('3466', '3275', 'data/village.txt')
#     159 #     attaquer_village('3466', '3172', 'data/village.txt')
# --> 160     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
#     161     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
#     162     delay_with_random_seconds()
#
# ~\AppData\Local\Temp\ipykernel_22416\3447074465.py in attaquer_village(troupes_file)
#      75
#      76         bouton = firefox.child_window(auto_id='troop_confirm_submit')
# ---> 77         bouton.click()
#      78         delay_with_random_seconds()
#      79
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     377         if len(self.criteria) >= 2:  # FIXME - this is surprising
#     378
# --> 379             ctrls = self.__resolve_control(self.criteria)
#     380
#     381             try:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     220                 if 'backend' not in ctrl_criteria:
#     221                     ctrl_criteria['backend'] = self.backend.name
# --> 222                 ctrl = self.backend.generic_wrapper_class(findwindows.find_element(**ctrl_criteria))
#     223                 previous_parent = ctrl.element_info
#     224                 ctrls.append(ctrl)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'auto_id': 'troop_confirm_submit', 'top_level_only': False, 'parent': <uia_element_info.UIAElementInfo - 'arion1 (556|484) - Guerre Tribale - Monde 81 — Mozilla Firefox', MozillaWindowClass, 3146552>, 'backend': 'uia'}
