# %%
from pywinauto.application import Application
import psutil
import time
import random
import requests
import csv
import datetime
import fileinput

def delay_with_random_seconds():
#     # Génère un délai aléatoire entre 1 et 5 secondes
#     random_seconds = random.randint(2, 4)
# #     print(random_seconds)
    
#     # Pause l'exécution du programme pendant le délai aléatoire
#     time.sleep(random_seconds)
    random_milliseconds = random.randint(1000, 3000)  # Générer un nombre aléatoire en millisecondes entre 2000 et 4000
    print('\n', datetime.datetime.now(),' - random_milliseconds \n...')   
    print(random_milliseconds)
    print('\n', datetime.datetime.now(),' - random_milliseconds / 1000 \n...')   
    print(random_milliseconds / 1000)
    time.sleep(random_milliseconds / 1000)  # Utiliser la valeur en millisecondes dans time.sleep()
 #     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()

def attaquer_village(troupes_file):
    # Réafficher la fenêtre de navigateur
#     firefox.activate()
    firefox.set_focus()

    lines = []

    # Lire le fichier et stocker les lignes dans une liste
    with open(troupes_file, 'r') as file:
        lines = file.readlines()

    # Exclure la première ligne (en-têtes)
    headers = lines[0].strip().split(',')
    lines = lines[1:]

    # Trier les lignes par heure_attaque la plus ancienne
    lines = sorted(lines, key=lambda x: datetime.datetime.strptime(x.strip().split(',')[headers.index('heure_attaque')], "%Y-%m-%d %H:%M:%S"))

    # Parcourir les lignes triées
    for i, line in enumerate(lines):
        data = line.strip().split(',')
        village_depart = data[headers.index('village_depart')]
        village_attaquer = data[headers.index('village_attaquer')]

        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_attaquer}"
        firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()

        # Saisir les champs pour chaque type de troupe
        for header in headers:
            if header not in ['heure_attaque', 'village_depart', 'village_attaquer']:
                value = int(data[headers.index(header)])
                if value > 0:
                    zone = firefox.child_window(auto_id=header)
                    zone.type_keys(str(value))
                    delay_with_random_seconds()

        # Mettre à jour la colonne heure_attaque avec l'heure actuelle
        heure_attaque_index = headers.index('heure_attaque')
        heure_attaque = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        data[heure_attaque_index] = heure_attaque

        # Modifier la ligne dans la liste
        lines[i] = ','.join(data) + '\n'

        bouton = firefox.child_window(auto_id='target_attack')
        bouton.click()
        delay_with_random_seconds()

        bouton = firefox.child_window(auto_id='troop_confirm_submit')
        bouton.click()
        delay_with_random_seconds()

    # Réécrire le fichier avec les lignes modifiées
    with open(troupes_file, 'w') as file:
        file.write(','.join(headers) + '\n')  # Réécrire les en-têtes
        file.writelines(lines)  # Réécrire les lignes modifiées


# Vérifier si Firefox est en cours d'exécution
firefox_running = False
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_running = True
        firefox_pid = process.pid
        break

# Fermer Firefox si c'est le cas
if firefox_running:
    process = psutil.Process(firefox_pid)
    process.terminate()
#     time.sleep(5)
# Ouvrir Firefox
time.sleep(2)

app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Ouvrir Firefox
# app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Trouver le PID de Firefox
firefox_pid = None
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_pid = process.pid
        break

# Vérifier si Firefox est en cours d'exécution
if firefox_pid is None:
    print("Firefox n'est pas en cours d'exécution.")
else:
    # Attacher Pywinauto à la fenêtre Firefox
    app = Application(backend='uia').connect(process=firefox_pid)

    # Ouvrir une page web
#     firefox = app.window(title_re='.*Nouvel onglet*')
    firefox = app.window( class_name='MozillaWindowClass')

    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     time.sleep(5)

#     # Saisir les champs
#     zone1 = firefox.window(title='user')
#     zone1.type_keys('*test1')
#     zone1 = firefox.child_window(control_type="Edit", found_index=0,  automation_id="user")
    zone1 = firefox.child_window(auto_id='user')

    zone1.type_keys('arion1')
    delay_with_random_seconds()

    zone2 = firefox.child_window(auto_id='password')
    zone2.type_keys('MiMa5158**')
    delay_with_random_seconds()
    # Cliquer sur le bouton
#     bouton = firefox.window(title='Connexion')
# #     bouton = firefox.child_window(auto_id='btn-login')
#     bouton = firefox.child_window(title='Connexion')
#     bouton.click()!
    bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
    bouton.invoke()
#     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
#     bouton.invoke()
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    
#     attaquer_village('3466', '3275', 'data/village.txt')
#     attaquer_village('3466', '3172', 'data/village.txt')
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
    delay_with_random_seconds()    
    # Fermer Firefox 
#     firefox.close()
# Out:
#  2023-07-03 11:51:01.488407  - random_milliseconds
# ...
# 1653
#
#  2023-07-03 11:51:01.488407  - random_milliseconds / 1000
# ...
# 1.653
#
#  2023-07-03 11:51:04.029581  - random_milliseconds
# ...
# 2168
#
#  2023-07-03 11:51:04.029581  - random_milliseconds / 1000
# ...
# 2.168
#
#  2023-07-03 11:51:07.242682  - random_milliseconds
# ...
# 2787
#
#  2023-07-03 11:51:07.242682  - random_milliseconds / 1000
# ...
# 2.787
#
#  2023-07-03 11:51:11.957945  - random_milliseconds
# ...
# 1261
#
#  2023-07-03 11:51:11.957945  - random_milliseconds / 1000
# ...
# 1.261
#
#  2023-07-03 11:51:15.732287  - random_milliseconds
# ...
# 2160
#
#  2023-07-03 11:51:15.732690  - random_milliseconds / 1000
# ...
# 2.16
#
#  2023-07-03 11:51:20.631755  - random_milliseconds
# ...
# 1143
#
#  2023-07-03 11:51:20.631755  - random_milliseconds / 1000
# ...
# 1.143
#
#  2023-07-03 11:51:23.639175  - random_milliseconds
# ...
# 1836
#
#  2023-07-03 11:51:23.639175  - random_milliseconds / 1000
# ...
# 1.836
#
#  2023-07-03 11:51:27.501940  - random_milliseconds
# ...
# 2501
#
#  2023-07-03 11:51:27.501940  - random_milliseconds / 1000
# ...
# 2.501
#
#  2023-07-03 11:51:32.113330  - random_milliseconds
# ...
# 2186
#
#  2023-07-03 11:51:32.113330  - random_milliseconds / 1000
# ...
# 2.186
#
#  2023-07-03 11:51:35.484844  - random_milliseconds
# ...
# 2596
#
#  2023-07-03 11:51:35.484844  - random_milliseconds / 1000
# ...
# 2.596
#
#  2023-07-03 11:51:40.561073  - random_milliseconds
# ...
# 2443
#
#  2023-07-03 11:51:40.561073  - random_milliseconds / 1000
# ...
# 2.443
#
#  2023-07-03 11:51:45.096207  - random_milliseconds
# ...
# 1387
#
#  2023-07-03 11:51:45.096207  - random_milliseconds / 1000
# ...
# 1.387
#
#  2023-07-03 11:51:47.958447  - random_milliseconds
# ...
# 2816
#
#  2023-07-03 11:51:47.958447  - random_milliseconds / 1000
# ...
# 2.816
#
#  2023-07-03 11:51:52.337336  - random_milliseconds
# ...
# 2362
#
#  2023-07-03 11:51:52.337336  - random_milliseconds / 1000
# ...
# 2.362
#
#  2023-07-03 11:51:56.052481  - random_milliseconds
# ...
# 1712
#
#  2023-07-03 11:51:56.052481  - random_milliseconds / 1000
# ...
# 1.712
#
#  2023-07-03 11:52:00.082199  - random_milliseconds
# ...
# 2736
#
#  2023-07-03 11:52:00.082199  - random_milliseconds / 1000
# ...
# 2.736
#
#  2023-07-03 11:52:04.783191  - random_milliseconds
# ...
# 1344
#
#  2023-07-03 11:52:04.783191  - random_milliseconds / 1000
# ...
# 1.344
#
#  2023-07-03 11:52:07.938385  - random_milliseconds
# ...
# 1522
#
#  2023-07-03 11:52:07.938385  - random_milliseconds / 1000
# ...
# 1.522
#
#  2023-07-03 11:52:11.901426  - random_milliseconds
# ...
# 1760
#
#  2023-07-03 11:52:11.901426  - random_milliseconds / 1000
# ...
# 1.76
#
#  2023-07-03 11:52:15.122986  - random_milliseconds
# ...
# 1643
#
#  2023-07-03 11:52:15.122986  - random_milliseconds / 1000
# ...
# 1.643
#
#  2023-07-03 11:52:19.246515  - random_milliseconds
# ...
# 1211
#
#  2023-07-03 11:52:19.246515  - random_milliseconds / 1000
# ...
# 1.211
#
#  2023-07-03 11:52:22.606784  - random_milliseconds
# ...
# 2265
#
#  2023-07-03 11:52:22.607373  - random_milliseconds / 1000
# ...
# 2.265
#
#  2023-07-03 11:52:26.932415  - random_milliseconds
# ...
# 2667
#
#  2023-07-03 11:52:26.932415  - random_milliseconds / 1000
# ...
# 2.667
#
#  2023-07-03 11:52:31.754471  - random_milliseconds
# ...
# 1473
#
#  2023-07-03 11:52:31.754675  - random_milliseconds / 1000
# ...
# 1.473
#
#  2023-07-03 11:52:34.704555  - random_milliseconds
# ...
# 1897
#
#  2023-07-03 11:52:34.704555  - random_milliseconds / 1000
# ...
# 1.897
#
#  2023-07-03 11:52:39.028199  - random_milliseconds
# ...
# 2489
#
#  2023-07-03 11:52:39.028199  - random_milliseconds / 1000
# ...
# 2.489
#
#  2023-07-03 11:52:43.461449  - random_milliseconds
# ...
# 2457
#
#  2023-07-03 11:52:43.461449  - random_milliseconds / 1000
# ...
# 2.457
#
#  2023-07-03 11:52:47.992506  - random_milliseconds
# ...
# 2126
#
#  2023-07-03 11:52:47.992506  - random_milliseconds / 1000
# ...
# 2.126
#
#  2023-07-03 11:52:52.283182  - random_milliseconds
# ...
# 1166
#
#  2023-07-03 11:52:52.283182  - random_milliseconds / 1000
# ...
# 1.166
#
#  2023-07-03 11:52:54.817986  - random_milliseconds
# ...
# 2176
#
#  2023-07-03 11:52:54.817986  - random_milliseconds / 1000
# ...
# 2.176
#
#  2023-07-03 11:52:59.176329  - random_milliseconds
# ...
# 2017
#
#  2023-07-03 11:52:59.176329  - random_milliseconds / 1000
# ...
# 2.017
#
#  2023-07-03 11:53:03.364473  - random_milliseconds
# ...
# 1187
#
#  2023-07-03 11:53:03.364473  - random_milliseconds / 1000
# ...
# 1.187
#
#  2023-07-03 11:53:06.776135  - random_milliseconds
# ...
# 2136
#
#  2023-07-03 11:53:06.776135  - random_milliseconds / 1000
# ...
# 2.136
#
#  2023-07-03 11:53:11.491013  - random_milliseconds
# ...
# 2759
#
#  2023-07-03 11:53:11.491013  - random_milliseconds / 1000
# ...
# 2.759
#
#  2023-07-03 11:53:15.733029  - random_milliseconds
# ...
# 1224
#
#  2023-07-03 11:53:15.733029  - random_milliseconds / 1000
# ...
# 1.224
#
#  2023-07-03 11:53:19.668719  - random_milliseconds
# ...
# 1185
#
#  2023-07-03 11:53:19.668719  - random_milliseconds / 1000
# ...
# 1.185
#
#  2023-07-03 11:53:23.016225  - random_milliseconds
# ...
# 2486
#
#  2023-07-03 11:53:23.017224  - random_milliseconds / 1000
# ...
# 2.486
#
#  2023-07-03 11:53:27.445022  - random_milliseconds
# ...
# 1001
#
#  2023-07-03 11:53:27.445022  - random_milliseconds / 1000
# ...
# 1.001
#
#  2023-07-03 11:53:30.196812  - random_milliseconds
# ...
# 2355
#
#  2023-07-03 11:53:30.196812  - random_milliseconds / 1000
# ...
# 2.355
#
#  2023-07-03 11:53:33.923036  - random_milliseconds
# ...
# 2519
#
#  2023-07-03 11:53:33.923036  - random_milliseconds / 1000
# ...
# 2.519
#
#  2023-07-03 11:53:39.105311  - random_milliseconds
# ...
# 2513
#
#  2023-07-03 11:53:39.105724  - random_milliseconds / 1000
# ...
# 2.513
#
#  2023-07-03 11:53:43.454284  - random_milliseconds
# ...
# 1496
#
#  2023-07-03 11:53:43.454284  - random_milliseconds / 1000
# ...
# 1.496
#
#  2023-07-03 11:53:46.937562  - random_milliseconds
# ...
# 1418
#
#  2023-07-03 11:53:46.938383  - random_milliseconds / 1000
# ...
# 1.418
#
#  2023-07-03 11:53:50.581772  - random_milliseconds
# ...
# 2226
#
#  2023-07-03 11:53:50.581772  - random_milliseconds / 1000
# ...
# 2.226
#
#  2023-07-03 11:53:54.205077  - random_milliseconds
# ...
# 1960
#
#  2023-07-03 11:53:54.205077  - random_milliseconds / 1000
# ...
# 1.96
#
#  2023-07-03 11:53:58.600113  - random_milliseconds
# ...
# 1229
#
#  2023-07-03 11:53:58.600113  - random_milliseconds / 1000
# ...
# 1.229
#
#  2023-07-03 11:54:01.628936  - random_milliseconds
# ...
# 1019
#
#  2023-07-03 11:54:01.628936  - random_milliseconds / 1000
# ...
# 1.019
#
#  2023-07-03 11:54:04.631951  - random_milliseconds
# ...
# 2958
#
#  2023-07-03 11:54:04.631951  - random_milliseconds / 1000
# ...
# 2.958
#
#  2023-07-03 11:54:10.247292  - random_milliseconds
# ...
# 2207
#
#  2023-07-03 11:54:10.247292  - random_milliseconds / 1000
# ...
# 2.207
#
#  2023-07-03 11:54:13.887452  - random_milliseconds
# ...
# 1832
#
#  2023-07-03 11:54:13.887452  - random_milliseconds / 1000
# ...
# 1.832
#
#  2023-07-03 11:54:17.679647  - random_milliseconds
# ...
# 2708
#
#  2023-07-03 11:54:17.679647  - random_milliseconds / 1000
# ...
# 2.708
#
#  2023-07-03 11:54:22.549574  - random_milliseconds
# ...
# 2836
#
#  2023-07-03 11:54:22.549574  - random_milliseconds / 1000
# ...
# 2.836
#
#  2023-07-03 11:54:27.649030  - random_milliseconds
# ...
# 1035
#
#  2023-07-03 11:54:27.649030  - random_milliseconds / 1000
# ...
# 1.035
#
#  2023-07-03 11:54:31.015852  - random_milliseconds
# ...
# 1646
#
#  2023-07-03 11:54:31.015852  - random_milliseconds / 1000
# ...
# 1.646
#
#  2023-07-03 11:54:33.783297  - random_milliseconds
# ...
# 1318
#
#  2023-07-03 11:54:33.783297  - random_milliseconds / 1000
# ...
# 1.318
#
#  2023-07-03 11:54:37.532180  - random_milliseconds
# ...
# 2918
#
#  2023-07-03 11:54:37.533178  - random_milliseconds / 1000
# ...
# 2.918
#
#  2023-07-03 11:54:42.738521  - random_milliseconds
# ...
# 2660
#
#  2023-07-03 11:54:42.738521  - random_milliseconds / 1000
# ...
# 2.66
#
#  2023-07-03 11:54:47.376435  - random_milliseconds
# ...
# 1172
#
#  2023-07-03 11:54:47.376435  - random_milliseconds / 1000
# ...
# 1.172
#
#  2023-07-03 11:54:50.720157  - random_milliseconds
# ...
# 1793
#
#  2023-07-03 11:54:50.721159  - random_milliseconds / 1000
# ...
# 1.793
#
#  2023-07-03 11:54:53.907444  - random_milliseconds
# ...
# 1579
#
#  2023-07-03 11:54:53.907444  - random_milliseconds / 1000
# ...
# 1.579
#
#  2023-07-03 11:54:58.016974  - random_milliseconds
# ...
# 1322
#
#  2023-07-03 11:54:58.017975  - random_milliseconds / 1000
# ...
# 1.322
#
#  2023-07-03 11:55:01.536570  - random_milliseconds
# ...
# 2108
#
#  2023-07-03 11:55:01.536570  - random_milliseconds / 1000
# ...
# 2.108
#
#  2023-07-03 11:55:05.897342  - random_milliseconds
# ...
# 2596
#
#  2023-07-03 11:55:05.897342  - random_milliseconds / 1000
# ...
# 2.596
#  2023-07-03 11:55:10.628140  - random_milliseconds
# ...
# 2588
#
#  2023-07-03 11:55:10.628812  - random_milliseconds / 1000
# ...
# 2.588
#
#  2023-07-03 11:55:14.790671  - random_milliseconds
# ...
# 2840
#
#  2023-07-03 11:55:14.790671  - random_milliseconds / 1000
# ...
# 2.84
#
#  2023-07-03 11:55:20.035409  - random_milliseconds
# ...
# 1882
#
#  2023-07-03 11:55:20.036409  - random_milliseconds / 1000
# ...
# 1.882
#
#  2023-07-03 11:55:24.074935  - random_milliseconds
# ...
# 1237
#
#  2023-07-03 11:55:24.074935  - random_milliseconds / 1000
# ...
# 1.237
#
#  2023-07-03 11:55:27.653577  - random_milliseconds
# ...
# 2264
#
#  2023-07-03 11:55:27.654596  - random_milliseconds / 1000
# ...
# 2.264
#
#  2023-07-03 11:55:32.263384  - random_milliseconds
# ...
# 2691
#
#  2023-07-03 11:55:32.263384  - random_milliseconds / 1000
# ...
# 2.691
#
#  2023-07-03 11:55:35.928503  - random_milliseconds
# ...
# 1613
#
#  2023-07-03 11:55:35.928503  - random_milliseconds / 1000
# ...
# 1.613
#
#  2023-07-03 11:55:39.852897  - random_milliseconds
# ...
# 1903
#
#  2023-07-03 11:55:39.852897  - random_milliseconds / 1000
# ...
# 1.903
#
#  2023-07-03 11:55:44.025897  - random_milliseconds
# ...
# 1003
#
#  2023-07-03 11:55:44.025897  - random_milliseconds / 1000
# ...
# 1.003
#
#  2023-07-03 11:55:47.400748  - random_milliseconds
# ...
# 1878
#
#  2023-07-03 11:55:47.400748  - random_milliseconds / 1000
# ...
# 1.878
#
#  2023-07-03 11:55:51.442394  - random_milliseconds
# ...
# 2326
#
#  2023-07-03 11:55:51.442394  - random_milliseconds / 1000
# ...
# 2.326
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3004\1406096497.py in <module>
#     162 #     attaquer_village('3466', '3275', 'data/village.txt')
#     163 #     attaquer_village('3466', '3172', 'data/village.txt')
# --> 164     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
#     165     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
#     166     delay_with_random_seconds()
#
# ~\AppData\Local\Temp\ipykernel_3004\1406096497.py in attaquer_village(troupes_file)
#      79
#      80         bouton = firefox.child_window(auto_id='troop_confirm_submit')
# ---> 81         bouton.click()
#      82         delay_with_random_seconds()
#      83
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     377         if len(self.criteria) >= 2:  # FIXME - this is surprising
#     378
# --> 379             ctrls = self.__resolve_control(self.criteria)
#     380
#     381             try:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     220                 if 'backend' not in ctrl_criteria:
#     221                     ctrl_criteria['backend'] = self.backend.name
# --> 222                 ctrl = self.backend.generic_wrapper_class(findwindows.find_element(**ctrl_criteria))
#     223                 previous_parent = ctrl.element_info
#     224                 ctrls.append(ctrl)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'auto_id': 'troop_confirm_submit', 'top_level_only': False, 'parent': <uia_element_info.UIAElementInfo - 'M81----1 (556|484) - Guerre Tribale - Monde 81 — Mozilla Firefox', MozillaWindowClass, 19400774>, 'backend': 'uia'}
