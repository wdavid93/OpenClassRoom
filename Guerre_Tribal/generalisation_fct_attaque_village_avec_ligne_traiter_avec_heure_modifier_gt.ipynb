# %%
from pywinauto.application import Application
import psutil
import time
import random
import requests
import csv
import datetime
import fileinput

def delay_with_random_seconds():
#     # Génère un délai aléatoire entre 1 et 5 secondes
#     random_seconds = random.randint(2, 4)
# #     print(random_seconds)
    
#     # Pause l'exécution du programme pendant le délai aléatoire
#     time.sleep(random_seconds)
    random_milliseconds = random.randint(1000, 3000)  # Générer un nombre aléatoire en millisecondes entre 2000 et 4000
    print('\n', datetime.datetime.now(),' - random_milliseconds \n...')   
    print(random_milliseconds)
    print('\n', datetime.datetime.now(),' - random_milliseconds / 1000 \n...')   
    print(random_milliseconds / 1000)
    time.sleep(random_milliseconds / 1000)  # Utiliser la valeur en millisecondes dans time.sleep()
 #     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()

def attaquer_village(troupes_file):
    # Réafficher la fenêtre de navigateur
#     firefox.activate()
    firefox.set_focus()

    lines = []

    # Lire le fichier et stocker les lignes dans une liste
    with open(troupes_file, 'r') as file:
        lines = file.readlines()

    # Exclure la première ligne (en-têtes)
    headers = lines[0].strip().split(',')
    lines = lines[1:]

    # Trier les lignes par heure_attaque la plus ancienne
    lines = sorted(lines, key=lambda x: datetime.datetime.strptime(x.strip().split(',')[headers.index('heure_attaque')], "%Y-%m-%d %H:%M:%S"))

    # Parcourir les lignes triées
    for i, line in enumerate(lines):
        data = line.strip().split(',')
        village_depart = data[headers.index('village_depart')]
        village_attaquer = data[headers.index('village_attaquer')]

        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_attaquer}"
        firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()

        # Saisir les champs pour chaque type de troupe
        for header in headers:
            if header not in ['heure_attaque', 'village_depart', 'village_attaquer']:
                value = int(data[headers.index(header)])
                if value > 0:
                    zone = firefox.child_window(auto_id=header)
                    zone.type_keys(str(value))
                    delay_with_random_seconds()

        # Mettre à jour la colonne heure_attaque avec l'heure actuelle
        heure_attaque_index = headers.index('heure_attaque')
        heure_attaque = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        data[heure_attaque_index] = heure_attaque

        # Modifier la ligne dans la liste
        lines[i] = ','.join(data) + '\n'

        bouton = firefox.child_window(auto_id='target_attack')
        bouton.click()
        delay_with_random_seconds()

        bouton = firefox.child_window(auto_id='troop_confirm_submit')
        bouton.click()
        delay_with_random_seconds()

    # Réécrire le fichier avec les lignes modifiées
    with open(troupes_file, 'w') as file:
        file.write(','.join(headers) + '\n')  # Réécrire les en-têtes
        file.writelines(lines)  # Réécrire les lignes modifiées


# Vérifier si Firefox est en cours d'exécution
firefox_running = False
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_running = True
        firefox_pid = process.pid
        break

# Fermer Firefox si c'est le cas
if firefox_running:
    process = psutil.Process(firefox_pid)
    process.terminate()
#     time.sleep(5)
# Ouvrir Firefox
time.sleep(2)

app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Ouvrir Firefox
# app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Trouver le PID de Firefox
firefox_pid = None
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_pid = process.pid
        break

# Vérifier si Firefox est en cours d'exécution
if firefox_pid is None:
    print("Firefox n'est pas en cours d'exécution.")
else:
    # Attacher Pywinauto à la fenêtre Firefox
    app = Application(backend='uia').connect(process=firefox_pid)

    # Ouvrir une page web
#     firefox = app.window(title_re='.*Nouvel onglet*')
    firefox = app.window( class_name='MozillaWindowClass')

    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     time.sleep(5)

#     # Saisir les champs
#     zone1 = firefox.window(title='user')
#     zone1.type_keys('*test1')
#     zone1 = firefox.child_window(control_type="Edit", found_index=0, automation_id="user")
    zone1 = firefox.child_window(auto_id='user')

    zone1.type_keys('arion1')
    delay_with_random_seconds()

    zone2 = firefox.child_window(auto_id='password')
    zone2.type_keys('MiMa5158**')
    delay_with_random_seconds()
    # Cliquer sur le bouton
#     bouton = firefox.window(title='Connexion')
# #     bouton = firefox.child_window(auto_id='btn-login')
#     bouton = firefox.child_window(title='Connexion')
#     bouton.click()!
    bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
    bouton.invoke()
#     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
#     bouton.invoke()
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    
#     attaquer_village('3466', '3275', 'data/village.txt')
#     attaquer_village('3466', '3172', 'data/village.txt')
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
    delay_with_random_seconds()    
    # Fermer Firefox 
#     firefox.close()
# Out:
#  2023-06-22 07:42:22.136847  - random_milliseconds
# ...
# 2903
#
#  2023-06-22 07:42:22.137845  - random_milliseconds / 1000
# ...
# 2.903
#
#  2023-06-22 07:42:25.696734  - random_milliseconds
# ...
# 1147
#
#  2023-06-22 07:42:25.696734  - random_milliseconds / 1000
# ...
# 1.147
#
#  2023-06-22 07:42:27.295858  - random_milliseconds
# ...
# 2343
#
#  2023-06-22 07:42:27.295858  - random_milliseconds / 1000
# ...
# 2.343
#
#  2023-06-22 07:42:30.890204  - random_milliseconds
# ...
# 2906
#
#  2023-06-22 07:42:30.890204  - random_milliseconds / 1000
# ...
# 2.906
#
#  2023-06-22 07:42:35.432650  - random_milliseconds
# ...
# 1317
#
#  2023-06-22 07:42:35.432650  - random_milliseconds / 1000
# ...
# 1.317
#
#  2023-06-22 07:42:38.691250  - random_milliseconds
# ...
# 1730
#
#  2023-06-22 07:42:38.691250  - random_milliseconds / 1000
# ...
# 1.73
#
#  2023-06-22 07:42:41.207191  - random_milliseconds
# ...
# 1368
#
#  2023-06-22 07:42:41.207191  - random_milliseconds / 1000
# ...
# 1.368
#
#  2023-06-22 07:42:43.405281  - random_milliseconds
# ...
# 2456
#
#  2023-06-22 07:42:43.405281  - random_milliseconds / 1000
# ...
# 2.456
#
#  2023-06-22 07:42:46.600539  - random_milliseconds
# ...
# 2342
#
#  2023-06-22 07:42:46.600539  - random_milliseconds / 1000
# ...
# 2.342
#
#  2023-06-22 07:42:49.677145  - random_milliseconds
# ...
# 1518
#
#  2023-06-22 07:42:49.677145  - random_milliseconds / 1000
# ...
# 1.518
#
#  2023-06-22 07:42:52.927321  - random_milliseconds
# ...
# 2310
#
#  2023-06-22 07:42:52.927321  - random_milliseconds / 1000
# ...
# 2.31
#
#  2023-06-22 07:42:56.058783  - random_milliseconds
# ...
# 1549
#
#  2023-06-22 07:42:56.058783  - random_milliseconds / 1000
# ...
# 1.549
#
#  2023-06-22 07:42:58.389149  - random_milliseconds
# ...
# 1531
#
#  2023-06-22 07:42:58.389149  - random_milliseconds / 1000
# ...
# 1.531
#
#  2023-06-22 07:43:00.747608  - random_milliseconds
# ...
# 2043
#
#  2023-06-22 07:43:00.755565  - random_milliseconds / 1000
# ...
# 2.043
#
#  2023-06-22 07:43:03.434722  - random_milliseconds
# ...
# 1256
#
#  2023-06-22 07:43:03.434722  - random_milliseconds / 1000
# ...
# 1.256
#
#  2023-06-22 07:43:06.495875  - random_milliseconds
# ...
# 1458
#
#  2023-06-22 07:43:06.495875  - random_milliseconds / 1000
# ...
# 1.458
#
#  2023-06-22 07:43:08.750954  - random_milliseconds
# ...
# 2691
#
#  2023-06-22 07:43:08.750954  - random_milliseconds / 1000
# ...
# 2.691
#
#  2023-06-22 07:43:12.285237  - random_milliseconds
# ...
# 2764
#
#  2023-06-22 07:43:12.285237  - random_milliseconds / 1000
# ...
# 2.764
#
#  2023-06-22 07:43:15.886442  - random_milliseconds
# ...
# 2281
#
#  2023-06-22 07:43:15.886442  - random_milliseconds / 1000
# ...
# 2.281
#
#  2023-06-22 07:43:18.895688  - random_milliseconds
# ...
# 2824
#
#  2023-06-22 07:43:18.895688  - random_milliseconds / 1000
# ...
# 2.824
#
#  2023-06-22 07:43:23.672362  - random_milliseconds
# ...
# 1554
#
#  2023-06-22 07:43:23.672362  - random_milliseconds / 1000
# ...
# 1.554
#
#  2023-06-22 07:43:26.012731  - random_milliseconds
# ...
# 2926
#
#  2023-06-22 07:43:26.012731  - random_milliseconds / 1000
# ...
# 2.926
#
#  2023-06-22 07:43:29.808893  - random_milliseconds
# ...
# 1349
#
#  2023-06-22 07:43:29.808893  - random_milliseconds / 1000
# ...
# 1.349
#
#  2023-06-22 07:43:32.131175  - random_milliseconds
# ...
# 2191
#
#  2023-06-22 07:43:32.131175  - random_milliseconds / 1000
# ...
# 2.191
#
#  2023-06-22 07:43:35.341394  - random_milliseconds
# ...
# 1000
#
#  2023-06-22 07:43:35.341394  - random_milliseconds / 1000
# ...
# 1.0
#
#  2023-06-22 07:43:38.250258  - random_milliseconds
# ...
# 1321
#
#  2023-06-22 07:43:38.250258  - random_milliseconds / 1000
# ...
# 1.321
#
#  2023-06-22 07:43:40.408505  - random_milliseconds
# ...
# 2340
#
#  2023-06-22 07:43:40.408505  - random_milliseconds / 1000
# ...
# 2.34
#
#  2023-06-22 07:43:43.568628  - random_milliseconds
# ...
# 2315
#
#  2023-06-22 07:43:43.568628  - random_milliseconds / 1000
# ...
# 2.315
#
#  2023-06-22 07:43:46.715082  - random_milliseconds
# ...
# 2789
#
#  2023-06-22 07:43:46.715082  - random_milliseconds / 1000
# ...
# 2.789
#
#  2023-06-22 07:43:50.188120  - random_milliseconds
# ...
# 2712
#
#  2023-06-22 07:43:50.188120  - random_milliseconds / 1000
# ...
# 2.712
#
#  2023-06-22 07:43:54.695242  - random_milliseconds
# ...
# 2627
#
#  2023-06-22 07:43:54.695242  - random_milliseconds / 1000
# ...
# 2.627
#
#  2023-06-22 07:43:58.146964  - random_milliseconds
# ...
# 2104
#
#  2023-06-22 07:43:58.146964  - random_milliseconds / 1000
# ...
# 2.104
#
#  2023-06-22 07:44:01.106567  - random_milliseconds
# ...
# 1271
#
#  2023-06-22 07:44:01.106567  - random_milliseconds / 1000
# ...
# 1.271
#
#  2023-06-22 07:44:03.152686  - random_milliseconds
# ...
# 2842
#
#  2023-06-22 07:44:03.152686  - random_milliseconds / 1000
# ...
# 2.842
#
#  2023-06-22 07:44:06.681964  - random_milliseconds
# ...
# 1034
#
#  2023-06-22 07:44:06.681964  - random_milliseconds / 1000
# ...
# 1.034
#
#  2023-06-22 07:44:09.643402  - random_milliseconds
# ...
# 1085
#
#  2023-06-22 07:44:09.643402  - random_milliseconds / 1000
# ...
# 1.085
#
#  2023-06-22 07:44:11.529223  - random_milliseconds
# ...
# 1942
#
#  2023-06-22 07:44:11.529223  - random_milliseconds / 1000
# ...
# 1.942
#
#  2023-06-22 07:44:14.228745  - random_milliseconds
# ...
# 1490
#
#  2023-06-22 07:44:14.228745  - random_milliseconds / 1000
# ...
# 1.49
#
#  2023-06-22 07:44:16.603613  - random_milliseconds
# ...
# 1560
#
#  2023-06-22 07:44:16.603613  - random_milliseconds / 1000
# ...
# 1.56
#
#  2023-06-22 07:44:18.815355  - random_milliseconds
# ...
# 1564
#
#  2023-06-22 07:44:18.815355  - random_milliseconds / 1000
# ...
# 1.564
#
#  2023-06-22 07:44:22.275897  - random_milliseconds
# ...
# 2207
#
#  2023-06-22 07:44:22.275897  - random_milliseconds / 1000
# ...
# 2.207
#
#  2023-06-22 07:44:25.374315  - random_milliseconds
# ...
# 2155
#
#  2023-06-22 07:44:25.374315  - random_milliseconds / 1000
# ...
# 2.155
#
#  2023-06-22 07:44:28.370196  - random_milliseconds
# ...
# 2423
#
#  2023-06-22 07:44:28.370196  - random_milliseconds / 1000
# ...
# 2.423
#
#  2023-06-22 07:44:31.671874  - random_milliseconds
# ...
# 1642
#
#  2023-06-22 07:44:31.671874  - random_milliseconds / 1000
# ...
# 1.642
#
#  2023-06-22 07:44:33.975633  - random_milliseconds
# ...
# 1073
#
#  2023-06-22 07:44:33.975633  - random_milliseconds / 1000
# ...
# 1.073
#
#  2023-06-22 07:44:36.970300  - random_milliseconds
# ...
# 2404
#
#  2023-06-22 07:44:36.970300  - random_milliseconds / 1000
# ...
# 2.404
#
#  2023-06-22 07:44:40.401068  - random_milliseconds
# ...
# 1171
#
#  2023-06-22 07:44:40.401068  - random_milliseconds / 1000
# ...
# 1.171
#
#  2023-06-22 07:44:42.425286  - random_milliseconds
# ...
# 1021
#
#  2023-06-22 07:44:42.425286  - random_milliseconds / 1000
# ...
# 1.021
#
#  2023-06-22 07:44:44.276773  - random_milliseconds
# ...
# 2447
#
#  2023-06-22 07:44:44.276773  - random_milliseconds / 1000
# ...
# 2.447
#
#  2023-06-22 07:44:47.431493  - random_milliseconds
# ...
# 1970
#
#  2023-06-22 07:44:47.431493  - random_milliseconds / 1000
# ...
# 1.97
#
#  2023-06-22 07:44:51.312169  - random_milliseconds
# ...
# 1124
#
#  2023-06-22 07:44:51.312169  - random_milliseconds / 1000
# ...
# 1.124
#
#  2023-06-22 07:44:53.248120  - random_milliseconds
# ...
# 1589
#
#  2023-06-22 07:44:53.248120  - random_milliseconds / 1000
# ...
# 1.589
#
#  2023-06-22 07:44:55.685407  - random_milliseconds
# ...
# 1590
#
#  2023-06-22 07:44:55.685407  - random_milliseconds / 1000
# ...
# 1.59
#
#  2023-06-22 07:44:58.143443  - random_milliseconds
# ...
# 2054
#
#  2023-06-22 07:44:58.143443  - random_milliseconds / 1000
# ...
# 2.054
#
#  2023-06-22 07:45:00.898746  - random_milliseconds
# ...
# 1338
#
#  2023-06-22 07:45:00.898746  - random_milliseconds / 1000
# ...
# 1.338
#
#  2023-06-22 07:45:04.172795  - random_milliseconds
# ...
# 1086
#
#  2023-06-22 07:45:04.172795  - random_milliseconds / 1000
# ...
# 1.086
#
#  2023-06-22 07:45:06.104629  - random_milliseconds
# ...
# 1513
#
#  2023-06-22 07:45:06.104629  - random_milliseconds / 1000
# ...
# 1.513
#
#  2023-06-22 07:45:08.467769  - random_milliseconds
# ...
# 2270
#
#  2023-06-22 07:45:08.467769  - random_milliseconds / 1000
# ...
# 2.27
#
#  2023-06-22 07:45:11.571753  - random_milliseconds
# ...
# 2107
#
#  2023-06-22 07:45:11.571753  - random_milliseconds / 1000
# ...
# 2.107
#
#  2023-06-22 07:45:14.388025  - random_milliseconds
# ...
# 2087
#
#  2023-06-22 07:45:14.388025  - random_milliseconds / 1000
# ...
# 2.087
#
#  2023-06-22 07:45:18.180363  - random_milliseconds
# ...
# 1072
#
#  2023-06-22 07:45:18.180363  - random_milliseconds / 1000
# ...
# 1.072
#
#  2023-06-22 07:45:20.179729  - random_milliseconds
# ...
# 2331
#
#  2023-06-22 07:45:20.179729  - random_milliseconds / 1000
# ...
# 2.331
#
#  2023-06-22 07:45:23.360002  - random_milliseconds
# ...
# 2469
#
#  2023-06-22 07:45:23.360002  - random_milliseconds / 1000
# ...
# 2.469
#  2023-06-22 07:45:26.678257  - random_milliseconds
# ...
# 1975
#
#  2023-06-22 07:45:26.678257  - random_milliseconds / 1000
# ...
# 1.975
#
#  2023-06-22 07:45:29.353456  - random_milliseconds
# ...
# 1269
#
#  2023-06-22 07:45:29.353456  - random_milliseconds / 1000
# ...
# 1.269
#
#  2023-06-22 07:45:32.377201  - random_milliseconds
# ...
# 2764
#
#  2023-06-22 07:45:32.377201  - random_milliseconds / 1000
# ...
# 2.764
#
#  2023-06-22 07:45:35.982559  - random_milliseconds
# ...
# 1006
#
#  2023-06-22 07:45:35.982559  - random_milliseconds / 1000
# ...
# 1.006
#
#  2023-06-22 07:45:38.189052  - random_milliseconds
# ...
# 1812
#
#  2023-06-22 07:45:38.189052  - random_milliseconds / 1000
# ...
# 1.812
#
#  2023-06-22 07:45:40.873091  - random_milliseconds
# ...
# 2581
#
#  2023-06-22 07:45:40.873091  - random_milliseconds / 1000
# ...
# 2.581
#
#  2023-06-22 07:45:44.129906  - random_milliseconds
# ...
# 2072
#
#  2023-06-22 07:45:44.129906  - random_milliseconds / 1000
# ...
# 2.072
#
#  2023-06-22 07:45:48.091037  - random_milliseconds
# ...
# 1920
#
#  2023-06-22 07:45:48.091037  - random_milliseconds / 1000
# ...
# 1.92
#
#  2023-06-22 07:45:50.924987  - random_milliseconds
# ...
# 1798
#
#  2023-06-22 07:45:50.924987  - random_milliseconds / 1000
# ...
# 1.798
#
#  2023-06-22 07:45:53.684934  - random_milliseconds
# ...
# 1771
#
#  2023-06-22 07:45:53.684934  - random_milliseconds / 1000
# ...
# 1.771
#
#  2023-06-22 07:45:56.368511  - random_milliseconds
# ...
# 1270
#
#  2023-06-22 07:45:56.368511  - random_milliseconds / 1000
# ...
# 1.27
#
#  2023-06-22 07:45:58.322274  - random_milliseconds
# ...
# 1596
#
#  2023-06-22 07:45:58.322274  - random_milliseconds / 1000
# ...
# 1.596
#
#  2023-06-22 07:46:01.646044  - random_milliseconds
# ...
# 1886
#
#  2023-06-22 07:46:01.646044  - random_milliseconds / 1000
# ...
# 1.886
#
#  2023-06-22 07:46:04.437398  - random_milliseconds
# ...
# 1156
#
#  2023-06-22 07:46:04.437398  - random_milliseconds / 1000
# ...
# 1.156
#
#  2023-06-22 07:46:06.490222  - random_milliseconds
# ...
# 2462
#
#  2023-06-22 07:46:06.490222  - random_milliseconds / 1000
# ...
# 2.462
#
#  2023-06-22 07:46:09.826941  - random_milliseconds
# ...
# 2456
#
#  2023-06-22 07:46:09.826941  - random_milliseconds / 1000
# ...
# 2.456
#
#  2023-06-22 07:46:12.948501  - random_milliseconds
# ...
# 1872
#
#  2023-06-22 07:46:12.948501  - random_milliseconds / 1000
# ...
# 1.872
#
#  2023-06-22 07:46:16.548391  - random_milliseconds
# ...
# 2371
#
#  2023-06-22 07:46:16.548391  - random_milliseconds / 1000
# ...
# 2.371
#
#  2023-06-22 07:46:19.779564  - random_milliseconds
# ...
# 2993
#
#  2023-06-22 07:46:19.779564  - random_milliseconds / 1000
# ...
# 2.993
#
#  2023-06-22 07:46:23.690385  - random_milliseconds
# ...
# 1520
#
#  2023-06-22 07:46:23.690385  - random_milliseconds / 1000
# ...
# 1.52
#
#  2023-06-22 07:46:26.139588  - random_milliseconds
# ...
# 2332
#
#  2023-06-22 07:46:26.139588  - random_milliseconds / 1000
# ...
# 2.332
#
#  2023-06-22 07:46:29.202466  - random_milliseconds
# ...
# 1398
#
#  2023-06-22 07:46:29.202466  - random_milliseconds / 1000
# ...
# 1.398
#
#  2023-06-22 07:46:32.408368  - random_milliseconds
# ...
# 1938
#
#  2023-06-22 07:46:32.408368  - random_milliseconds / 1000
# ...
# 1.938
#
#  2023-06-22 07:46:35.528425  - random_milliseconds
# ...
# 1155
#
#  2023-06-22 07:46:35.528425  - random_milliseconds / 1000
# ...
# 1.155
#
#  2023-06-22 07:46:37.563144  - random_milliseconds
# ...
# 2678
#
#  2023-06-22 07:46:37.563144  - random_milliseconds / 1000
# ...
# 2.678
#
#  2023-06-22 07:46:41.241208  - random_milliseconds
# ...
# 1179
#
#  2023-06-22 07:46:41.241208  - random_milliseconds / 1000
# ...
# 1.179
#
#  2023-06-22 07:46:43.122207  - random_milliseconds
# ...
# 1577
#
#  2023-06-22 07:46:43.122207  - random_milliseconds / 1000
# ...
# 1.577
#
#  2023-06-22 07:46:46.540143  - random_milliseconds
# ...
# 1762
#
#  2023-06-22 07:46:46.540143  - random_milliseconds / 1000
# ...
# 1.762
#
#  2023-06-22 07:46:49.179000  - random_milliseconds
# ...
# 1366
#
#  2023-06-22 07:46:49.179000  - random_milliseconds / 1000
# ...
# 1.366
#
#  2023-06-22 07:46:51.439540  - random_milliseconds
# ...
# 2360
#
#  2023-06-22 07:46:51.439540  - random_milliseconds / 1000
# ...
# 2.36
#
#  2023-06-22 07:46:54.751430  - random_milliseconds
# ...
# 2101
#
#  2023-06-22 07:46:54.751430  - random_milliseconds / 1000
# ...
# 2.101
#
#  2023-06-22 07:46:57.540653  - random_milliseconds
# ...
# 2166
#
#  2023-06-22 07:46:57.540653  - random_milliseconds / 1000
# ...
# 2.166
#
#  2023-06-22 07:47:01.425510  - random_milliseconds
# ...
# 2825
#
#  2023-06-22 07:47:01.425510  - random_milliseconds / 1000
# ...
# 2.825
#
#  2023-06-22 07:47:05.163122  - random_milliseconds
# ...
# 2560
#
#  2023-06-22 07:47:05.163122  - random_milliseconds / 1000
# ...
# 2.56
#
#  2023-06-22 07:47:08.622041  - random_milliseconds
# ...
# 2857
#
#  2023-06-22 07:47:08.622041  - random_milliseconds / 1000
# ...
# 2.857
#
#  2023-06-22 07:47:12.536693  - random_milliseconds
# ...
# 2785
#
#  2023-06-22 07:47:12.536693  - random_milliseconds / 1000
# ...
# 2.785
#
#  2023-06-22 07:47:16.010186  - random_milliseconds
# ...
# 1232
#
#  2023-06-22 07:47:16.010186  - random_milliseconds / 1000
# ...
# 1.232
#
#  2023-06-22 07:47:18.958140  - random_milliseconds
# ...
# 1575
#
#  2023-06-22 07:47:18.958140  - random_milliseconds / 1000
# ...
# 1.575
#
#  2023-06-22 07:47:21.514599  - random_milliseconds
# ...
# 2547
#
#  2023-06-22 07:47:21.514599  - random_milliseconds / 1000
# ...
# 2.547
#
#  2023-06-22 07:47:25.018979  - random_milliseconds
# ...
# 2642
#
#  2023-06-22 07:47:25.018979  - random_milliseconds / 1000
# ...
# 2.642
#
#  2023-06-22 07:47:28.660821  - random_milliseconds
# ...
# 1425
#
#  2023-06-22 07:47:28.660821  - random_milliseconds / 1000
# ...
# 1.425
#
#  2023-06-22 07:47:31.071239  - random_milliseconds
# ...
# 1721
#
#  2023-06-22 07:47:31.071239  - random_milliseconds / 1000
# ...
# 1.721
#
#  2023-06-22 07:47:34.621983  - random_milliseconds
# ...
# 1744
#
#  2023-06-22 07:47:34.621983  - random_milliseconds / 1000
# ...
# 1.744
#
#  2023-06-22 07:47:37.298208  - random_milliseconds
# ...
# 2240
#
#  2023-06-22 07:47:37.298208  - random_milliseconds / 1000
# ...
# 2.24
#
#  2023-06-22 07:47:40.526049  - random_milliseconds
# ...
# 2187
#
#  2023-06-22 07:47:40.526049  - random_milliseconds / 1000
# ...
# 2.187
#
#  2023-06-22 07:47:43.654815  - random_milliseconds
# ...
# 1045
#
#  2023-06-22 07:47:43.654815  - random_milliseconds / 1000
# ...
# 1.045
#
#  2023-06-22 07:47:45.438903  - random_milliseconds
# ...
# 2139
#
#  2023-06-22 07:47:45.438903  - random_milliseconds / 1000
# ...
# 2.139
#
#  2023-06-22 07:47:49.384018  - random_milliseconds
# ...
# 1096
#
#  2023-06-22 07:47:49.384018  - random_milliseconds / 1000
# ...
# 1.096
#
#  2023-06-22 07:47:51.466960  - random_milliseconds
# ...
# 2464
#
#  2023-06-22 07:47:51.466960  - random_milliseconds / 1000
# ...
# 2.464
#
#  2023-06-22 07:47:54.890098  - random_milliseconds
# ...
# 2976
#
#  2023-06-22 07:47:54.890098  - random_milliseconds / 1000
# ...
# 2.976
#
#  2023-06-22 07:47:58.768373  - random_milliseconds
# ...
# 1878
#
#  2023-06-22 07:47:58.768373  - random_milliseconds / 1000
# ...
# 1.878
#
#  2023-06-22 07:48:01.348609  - random_milliseconds
# ...
# 2583
#
#  2023-06-22 07:48:01.348609  - random_milliseconds / 1000
# ...
# 2.583
#
#  2023-06-22 07:48:05.879274  - random_milliseconds
# ...
# 1686
#
#  2023-06-22 07:48:05.879274  - random_milliseconds / 1000
# ...
# 1.686
#
#  2023-06-22 07:48:08.510440  - random_milliseconds
# ...
# 2536
#
#  2023-06-22 07:48:08.510440  - random_milliseconds / 1000
# ...
# 2.536
#
#  2023-06-22 07:48:12.013252  - random_milliseconds
# ...
# 2748
#
#  2023-06-22 07:48:12.013252  - random_milliseconds / 1000
# ...
# 2.748
#
#  2023-06-22 07:48:15.807452  - random_milliseconds
# ...
# 2993
#
#  2023-06-22 07:48:15.807452  - random_milliseconds / 1000
# ...
# 2.993
#
#  2023-06-22 07:48:19.453017  - random_milliseconds
# ...
# 1147
#
#  2023-06-22 07:48:19.453017  - random_milliseconds / 1000
# ...
# 1.147
#
#  2023-06-22 07:48:22.516235  - random_milliseconds
# ...
# 2077
#
#  2023-06-22 07:48:22.516235  - random_milliseconds / 1000
# ...
# 2.077
#
#  2023-06-22 07:48:25.547933  - random_milliseconds
# ...
# 1710
#
#  2023-06-22 07:48:25.547933  - random_milliseconds / 1000
# ...
# 1.71
#
#  2023-06-22 07:48:28.634194  - random_milliseconds
# ...
# 1465
#
#  2023-06-22 07:48:28.634194  - random_milliseconds / 1000
# ...
# 1.465
#
#  2023-06-22 07:48:31.080442  - random_milliseconds
# ...
# 1039
#
#  2023-06-22 07:48:31.080442  - random_milliseconds / 1000
# ...
# 1.039
#
#  2023-06-22 07:48:32.790689  - random_milliseconds
# ...
# 2235
#
#  2023-06-22 07:48:32.790689  - random_milliseconds / 1000
# ...
# 2.235
#
#  2023-06-22 07:48:36.900949  - random_milliseconds
# ...
# 1079
#
#  2023-06-22 07:48:36.900949  - random_milliseconds / 1000
# ...
# 1.079
#  2023-06-22 07:48:38.956322  - random_milliseconds
# ...
# 1168
#
#  2023-06-22 07:48:38.956322  - random_milliseconds / 1000
# ...
# 1.168
#
#  2023-06-22 07:48:41.162301  - random_milliseconds
# ...
# 1599
#
#  2023-06-22 07:48:41.162301  - random_milliseconds / 1000
# ...
# 1.599
#
#  2023-06-22 07:48:43.794335  - random_milliseconds
# ...
# 1294
#
#  2023-06-22 07:48:43.794335  - random_milliseconds / 1000
# ...
# 1.294
#
#  2023-06-22 07:48:45.789403  - random_milliseconds
# ...
# 2096
#
#  2023-06-22 07:48:45.789403  - random_milliseconds / 1000
# ...
# 2.096
#
#  2023-06-22 07:48:49.761701  - random_milliseconds
# ...
# 1788
#
#  2023-06-22 07:48:49.761701  - random_milliseconds / 1000
# ...
# 1.788
#
#  2023-06-22 07:48:52.582017  - random_milliseconds
# ...
# 1956
#
#  2023-06-22 07:48:52.582017  - random_milliseconds / 1000
# ...
# 1.956
#
#  2023-06-22 07:48:55.553266  - random_milliseconds
# ...
# 1996
#
#  2023-06-22 07:48:55.553266  - random_milliseconds / 1000
# ...
# 1.996
#
#  2023-06-22 07:48:58.532197  - random_milliseconds
# ...
# 2765
#
#  2023-06-22 07:48:58.532197  - random_milliseconds / 1000
# ...
# 2.765
#
#  2023-06-22 07:49:02.035046  - random_milliseconds
# ...
# 2464
#
#  2023-06-22 07:49:02.035046  - random_milliseconds / 1000
# ...
# 2.464
#
#  2023-06-22 07:49:06.393590  - random_milliseconds
# ...
# 1400
#
#  2023-06-22 07:49:06.393590  - random_milliseconds / 1000
# ...
# 1.4
#
#  2023-06-22 07:49:08.783310  - random_milliseconds
# ...
# 2322
#
#  2023-06-22 07:49:08.783310  - random_milliseconds / 1000
# ...
# 2.322
#
#  2023-06-22 07:49:12.103273  - random_milliseconds
# ...
# 2070
#
#  2023-06-22 07:49:12.103273  - random_milliseconds / 1000
# ...
# 2.07
#
#  2023-06-22 07:49:15.459446  - random_milliseconds
# ...
# 1021
#
#  2023-06-22 07:49:15.459446  - random_milliseconds / 1000
# ...
# 1.021
#
#  2023-06-22 07:49:17.120778  - random_milliseconds
# ...
# 1821
#
#  2023-06-22 07:49:17.120778  - random_milliseconds / 1000
# ...
# 1.821
#
#  2023-06-22 07:49:20.863862  - random_milliseconds
# ...
# 2637
#
#  2023-06-22 07:49:20.863862  - random_milliseconds / 1000
# ...
# 2.637
#
#  2023-06-22 07:49:24.503118  - random_milliseconds
# ...
# 2637
#
#  2023-06-22 07:49:24.503118  - random_milliseconds / 1000
# ...
# 2.637
#
#  2023-06-22 07:49:28.158099  - random_milliseconds
# ...
# 2743
#
#  2023-06-22 07:49:28.158099  - random_milliseconds / 1000
# ...
# 2.743
#
#  2023-06-22 07:49:31.923682  - random_milliseconds
# ...
# 2024
#
#  2023-06-22 07:49:31.923682  - random_milliseconds / 1000
# ...
# 2.024
#
#  2023-06-22 07:49:34.631012  - random_milliseconds
# ...
# 1030
#
#  2023-06-22 07:49:34.631012  - random_milliseconds / 1000
# ...
# 1.03
#
#  2023-06-22 07:49:37.593510  - random_milliseconds
# ...
# 1505
#
#  2023-06-22 07:49:37.593510  - random_milliseconds / 1000
# ...
# 1.505
#
#  2023-06-22 07:49:40.073109  - random_milliseconds
# ...
# 2649
#
#  2023-06-22 07:49:40.073109  - random_milliseconds / 1000
# ...
# 2.649
#
#  2023-06-22 07:49:43.739943  - random_milliseconds
# ...
# 1556
#
#  2023-06-22 07:49:43.739943  - random_milliseconds / 1000
# ...
# 1.556
#
#  2023-06-22 07:49:46.284006  - random_milliseconds
# ...
# 1315
#
#  2023-06-22 07:49:46.284006  - random_milliseconds / 1000
# ...
# 1.315
#
#  2023-06-22 07:49:48.227308  - random_milliseconds
# ...
# 1869
#
#  2023-06-22 07:49:48.227308  - random_milliseconds / 1000
# ...
# 1.869
#
#  2023-06-22 07:49:51.806199  - random_milliseconds
# ...
# 2518
#
#  2023-06-22 07:49:51.806199  - random_milliseconds / 1000
# ...
# 2.518
#
#  2023-06-22 07:49:55.355934  - random_milliseconds
# ...
# 2036
#
#  2023-06-22 07:49:55.355934  - random_milliseconds / 1000
# ...
# 2.036
#
#  2023-06-22 07:49:58.453228  - random_milliseconds
# ...
# 2540
#
#  2023-06-22 07:49:58.453228  - random_milliseconds / 1000
# ...
# 2.54
#
#  2023-06-22 07:50:02.031279  - random_milliseconds
# ...
# 1057
#
#  2023-06-22 07:50:02.031279  - random_milliseconds / 1000
# ...
# 1.057
#
#  2023-06-22 07:50:03.768981  - random_milliseconds
# ...
# 2105
#
#  2023-06-22 07:50:03.768981  - random_milliseconds / 1000
# ...
# 2.105
#
#  2023-06-22 07:50:08.006805  - random_milliseconds
# ...
# 1149
#
#  2023-06-22 07:50:08.006805  - random_milliseconds / 1000
# ...
# 1.149
#
#  2023-06-22 07:50:10.144595  - random_milliseconds
# ...
# 2478
#
#  2023-06-22 07:50:10.144595  - random_milliseconds / 1000
# ...
# 2.478
#
#  2023-06-22 07:50:13.659507  - random_milliseconds
# ...
# 1614
#
#  2023-06-22 07:50:13.659507  - random_milliseconds / 1000
# ...
# 1.614
#
#  2023-06-22 07:50:16.259200  - random_milliseconds
# ...
# 2018
#
#  2023-06-22 07:50:16.259200  - random_milliseconds / 1000
# ...
# 2.018
#
#  2023-06-22 07:50:18.904812  - random_milliseconds
# ...
# 2839
#
#  2023-06-22 07:50:18.904812  - random_milliseconds / 1000
# ...
# 2.839
#
#  2023-06-22 07:50:23.651097  - random_milliseconds
# ...
# 1626
#
#  2023-06-22 07:50:23.651097  - random_milliseconds / 1000
# ...
# 1.626
#
#  2023-06-22 07:50:26.296729  - random_milliseconds
# ...
# 1914
#
#  2023-06-22 07:50:26.296729  - random_milliseconds / 1000
# ...
# 1.914
#
#  2023-06-22 07:50:29.262082  - random_milliseconds
# ...
# 2776
#
#  2023-06-22 07:50:29.262082  - random_milliseconds / 1000
# ...
# 2.776
#
#  2023-06-22 07:50:33.124677  - random_milliseconds
# ...
# 1351
#
#  2023-06-22 07:50:33.124677  - random_milliseconds / 1000
# ...
# 1.351
#
#  2023-06-22 07:50:35.158763  - random_milliseconds
# ...
# 2176
#
#  2023-06-22 07:50:35.158763  - random_milliseconds / 1000
# ...
# 2.176
#
#  2023-06-22 07:50:39.286521  - random_milliseconds
# ...
# 1084
#
#  2023-06-22 07:50:39.286521  - random_milliseconds / 1000
# ...
# 1.084
#
#  2023-06-22 07:50:41.489500  - random_milliseconds
# ...
# 1636
#
#  2023-06-22 07:50:41.489500  - random_milliseconds / 1000
# ...
# 1.636
#
#  2023-06-22 07:50:44.180648  - random_milliseconds
# ...
# 1755
#
#  2023-06-22 07:50:44.180648  - random_milliseconds / 1000
# ...
# 1.755
#
#  2023-06-22 07:50:46.964992  - random_milliseconds
# ...
# 1625
#
#  2023-06-22 07:50:46.964992  - random_milliseconds / 1000
# ...
# 1.625
#
#  2023-06-22 07:50:49.274559  - random_milliseconds
# ...
# 1473
#
#  2023-06-22 07:50:49.274559  - random_milliseconds / 1000
# ...
# 1.473
#
#  2023-06-22 07:50:52.641829  - random_milliseconds
# ...
# 2998
#
#  2023-06-22 07:50:52.641829  - random_milliseconds / 1000
# ...
# 2.998
#
#  2023-06-22 07:50:57.299030  - random_milliseconds
# ...
# 2432
#
#  2023-06-22 07:50:57.299030  - random_milliseconds / 1000
# ...
# 2.432
#
#  2023-06-22 07:51:00.879219  - random_milliseconds
# ...
# 2402
#
#  2023-06-22 07:51:00.879219  - random_milliseconds / 1000
# ...
# 2.402
#
#  2023-06-22 07:51:04.384091  - random_milliseconds
# ...
# 1893
#
#  2023-06-22 07:51:04.384091  - random_milliseconds / 1000
# ...
# 1.893
#
#  2023-06-22 07:51:06.992295  - random_milliseconds
# ...
# 1996
#
#  2023-06-22 07:51:06.992295  - random_milliseconds / 1000
# ...
# 1.996
#
#  2023-06-22 07:51:10.901179  - random_milliseconds
# ...
# 1105
#
#  2023-06-22 07:51:10.901179  - random_milliseconds / 1000
# ...
# 1.105
#
#  2023-06-22 07:51:13.116024  - random_milliseconds
# ...
# 1554
#
#  2023-06-22 07:51:13.116024  - random_milliseconds / 1000
# ...
# 1.554
#
#  2023-06-22 07:51:15.757265  - random_milliseconds
# ...
# 1632
#
#  2023-06-22 07:51:15.757265  - random_milliseconds / 1000
# ...
# 1.632
#
#  2023-06-22 07:51:18.473249  - random_milliseconds
# ...
# 1234
#
#  2023-06-22 07:51:18.473249  - random_milliseconds / 1000
# ...
# 1.234
#
#  2023-06-22 07:51:20.387698  - random_milliseconds
# ...
# 2065
#
#  2023-06-22 07:51:20.387698  - random_milliseconds / 1000
# ...
# 2.065
#
#  2023-06-22 07:51:24.262641  - random_milliseconds
# ...
# 1238
#
#  2023-06-22 07:51:24.262641  - random_milliseconds / 1000
# ...
# 1.238
#
#  2023-06-22 07:51:26.546131  - random_milliseconds
# ...
# 1131
#
#  2023-06-22 07:51:26.546131  - random_milliseconds / 1000
# ...
# 1.131
#
#  2023-06-22 07:51:28.844763  - random_milliseconds
# ...
# 1327
#
#  2023-06-22 07:51:28.844763  - random_milliseconds / 1000
# ...
# 1.327
#
#  2023-06-22 07:51:31.263298  - random_milliseconds
# ...
# 2288
#
#  2023-06-22 07:51:31.263298  - random_milliseconds / 1000
# ...
# 2.288
#
#  2023-06-22 07:51:34.232905  - random_milliseconds
# ...
# 2350
#
#  2023-06-22 07:51:34.232905  - random_milliseconds / 1000
# ...
# 2.35
#
#  2023-06-22 07:51:38.356298  - random_milliseconds
# ...
# 1756
#
#  2023-06-22 07:51:38.356298  - random_milliseconds / 1000
# ...
# 1.756
#
#  2023-06-22 07:51:41.656709  - random_milliseconds
# ...
# 1470
#
#  2023-06-22 07:51:41.656709  - random_milliseconds / 1000
# ...
# 1.47
#
#  2023-06-22 07:51:44.347849  - random_milliseconds
# ...
# 2773
#
#  2023-06-22 07:51:44.347849  - random_milliseconds / 1000
# ...
# 2.773
#
#  2023-06-22 07:51:48.274358  - random_milliseconds
# ...
# 1969
#
#  2023-06-22 07:51:48.274358  - random_milliseconds / 1000
# ...
# 1.969
#  2023-06-22 07:51:50.911675  - random_milliseconds
# ...
# 1041
#
#  2023-06-22 07:51:50.911675  - random_milliseconds / 1000
# ...
# 1.041
#
#  2023-06-22 07:51:53.679433  - random_milliseconds
# ...
# 2752
#
#  2023-06-22 07:51:53.679433  - random_milliseconds / 1000
# ...
# 2.752
#
#  2023-06-22 07:51:57.501489  - random_milliseconds
# ...
# 2299
#
#  2023-06-22 07:51:57.501489  - random_milliseconds / 1000
# ...
# 2.299
#
#  2023-06-22 07:52:01.048490  - random_milliseconds
# ...
# 2119
#
#  2023-06-22 07:52:01.048490  - random_milliseconds / 1000
# ...
# 2.119
#
#  2023-06-22 07:52:04.387586  - random_milliseconds
# ...
# 2184
#
#  2023-06-22 07:52:04.387586  - random_milliseconds / 1000
# ...
# 2.184
#
#  2023-06-22 07:52:07.290842  - random_milliseconds
# ...
# 1690
#
#  2023-06-22 07:52:07.290842  - random_milliseconds / 1000
# ...
# 1.69
#
#  2023-06-22 07:52:10.800626  - random_milliseconds
# ...
# 2679
#
#  2023-06-22 07:52:10.800626  - random_milliseconds / 1000
# ...
# 2.679
#
#  2023-06-22 07:52:14.633377  - random_milliseconds
# ...
# 1184
#
#  2023-06-22 07:52:14.633377  - random_milliseconds / 1000
# ...
# 1.184
#
#  2023-06-22 07:52:17.046455  - random_milliseconds
# ...
# 1220
#
#  2023-06-22 07:52:17.046455  - random_milliseconds / 1000
# ...
# 1.22
#
#  2023-06-22 07:52:19.394534  - random_milliseconds
# ...
# 2921
#
#  2023-06-22 07:52:19.394534  - random_milliseconds / 1000
# ...
# 2.921
#
#  2023-06-22 07:52:23.274656  - random_milliseconds
# ...
# 1332
#
#  2023-06-22 07:52:23.274656  - random_milliseconds / 1000
# ...
# 1.332
#
#  2023-06-22 07:52:26.274677  - random_milliseconds
# ...
# 1135
#
#  2023-06-22 07:52:26.274677  - random_milliseconds / 1000
# ...
# 1.135
#
#  2023-06-22 07:52:28.496493  - random_milliseconds
# ...
# 2307
#
#  2023-06-22 07:52:28.496493  - random_milliseconds / 1000
# ...
# 2.307
#
#  2023-06-22 07:52:32.045393  - random_milliseconds
# ...
# 2019
#
#  2023-06-22 07:52:32.045393  - random_milliseconds / 1000
# ...
# 2.019
#
#  2023-06-22 07:52:35.211511  - random_milliseconds
# ...
# 2486
#
#  2023-06-22 07:52:35.211511  - random_milliseconds / 1000
# ...
# 2.486
#
#  2023-06-22 07:52:38.377394  - random_milliseconds
# ...
# 2623
#
#  2023-06-22 07:52:38.377394  - random_milliseconds / 1000
# ...
# 2.623
#
#  2023-06-22 07:52:42.736248  - random_milliseconds
# ...
# 2429
#
#  2023-06-22 07:52:42.736248  - random_milliseconds / 1000
# ...
# 2.429
#
#  2023-06-22 07:52:46.381049  - random_milliseconds
# ...
# 2465
#
#  2023-06-22 07:52:46.381049  - random_milliseconds / 1000
# ...
# 2.465
#
#  2023-06-22 07:52:50.034397  - random_milliseconds
# ...
# 2683
#
#  2023-06-22 07:52:50.034397  - random_milliseconds / 1000
# ...
# 2.683
#
#  2023-06-22 07:52:53.898559  - random_milliseconds
# ...
# 1612
#
#  2023-06-22 07:52:53.898559  - random_milliseconds / 1000
# ...
# 1.612
#
#  2023-06-22 07:52:56.165335  - random_milliseconds
# ...
# 1581
#
#  2023-06-22 07:52:56.165335  - random_milliseconds / 1000
# ...
# 1.581
#
#  2023-06-22 07:52:59.547943  - random_milliseconds
# ...
# 2241
#
#  2023-06-22 07:52:59.547943  - random_milliseconds / 1000
# ...
# 2.241
#
#  2023-06-22 07:53:02.992448  - random_milliseconds
# ...
# 1983
#
#  2023-06-22 07:53:02.992448  - random_milliseconds / 1000
# ...
# 1.983
#
#  2023-06-22 07:53:06.169085  - random_milliseconds
# ...
# 1913
#
#  2023-06-22 07:53:06.169085  - random_milliseconds / 1000
# ...
# 1.913
#
#  2023-06-22 07:53:09.723489  - random_milliseconds
# ...
# 2768
#
#  2023-06-22 07:53:09.723489  - random_milliseconds / 1000
# ...
# 2.768
#
#  2023-06-22 07:53:13.130393  - random_milliseconds
# ...
# 2383
#
#  2023-06-22 07:53:13.130393  - random_milliseconds / 1000
# ...
# 2.383
#
#  2023-06-22 07:53:17.358029  - random_milliseconds
# ...
# 1364
#
#  2023-06-22 07:53:17.358029  - random_milliseconds / 1000
# ...
# 1.364
#
#  2023-06-22 07:53:19.981983  - random_milliseconds
# ...
# 2118
#
#  2023-06-22 07:53:19.981983  - random_milliseconds / 1000
# ...
# 2.118
#
#  2023-06-22 07:53:23.293758  - random_milliseconds
# ...
# 1070
#
#  2023-06-22 07:53:23.293758  - random_milliseconds / 1000
# ...
# 1.07
#
#  2023-06-22 07:53:25.493248  - random_milliseconds
# ...
# 2399
#
#  2023-06-22 07:53:25.493248  - random_milliseconds / 1000
# ...
# 2.399
#
#  2023-06-22 07:53:28.555813  - random_milliseconds
# ...
# 1925
#
#  2023-06-22 07:53:28.555813  - random_milliseconds / 1000
# ...
# 1.925
#
#  2023-06-22 07:53:32.158557  - random_milliseconds
# ...
# 2054
#
#  2023-06-22 07:53:32.158557  - random_milliseconds / 1000
# ...
# 2.054
#
#  2023-06-22 07:53:35.418991  - random_milliseconds
# ...
# 2270
#
#  2023-06-22 07:53:35.418991  - random_milliseconds / 1000
# ...
# 2.27
#
#  2023-06-22 07:53:38.992815  - random_milliseconds
# ...
# 2670
#
#  2023-06-22 07:53:38.992815  - random_milliseconds / 1000
# ...
# 2.67
#
#  2023-06-22 07:53:42.818295  - random_milliseconds
# ...
# 1764
#
#  2023-06-22 07:53:42.818295  - random_milliseconds / 1000
# ...
# 1.764
#
#  2023-06-22 07:53:45.234295  - random_milliseconds
# ...
# 2016
#
#  2023-06-22 07:53:45.234295  - random_milliseconds / 1000
# ...
# 2.016
#
#  2023-06-22 07:53:49.007858  - random_milliseconds
# ...
# 2666
#
#  2023-06-22 07:53:49.007858  - random_milliseconds / 1000
# ...
# 2.666
#
#  2023-06-22 07:53:52.996647  - random_milliseconds
# ...
# 1419
#
#  2023-06-22 07:53:52.996647  - random_milliseconds / 1000
# ...
# 1.419
#
#  2023-06-22 07:53:55.977572  - random_milliseconds
# ...
# 2763
#
#  2023-06-22 07:53:55.977572  - random_milliseconds / 1000
# ...
# 2.763
#
#  2023-06-22 07:53:59.941371  - random_milliseconds
# ...
# 2912
#
#  2023-06-22 07:53:59.941371  - random_milliseconds / 1000
# ...
# 2.912
#
#  2023-06-22 07:54:03.501009  - random_milliseconds
# ...
# 2613
#
#  2023-06-22 07:54:03.501009  - random_milliseconds / 1000
# ...
# 2.613
#
#  2023-06-22 07:54:07.983317  - random_milliseconds
# ...
# 2074
#
#  2023-06-22 07:54:07.983317  - random_milliseconds / 1000
# ...
# 2.074
#
#  2023-06-22 07:54:11.271992  - random_milliseconds
# ...
# 1779
#
#  2023-06-22 07:54:11.271992  - random_milliseconds / 1000
# ...
# 1.779
#
#  2023-06-22 07:54:14.257268  - random_milliseconds
# ...
# 1184
#
#  2023-06-22 07:54:14.257268  - random_milliseconds / 1000
# ...
# 1.184
#
#  2023-06-22 07:54:16.600066  - random_milliseconds
# ...
# 1372
#
#  2023-06-22 07:54:16.609023  - random_milliseconds / 1000
# ...
# 1.372
#
#  2023-06-22 07:54:18.648285  - random_milliseconds
# ...
# 2330
#
#  2023-06-22 07:54:18.648285  - random_milliseconds / 1000
# ...
# 2.33
#
#  2023-06-22 07:54:22.783755  - random_milliseconds
# ...
# 2527
#
#  2023-06-22 07:54:22.783755  - random_milliseconds / 1000
# ...
# 2.527
#
#  2023-06-22 07:54:26.509780  - random_milliseconds
# ...
# 2068
#
#  2023-06-22 07:54:26.509780  - random_milliseconds / 1000
# ...
# 2.068
#
#  2023-06-22 07:54:29.777685  - random_milliseconds
# ...
# 1816
#
#  2023-06-22 07:54:29.777685  - random_milliseconds / 1000
# ...
# 1.816
#
#  2023-06-22 07:54:32.845193  - random_milliseconds
# ...
# 1458
#
#  2023-06-22 07:54:32.845193  - random_milliseconds / 1000
# ...
# 1.458
#
#  2023-06-22 07:54:35.015343  - random_milliseconds
# ...
# 1455
#
#  2023-06-22 07:54:35.015343  - random_milliseconds / 1000
# ...
# 1.455
#
#  2023-06-22 07:54:38.283251  - random_milliseconds
# ...
# 2123
#
#  2023-06-22 07:54:38.283251  - random_milliseconds / 1000
# ...
# 2.123
#
#  2023-06-22 07:54:42.128372  - random_milliseconds
# ...
# 2934
#
#  2023-06-22 07:54:42.128372  - random_milliseconds / 1000
# ...
# 2.934
#
#  2023-06-22 07:54:46.236561  - random_milliseconds
# ...
# 2126
#
#  2023-06-22 07:54:46.236561  - random_milliseconds / 1000
# ...
# 2.126
#
#  2023-06-22 07:54:49.562080  - random_milliseconds
# ...
# 2263
#
#  2023-06-22 07:54:49.562080  - random_milliseconds / 1000
# ...
# 2.263
#
#  2023-06-22 07:54:52.505326  - random_milliseconds
# ...
# 2184
#
#  2023-06-22 07:54:52.505326  - random_milliseconds / 1000
# ...
# 2.184
#
#  2023-06-22 07:54:56.614421  - random_milliseconds
# ...
# 1953
#
#  2023-06-22 07:54:56.614421  - random_milliseconds / 1000
# ...
# 1.953
#
#  2023-06-22 07:54:59.707067  - random_milliseconds
# ...
# 2641
#
#  2023-06-22 07:54:59.707067  - random_milliseconds / 1000
# ...
# 2.641
#
#  2023-06-22 07:55:03.561266  - random_milliseconds
# ...
# 2155
#
#  2023-06-22 07:55:03.561266  - random_milliseconds / 1000
# ...
# 2.155
#
#  2023-06-22 07:55:06.982032  - random_milliseconds
# ...
# 1767
#
#  2023-06-22 07:55:06.982032  - random_milliseconds / 1000
# ...
# 1.767
#
#  2023-06-22 07:55:09.452966  - random_milliseconds
# ...
# 1599
#
#  2023-06-22 07:55:09.452966  - random_milliseconds / 1000
# ...
# 1.599
#
#  2023-06-22 07:55:12.975963  - random_milliseconds
# ...
# 1458
#
#  2023-06-22 07:55:12.975963  - random_milliseconds / 1000
# ...
# 1.458
#
#  2023-06-22 07:55:15.642940  - random_milliseconds
# ...
# 2442
#
#  2023-06-22 07:55:15.642940  - random_milliseconds / 1000
# ...
# 2.442
#  2023-06-22 07:55:19.386344  - random_milliseconds
# ...
# 2553
#
#  2023-06-22 07:55:19.386344  - random_milliseconds / 1000
# ...
# 2.553
#
#  2023-06-22 07:55:23.551686  - random_milliseconds
# ...
# 2543
#
#  2023-06-22 07:55:23.551686  - random_milliseconds / 1000
# ...
# 2.543
#
#  2023-06-22 07:55:26.746839  - random_milliseconds
# ...
# 2730
#
#  2023-06-22 07:55:26.746839  - random_milliseconds / 1000
# ...
# 2.73
#
#  2023-06-22 07:55:31.357105  - random_milliseconds
# ...
# 1037
#
#  2023-06-22 07:55:31.357105  - random_milliseconds / 1000
# ...
# 1.037
#
#  2023-06-22 07:55:33.626952  - random_milliseconds
# ...
# 1815
#
#  2023-06-22 07:55:33.626952  - random_milliseconds / 1000
# ...
# 1.815
#
#  2023-06-22 07:55:36.711684  - random_milliseconds
# ...
# 2888
#
#  2023-06-22 07:55:36.711684  - random_milliseconds / 1000
# ...
# 2.888
#
#  2023-06-22 07:55:40.854476  - random_milliseconds
# ...
# 1357
#
#  2023-06-22 07:55:40.854476  - random_milliseconds / 1000
# ...
# 1.357
#
#  2023-06-22 07:55:42.871225  - random_milliseconds
# ...
# 1048
#
#  2023-06-22 07:55:42.871225  - random_milliseconds / 1000
# ...
# 1.048
#
#  2023-06-22 07:55:45.828057  - random_milliseconds
# ...
# 2886
#
#  2023-06-22 07:55:45.828057  - random_milliseconds / 1000
# ...
# 2.886
#
#  2023-06-22 07:55:50.042522  - random_milliseconds
# ...
# 1104
#
#  2023-06-22 07:55:50.042522  - random_milliseconds / 1000
# ...
# 1.104
#
#  2023-06-22 07:55:52.405200  - random_milliseconds
# ...
# 2197
#
#  2023-06-22 07:55:52.405200  - random_milliseconds / 1000
# ...
# 2.197
#
#  2023-06-22 07:55:55.919811  - random_milliseconds
# ...
# 1469
#
#  2023-06-22 07:55:55.919811  - random_milliseconds / 1000
# ...
# 1.469
#
#  2023-06-22 07:55:58.079413  - random_milliseconds
# ...
# 1727
#
#  2023-06-22 07:55:58.079413  - random_milliseconds / 1000
# ...
# 1.727
#
#  2023-06-22 07:56:01.712372  - random_milliseconds
# ...
# 2959
#
#  2023-06-22 07:56:01.712372  - random_milliseconds / 1000
# ...
# 2.959
#
#  2023-06-22 07:56:05.994688  - random_milliseconds
# ...
# 2143
#
#  2023-06-22 07:56:05.994688  - random_milliseconds / 1000
# ...
# 2.143
#
#  2023-06-22 07:56:09.829310  - random_milliseconds
# ...
# 1638
#
#  2023-06-22 07:56:09.829310  - random_milliseconds / 1000
# ...
# 1.638
#
#  2023-06-22 07:56:12.688700  - random_milliseconds
# ...
# 2695
#
#  2023-06-22 07:56:12.688700  - random_milliseconds / 1000
# ...
# 2.695
#
#  2023-06-22 07:56:16.187026  - random_milliseconds
# ...
# 2825
#
#  2023-06-22 07:56:16.187026  - random_milliseconds / 1000
# ...
# 2.825
#
#  2023-06-22 07:56:20.811445  - random_milliseconds
# ...
# 1522
#
#  2023-06-22 07:56:20.811445  - random_milliseconds / 1000
# ...
# 1.522
#
#  2023-06-22 07:56:23.670780  - random_milliseconds
# ...
# 1834
#
#  2023-06-22 07:56:23.670780  - random_milliseconds / 1000
# ...
# 1.834
#
#  2023-06-22 07:56:26.765950  - random_milliseconds
# ...
# 2462
#
#  2023-06-22 07:56:26.765950  - random_milliseconds / 1000
# ...
# 2.462
#
#  2023-06-22 07:56:30.466465  - random_milliseconds
# ...
# 1503
#
#  2023-06-22 07:56:30.466465  - random_milliseconds / 1000
# ...
# 1.503
#
#  2023-06-22 07:56:32.631333  - random_milliseconds
# ...
# 2143
#
#  2023-06-22 07:56:32.631333  - random_milliseconds / 1000
# ...
# 2.143
#
#  2023-06-22 07:56:36.566762  - random_milliseconds
# ...
# 2400
#
#  2023-06-22 07:56:36.566762  - random_milliseconds / 1000
# ...
# 2.4
#
#  2023-06-22 07:56:40.310065  - random_milliseconds
# ...
# 2606
#
#  2023-06-22 07:56:40.310065  - random_milliseconds / 1000
# ...
# 2.606
#
#  2023-06-22 07:56:44.267341  - random_milliseconds
# ...
# 1640
#
#  2023-06-22 07:56:44.267341  - random_milliseconds / 1000
# ...
# 1.64
#
#  2023-06-22 07:56:47.232274  - random_milliseconds
# ...
# 2433
#
#  2023-06-22 07:56:47.232274  - random_milliseconds / 1000
# ...
# 2.433
#
#  2023-06-22 07:56:50.776176  - random_milliseconds
# ...
# 2010
#
#  2023-06-22 07:56:50.776176  - random_milliseconds / 1000
# ...
# 2.01
#
#  2023-06-22 07:56:54.630455  - random_milliseconds
# ...
# 2156
#
#  2023-06-22 07:56:54.630455  - random_milliseconds / 1000
# ...
# 2.156
#
#  2023-06-22 07:56:58.100242  - random_milliseconds
# ...
# 2571
#
#  2023-06-22 07:56:58.100242  - random_milliseconds / 1000
# ...
# 2.571
#
#  2023-06-22 07:57:02.074436  - random_milliseconds
# ...
# 1879
#
#  2023-06-22 07:57:02.074436  - random_milliseconds / 1000
# ...
# 1.879
#
#  2023-06-22 07:57:05.481484  - random_milliseconds
# ...
# 1898
#
#  2023-06-22 07:57:05.481484  - random_milliseconds / 1000
# ...
# 1.898
#
#  2023-06-22 07:57:08.034984  - random_milliseconds
# ...
# 1872
#
#  2023-06-22 07:57:08.034984  - random_milliseconds / 1000
# ...
# 1.872
#
#  2023-06-22 07:57:11.765321  - random_milliseconds
# ...
# 2944
#
#  2023-06-22 07:57:11.765321  - random_milliseconds / 1000
# ...
# 2.944
#
#  2023-06-22 07:57:16.062258  - random_milliseconds
# ...
# 2180
#
#  2023-06-22 07:57:16.062258  - random_milliseconds / 1000
# ...
# 2.18
#
#  2023-06-22 07:57:19.513041  - random_milliseconds
# ...
# 1493
#
#  2023-06-22 07:57:19.513041  - random_milliseconds / 1000
# ...
# 1.493
#
#  2023-06-22 07:57:22.387216  - random_milliseconds
# ...
# 2278
#
#  2023-06-22 07:57:22.387216  - random_milliseconds / 1000
# ...
# 2.278
#
#  2023-06-22 07:57:25.377258  - random_milliseconds
# ...
# 1347
#
#  2023-06-22 07:57:25.377258  - random_milliseconds / 1000
# ...
# 1.347
#
#  2023-06-22 07:57:28.440637  - random_milliseconds
# ...
# 2881
#
#  2023-06-22 07:57:28.440637  - random_milliseconds / 1000
# ...
# 2.881
#
#  2023-06-22 07:57:32.659607  - random_milliseconds
# ...
# 2842
#
#  2023-06-22 07:57:32.659607  - random_milliseconds / 1000
# ...
# 2.842
#
#  2023-06-22 07:57:37.412440  - random_milliseconds
# ...
# 1487
#
#  2023-06-22 07:57:37.412440  - random_milliseconds / 1000
# ...
# 1.487
#
#  2023-06-22 07:57:40.223577  - random_milliseconds
# ...
# 1712
#
#  2023-06-22 07:57:40.223577  - random_milliseconds / 1000
# ...
# 1.712
#
#  2023-06-22 07:57:42.587428  - random_milliseconds
# ...
# 1951
#
#  2023-06-22 07:57:42.587428  - random_milliseconds / 1000
# ...
# 1.951
#
#  2023-06-22 07:57:46.298542  - random_milliseconds
# ...
# 2984
#
#  2023-06-22 07:57:46.298542  - random_milliseconds / 1000
# ...
# 2.984
#
#  2023-06-22 07:57:50.578295  - random_milliseconds
# ...
# 2801
#
#  2023-06-22 07:57:50.578295  - random_milliseconds / 1000
# ...
# 2.801
#
#  2023-06-22 07:57:54.707905  - random_milliseconds
# ...
# 1306
#
#  2023-06-22 07:57:54.707905  - random_milliseconds / 1000
# ...
# 1.306
#
#  2023-06-22 07:57:57.295349  - random_milliseconds
# ...
# 2026
#
#  2023-06-22 07:57:57.295349  - random_milliseconds / 1000
# ...
# 2.026
#
#  2023-06-22 07:58:00.031513  - random_milliseconds
# ...
# 2924
#
#  2023-06-22 07:58:00.031513  - random_milliseconds / 1000
# ...
# 2.924
#
#  2023-06-22 07:58:04.830235  - random_milliseconds
# ...
# 2642
#
#  2023-06-22 07:58:04.830235  - random_milliseconds / 1000
# ...
# 2.642
#
#  2023-06-22 07:58:08.922497  - random_milliseconds
# ...
# 2711
#
#  2023-06-22 07:58:08.922497  - random_milliseconds / 1000
# ...
# 2.711
#
#  2023-06-22 07:58:12.989612  - random_milliseconds
# ...
# 2735
#
#  2023-06-22 07:58:12.989612  - random_milliseconds / 1000
# ...
# 2.735
#
#  2023-06-22 07:58:17.529089  - random_milliseconds
# ...
# 1474
#
#  2023-06-22 07:58:17.529089  - random_milliseconds / 1000
# ...
# 1.474
#
#  2023-06-22 07:58:19.676145  - random_milliseconds
# ...
# 1085
#
#  2023-06-22 07:58:19.676145  - random_milliseconds / 1000
# ...
# 1.085
#
#  2023-06-22 07:58:22.610688  - random_milliseconds
# ...
# 1883
#
#  2023-06-22 07:58:22.610688  - random_milliseconds / 1000
# ...
# 1.883
#
#  2023-06-22 07:58:25.895987  - random_milliseconds
# ...
# 2924
#
#  2023-06-22 07:58:25.895987  - random_milliseconds / 1000
# ...
# 2.924
#
#  2023-06-22 07:58:30.137460  - random_milliseconds
# ...
# 2976
#
#  2023-06-22 07:58:30.137460  - random_milliseconds / 1000
# ...
# 2.976
#
#  2023-06-22 07:58:34.463525  - random_milliseconds
# ...
# 1675
#
#  2023-06-22 07:58:34.463525  - random_milliseconds / 1000
# ...
# 1.675
#
#  2023-06-22 07:58:36.854217  - random_milliseconds
# ...
# 1870
#
#  2023-06-22 07:58:36.854217  - random_milliseconds / 1000
# ...
# 1.87
#
#  2023-06-22 07:58:40.530381  - random_milliseconds
# ...
# 2959
#
#  2023-06-22 07:58:40.530381  - random_milliseconds / 1000
# ...
# 2.959
#
#  2023-06-22 07:58:44.792661  - random_milliseconds
# ...
# 1144
#
#  2023-06-22 07:58:44.792661  - random_milliseconds / 1000
# ...
# 1.144
#
#  2023-06-22 07:58:47.270635  - random_milliseconds
# ...
# 2905
#
#  2023-06-22 07:58:47.270635  - random_milliseconds / 1000
# ...
# 2.905
#
#  2023-06-22 07:58:51.544028  - random_milliseconds
# ...
# 2531
#
#  2023-06-22 07:58:51.544028  - random_milliseconds / 1000
# ...
# 2.531
#
#  2023-06-22 07:58:54.742322  - random_milliseconds
# ...
# 1185
#
#  2023-06-22 07:58:54.742322  - random_milliseconds / 1000
# ...
# 1.185
#  2023-06-22 07:58:57.763488  - random_milliseconds
# ...
# 1891
#
#  2023-06-22 07:58:57.763488  - random_milliseconds / 1000
# ...
# 1.891
#
#  2023-06-22 07:59:01.431117  - random_milliseconds
# ...
# 1460
#
#  2023-06-22 07:59:01.431117  - random_milliseconds / 1000
# ...
# 1.46
#
#  2023-06-22 07:59:04.235548  - random_milliseconds
# ...
# 2842
#
#  2023-06-22 07:59:04.235548  - random_milliseconds / 1000
# ...
# 2.842
#
#  2023-06-22 07:59:08.407418  - random_milliseconds
# ...
# 2314
#
#  2023-06-22 07:59:08.407418  - random_milliseconds / 1000
# ...
# 2.314
#
#  2023-06-22 07:59:11.367995  - random_milliseconds
# ...
# 1095
#
#  2023-06-22 07:59:11.367995  - random_milliseconds / 1000
# ...
# 1.095
#
#  2023-06-22 07:59:14.277287  - random_milliseconds
# ...
# 2622
#
#  2023-06-22 07:59:14.277287  - random_milliseconds / 1000
# ...
# 2.622
#
#  2023-06-22 07:59:18.243946  - random_milliseconds
# ...
# 2215
#
#  2023-06-22 07:59:18.243946  - random_milliseconds / 1000
# ...
# 2.215
#
#  2023-06-22 07:59:21.763598  - random_milliseconds
# ...
# 1610
#
#  2023-06-22 07:59:21.763598  - random_milliseconds / 1000
# ...
# 1.61
#
#  2023-06-22 07:59:24.702867  - random_milliseconds
# ...
# 2020
#
#  2023-06-22 07:59:24.702867  - random_milliseconds / 1000
# ...
# 2.02
#
#  2023-06-22 07:59:27.432015  - random_milliseconds
# ...
# 2731
#
#  2023-06-22 07:59:27.432015  - random_milliseconds / 1000
# ...
# 2.731
#
#  2023-06-22 07:59:31.989708  - random_milliseconds
# ...
# 2185
#
#  2023-06-22 07:59:31.989708  - random_milliseconds / 1000
# ...
# 2.185
#
#  2023-06-22 07:59:35.505767  - random_milliseconds
# ...
# 1845
#
#  2023-06-22 07:59:35.505767  - random_milliseconds / 1000
# ...
# 1.845
#
#  2023-06-22 07:59:39.140958  - random_milliseconds
# ...
# 2987
#
#  2023-06-22 07:59:39.140958  - random_milliseconds / 1000
# ...
# 2.987
#
#  2023-06-22 07:59:43.488253  - random_milliseconds
# ...
# 2421
#
#  2023-06-22 07:59:43.488253  - random_milliseconds / 1000
# ...
# 2.421
#
#  2023-06-22 07:59:46.598343  - random_milliseconds
# ...
# 1850
#
#  2023-06-22 07:59:46.598343  - random_milliseconds / 1000
# ...
# 1.85
#
#  2023-06-22 07:59:50.323121  - random_milliseconds
# ...
# 1876
#
#  2023-06-22 07:59:50.323121  - random_milliseconds / 1000
# ...
# 1.876
#
#  2023-06-22 07:59:53.516499  - random_milliseconds
# ...
# 2007
#
#  2023-06-22 07:59:53.516499  - random_milliseconds / 1000
# ...
# 2.007
#
#  2023-06-22 07:59:56.896164  - random_milliseconds
# ...
# 1053
#
#  2023-06-22 07:59:56.896164  - random_milliseconds / 1000
# ...
# 1.053
#
#  2023-06-22 07:59:59.318926  - random_milliseconds
# ...
# 1368
#
#  2023-06-22 07:59:59.318926  - random_milliseconds / 1000
# ...
# 1.368
#
#  2023-06-22 08:00:01.371600  - random_milliseconds
# ...
# 2268
#
#  2023-06-22 08:00:01.371600  - random_milliseconds / 1000
# ...
# 2.268
#
#  2023-06-22 08:00:05.573570  - random_milliseconds
# ...
# 2688
#
#  2023-06-22 08:00:05.573570  - random_milliseconds / 1000
# ...
# 2.688
#
#  2023-06-22 08:00:09.605356  - random_milliseconds
# ...
# 2325
#
#  2023-06-22 08:00:09.605356  - random_milliseconds / 1000
# ...
# 2.325
#
#  2023-06-22 08:00:13.347182  - random_milliseconds
# ...
# 1710
#
#  2023-06-22 08:00:13.347182  - random_milliseconds / 1000
# ...
# 1.71
#
#  2023-06-22 08:00:17.048314  - random_milliseconds
# ...
# 1959
#
#  2023-06-22 08:00:17.048314  - random_milliseconds / 1000
# ...
# 1.959
#
#  2023-06-22 08:00:19.713402  - random_milliseconds
# ...
# 1887
#
#  2023-06-22 08:00:19.713402  - random_milliseconds / 1000
# ...
# 1.887
#
#  2023-06-22 08:00:23.539411  - random_milliseconds
# ...
# 2077
#
#  2023-06-22 08:00:23.539411  - random_milliseconds / 1000
# ...
# 2.077
#
#  2023-06-22 08:00:27.009695  - random_milliseconds
# ...
# 2713
#
#  2023-06-22 08:00:27.009695  - random_milliseconds / 1000
# ...
# 2.713
#
#  2023-06-22 08:00:31.123813  - random_milliseconds
# ...
# 2579
#
#  2023-06-22 08:00:31.123813  - random_milliseconds / 1000
# ...
# 2.579
#
#  2023-06-22 08:00:35.190829  - random_milliseconds
# ...
# 1381
#
#  2023-06-22 08:00:35.190829  - random_milliseconds / 1000
# ...
# 1.381
#
#  2023-06-22 08:00:37.275985  - random_milliseconds
# ...
# 1292
#
#  2023-06-22 08:00:37.275985  - random_milliseconds / 1000
# ...
# 1.292
#
#  2023-06-22 08:00:40.284211  - random_milliseconds
# ...
# 1336
#
#  2023-06-22 08:00:40.284211  - random_milliseconds / 1000
# ...
# 1.336
#
#  2023-06-22 08:00:43.005697  - random_milliseconds
# ...
# 2368
#
#  2023-06-22 08:00:43.005697  - random_milliseconds / 1000
# ...
# 2.368
#
#  2023-06-22 08:00:46.856252  - random_milliseconds
# ...
# 1390
#
#  2023-06-22 08:00:46.856252  - random_milliseconds / 1000
# ...
# 1.39
#
#  2023-06-22 08:00:49.843492  - random_milliseconds
# ...
# 1933
#
#  2023-06-22 08:00:49.843492  - random_milliseconds / 1000
# ...
# 1.933
#
#  2023-06-22 08:00:52.487656  - random_milliseconds
# ...
# 2006
#
#  2023-06-22 08:00:52.487656  - random_milliseconds / 1000
# ...
# 2.006
#
#  2023-06-22 08:00:56.202031  - random_milliseconds
# ...
# 1610
#
#  2023-06-22 08:00:56.202031  - random_milliseconds / 1000
# ...
# 1.61
#
#  2023-06-22 08:00:59.593464  - random_milliseconds
# ...
# 2639
#
#  2023-06-22 08:00:59.593464  - random_milliseconds / 1000
# ...
# 2.639
#
#  2023-06-22 08:01:03.663713  - random_milliseconds
# ...
# 1587
#
#  2023-06-22 08:01:03.663713  - random_milliseconds / 1000
# ...
# 1.587
#
#  2023-06-22 08:01:06.740690  - random_milliseconds
# ...
# 2388
#
#  2023-06-22 08:01:06.740690  - random_milliseconds / 1000
# ...
# 2.388
#
#  2023-06-22 08:01:09.859344  - random_milliseconds
# ...
# 2026
#
#  2023-06-22 08:01:09.859344  - random_milliseconds / 1000
# ...
# 2.026
#
#  2023-06-22 08:01:13.585680  - random_milliseconds
# ...
# 2918
#
#  2023-06-22 08:01:13.585680  - random_milliseconds / 1000
# ...
# 2.918
#
#  2023-06-22 08:01:17.908933  - random_milliseconds
# ...
# 2884
#
#  2023-06-22 08:01:17.908933  - random_milliseconds / 1000
# ...
# 2.884
#
#  2023-06-22 08:01:22.373151  - random_milliseconds
# ...
# 1590
#
#  2023-06-22 08:01:22.373151  - random_milliseconds / 1000
# ...
# 1.59
#
#  2023-06-22 08:01:25.387681  - random_milliseconds
# ...
# 1609
#
#  2023-06-22 08:01:25.387681  - random_milliseconds / 1000
# ...
# 1.609
#
#  2023-06-22 08:01:27.698121  - random_milliseconds
# ...
# 1412
#
#  2023-06-22 08:01:27.698121  - random_milliseconds / 1000
# ...
# 1.412
#
#  2023-06-22 08:01:30.800913  - random_milliseconds
# ...
# 2332
#
#  2023-06-22 08:01:30.800913  - random_milliseconds / 1000
# ...
# 2.332
#
#  2023-06-22 08:01:34.516693  - random_milliseconds
# ...
# 1297
#
#  2023-06-22 08:01:34.516693  - random_milliseconds / 1000
# ...
# 1.297
#
#  2023-06-22 08:01:37.916436  - random_milliseconds
# ...
# 2216
#
#  2023-06-22 08:01:37.916436  - random_milliseconds / 1000
# ...
# 2.216
#
#  2023-06-22 08:01:41.572871  - random_milliseconds
# ...
# 2381
#
#  2023-06-22 08:01:41.572871  - random_milliseconds / 1000
# ...
# 2.381
#
#  2023-06-22 08:01:44.639004  - random_milliseconds
# ...
# 1507
#
#  2023-06-22 08:01:44.639004  - random_milliseconds / 1000
# ...
# 1.507
#
#  2023-06-22 08:01:47.924246  - random_milliseconds
# ...
# 2739
#
#  2023-06-22 08:01:47.924246  - random_milliseconds / 1000
# ...
# 2.739
#
#  2023-06-22 08:01:52.181012  - random_milliseconds
# ...
# 2348
#
#  2023-06-22 08:01:52.181012  - random_milliseconds / 1000
# ...
# 2.348
#
#  2023-06-22 08:01:55.972319  - random_milliseconds
# ...
# 1295
#
#  2023-06-22 08:01:55.972319  - random_milliseconds / 1000
# ...
# 1.295
#
#  2023-06-22 08:01:58.632731  - random_milliseconds
# ...
# 2250
#
#  2023-06-22 08:01:58.632731  - random_milliseconds / 1000
# ...
# 2.25
#
#  2023-06-22 08:02:01.574128  - random_milliseconds
# ...
# 1652
#
#  2023-06-22 08:02:01.574128  - random_milliseconds / 1000
# ...
# 1.652
#
#  2023-06-22 08:02:04.993625  - random_milliseconds
# ...
# 2906
#
#  2023-06-22 08:02:04.993625  - random_milliseconds / 1000
# ...
# 2.906
#
#  2023-06-22 08:02:09.360186  - random_milliseconds
# ...
# 1143
#
#  2023-06-22 08:02:09.360186  - random_milliseconds / 1000
# ...
# 1.143
#
#  2023-06-22 08:02:12.420785  - random_milliseconds
# ...
# 2368
#
#  2023-06-22 08:02:12.420785  - random_milliseconds / 1000
# ...
# 2.368
#
#  2023-06-22 08:02:16.194659  - random_milliseconds
# ...
# 2923
#
#  2023-06-22 08:02:16.194659  - random_milliseconds / 1000
# ...
# 2.923
#
#  2023-06-22 08:02:19.836305  - random_milliseconds
# ...
# 2724
#
#  2023-06-22 08:02:19.836305  - random_milliseconds / 1000
# ...
# 2.724
#
#  2023-06-22 08:02:24.410432  - random_milliseconds
# ...
# 1186
#
#  2023-06-22 08:02:24.410432  - random_milliseconds / 1000
# ...
# 1.186
#
#  2023-06-22 08:02:27.041816  - random_milliseconds
# ...
# 2495
#
#  2023-06-22 08:02:27.041816  - random_milliseconds / 1000
# ...
# 2.495
#
#  2023-06-22 08:02:31.015745  - random_milliseconds
# ...
# 1783
#
#  2023-06-22 08:02:31.015745  - random_milliseconds / 1000
# ...
# 1.783
#  2023-06-22 08:02:34.229835  - random_milliseconds
# ...
# 2986
#
#  2023-06-22 08:02:34.229835  - random_milliseconds / 1000
# ...
# 2.986
#
#  2023-06-22 08:02:37.899827  - random_milliseconds
# ...
# 1302
#
#  2023-06-22 08:02:37.899827  - random_milliseconds / 1000
# ...
# 1.302
#
#  2023-06-22 08:02:41.130439  - random_milliseconds
# ...
# 1164
#
#  2023-06-22 08:02:41.130439  - random_milliseconds / 1000
# ...
# 1.164
#
#  2023-06-22 08:02:43.747777  - random_milliseconds
# ...
# 1442
#
#  2023-06-22 08:02:43.747777  - random_milliseconds / 1000
# ...
# 1.442
#
#  2023-06-22 08:02:46.700562  - random_milliseconds
# ...
# 2964
#
#  2023-06-22 08:02:46.700562  - random_milliseconds / 1000
# ...
# 2.964
#
#  2023-06-22 08:02:51.607640  - random_milliseconds
# ...
# 2222
#
#  2023-06-22 08:02:51.607640  - random_milliseconds / 1000
# ...
# 2.222
#
#  2023-06-22 08:02:54.540278  - random_milliseconds
# ...
# 2507
#
#  2023-06-22 08:02:54.540278  - random_milliseconds / 1000
# ...
# 2.507
#
#  2023-06-22 08:02:58.738710  - random_milliseconds
# ...
# 2702
#
#  2023-06-22 08:02:58.738710  - random_milliseconds / 1000
# ...
# 2.702
#
#  2023-06-22 08:03:02.888623  - random_milliseconds
# ...
# 2568
#
#  2023-06-22 08:03:02.888623  - random_milliseconds / 1000
# ...
# 2.568
#
#  2023-06-22 08:03:06.993078  - random_milliseconds
# ...
# 1750
#
#  2023-06-22 08:03:06.993078  - random_milliseconds / 1000
# ...
# 1.75
#
#  2023-06-22 08:03:10.255378  - random_milliseconds
# ...
# 1499
#
#  2023-06-22 08:03:10.255378  - random_milliseconds / 1000
# ...
# 1.499
#
#  2023-06-22 08:03:12.510213  - random_milliseconds
# ...
# 1741
#
#  2023-06-22 08:03:12.510213  - random_milliseconds / 1000
# ...
# 1.741
#
#  2023-06-22 08:03:15.942316  - random_milliseconds
# ...
# 1728
#
#  2023-06-22 08:03:15.942316  - random_milliseconds / 1000
# ...
# 1.728
#
#  2023-06-22 08:03:19.204584  - random_milliseconds
# ...
# 1416
#
#  2023-06-22 08:03:19.204584  - random_milliseconds / 1000
# ...
# 1.416
#
#  2023-06-22 08:03:22.203268  - random_milliseconds
# ...
# 2605
#
#  2023-06-22 08:03:22.203268  - random_milliseconds / 1000
# ...
# 2.605
#
#  2023-06-22 08:03:26.728538  - random_milliseconds
# ...
# 2831
#
#  2023-06-22 08:03:26.728538  - random_milliseconds / 1000
# ...
# 2.831
#
#  2023-06-22 08:03:30.235343  - random_milliseconds
# ...
# 1565
#
#  2023-06-22 08:03:30.235343  - random_milliseconds / 1000
# ...
# 1.565
#
#  2023-06-22 08:03:33.628024  - random_milliseconds
# ...
# 1851
#
#  2023-06-22 08:03:33.628024  - random_milliseconds / 1000
# ...
# 1.851
#
#  2023-06-22 08:03:36.965077  - random_milliseconds
# ...
# 2034
#
#  2023-06-22 08:03:36.965077  - random_milliseconds / 1000
# ...
# 2.034
#
#  2023-06-22 08:03:40.498867  - random_milliseconds
# ...
# 2083
#
#  2023-06-22 08:03:40.498867  - random_milliseconds / 1000
# ...
# 2.083
#
#  2023-06-22 08:03:44.162177  - random_milliseconds
# ...
# 2620
#
#  2023-06-22 08:03:44.162177  - random_milliseconds / 1000
# ...
# 2.62
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3004\1992347053.py in <module>
#     163 #     attaquer_village('3466', '3172', 'data/village.txt')
#     164     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
# --> 165     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
#     166     delay_with_random_seconds()
#     167     # Fermer Firefox
#
# ~\AppData\Local\Temp\ipykernel_3004\1992347053.py in attaquer_village(troupes_file)
#      79
#      80         bouton = firefox.child_window(auto_id='troop_confirm_submit')
# ---> 81         bouton.click()
#      82         delay_with_random_seconds()
#      83
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     377         if len(self.criteria) >= 2:  # FIXME - this is surprising
#     378
# --> 379             ctrls = self.__resolve_control(self.criteria)
#     380
#     381             try:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     220                 if 'backend' not in ctrl_criteria:
#     221                     ctrl_criteria['backend'] = self.backend.name
# --> 222                 ctrl = self.backend.generic_wrapper_class(findwindows.find_element(**ctrl_criteria))
#     223                 previous_parent = ctrl.element_info
#     224                 ctrls.append(ctrl)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'auto_id': 'troop_confirm_submit', 'top_level_only': False, 'parent': <uia_element_info.UIAElementInfo - 'M81----1 (556|484) - Guerre Tribale - Monde 81 — Mozilla Firefox', MozillaWindowClass, 4785774>, 'backend': 'uia'}
