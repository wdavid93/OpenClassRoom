# %%
from pywinauto.application import Application
import psutil
import time
import random
import requests
import csv
import datetime
import fileinput

def delay_with_random_seconds():
#     # Génère un délai aléatoire entre 1 et 5 secondes
#     random_seconds = random.randint(2, 4)
# #     print(random_seconds)
    
#     # Pause l'exécution du programme pendant le délai aléatoire
#     time.sleep(random_seconds)
    random_milliseconds = random.randint(2000, 4000)  # Générer un nombre aléatoire en millisecondes entre 2000 et 4000
    print('\n', datetime.datetime.now(),' - random_milliseconds \n...')   
    print(random_milliseconds)
    print('\n', datetime.datetime.now(),' - random_milliseconds / 1000 \n...')   
    print(random_milliseconds / 1000)
    time.sleep(random_milliseconds / 1000)  # Utiliser la valeur en millisecondes dans time.sleep()
 #     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()

def attaquer_village(troupes_file):
    lines = []

    # Lire le fichier et stocker les lignes dans une liste
    with open(troupes_file, 'r') as file:
        lines = file.readlines()

    # Exclure la première ligne (en-têtes)
    headers = lines[0].strip().split(',')
    lines = lines[1:]

    # Trier les lignes par heure_attaque la plus ancienne
    lines = sorted(lines, key=lambda x: datetime.datetime.strptime(x.strip().split(',')[headers.index('heure_attaque')], "%Y-%m-%d %H:%M:%S"))

    # Parcourir les lignes triées
    for i, line in enumerate(lines):
        data = line.strip().split(',')
        village_depart = data[headers.index('village_depart')]
        village_attaquer = data[headers.index('village_attaquer')]

        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_attaquer}"
        firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()

        # Saisir les champs pour chaque type de troupe
        for header in headers:
            if header not in ['heure_attaque', 'village_depart', 'village_attaquer']:
                value = int(data[headers.index(header)])
                if value > 0:
                    zone = firefox.child_window(auto_id=header)
                    zone.type_keys(str(value))
                    delay_with_random_seconds()

        # Mettre à jour la colonne heure_attaque avec l'heure actuelle
        heure_attaque_index = headers.index('heure_attaque')
        heure_attaque = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        data[heure_attaque_index] = heure_attaque

        # Modifier la ligne dans la liste
        lines[i] = ','.join(data) + '\n'

        bouton = firefox.child_window(auto_id='target_attack')
        bouton.click()
        delay_with_random_seconds()

        bouton = firefox.child_window(auto_id='troop_confirm_submit')
        bouton.click()
        delay_with_random_seconds()

    # Réécrire le fichier avec les lignes modifiées
    with open(troupes_file, 'w') as file:
        file.write(','.join(headers) + '\n')  # Réécrire les en-têtes
        file.writelines(lines)  # Réécrire les lignes modifiées


# Vérifier si Firefox est en cours d'exécution
firefox_running = False
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_running = True
        firefox_pid = process.pid
        break

# Fermer Firefox si c'est le cas
if firefox_running:
    process = psutil.Process(firefox_pid)
    process.terminate()
#     time.sleep(5)
# Ouvrir Firefox
time.sleep(2)

app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Ouvrir Firefox
# app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Trouver le PID de Firefox
firefox_pid = None
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_pid = process.pid
        break

# Vérifier si Firefox est en cours d'exécution
if firefox_pid is None:
    print("Firefox n'est pas en cours d'exécution.")
else:
    # Attacher Pywinauto à la fenêtre Firefox
    app = Application(backend='uia').connect(process=firefox_pid)

    # Ouvrir une page web
#     firefox = app.window(title_re='.*Nouvel onglet*')
    firefox = app.window( class_name='MozillaWindowClass')

    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     time.sleep(5)

#     # Saisir les champs
#     zone1 = firefox.window(title='user')
#     zone1.type_keys('*test1')
#     zone1 = firefox.child_window(control_type="Edit", found_index=0, automation_id="user")
    zone1 = firefox.child_window(auto_id='user')

    zone1.type_keys('arion1')
    delay_with_random_seconds()

    zone2 = firefox.child_window(auto_id='password')
    zone2.type_keys('MiMa5158**')
    delay_with_random_seconds()
    # Cliquer sur le bouton
#     bouton = firefox.window(title='Connexion')
# #     bouton = firefox.child_window(auto_id='btn-login')
#     bouton = firefox.child_window(title='Connexion')
#     bouton.click()!
    bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
    bouton.invoke()
#     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
#     bouton.invoke()
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    
#     attaquer_village('3466', '3275', 'data/village.txt')
#     attaquer_village('3466', '3172', 'data/village.txt')
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
    delay_with_random_seconds()    
    # Fermer Firefox 
#     firefox.close()
# Out:
#  2023-06-09 09:33:34.924726  - random_milliseconds
# ...
# 3398
#
#  2023-06-09 09:33:34.924726  - random_milliseconds / 1000
# ...
# 3.398
#
#  2023-06-09 09:33:39.125172  - random_milliseconds
# ...
# 3264
#
#  2023-06-09 09:33:39.125172  - random_milliseconds / 1000
# ...
# 3.264
#
#  2023-06-09 09:33:42.901137  - random_milliseconds
# ...
# 2009
#
#  2023-06-09 09:33:42.901137  - random_milliseconds / 1000
# ...
# 2.009
#
#  2023-06-09 09:33:46.453398  - random_milliseconds
# ...
# 3103
#
#  2023-06-09 09:33:46.453398  - random_milliseconds / 1000
# ...
# 3.103
#
#  2023-06-09 09:33:51.509091  - random_milliseconds
# ...
# 2797
#
#  2023-06-09 09:33:51.509091  - random_milliseconds / 1000
# ...
# 2.797
#
#  2023-06-09 09:33:56.222451  - random_milliseconds
# ...
# 2189
#
#  2023-06-09 09:33:56.222451  - random_milliseconds / 1000
# ...
# 2.189
#
#  2023-06-09 09:33:59.334926  - random_milliseconds
# ...
# 2290
#
#  2023-06-09 09:33:59.334926  - random_milliseconds / 1000
# ...
# 2.29
#
#  2023-06-09 09:34:02.619333  - random_milliseconds
# ...
# 3228
#
#  2023-06-09 09:34:02.619333  - random_milliseconds / 1000
# ...
# 3.228
#
#  2023-06-09 09:34:06.828055  - random_milliseconds
# ...
# 2512
#
#  2023-06-09 09:34:06.828055  - random_milliseconds / 1000
# ...
# 2.512
#
#  2023-06-09 09:34:10.658738  - random_milliseconds
# ...
# 3949
#
#  2023-06-09 09:34:10.658738  - random_milliseconds / 1000
# ...
# 3.949
#
#  2023-06-09 09:34:16.522948  - random_milliseconds
# ...
# 2051
#
#  2023-06-09 09:34:16.522948  - random_milliseconds / 1000
# ...
# 2.051
#
#  2023-06-09 09:34:19.749796  - random_milliseconds
# ...
# 3090
#
#  2023-06-09 09:34:19.749796  - random_milliseconds / 1000
# ...
# 3.09
#
#  2023-06-09 09:34:23.831301  - random_milliseconds
# ...
# 3251
#
#  2023-06-09 09:34:23.831301  - random_milliseconds / 1000
# ...
# 3.251
#
#  2023-06-09 09:34:28.108497  - random_milliseconds
# ...
# 2724
#
#  2023-06-09 09:34:28.108497  - random_milliseconds / 1000
# ...
# 2.724
#
#  2023-06-09 09:34:31.945649  - random_milliseconds
# ...
# 3951
#
#  2023-06-09 09:34:31.945649  - random_milliseconds / 1000
# ...
# 3.951
#
#  2023-06-09 09:34:37.772510  - random_milliseconds
# ...
# 2742
#
#  2023-06-09 09:34:37.772510  - random_milliseconds / 1000
# ...
# 2.742
#
#  2023-06-09 09:34:41.831863  - random_milliseconds
# ...
# 3588
#
#  2023-06-09 09:34:41.831863  - random_milliseconds / 1000
# ...
# 3.588
#
#  2023-06-09 09:34:46.792658  - random_milliseconds
# ...
# 3927
#
#  2023-06-09 09:34:46.792658  - random_milliseconds / 1000
# ...
# 3.927
#
#  2023-06-09 09:34:52.134360  - random_milliseconds
# ...
# 2001
#
#  2023-06-09 09:34:52.134360  - random_milliseconds / 1000
# ...
# 2.001
#
#  2023-06-09 09:34:55.202826  - random_milliseconds
# ...
# 3729
#
#  2023-06-09 09:34:55.202826  - random_milliseconds / 1000
# ...
# 3.729
#
#  2023-06-09 09:35:01.585717  - random_milliseconds
# ...
# 3126
#
#  2023-06-09 09:35:01.586678  - random_milliseconds / 1000
# ...
# 3.126
#
#  2023-06-09 09:35:05.989961  - random_milliseconds
# ...
# 2511
#
#  2023-06-09 09:35:05.989961  - random_milliseconds / 1000
# ...
# 2.511
#
#  2023-06-09 09:35:09.606005  - random_milliseconds
# ...
# 3700
#
#  2023-06-09 09:35:09.606005  - random_milliseconds / 1000
# ...
# 3.7
#
#  2023-06-09 09:35:14.684174  - random_milliseconds
# ...
# 3884
#
#  2023-06-09 09:35:14.684174  - random_milliseconds / 1000
# ...
# 3.884
#
#  2023-06-09 09:35:19.966221  - random_milliseconds
# ...
# 3206
#
#  2023-06-09 09:35:19.966221  - random_milliseconds / 1000
# ...
# 3.206
#
#  2023-06-09 09:35:25.562645  - random_milliseconds
# ...
# 3519
#
#  2023-06-09 09:35:25.562645  - random_milliseconds / 1000
# ...
# 3.519
#
#  2023-06-09 09:35:30.430346  - random_milliseconds
# ...
# 2530
#
#  2023-06-09 09:35:30.430346  - random_milliseconds / 1000
# ...
# 2.53
#
#  2023-06-09 09:35:34.440161  - random_milliseconds
# ...
# 2083
#
#  2023-06-09 09:35:34.440161  - random_milliseconds / 1000
# ...
# 2.083
#
#  2023-06-09 09:35:37.928182  - random_milliseconds
# ...
# 2753
#
#  2023-06-09 09:35:37.928182  - random_milliseconds / 1000
# ...
# 2.753
#
#  2023-06-09 09:35:41.750452  - random_milliseconds
# ...
# 3931
#
#  2023-06-09 09:35:41.750452  - random_milliseconds / 1000
# ...
# 3.931
#
#  2023-06-09 09:35:48.078802  - random_milliseconds
# ...
# 3673
#
#  2023-06-09 09:35:48.078802  - random_milliseconds / 1000
# ...
# 3.673
#
#  2023-06-09 09:35:53.240941  - random_milliseconds
# ...
# 3991
#
#  2023-06-09 09:35:53.240941  - random_milliseconds / 1000
# ...
# 3.991
#
#  2023-06-09 09:35:58.392042  - random_milliseconds
# ...
# 2593
#
#  2023-06-09 09:35:58.392042  - random_milliseconds / 1000
# ...
# 2.593
#
#  2023-06-09 09:36:02.392386  - random_milliseconds
# ...
# 2757
#
#  2023-06-09 09:36:02.392386  - random_milliseconds / 1000
# ...
# 2.757
#
#  2023-06-09 09:36:06.250184  - random_milliseconds
# ...
# 3856
#
#  2023-06-09 09:36:06.250184  - random_milliseconds / 1000
# ...
# 3.856
#
#  2023-06-09 09:36:12.586500  - random_milliseconds
# ...
# 2999
#
#  2023-06-09 09:36:12.586500  - random_milliseconds / 1000
# ...
# 2.999
#
#  2023-06-09 09:36:16.911121  - random_milliseconds
# ...
# 3602
#
#  2023-06-09 09:36:16.911121  - random_milliseconds / 1000
# ...
# 3.602
#
#  2023-06-09 09:36:21.942742  - random_milliseconds
# ...
# 2865
#
#  2023-06-09 09:36:21.942742  - random_milliseconds / 1000
# ...
# 2.865
#
#  2023-06-09 09:36:26.184448  - random_milliseconds
# ...
# 2759
#
#  2023-06-09 09:36:26.184448  - random_milliseconds / 1000
# ...
# 2.759
#
#  2023-06-09 09:36:29.876032  - random_milliseconds
# ...
# 2916
#
#  2023-06-09 09:36:29.876032  - random_milliseconds / 1000
# ...
# 2.916
#
#  2023-06-09 09:36:35.133177  - random_milliseconds
# ...
# 2737
#
#  2023-06-09 09:36:35.133177  - random_milliseconds / 1000
# ...
# 2.737
#
#  2023-06-09 09:36:39.201345  - random_milliseconds
# ...
# 2999
#
#  2023-06-09 09:36:39.201345  - random_milliseconds / 1000
# ...
# 2.999
#
#  2023-06-09 09:36:43.601249  - random_milliseconds
# ...
# 3970
#
#  2023-06-09 09:36:43.601249  - random_milliseconds / 1000
# ...
# 3.97
#
#  2023-06-09 09:36:48.995034  - random_milliseconds
# ...
# 3724
#
#  2023-06-09 09:36:48.995034  - random_milliseconds / 1000
# ...
# 3.724
#
#  2023-06-09 09:36:53.954540  - random_milliseconds
# ...
# 3433
#
#  2023-06-09 09:36:53.954540  - random_milliseconds / 1000
# ...
# 3.433
#
#  2023-06-09 09:36:59.825189  - random_milliseconds
# ...
# 2656
#
#  2023-06-09 09:36:59.826190  - random_milliseconds / 1000
# ...
# 2.656
#
#  2023-06-09 09:37:03.834836  - random_milliseconds
# ...
# 3105
#
#  2023-06-09 09:37:03.834836  - random_milliseconds / 1000
# ...
# 3.105
#
#  2023-06-09 09:37:08.367639  - random_milliseconds
# ...
# 2631
#
#  2023-06-09 09:37:08.367639  - random_milliseconds / 1000
# ...
# 2.631
#
#  2023-06-09 09:37:12.376421  - random_milliseconds
# ...
# 3187
#
#  2023-06-09 09:37:12.376421  - random_milliseconds / 1000
# ...
# 3.187
#
#  2023-06-09 09:37:16.596009  - random_milliseconds
# ...
# 3418
#
#  2023-06-09 09:37:16.596009  - random_milliseconds / 1000
# ...
# 3.418
#
#  2023-06-09 09:37:22.477143  - random_milliseconds
# ...
# 3490
#
#  2023-06-09 09:37:22.477143  - random_milliseconds / 1000
# ...
# 3.49
#
#  2023-06-09 09:37:27.449064  - random_milliseconds
# ...
# 3398
#
#  2023-06-09 09:37:27.449064  - random_milliseconds / 1000
# ...
# 3.398
#
#  2023-06-09 09:37:32.293310  - random_milliseconds
# ...
# 3607
#
#  2023-06-09 09:37:32.293310  - random_milliseconds / 1000
# ...
# 3.607
#
#  2023-06-09 09:37:37.303451  - random_milliseconds
# ...
# 2506
#
#  2023-06-09 09:37:37.303451  - random_milliseconds / 1000
# ...
# 2.506
#
#  2023-06-09 09:37:41.314557  - random_milliseconds
# ...
# 3716
#
#  2023-06-09 09:37:41.314557  - random_milliseconds / 1000
# ...
# 3.716
#
#  2023-06-09 09:37:47.617232  - random_milliseconds
# ...
# 3801
#
#  2023-06-09 09:37:47.617232  - random_milliseconds / 1000
# ...
# 3.801
#
#  2023-06-09 09:37:52.891969  - random_milliseconds
# ...
# 2822
#
#  2023-06-09 09:37:52.891969  - random_milliseconds / 1000
# ...
# 2.822
#
#  2023-06-09 09:37:57.308160  - random_milliseconds
# ...
# 3533
#
#  2023-06-09 09:37:57.308160  - random_milliseconds / 1000
# ...
# 3.533
#
#  2023-06-09 09:38:02.283617  - random_milliseconds
# ...
# 2228
#
#  2023-06-09 09:38:02.283617  - random_milliseconds / 1000
# ...
# 2.228
#
#  2023-06-09 09:38:05.461808  - random_milliseconds
# ...
# 2271
#
#  2023-06-09 09:38:05.461808  - random_milliseconds / 1000
# ...
# 2.271
#
#  2023-06-09 09:38:10.049650  - random_milliseconds
# ...
# 3036
#
#  2023-06-09 09:38:10.049650  - random_milliseconds / 1000
# ...
# 3.036
#
#  2023-06-09 09:38:14.482077  - random_milliseconds
# ...
# 3134
#
#  2023-06-09 09:38:14.482077  - random_milliseconds / 1000
# ...
# 3.134
#
#  2023-06-09 09:38:18.971353  - random_milliseconds
# ...
# 3899
#
#  2023-06-09 09:38:18.971353  - random_milliseconds / 1000
# ...
# 3.899
#  2023-06-09 09:38:24.414310  - random_milliseconds
# ...
# 2279
#
#  2023-06-09 09:38:24.414310  - random_milliseconds / 1000
# ...
# 2.279
#
#  2023-06-09 09:38:27.846608  - random_milliseconds
# ...
# 3712
#
#  2023-06-09 09:38:27.846608  - random_milliseconds / 1000
# ...
# 3.712
#
#  2023-06-09 09:38:33.859666  - random_milliseconds
# ...
# 2229
#
#  2023-06-09 09:38:33.859666  - random_milliseconds / 1000
# ...
# 2.229
#
#  2023-06-09 09:38:37.310346  - random_milliseconds
# ...
# 3682
#
#  2023-06-09 09:38:37.310346  - random_milliseconds / 1000
# ...
# 3.682
#
#  2023-06-09 09:38:42.572138  - random_milliseconds
# ...
# 2599
#
#  2023-06-09 09:38:42.572138  - random_milliseconds / 1000
# ...
# 2.599
#
#  2023-06-09 09:38:46.624823  - random_milliseconds
# ...
# 2237
#
#  2023-06-09 09:38:46.624823  - random_milliseconds / 1000
# ...
# 2.237
#
#  2023-06-09 09:38:50.063965  - random_milliseconds
# ...
# 2380
#
#  2023-06-09 09:38:50.063965  - random_milliseconds / 1000
# ...
# 2.38
#
#  2023-06-09 09:38:54.340267  - random_milliseconds
# ...
# 2723
#
#  2023-06-09 09:38:54.340267  - random_milliseconds / 1000
# ...
# 2.723
#
#  2023-06-09 09:38:58.508278  - random_milliseconds
# ...
# 3974
#
#  2023-06-09 09:38:58.508278  - random_milliseconds / 1000
# ...
# 3.974
#
#  2023-06-09 09:39:03.981380  - random_milliseconds
# ...
# 2464
#
#  2023-06-09 09:39:03.981380  - random_milliseconds / 1000
# ...
# 2.464
#
#  2023-06-09 09:39:08.232614  - random_milliseconds
# ...
# 2901
#
#  2023-06-09 09:39:08.232614  - random_milliseconds / 1000
# ...
# 2.901
#
#  2023-06-09 09:39:12.308742  - random_milliseconds
# ...
# 3887
#
#  2023-06-09 09:39:12.308742  - random_milliseconds / 1000
# ...
# 3.887
#
#  2023-06-09 09:39:18.636736  - random_milliseconds
# ...
# 2981
#
#  2023-06-09 09:39:18.636736  - random_milliseconds / 1000
# ...
# 2.981
#
#  2023-06-09 09:39:23.025537  - random_milliseconds
# ...
# 3672
#
#  2023-06-09 09:39:23.025537  - random_milliseconds / 1000
# ...
# 3.672
#
#  2023-06-09 09:39:28.228049  - random_milliseconds
# ...
# 2664
#
#  2023-06-09 09:39:28.229047  - random_milliseconds / 1000
# ...
# 2.664
#
#  2023-06-09 09:39:32.343829  - random_milliseconds
# ...
# 3532
#
#  2023-06-09 09:39:32.343923  - random_milliseconds / 1000
# ...
# 3.532
#
#  2023-06-09 09:39:36.944924  - random_milliseconds
# ...
# 3829
#
#  2023-06-09 09:39:36.944924  - random_milliseconds / 1000
# ...
# 3.829
#
#  2023-06-09 09:39:42.980661  - random_milliseconds
# ...
# 3335
#
#  2023-06-09 09:39:42.980661  - random_milliseconds / 1000
# ...
# 3.335
#
#  2023-06-09 09:39:47.745447  - random_milliseconds
# ...
# 2754
#
#  2023-06-09 09:39:47.745447  - random_milliseconds / 1000
# ...
# 2.754
#
#  2023-06-09 09:39:51.986638  - random_milliseconds
# ...
# 3802
#
#  2023-06-09 09:39:51.986638  - random_milliseconds / 1000
# ...
# 3.802
#
#  2023-06-09 09:39:57.169080  - random_milliseconds
# ...
# 3885
#
#  2023-06-09 09:39:57.169080  - random_milliseconds / 1000
# ...
# 3.885
#
#  2023-06-09 09:40:02.361397  - random_milliseconds
# ...
# 2742
#
#  2023-06-09 09:40:02.361397  - random_milliseconds / 1000
# ...
# 2.742
#
#  2023-06-09 09:40:07.358751  - random_milliseconds
# ...
# 3971
#
#  2023-06-09 09:40:07.358751  - random_milliseconds / 1000
# ...
# 3.971
#
#  2023-06-09 09:40:12.839816  - random_milliseconds
# ...
# 3839
#
#  2023-06-09 09:40:12.839816  - random_milliseconds / 1000
# ...
# 3.839
#
#  2023-06-09 09:40:18.232420  - random_milliseconds
# ...
# 2913
#
#  2023-06-09 09:40:18.232420  - random_milliseconds / 1000
# ...
# 2.913
#
#  2023-06-09 09:40:22.609275  - random_milliseconds
# ...
# 2741
#
#  2023-06-09 09:40:22.609275  - random_milliseconds / 1000
# ...
# 2.741
#
#  2023-06-09 09:40:26.517132  - random_milliseconds
# ...
# 2747
#
#  2023-06-09 09:40:26.517132  - random_milliseconds / 1000
# ...
# 2.747
#
#  2023-06-09 09:40:31.279478  - random_milliseconds
# ...
# 3397
#
#  2023-06-09 09:40:31.279478  - random_milliseconds / 1000
# ...
# 3.397
#
#  2023-06-09 09:40:36.203791  - random_milliseconds
# ...
# 2944
#
#  2023-06-09 09:40:36.203791  - random_milliseconds / 1000
# ...
# 2.944
#
#  2023-06-09 09:40:40.939633  - random_milliseconds
# ...
# 3117
#
#  2023-06-09 09:40:40.939633  - random_milliseconds / 1000
# ...
# 3.117
#
#  2023-06-09 09:40:45.325364  - random_milliseconds
# ...
# 2044
#
#  2023-06-09 09:40:45.325364  - random_milliseconds / 1000
# ...
# 2.044
#
#  2023-06-09 09:40:48.577181  - random_milliseconds
# ...
# 2065
#
#  2023-06-09 09:40:48.577181  - random_milliseconds / 1000
# ...
# 2.065
#
#  2023-06-09 09:40:53.285268  - random_milliseconds
# ...
# 3528
#
#  2023-06-09 09:40:53.285268  - random_milliseconds / 1000
# ...
# 3.528
#
#  2023-06-09 09:40:58.402113  - random_milliseconds
# ...
# 3033
#
#  2023-06-09 09:40:58.402113  - random_milliseconds / 1000
# ...
# 3.033
#
#  2023-06-09 09:41:02.716565  - random_milliseconds
# ...
# 2227
#
#  2023-06-09 09:41:02.716565  - random_milliseconds / 1000
# ...
# 2.227
#
#  2023-06-09 09:41:06.744716  - random_milliseconds
# ...
# 3137
#
#  2023-06-09 09:41:06.745729  - random_milliseconds / 1000
# ...
# 3.137
#
#  2023-06-09 09:41:10.880666  - random_milliseconds
# ...
# 2353
#
#  2023-06-09 09:41:10.880666  - random_milliseconds / 1000
# ...
# 2.353
#
#  2023-06-09 09:41:15.845597  - random_milliseconds
# ...
# 3817
#
#  2023-06-09 09:41:15.845654  - random_milliseconds / 1000
# ...
# 3.817
#
#  2023-06-09 09:41:21.240997  - random_milliseconds
# ...
# 3037
#
#  2023-06-09 09:41:21.240997  - random_milliseconds / 1000
# ...
# 3.037
#
#  2023-06-09 09:41:25.925259  - random_milliseconds
# ...
# 3980
#
#  2023-06-09 09:41:25.925259  - random_milliseconds / 1000
# ...
# 3.98
#
#  2023-06-09 09:41:31.698128  - random_milliseconds
# ...
# 3405
#
#  2023-06-09 09:41:31.698128  - random_milliseconds / 1000
# ...
# 3.405
#
#  2023-06-09 09:41:36.232502  - random_milliseconds
# ...
# 3640
#
#  2023-06-09 09:41:36.233500  - random_milliseconds / 1000
# ...
# 3.64
#
#  2023-06-09 09:41:42.220070  - random_milliseconds
# ...
# 3683
#
#  2023-06-09 09:41:42.220070  - random_milliseconds / 1000
# ...
# 3.683
#
#  2023-06-09 09:41:47.612561  - random_milliseconds
# ...
# 2164
#
#  2023-06-09 09:41:47.612561  - random_milliseconds / 1000
# ...
# 2.164
#
#  2023-06-09 09:41:51.310850  - random_milliseconds
# ...
# 2784
#
#  2023-06-09 09:41:51.310850  - random_milliseconds / 1000
# ...
# 2.784
#
#  2023-06-09 09:41:55.990615  - random_milliseconds
# ...
# 3587
#
#  2023-06-09 09:41:55.990615  - random_milliseconds / 1000
# ...
# 3.587
#
#  2023-06-09 09:42:00.804900  - random_milliseconds
# ...
# 2824
#
#  2023-06-09 09:42:00.804900  - random_milliseconds / 1000
# ...
# 2.824
#
#  2023-06-09 09:42:05.873274  - random_milliseconds
# ...
# 2851
#
#  2023-06-09 09:42:05.873274  - random_milliseconds / 1000
# ...
# 2.851
#
#  2023-06-09 09:42:10.733690  - random_milliseconds
# ...
# 2335
#
#  2023-06-09 09:42:10.733690  - random_milliseconds / 1000
# ...
# 2.335
#
#  2023-06-09 09:42:14.683919  - random_milliseconds
# ...
# 3944
#
#  2023-06-09 09:42:14.684946  - random_milliseconds / 1000
# ...
# 3.944
#
#  2023-06-09 09:42:20.317218  - random_milliseconds
# ...
# 3579
#
#  2023-06-09 09:42:20.317218  - random_milliseconds / 1000
# ...
# 3.579
#
#  2023-06-09 09:42:25.009129  - random_milliseconds
# ...
# 2721
#
#  2023-06-09 09:42:25.009129  - random_milliseconds / 1000
# ...
# 2.721
#
#  2023-06-09 09:42:30.141606  - random_milliseconds
# ...
# 2000
#
#  2023-06-09 09:42:30.141606  - random_milliseconds / 1000
# ...
# 2.0
#
#  2023-06-09 09:42:33.629790  - random_milliseconds
# ...
# 2374
#
#  2023-06-09 09:42:33.629790  - random_milliseconds / 1000
# ...
# 2.374
#
#  2023-06-09 09:42:37.373960  - random_milliseconds
# ...
# 2774
#
#  2023-06-09 09:42:37.374998  - random_milliseconds / 1000
# ...
# 2.774
#
#  2023-06-09 09:42:41.887424  - random_milliseconds
# ...
# 2358
#
#  2023-06-09 09:42:41.887424  - random_milliseconds / 1000
# ...
# 2.358
#
#  2023-06-09 09:42:45.437212  - random_milliseconds
# ...
# 2796
#
#  2023-06-09 09:42:45.437212  - random_milliseconds / 1000
# ...
# 2.796
#
#  2023-06-09 09:42:50.746279  - random_milliseconds
# ...
# 3970
#
#  2023-06-09 09:42:50.746279  - random_milliseconds / 1000
# ...
# 3.97
#
#  2023-06-09 09:42:56.324602  - random_milliseconds
# ...
# 2435
#
#  2023-06-09 09:42:56.324602  - random_milliseconds / 1000
# ...
# 2.435
#
#  2023-06-09 09:43:00.530581  - random_milliseconds
# ...
# 3337
#
#  2023-06-09 09:43:00.530581  - random_milliseconds / 1000
# ...
# 3.337
#
#  2023-06-09 09:43:05.541506  - random_milliseconds
# ...
# 2735
#
#  2023-06-09 09:43:05.542504  - random_milliseconds / 1000
# ...
# 2.735
#
#  2023-06-09 09:43:09.174493  - random_milliseconds
# ...
# 2404
#
#  2023-06-09 09:43:09.174493  - random_milliseconds / 1000
# ...
# 2.404
#
#  2023-06-09 09:43:14.135449  - random_milliseconds
# ...
# 3100
#
#  2023-06-09 09:43:14.135449  - random_milliseconds / 1000
# ...
# 3.1
#  2023-06-09 09:43:18.923986  - random_milliseconds
# ...
# 2668
#
#  2023-06-09 09:43:18.923986  - random_milliseconds / 1000
# ...
# 2.668
#
#  2023-06-09 09:43:23.588093  - random_milliseconds
# ...
# 3624
#
#  2023-06-09 09:43:23.588093  - random_milliseconds / 1000
# ...
# 3.624
#
#  2023-06-09 09:43:28.919891  - random_milliseconds
# ...
# 2406
#
#  2023-06-09 09:43:28.919891  - random_milliseconds / 1000
# ...
# 2.406
#
#  2023-06-09 09:43:32.390486  - random_milliseconds
# ...
# 2320
#
#  2023-06-09 09:43:32.390486  - random_milliseconds / 1000
# ...
# 2.32
#
#  2023-06-09 09:43:37.081599  - random_milliseconds
# ...
# 3179
#
#  2023-06-09 09:43:37.081599  - random_milliseconds / 1000
# ...
# 3.179
#
#  2023-06-09 09:43:41.619590  - random_milliseconds
# ...
# 2562
#
#  2023-06-09 09:43:41.619590  - random_milliseconds / 1000
# ...
# 2.562
#
#  2023-06-09 09:43:45.990937  - random_milliseconds
# ...
# 3125
#
#  2023-06-09 09:43:45.990937  - random_milliseconds / 1000
# ...
# 3.125
#
#  2023-06-09 09:43:50.838234  - random_milliseconds
# ...
# 2164
#
#  2023-06-09 09:43:50.838234  - random_milliseconds / 1000
# ...
# 2.164
#
#  2023-06-09 09:43:54.098576  - random_milliseconds
# ...
# 2160
#
#  2023-06-09 09:43:54.098576  - random_milliseconds / 1000
# ...
# 2.16
#
#  2023-06-09 09:43:58.184673  - random_milliseconds
# ...
# 3187
#
#  2023-06-09 09:43:58.184673  - random_milliseconds / 1000
# ...
# 3.187
#
#  2023-06-09 09:44:02.911353  - random_milliseconds
# ...
# 3753
#
#  2023-06-09 09:44:02.911353  - random_milliseconds / 1000
# ...
# 3.753
#
#  2023-06-09 09:44:08.302077  - random_milliseconds
# ...
# 2327
#
#  2023-06-09 09:44:08.302077  - random_milliseconds / 1000
# ...
# 2.327
#
#  2023-06-09 09:44:12.228912  - random_milliseconds
# ...
# 3748
#
#  2023-06-09 09:44:12.228912  - random_milliseconds / 1000
# ...
# 3.748
#
#  2023-06-09 09:44:17.185285  - random_milliseconds
# ...
# 2275
#
#  2023-06-09 09:44:17.185285  - random_milliseconds / 1000
# ...
# 2.275
#
#  2023-06-09 09:44:21.861060  - random_milliseconds
# ...
# 2044
#
#  2023-06-09 09:44:21.861060  - random_milliseconds / 1000
# ...
# 2.044
#
#  2023-06-09 09:44:25.556689  - random_milliseconds
# ...
# 2806
#
#  2023-06-09 09:44:25.556689  - random_milliseconds / 1000
# ...
# 2.806
#
#  2023-06-09 09:44:29.815790  - random_milliseconds
# ...
# 2882
#
#  2023-06-09 09:44:29.815790  - random_milliseconds / 1000
# ...
# 2.882
#
#  2023-06-09 09:44:34.693444  - random_milliseconds
# ...
# 3287
#
#  2023-06-09 09:44:34.693444  - random_milliseconds / 1000
# ...
# 3.287
#
#  2023-06-09 09:44:39.161230  - random_milliseconds
# ...
# 3879
#
#  2023-06-09 09:44:39.161230  - random_milliseconds / 1000
# ...
# 3.879
#
#  2023-06-09 09:44:45.219633  - random_milliseconds
# ...
# 2200
#
#  2023-06-09 09:44:45.219633  - random_milliseconds / 1000
# ...
# 2.2
#
#  2023-06-09 09:44:48.984769  - random_milliseconds
# ...
# 3071
#
#  2023-06-09 09:44:48.984769  - random_milliseconds / 1000
# ...
# 3.071
#
#  2023-06-09 09:44:53.635708  - random_milliseconds
# ...
# 2108
#
#  2023-06-09 09:44:53.635708  - random_milliseconds / 1000
# ...
# 2.108
#
#  2023-06-09 09:44:57.252925  - random_milliseconds
# ...
# 3788
#
#  2023-06-09 09:44:57.252925  - random_milliseconds / 1000
# ...
# 3.788
#
#  2023-06-09 09:45:02.020957  - random_milliseconds
# ...
# 3578
#
#  2023-06-09 09:45:02.020957  - random_milliseconds / 1000
# ...
# 3.578
#
#  2023-06-09 09:45:08.233168  - random_milliseconds
# ...
# 3326
#
#  2023-06-09 09:45:08.233168  - random_milliseconds / 1000
# ...
# 3.326
#
#  2023-06-09 09:45:13.217912  - random_milliseconds
# ...
# 2148
#
#  2023-06-09 09:45:13.217912  - random_milliseconds / 1000
# ...
# 2.148
#
#  2023-06-09 09:45:17.171782  - random_milliseconds
# ...
# 3407
#
#  2023-06-09 09:45:17.171782  - random_milliseconds / 1000
# ...
# 3.407
#
#  2023-06-09 09:45:22.315624  - random_milliseconds
# ...
# 2188
#
#  2023-06-09 09:45:22.316621  - random_milliseconds / 1000
# ...
# 2.188
#
#  2023-06-09 09:45:25.607115  - random_milliseconds
# ...
# 2399
#
#  2023-06-09 09:45:25.607115  - random_milliseconds / 1000
# ...
# 2.399
#
#  2023-06-09 09:45:30.488542  - random_milliseconds
# ...
# 3904
#
#  2023-06-09 09:45:30.488542  - random_milliseconds / 1000
# ...
# 3.904
#
#  2023-06-09 09:45:36.187443  - random_milliseconds
# ...
# 2234
#
#  2023-06-09 09:45:36.187443  - random_milliseconds / 1000
# ...
# 2.234
#
#  2023-06-09 09:45:40.112415  - random_milliseconds
# ...
# 3166
#
#  2023-06-09 09:45:40.112415  - random_milliseconds / 1000
# ...
# 3.166
#
#  2023-06-09 09:45:45.070912  - random_milliseconds
# ...
# 2253
#
#  2023-06-09 09:45:45.070912  - random_milliseconds / 1000
# ...
# 2.253
#
#  2023-06-09 09:45:49.122920  - random_milliseconds
# ...
# 3732
#
#  2023-06-09 09:45:49.122920  - random_milliseconds / 1000
# ...
# 3.732
#
#  2023-06-09 09:45:55.400666  - random_milliseconds
# ...
# 2951
#
#  2023-06-09 09:45:55.400666  - random_milliseconds / 1000
# ...
# 2.951
#
#  2023-06-09 09:46:00.085226  - random_milliseconds
# ...
# 2304
#
#  2023-06-09 09:46:00.085226  - random_milliseconds / 1000
# ...
# 2.304
#
#  2023-06-09 09:46:04.256572  - random_milliseconds
# ...
# 2442
#
#  2023-06-09 09:46:04.256572  - random_milliseconds / 1000
# ...
# 2.442
#
#  2023-06-09 09:46:08.584850  - random_milliseconds
# ...
# 2825
#
#  2023-06-09 09:46:08.584850  - random_milliseconds / 1000
# ...
# 2.825
#
#  2023-06-09 09:46:12.638619  - random_milliseconds
# ...
# 2917
#
#  2023-06-09 09:46:12.639613  - random_milliseconds / 1000
# ...
# 2.917
#
#  2023-06-09 09:46:18.139372  - random_milliseconds
# ...
# 2776
#
#  2023-06-09 09:46:18.139372  - random_milliseconds / 1000
# ...
# 2.776
#
#  2023-06-09 09:46:22.433659  - random_milliseconds
# ...
# 3843
#
#  2023-06-09 09:46:22.433659  - random_milliseconds / 1000
# ...
# 3.843
#
#  2023-06-09 09:46:28.135507  - random_milliseconds
# ...
# 3881
#
#  2023-06-09 09:46:28.135507  - random_milliseconds / 1000
# ...
# 3.881
#
#  2023-06-09 09:46:33.848878  - random_milliseconds
# ...
# 3228
#
#  2023-06-09 09:46:33.849875  - random_milliseconds / 1000
# ...
# 3.228
#
#  2023-06-09 09:46:38.063510  - random_milliseconds
# ...
# 3180
#
#  2023-06-09 09:46:38.063510  - random_milliseconds / 1000
# ...
# 3.18
#
#  2023-06-09 09:46:43.694189  - random_milliseconds
# ...
# 3643
#
#  2023-06-09 09:46:43.694189  - random_milliseconds / 1000
# ...
# 3.643
#
#  2023-06-09 09:46:49.193052  - random_milliseconds
# ...
# 2335
#
#  2023-06-09 09:46:49.193052  - random_milliseconds / 1000
# ...
# 2.335
#
#  2023-06-09 09:46:53.282388  - random_milliseconds
# ...
# 3666
#
#  2023-06-09 09:46:53.283385  - random_milliseconds / 1000
# ...
# 3.666
#
#  2023-06-09 09:46:58.788237  - random_milliseconds
# ...
# 3886
#
#  2023-06-09 09:46:58.788237  - random_milliseconds / 1000
# ...
# 3.886
#
#  2023-06-09 09:47:04.257827  - random_milliseconds
# ...
# 3991
#
#  2023-06-09 09:47:04.257827  - random_milliseconds / 1000
# ...
# 3.991
#
#  2023-06-09 09:47:10.316912  - random_milliseconds
# ...
# 3254
#
#  2023-06-09 09:47:10.316912  - random_milliseconds / 1000
# ...
# 3.254
#
#  2023-06-09 09:47:15.329727  - random_milliseconds
# ...
# 2141
#
#  2023-06-09 09:47:15.329727  - random_milliseconds / 1000
# ...
# 2.141
#
#  2023-06-09 09:47:19.249080  - random_milliseconds
# ...
# 3137
#
#  2023-06-09 09:47:19.249080  - random_milliseconds / 1000
# ...
# 3.137
#
#  2023-06-09 09:47:24.294137  - random_milliseconds
# ...
# 2167
#
#  2023-06-09 09:47:24.294137  - random_milliseconds / 1000
# ...
# 2.167
#
#  2023-06-09 09:47:27.667505  - random_milliseconds
# ...
# 3367
#
#  2023-06-09 09:47:27.667505  - random_milliseconds / 1000
# ...
# 3.367
#
#  2023-06-09 09:47:33.639868  - random_milliseconds
# ...
# 2169
#
#  2023-06-09 09:47:33.639868  - random_milliseconds / 1000
# ...
# 2.169
#
#  2023-06-09 09:47:37.582602  - random_milliseconds
# ...
# 3970
#
#  2023-06-09 09:47:37.582602  - random_milliseconds / 1000
# ...
# 3.97
#
#  2023-06-09 09:47:43.189850  - random_milliseconds
# ...
# 3851
#
#  2023-06-09 09:47:43.189850  - random_milliseconds / 1000
# ...
# 3.851
#
#  2023-06-09 09:47:48.809637  - random_milliseconds
# ...
# 3956
#
#  2023-06-09 09:47:48.809637  - random_milliseconds / 1000
# ...
# 3.956
#
#  2023-06-09 09:47:53.884461  - random_milliseconds
# ...
# 3754
#
#  2023-06-09 09:47:53.884461  - random_milliseconds / 1000
# ...
# 3.754
#
#  2023-06-09 09:48:00.108474  - random_milliseconds
# ...
# 3133
#
#  2023-06-09 09:48:00.108474  - random_milliseconds / 1000
# ...
# 3.133
#
#  2023-06-09 09:48:04.994990  - random_milliseconds
# ...
# 3644
#
#  2023-06-09 09:48:04.994990  - random_milliseconds / 1000
# ...
# 3.644
#
#  2023-06-09 09:48:10.512037  - random_milliseconds
# ...
# 2361
#
#  2023-06-09 09:48:10.512037  - random_milliseconds / 1000
# ...
# 2.361
#
#  2023-06-09 09:48:14.544367  - random_milliseconds
# ...
# 3389
#
#  2023-06-09 09:48:14.544367  - random_milliseconds / 1000
# ...
# 3.389
#  2023-06-09 09:48:19.403251  - random_milliseconds
# ...
# 3778
#
#  2023-06-09 09:48:19.403251  - random_milliseconds / 1000
# ...
# 3.778
#
#  2023-06-09 09:48:25.709962  - random_milliseconds
# ...
# 2378
#
#  2023-06-09 09:48:25.709962  - random_milliseconds / 1000
# ...
# 2.378
#
#  2023-06-09 09:48:29.648304  - random_milliseconds
# ...
# 3782
#
#  2023-06-09 09:48:29.648304  - random_milliseconds / 1000
# ...
# 3.782
#
#  2023-06-09 09:48:35.276644  - random_milliseconds
# ...
# 3533
#
#  2023-06-09 09:48:35.276644  - random_milliseconds / 1000
# ...
# 3.533
#
#  2023-06-09 09:48:40.656883  - random_milliseconds
# ...
# 3065
#
#  2023-06-09 09:48:40.656883  - random_milliseconds / 1000
# ...
# 3.065
#
#  2023-06-09 09:48:44.810533  - random_milliseconds
# ...
# 3908
#
#  2023-06-09 09:48:44.810533  - random_milliseconds / 1000
# ...
# 3.908
#
#  2023-06-09 09:48:51.166495  - random_milliseconds
# ...
# 2051
#
#  2023-06-09 09:48:51.166495  - random_milliseconds / 1000
# ...
# 2.051
#
#  2023-06-09 09:48:54.989485  - random_milliseconds
# ...
# 2217
#
#  2023-06-09 09:48:54.989485  - random_milliseconds / 1000
# ...
# 2.217
#
#  2023-06-09 09:48:58.984516  - random_milliseconds
# ...
# 2341
#
#  2023-06-09 09:48:58.984516  - random_milliseconds / 1000
# ...
# 2.341
#
#  2023-06-09 09:49:02.849007  - random_milliseconds
# ...
# 3088
#
#  2023-06-09 09:49:02.849007  - random_milliseconds / 1000
# ...
# 3.088
#
#  2023-06-09 09:49:07.076521  - random_milliseconds
# ...
# 3989
#
#  2023-06-09 09:49:07.076521  - random_milliseconds / 1000
# ...
# 3.989
#
#  2023-06-09 09:49:13.350819  - random_milliseconds
# ...
# 2822
#
#  2023-06-09 09:49:13.350819  - random_milliseconds / 1000
# ...
# 2.822
#
#  2023-06-09 09:49:17.802081  - random_milliseconds
# ...
# 3408
#
#  2023-06-09 09:49:17.802081  - random_milliseconds / 1000
# ...
# 3.408
#
#  2023-06-09 09:49:23.012319  - random_milliseconds
# ...
# 3097
#
#  2023-06-09 09:49:23.012319  - random_milliseconds / 1000
# ...
# 3.097
#
#  2023-06-09 09:49:28.288485  - random_milliseconds
# ...
# 3214
#
#  2023-06-09 09:49:28.288485  - random_milliseconds / 1000
# ...
# 3.214
#
#  2023-06-09 09:49:32.699004  - random_milliseconds
# ...
# 3895
#
#  2023-06-09 09:49:32.699004  - random_milliseconds / 1000
# ...
# 3.895
#
#  2023-06-09 09:49:39.069864  - random_milliseconds
# ...
# 2226
#
#  2023-06-09 09:49:39.069864  - random_milliseconds / 1000
# ...
# 2.226
#
#  2023-06-09 09:49:43.160355  - random_milliseconds
# ...
# 2307
#
#  2023-06-09 09:49:43.160355  - random_milliseconds / 1000
# ...
# 2.307
#
#  2023-06-09 09:49:47.364206  - random_milliseconds
# ...
# 2073
#
#  2023-06-09 09:49:47.364206  - random_milliseconds / 1000
# ...
# 2.073
#
#  2023-06-09 09:49:51.163392  - random_milliseconds
# ...
# 2868
#
#  2023-06-09 09:49:51.163392  - random_milliseconds / 1000
# ...
# 2.868
#
#  2023-06-09 09:49:55.122681  - random_milliseconds
# ...
# 3193
#
#  2023-06-09 09:49:55.122681  - random_milliseconds / 1000
# ...
# 3.193
#
#  2023-06-09 09:50:00.846816  - random_milliseconds
# ...
# 2610
#
#  2023-06-09 09:50:00.846816  - random_milliseconds / 1000
# ...
# 2.61
#
#  2023-06-09 09:50:05.251472  - random_milliseconds
# ...
# 3717
#
#  2023-06-09 09:50:05.251472  - random_milliseconds / 1000
# ...
# 3.717
#
#  2023-06-09 09:50:10.808310  - random_milliseconds
# ...
# 3220
#
#  2023-06-09 09:50:10.808310  - random_milliseconds / 1000
# ...
# 3.22
#
#  2023-06-09 09:50:15.964954  - random_milliseconds
# ...
# 3794
#
#  2023-06-09 09:50:15.964954  - random_milliseconds / 1000
# ...
# 3.794
#
#  2023-06-09 09:50:20.824801  - random_milliseconds
# ...
# 3790
#
#  2023-06-09 09:50:20.824801  - random_milliseconds / 1000
# ...
# 3.79
#
#  2023-06-09 09:50:27.129985  - random_milliseconds
# ...
# 3900
#
#  2023-06-09 09:50:27.129985  - random_milliseconds / 1000
# ...
# 3.9
#
#  2023-06-09 09:50:33.010988  - random_milliseconds
# ...
# 2522
#
#  2023-06-09 09:50:33.010988  - random_milliseconds / 1000
# ...
# 2.522
#
#  2023-06-09 09:50:37.472861  - random_milliseconds
# ...
# 3291
#
#  2023-06-09 09:50:37.472861  - random_milliseconds / 1000
# ...
# 3.291
#
#  2023-06-09 09:50:43.040516  - random_milliseconds
# ...
# 2304
#
#  2023-06-09 09:50:43.040516  - random_milliseconds / 1000
# ...
# 2.304
#
#  2023-06-09 09:50:46.622254  - random_milliseconds
# ...
# 3816
#
#  2023-06-09 09:50:46.622254  - random_milliseconds / 1000
# ...
# 3.816
#
#  2023-06-09 09:50:52.759251  - random_milliseconds
# ...
# 3698
#
#  2023-06-09 09:50:52.759251  - random_milliseconds / 1000
# ...
# 3.698
#
#  2023-06-09 09:50:58.254370  - random_milliseconds
# ...
# 2738
#
#  2023-06-09 09:50:58.254370  - random_milliseconds / 1000
# ...
# 2.738
#
#  2023-06-09 09:51:02.817057  - random_milliseconds
# ...
# 3670
#
#  2023-06-09 09:51:02.817057  - random_milliseconds / 1000
# ...
# 3.67
#
#  2023-06-09 09:51:08.362621  - random_milliseconds
# ...
# 3235
#
#  2023-06-09 09:51:08.363618  - random_milliseconds / 1000
# ...
# 3.235
#
#  2023-06-09 09:51:12.740812  - random_milliseconds
# ...
# 2685
#
#  2023-06-09 09:51:12.741811  - random_milliseconds / 1000
# ...
# 2.685
#
#  2023-06-09 09:51:18.012351  - random_milliseconds
# ...
# 2425
#
#  2023-06-09 09:51:18.012351  - random_milliseconds / 1000
# ...
# 2.425
#
#  2023-06-09 09:51:22.311505  - random_milliseconds
# ...
# 3746
#
#  2023-06-09 09:51:22.311505  - random_milliseconds / 1000
# ...
# 3.746
#
#  2023-06-09 09:51:27.995123  - random_milliseconds
# ...
# 2438
#
#  2023-06-09 09:51:27.995123  - random_milliseconds / 1000
# ...
# 2.438
#
#  2023-06-09 09:51:32.375577  - random_milliseconds
# ...
# 2308
#
#  2023-06-09 09:51:32.375577  - random_milliseconds / 1000
# ...
# 2.308
#
#  2023-06-09 09:51:35.960724  - random_milliseconds
# ...
# 3979
#
#  2023-06-09 09:51:35.960724  - random_milliseconds / 1000
# ...
# 3.979
#
#  2023-06-09 09:51:42.053028  - random_milliseconds
# ...
# 2747
#
#  2023-06-09 09:51:42.053028  - random_milliseconds / 1000
# ...
# 2.747
#
#  2023-06-09 09:51:46.702473  - random_milliseconds
# ...
# 3155
#
#  2023-06-09 09:51:46.702473  - random_milliseconds / 1000
# ...
# 3.155
#
#  2023-06-09 09:51:52.180757  - random_milliseconds
# ...
# 3412
#
#  2023-06-09 09:51:52.180757  - random_milliseconds / 1000
# ...
# 3.412
#
#  2023-06-09 09:51:57.487840  - random_milliseconds
# ...
# 3311
#
#  2023-06-09 09:51:57.487840  - random_milliseconds / 1000
# ...
# 3.311
#
#  2023-06-09 09:52:01.957634  - random_milliseconds
# ...
# 3715
#
#  2023-06-09 09:52:01.957634  - random_milliseconds / 1000
# ...
# 3.715
#
#  2023-06-09 09:52:08.153169  - random_milliseconds
# ...
# 2830
#
#  2023-06-09 09:52:08.153169  - random_milliseconds / 1000
# ...
# 2.83
#
#  2023-06-09 09:52:12.853561  - random_milliseconds
# ...
# 3370
#
#  2023-06-09 09:52:12.853561  - random_milliseconds / 1000
# ...
# 3.37
#
#  2023-06-09 09:52:18.048894  - random_milliseconds
# ...
# 3218
#
#  2023-06-09 09:52:18.048894  - random_milliseconds / 1000
# ...
# 3.218
#
#  2023-06-09 09:52:23.194656  - random_milliseconds
# ...
# 2837
#
#  2023-06-09 09:52:23.195655  - random_milliseconds / 1000
# ...
# 2.837
#
#  2023-06-09 09:52:27.270547  - random_milliseconds
# ...
# 3650
#
#  2023-06-09 09:52:27.270547  - random_milliseconds / 1000
# ...
# 3.65
#
#  2023-06-09 09:52:33.450296  - random_milliseconds
# ...
# 3554
#
#  2023-06-09 09:52:33.450296  - random_milliseconds / 1000
# ...
# 3.554
#
#  2023-06-09 09:52:39.039442  - random_milliseconds
# ...
# 3081
#
#  2023-06-09 09:52:39.039442  - random_milliseconds / 1000
# ...
# 3.081
#
#  2023-06-09 09:52:44.270344  - random_milliseconds
# ...
# 3357
#
#  2023-06-09 09:52:44.270344  - random_milliseconds / 1000
# ...
# 3.357
#
#  2023-06-09 09:52:49.902097  - random_milliseconds
# ...
# 2338
#
#  2023-06-09 09:52:49.902097  - random_milliseconds / 1000
# ...
# 2.338
#
#  2023-06-09 09:52:53.437620  - random_milliseconds
# ...
# 3766
#
#  2023-06-09 09:52:53.437620  - random_milliseconds / 1000
# ...
# 3.766
#
#  2023-06-09 09:52:59.804986  - random_milliseconds
# ...
# 3701
#
#  2023-06-09 09:52:59.804986  - random_milliseconds / 1000
# ...
# 3.701
#
#  2023-06-09 09:53:05.868938  - random_milliseconds
# ...
# 2609
#
#  2023-06-09 09:53:05.868938  - random_milliseconds / 1000
# ...
# 2.609
#
#  2023-06-09 09:53:10.566461  - random_milliseconds
# ...
# 2920
#
#  2023-06-09 09:53:10.566461  - random_milliseconds / 1000
# ...
# 2.92
#
#  2023-06-09 09:53:15.477717  - random_milliseconds
# ...
# 2725
#
#  2023-06-09 09:53:15.478714  - random_milliseconds / 1000
# ...
# 2.725
#
#  2023-06-09 09:53:19.188812  - random_milliseconds
# ...
# 2900
#
#  2023-06-09 09:53:19.188812  - random_milliseconds / 1000
# ...
# 2.9
#
#  2023-06-09 09:53:24.622480  - random_milliseconds
# ...
# 3472
#
#  2023-06-09 09:53:24.622480  - random_milliseconds / 1000
# ...
# 3.472
#
#  2023-06-09 09:53:30.029100  - random_milliseconds
# ...
# 3311
#
#  2023-06-09 09:53:30.029100  - random_milliseconds / 1000
# ...
# 3.311
#  2023-06-09 09:53:35.096600  - random_milliseconds
# ...
# 2674
#
#  2023-06-09 09:53:35.097613  - random_milliseconds / 1000
# ...
# 2.674
#
#  2023-06-09 09:53:39.932709  - random_milliseconds
# ...
# 2600
#
#  2023-06-09 09:53:39.932709  - random_milliseconds / 1000
# ...
# 2.6
#
#  2023-06-09 09:53:43.721114  - random_milliseconds
# ...
# 2290
#
#  2023-06-09 09:53:43.721114  - random_milliseconds / 1000
# ...
# 2.29
#
#  2023-06-09 09:53:48.507053  - random_milliseconds
# ...
# 3191
#
#  2023-06-09 09:53:48.507053  - random_milliseconds / 1000
# ...
# 3.191
#
#  2023-06-09 09:53:53.505828  - random_milliseconds
# ...
# 2907
#
#  2023-06-09 09:53:53.505828  - random_milliseconds / 1000
# ...
# 2.907
#
#  2023-06-09 09:53:58.501984  - random_milliseconds
# ...
# 3130
#
#  2023-06-09 09:53:58.502984  - random_milliseconds / 1000
# ...
# 3.13
#
#  2023-06-09 09:54:04.017581  - random_milliseconds
# ...
# 3896
#
#  2023-06-09 09:54:04.018596  - random_milliseconds / 1000
# ...
# 3.896
#
#  2023-06-09 09:54:09.194647  - random_milliseconds
# ...
# 2939
#
#  2023-06-09 09:54:09.194647  - random_milliseconds / 1000
# ...
# 2.939
#
#  2023-06-09 09:54:14.732090  - random_milliseconds
# ...
# 3350
#
#  2023-06-09 09:54:14.732090  - random_milliseconds / 1000
# ...
# 3.35
#
#  2023-06-09 09:54:19.983922  - random_milliseconds
# ...
# 3023
#
#  2023-06-09 09:54:19.983922  - random_milliseconds / 1000
# ...
# 3.023
#
#  2023-06-09 09:54:24.959544  - random_milliseconds
# ...
# 3797
#
#  2023-06-09 09:54:24.960549  - random_milliseconds / 1000
# ...
# 3.797
#
#  2023-06-09 09:54:31.179041  - random_milliseconds
# ...
# 2009
#
#  2023-06-09 09:54:31.179041  - random_milliseconds / 1000
# ...
# 2.009
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22416\3447074465.py in <module>
#     158 #     attaquer_village('3466', '3275', 'data/village.txt')
#     159 #     attaquer_village('3466', '3172', 'data/village.txt')
# --> 160     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
#     161     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
#     162     delay_with_random_seconds()
#
# ~\AppData\Local\Temp\ipykernel_22416\3447074465.py in attaquer_village(troupes_file)
#      75
#      76         bouton = firefox.child_window(auto_id='troop_confirm_submit')
# ---> 77         bouton.click()
#      78         delay_with_random_seconds()
#      79
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     377         if len(self.criteria) >= 2:  # FIXME - this is surprising
#     378
# --> 379             ctrls = self.__resolve_control(self.criteria)
#     380
#     381             try:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     220                 if 'backend' not in ctrl_criteria:
#     221                     ctrl_criteria['backend'] = self.backend.name
# --> 222                 ctrl = self.backend.generic_wrapper_class(findwindows.find_element(**ctrl_criteria))
#     223                 previous_parent = ctrl.element_info
#     224                 ctrls.append(ctrl)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'auto_id': 'troop_confirm_submit', 'top_level_only': False, 'parent': <uia_element_info.UIAElementInfo - 'arion1 (556|484) - Guerre Tribale - Monde 81 — Mozilla Firefox', MozillaWindowClass, 71567738>, 'backend': 'uia'}
