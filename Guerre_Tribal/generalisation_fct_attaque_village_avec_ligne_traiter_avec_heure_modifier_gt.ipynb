# %%
from pywinauto.application import Application
import psutil
import time
import random
import requests
import csv
import datetime
import fileinput

def delay_with_random_seconds():
#     # Génère un délai aléatoire entre 1 et 5 secondes
#     random_seconds = random.randint(2, 4)
# #     print(random_seconds)
    
#     # Pause l'exécution du programme pendant le délai aléatoire
#     time.sleep(random_seconds)
    random_milliseconds = random.randint(2000, 4000)  # Générer un nombre aléatoire en millisecondes entre 2000 et 4000
    print('\n', datetime.datetime.now(),' - random_milliseconds \n...')   
    print(random_milliseconds)
    print('\n', datetime.datetime.now(),' - random_milliseconds / 1000 \n...')   
    print(random_milliseconds / 1000)
    time.sleep(random_milliseconds / 1000)  # Utiliser la valeur en millisecondes dans time.sleep()
 #     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()

def attaquer_village(troupes_file):
    # Réafficher la fenêtre de navigateur
#     firefox.activate()
    firefox.set_focus()

    lines = []

    # Lire le fichier et stocker les lignes dans une liste
    with open(troupes_file, 'r') as file:
        lines = file.readlines()

    # Exclure la première ligne (en-têtes)
    headers = lines[0].strip().split(',')
    lines = lines[1:]

    # Trier les lignes par heure_attaque la plus ancienne
    lines = sorted(lines, key=lambda x: datetime.datetime.strptime(x.strip().split(',')[headers.index('heure_attaque')], "%Y-%m-%d %H:%M:%S"))

    # Parcourir les lignes triées
    for i, line in enumerate(lines):
        data = line.strip().split(',')
        village_depart = data[headers.index('village_depart')]
        village_attaquer = data[headers.index('village_attaquer')]

        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_attaquer}"
        firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()

        # Saisir les champs pour chaque type de troupe
        for header in headers:
            if header not in ['heure_attaque', 'village_depart', 'village_attaquer']:
                value = int(data[headers.index(header)])
                if value > 0:
                    zone = firefox.child_window(auto_id=header)
                    zone.type_keys(str(value))
                    delay_with_random_seconds()

        # Mettre à jour la colonne heure_attaque avec l'heure actuelle
        heure_attaque_index = headers.index('heure_attaque')
        heure_attaque = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        data[heure_attaque_index] = heure_attaque

        # Modifier la ligne dans la liste
        lines[i] = ','.join(data) + '\n'

        bouton = firefox.child_window(auto_id='target_attack')
        bouton.click()
        delay_with_random_seconds()

        bouton = firefox.child_window(auto_id='troop_confirm_submit')
        bouton.click()
        delay_with_random_seconds()

    # Réécrire le fichier avec les lignes modifiées
    with open(troupes_file, 'w') as file:
        file.write(','.join(headers) + '\n')  # Réécrire les en-têtes
        file.writelines(lines)  # Réécrire les lignes modifiées


# Vérifier si Firefox est en cours d'exécution
firefox_running = False
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_running = True
        firefox_pid = process.pid
        break

# Fermer Firefox si c'est le cas
if firefox_running:
    process = psutil.Process(firefox_pid)
    process.terminate()
#     time.sleep(5)
# Ouvrir Firefox
time.sleep(2)

app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Ouvrir Firefox
# app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Trouver le PID de Firefox
firefox_pid = None
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_pid = process.pid
        break

# Vérifier si Firefox est en cours d'exécution
if firefox_pid is None:
    print("Firefox n'est pas en cours d'exécution.")
else:
    # Attacher Pywinauto à la fenêtre Firefox
    app = Application(backend='uia').connect(process=firefox_pid)

    # Ouvrir une page web
#     firefox = app.window(title_re='.*Nouvel onglet*')
    firefox = app.window( class_name='MozillaWindowClass')

    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     time.sleep(5)

#     # Saisir les champs
#     zone1 = firefox.window(title='user')
#     zone1.type_keys('*test1')
#     zone1 = firefox.child_window(control_type="Edit", found_index=0, automation_id="user")
    zone1 = firefox.child_window(auto_id='user')

    zone1.type_keys('arion1')
    delay_with_random_seconds()

    zone2 = firefox.child_window(auto_id='password')
    zone2.type_keys('MiMa5158**')
    delay_with_random_seconds()
    # Cliquer sur le bouton
#     bouton = firefox.window(title='Connexion')
# #     bouton = firefox.child_window(auto_id='btn-login')
#     bouton = firefox.child_window(title='Connexion')
#     bouton.click()!
    bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
    bouton.invoke()
#     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
#     bouton.invoke()
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    
#     attaquer_village('3466', '3275', 'data/village.txt')
#     attaquer_village('3466', '3172', 'data/village.txt')
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
    delay_with_random_seconds()    
    # Fermer Firefox 
#     firefox.close()
# Out:
#  2023-06-13 18:01:42.222499  - random_milliseconds
# ...
# 2642
#
#  2023-06-13 18:01:42.222499  - random_milliseconds / 1000
# ...
# 2.642
#
#  2023-06-13 18:01:45.717460  - random_milliseconds
# ...
# 2349
#
#  2023-06-13 18:01:45.717460  - random_milliseconds / 1000
# ...
# 2.349
#
#  2023-06-13 18:01:48.582228  - random_milliseconds
# ...
# 2719
#
#  2023-06-13 18:01:48.583225  - random_milliseconds / 1000
# ...
# 2.719
#
#  2023-06-13 18:01:52.601357  - random_milliseconds
# ...
# 3421
#
#  2023-06-13 18:01:52.601357  - random_milliseconds / 1000
# ...
# 3.421
#
#  2023-06-13 18:01:57.717334  - random_milliseconds
# ...
# 3087
#
#  2023-06-13 18:01:57.717334  - random_milliseconds / 1000
# ...
# 3.087
#
#  2023-06-13 18:02:02.796648  - random_milliseconds
# ...
# 3000
#
#  2023-06-13 18:02:02.796648  - random_milliseconds / 1000
# ...
# 3.0
#
#  2023-06-13 18:02:07.292200  - random_milliseconds
# ...
# 2779
#
#  2023-06-13 18:02:07.292200  - random_milliseconds / 1000
# ...
# 2.779
#
#  2023-06-13 18:02:11.755846  - random_milliseconds
# ...
# 2559
#
#  2023-06-13 18:02:11.755846  - random_milliseconds / 1000
# ...
# 2.559
#
#  2023-06-13 18:02:15.885210  - random_milliseconds
# ...
# 2482
#
#  2023-06-13 18:02:15.885210  - random_milliseconds / 1000
# ...
# 2.482
#
#  2023-06-13 18:02:19.163735  - random_milliseconds
# ...
# 2917
#
#  2023-06-13 18:02:19.163735  - random_milliseconds / 1000
# ...
# 2.917
#
#  2023-06-13 18:02:23.921244  - random_milliseconds
# ...
# 2283
#
#  2023-06-13 18:02:23.921244  - random_milliseconds / 1000
# ...
# 2.283
#
#  2023-06-13 18:02:27.916738  - random_milliseconds
# ...
# 3387
#
#  2023-06-13 18:02:27.916738  - random_milliseconds / 1000
# ...
# 3.387
#
#  2023-06-13 18:02:33.488814  - random_milliseconds
# ...
# 3952
#
#  2023-06-13 18:02:33.488814  - random_milliseconds / 1000
# ...
# 3.952
#
#  2023-06-13 18:02:39.403336  - random_milliseconds
# ...
# 2888
#
#  2023-06-13 18:02:39.403336  - random_milliseconds / 1000
# ...
# 2.888
#
#  2023-06-13 18:02:43.018365  - random_milliseconds
# ...
# 2502
#
#  2023-06-13 18:02:43.018365  - random_milliseconds / 1000
# ...
# 2.502
#
#  2023-06-13 18:02:47.338149  - random_milliseconds
# ...
# 2992
#
#  2023-06-13 18:02:47.338149  - random_milliseconds / 1000
# ...
# 2.992
#
#  2023-06-13 18:02:51.939324  - random_milliseconds
# ...
# 2929
#
#  2023-06-13 18:02:51.939324  - random_milliseconds / 1000
# ...
# 2.929
#
#  2023-06-13 18:02:56.474491  - random_milliseconds
# ...
# 3786
#
#  2023-06-13 18:02:56.474491  - random_milliseconds / 1000
# ...
# 3.786
#
#  2023-06-13 18:03:01.936115  - random_milliseconds
# ...
# 3289
#
#  2023-06-13 18:03:01.936115  - random_milliseconds / 1000
# ...
# 3.289
#
#  2023-06-13 18:03:05.985882  - random_milliseconds
# ...
# 2068
#
#  2023-06-13 18:03:05.985882  - random_milliseconds / 1000
# ...
# 2.068
#
#  2023-06-13 18:03:09.909826  - random_milliseconds
# ...
# 2649
#
#  2023-06-13 18:03:09.909826  - random_milliseconds / 1000
# ...
# 2.649
#
#  2023-06-13 18:03:14.130245  - random_milliseconds
# ...
# 2020
#
#  2023-06-13 18:03:14.130245  - random_milliseconds / 1000
# ...
# 2.02
#
#  2023-06-13 18:03:18.260044  - random_milliseconds
# ...
# 3300
#
#  2023-06-13 18:03:18.260044  - random_milliseconds / 1000
# ...
# 3.3
#
#  2023-06-13 18:03:23.156579  - random_milliseconds
# ...
# 2806
#
#  2023-06-13 18:03:23.156579  - random_milliseconds / 1000
# ...
# 2.806
#
#  2023-06-13 18:03:26.709555  - random_milliseconds
# ...
# 3338
#
#  2023-06-13 18:03:26.709555  - random_milliseconds / 1000
# ...
# 3.338
#
#  2023-06-13 18:03:31.887546  - random_milliseconds
# ...
# 3851
#
#  2023-06-13 18:03:31.887546  - random_milliseconds / 1000
# ...
# 3.851
#
#  2023-06-13 18:03:37.323623  - random_milliseconds
# ...
# 3389
#
#  2023-06-13 18:03:37.323623  - random_milliseconds / 1000
# ...
# 3.389
#
#  2023-06-13 18:03:42.345225  - random_milliseconds
# ...
# 2104
#
#  2023-06-13 18:03:42.345225  - random_milliseconds / 1000
# ...
# 2.104
#
#  2023-06-13 18:03:46.213320  - random_milliseconds
# ...
# 2890
#
#  2023-06-13 18:03:46.213320  - random_milliseconds / 1000
# ...
# 2.89
#
#  2023-06-13 18:03:49.843868  - random_milliseconds
# ...
# 2857
#
#  2023-06-13 18:03:49.843868  - random_milliseconds / 1000
# ...
# 2.857
#
#  2023-06-13 18:03:54.503951  - random_milliseconds
# ...
# 3323
#
#  2023-06-13 18:03:54.503951  - random_milliseconds / 1000
# ...
# 3.323
#
#  2023-06-13 18:03:59.406976  - random_milliseconds
# ...
# 3159
#
#  2023-06-13 18:03:59.407973  - random_milliseconds / 1000
# ...
# 3.159
#
#  2023-06-13 18:04:04.829450  - random_milliseconds
# ...
# 3551
#
#  2023-06-13 18:04:04.829450  - random_milliseconds / 1000
# ...
# 3.551
#
#  2023-06-13 18:04:10.039634  - random_milliseconds
# ...
# 3576
#
#  2023-06-13 18:04:10.039634  - random_milliseconds / 1000
# ...
# 3.576
#
#  2023-06-13 18:04:14.382121  - random_milliseconds
# ...
# 2329
#
#  2023-06-13 18:04:14.382121  - random_milliseconds / 1000
# ...
# 2.329
#
#  2023-06-13 18:04:18.507564  - random_milliseconds
# ...
# 3262
#
#  2023-06-13 18:04:18.507564  - random_milliseconds / 1000
# ...
# 3.262
#
#  2023-06-13 18:04:23.315908  - random_milliseconds
# ...
# 2228
#
#  2023-06-13 18:04:23.316905  - random_milliseconds / 1000
# ...
# 2.228
#
#  2023-06-13 18:04:27.274600  - random_milliseconds
# ...
# 3517
#
#  2023-06-13 18:04:27.274600  - random_milliseconds / 1000
# ...
# 3.517
#
#  2023-06-13 18:04:32.510485  - random_milliseconds
# ...
# 2912
#
#  2023-06-13 18:04:32.510485  - random_milliseconds / 1000
# ...
# 2.912
#
#  2023-06-13 18:04:36.143759  - random_milliseconds
# ...
# 2729
#
#  2023-06-13 18:04:36.143759  - random_milliseconds / 1000
# ...
# 2.729
#
#  2023-06-13 18:04:40.663150  - random_milliseconds
# ...
# 3220
#
#  2023-06-13 18:04:40.663150  - random_milliseconds / 1000
# ...
# 3.22
#
#  2023-06-13 18:04:45.480385  - random_milliseconds
# ...
# 2068
#
#  2023-06-13 18:04:45.480385  - random_milliseconds / 1000
# ...
# 2.068
#
#  2023-06-13 18:04:49.232947  - random_milliseconds
# ...
# 2623
#
#  2023-06-13 18:04:49.232947  - random_milliseconds / 1000
# ...
# 2.623
#
#  2023-06-13 18:04:54.105627  - random_milliseconds
# ...
# 2853
#
#  2023-06-13 18:04:54.105627  - random_milliseconds / 1000
# ...
# 2.853
#
#  2023-06-13 18:04:57.723070  - random_milliseconds
# ...
# 2847
#
#  2023-06-13 18:04:57.723070  - random_milliseconds / 1000
# ...
# 2.847
#
#  2023-06-13 18:05:02.357174  - random_milliseconds
# ...
# 3190
#
#  2023-06-13 18:05:02.357174  - random_milliseconds / 1000
# ...
# 3.19
#
#  2023-06-13 18:05:07.340861  - random_milliseconds
# ...
# 2661
#
#  2023-06-13 18:05:07.340861  - random_milliseconds / 1000
# ...
# 2.661
#
#  2023-06-13 18:05:11.749163  - random_milliseconds
# ...
# 2863
#
#  2023-06-13 18:05:11.749163  - random_milliseconds / 1000
# ...
# 2.863
#
#  2023-06-13 18:05:16.643326  - random_milliseconds
# ...
# 3280
#
#  2023-06-13 18:05:16.643326  - random_milliseconds / 1000
# ...
# 3.28
#
#  2023-06-13 18:05:20.697312  - random_milliseconds
# ...
# 2300
#
#  2023-06-13 18:05:20.697312  - random_milliseconds / 1000
# ...
# 2.3
#
#  2023-06-13 18:05:24.846745  - random_milliseconds
# ...
# 2488
#
#  2023-06-13 18:05:24.846745  - random_milliseconds / 1000
# ...
# 2.488
#
#  2023-06-13 18:05:29.001918  - random_milliseconds
# ...
# 2958
#
#  2023-06-13 18:05:29.001918  - random_milliseconds / 1000
# ...
# 2.958
#
#  2023-06-13 18:05:34.000113  - random_milliseconds
# ...
# 2160
#
#  2023-06-13 18:05:34.000113  - random_milliseconds / 1000
# ...
# 2.16
#
#  2023-06-13 18:05:37.811054  - random_milliseconds
# ...
# 2892
#
#  2023-06-13 18:05:37.811054  - random_milliseconds / 1000
# ...
# 2.892
#
#  2023-06-13 18:05:41.445576  - random_milliseconds
# ...
# 2726
#
#  2023-06-13 18:05:41.445576  - random_milliseconds / 1000
# ...
# 2.726
#
#  2023-06-13 18:05:46.001277  - random_milliseconds
# ...
# 2222
#
#  2023-06-13 18:05:46.001277  - random_milliseconds / 1000
# ...
# 2.222
#
#  2023-06-13 18:05:49.890273  - random_milliseconds
# ...
# 2995
#
#  2023-06-13 18:05:49.890273  - random_milliseconds / 1000
# ...
# 2.995
#
#  2023-06-13 18:05:54.742091  - random_milliseconds
# ...
# 3390
#
#  2023-06-13 18:05:54.742091  - random_milliseconds / 1000
# ...
# 3.39
#
#  2023-06-13 18:05:59.849904  - random_milliseconds
# ...
# 3618
#
#  2023-06-13 18:05:59.850901  - random_milliseconds / 1000
# ...
# 3.618
#
#  2023-06-13 18:06:04.238885  - random_milliseconds
# ...
# 2061
#
#  2023-06-13 18:06:04.238885  - random_milliseconds / 1000
# ...
# 2.061
#
#  2023-06-13 18:06:08.133286  - random_milliseconds
# ...
# 3466
#
#  2023-06-13 18:06:08.133286  - random_milliseconds / 1000
# ...
# 3.466
#
#  2023-06-13 18:06:13.250466  - random_milliseconds
# ...
# 3354
#
#  2023-06-13 18:06:13.251478  - random_milliseconds / 1000
# ...
# 3.354
#
#  2023-06-13 18:06:18.730168  - random_milliseconds
# ...
# 2724
#
#  2023-06-13 18:06:18.730168  - random_milliseconds / 1000
# ...
# 2.724
#  2023-06-13 18:06:23.117518  - random_milliseconds
# ...
# 2619
#
#  2023-06-13 18:06:23.117518  - random_milliseconds / 1000
# ...
# 2.619
#
#  2023-06-13 18:06:26.583229  - random_milliseconds
# ...
# 3290
#
#  2023-06-13 18:06:26.583229  - random_milliseconds / 1000
# ...
# 3.29
#
#  2023-06-13 18:06:31.672634  - random_milliseconds
# ...
# 3069
#
#  2023-06-13 18:06:31.672634  - random_milliseconds / 1000
# ...
# 3.069
#
#  2023-06-13 18:06:36.369556  - random_milliseconds
# ...
# 3520
#
#  2023-06-13 18:06:36.369556  - random_milliseconds / 1000
# ...
# 3.52
#
#  2023-06-13 18:06:41.544177  - random_milliseconds
# ...
# 3956
#
#  2023-06-13 18:06:41.544177  - random_milliseconds / 1000
# ...
# 3.956
#
#  2023-06-13 18:06:47.253677  - random_milliseconds
# ...
# 3770
#
#  2023-06-13 18:06:47.253677  - random_milliseconds / 1000
# ...
# 3.77
#
#  2023-06-13 18:06:51.815473  - random_milliseconds
# ...
# 2169
#
#  2023-06-13 18:06:51.815473  - random_milliseconds / 1000
# ...
# 2.169
#
#  2023-06-13 18:06:55.826572  - random_milliseconds
# ...
# 3056
#
#  2023-06-13 18:06:55.826572  - random_milliseconds / 1000
# ...
# 3.056
#
#  2023-06-13 18:07:00.626167  - random_milliseconds
# ...
# 2421
#
#  2023-06-13 18:07:00.626167  - random_milliseconds / 1000
# ...
# 2.421
#
#  2023-06-13 18:07:05.178478  - random_milliseconds
# ...
# 2859
#
#  2023-06-13 18:07:05.178478  - random_milliseconds / 1000
# ...
# 2.859
#
#  2023-06-13 18:07:09.756986  - random_milliseconds
# ...
# 3160
#
#  2023-06-13 18:07:09.757984  - random_milliseconds / 1000
# ...
# 3.16
#
#  2023-06-13 18:07:13.656289  - random_milliseconds
# ...
# 2987
#
#  2023-06-13 18:07:13.656289  - random_milliseconds / 1000
# ...
# 2.987
#
#  2023-06-13 18:07:18.422327  - random_milliseconds
# ...
# 3323
#
#  2023-06-13 18:07:18.422327  - random_milliseconds / 1000
# ...
# 3.323
#
#  2023-06-13 18:07:23.367964  - random_milliseconds
# ...
# 2347
#
#  2023-06-13 18:07:23.367964  - random_milliseconds / 1000
# ...
# 2.347
#
#  2023-06-13 18:07:27.449119  - random_milliseconds
# ...
# 3011
#
#  2023-06-13 18:07:27.449119  - random_milliseconds / 1000
# ...
# 3.011
#
#  2023-06-13 18:07:32.268617  - random_milliseconds
# ...
# 2894
#
#  2023-06-13 18:07:32.269629  - random_milliseconds / 1000
# ...
# 2.894
#
#  2023-06-13 18:07:35.881330  - random_milliseconds
# ...
# 2554
#
#  2023-06-13 18:07:35.882330  - random_milliseconds / 1000
# ...
# 2.554
#
#  2023-06-13 18:07:40.252479  - random_milliseconds
# ...
# 3866
#
#  2023-06-13 18:07:40.252479  - random_milliseconds / 1000
# ...
# 3.866
#
#  2023-06-13 18:07:45.849130  - random_milliseconds
# ...
# 3054
#
#  2023-06-13 18:07:45.849130  - random_milliseconds / 1000
# ...
# 3.054
#
#  2023-06-13 18:07:51.134673  - random_milliseconds
# ...
# 3041
#
#  2023-06-13 18:07:51.134673  - random_milliseconds / 1000
# ...
# 3.041
#
#  2023-06-13 18:07:55.874962  - random_milliseconds
# ...
# 2029
#
#  2023-06-13 18:07:55.874962  - random_milliseconds / 1000
# ...
# 2.029
#
#  2023-06-13 18:07:58.684301  - random_milliseconds
# ...
# 3322
#
#  2023-06-13 18:07:58.684301  - random_milliseconds / 1000
# ...
# 3.322
#
#  2023-06-13 18:08:03.849189  - random_milliseconds
# ...
# 3530
#
#  2023-06-13 18:08:03.849189  - random_milliseconds / 1000
# ...
# 3.53
#
#  2023-06-13 18:08:09.066878  - random_milliseconds
# ...
# 2049
#
#  2023-06-13 18:08:09.066878  - random_milliseconds / 1000
# ...
# 2.049
#
#  2023-06-13 18:08:12.826932  - random_milliseconds
# ...
# 2604
#
#  2023-06-13 18:08:12.826932  - random_milliseconds / 1000
# ...
# 2.604
#
#  2023-06-13 18:08:17.242355  - random_milliseconds
# ...
# 2524
#
#  2023-06-13 18:08:17.243357  - random_milliseconds / 1000
# ...
# 2.524
#
#  2023-06-13 18:08:20.570835  - random_milliseconds
# ...
# 3910
#
#  2023-06-13 18:08:20.571832  - random_milliseconds / 1000
# ...
# 3.91
#
#  2023-06-13 18:08:26.290956  - random_milliseconds
# ...
# 2204
#
#  2023-06-13 18:08:26.290956  - random_milliseconds / 1000
# ...
# 2.204
#
#  2023-06-13 18:08:30.221313  - random_milliseconds
# ...
# 3892
#
#  2023-06-13 18:08:30.221313  - random_milliseconds / 1000
# ...
# 3.892
#
#  2023-06-13 18:08:36.611322  - random_milliseconds
# ...
# 3332
#
#  2023-06-13 18:08:36.611322  - random_milliseconds / 1000
# ...
# 3.332
#
#  2023-06-13 18:08:41.780313  - random_milliseconds
# ...
# 2722
#
#  2023-06-13 18:08:41.780313  - random_milliseconds / 1000
# ...
# 2.722
#
#  2023-06-13 18:08:45.239700  - random_milliseconds
# ...
# 3186
#
#  2023-06-13 18:08:45.239700  - random_milliseconds / 1000
# ...
# 3.186
#
#  2023-06-13 18:08:50.297423  - random_milliseconds
# ...
# 2050
#
#  2023-06-13 18:08:50.297423  - random_milliseconds / 1000
# ...
# 2.05
#
#  2023-06-13 18:08:54.068737  - random_milliseconds
# ...
# 3528
#
#  2023-06-13 18:08:54.068737  - random_milliseconds / 1000
# ...
# 3.528
#
#  2023-06-13 18:08:59.379301  - random_milliseconds
# ...
# 3073
#
#  2023-06-13 18:08:59.379301  - random_milliseconds / 1000
# ...
# 3.073
#
#  2023-06-13 18:09:04.180195  - random_milliseconds
# ...
# 2834
#
#  2023-06-13 18:09:04.180195  - random_milliseconds / 1000
# ...
# 2.834
#
#  2023-06-13 18:09:07.736406  - random_milliseconds
# ...
# 2637
#
#  2023-06-13 18:09:07.736406  - random_milliseconds / 1000
# ...
# 2.637
#
#  2023-06-13 18:09:12.189765  - random_milliseconds
# ...
# 2540
#
#  2023-06-13 18:09:12.189765  - random_milliseconds / 1000
# ...
# 2.54
#
#  2023-06-13 18:09:16.810988  - random_milliseconds
# ...
# 2367
#
#  2023-06-13 18:09:16.810988  - random_milliseconds / 1000
# ...
# 2.367
#
#  2023-06-13 18:09:20.942451  - random_milliseconds
# ...
# 3428
#
#  2023-06-13 18:09:20.942451  - random_milliseconds / 1000
# ...
# 3.428
#
#  2023-06-13 18:09:26.151378  - random_milliseconds
# ...
# 3633
#
#  2023-06-13 18:09:26.151378  - random_milliseconds / 1000
# ...
# 3.633
#
#  2023-06-13 18:09:30.511637  - random_milliseconds
# ...
# 2213
#
#  2023-06-13 18:09:30.511637  - random_milliseconds / 1000
# ...
# 2.213
#
#  2023-06-13 18:09:34.497983  - random_milliseconds
# ...
# 2262
#
#  2023-06-13 18:09:34.497983  - random_milliseconds / 1000
# ...
# 2.262
#
#  2023-06-13 18:09:38.457384  - random_milliseconds
# ...
# 3778
#
#  2023-06-13 18:09:38.457384  - random_milliseconds / 1000
# ...
# 3.778
#
#  2023-06-13 18:09:43.998126  - random_milliseconds
# ...
# 3572
#
#  2023-06-13 18:09:43.998126  - random_milliseconds / 1000
# ...
# 3.572
#
#  2023-06-13 18:09:49.323729  - random_milliseconds
# ...
# 3866
#
#  2023-06-13 18:09:49.323729  - random_milliseconds / 1000
# ...
# 3.866
#
#  2023-06-13 18:09:53.933530  - random_milliseconds
# ...
# 2301
#
#  2023-06-13 18:09:53.933530  - random_milliseconds / 1000
# ...
# 2.301
#
#  2023-06-13 18:09:58.059759  - random_milliseconds
# ...
# 3515
#
#  2023-06-13 18:09:58.059759  - random_milliseconds / 1000
# ...
# 3.515
#
#  2023-06-13 18:10:03.850094  - random_milliseconds
# ...
# 3440
#
#  2023-06-13 18:10:03.850094  - random_milliseconds / 1000
# ...
# 3.44
#
#  2023-06-13 18:10:09.060233  - random_milliseconds
# ...
# 3586
#
#  2023-06-13 18:10:09.060233  - random_milliseconds / 1000
# ...
# 3.586
#
#  2023-06-13 18:10:14.428356  - random_milliseconds
# ...
# 3521
#
#  2023-06-13 18:10:14.429355  - random_milliseconds / 1000
# ...
# 3.521
#
#  2023-06-13 18:10:18.721398  - random_milliseconds
# ...
# 2688
#
#  2023-06-13 18:10:18.721398  - random_milliseconds / 1000
# ...
# 2.688
#
#  2023-06-13 18:10:23.248543  - random_milliseconds
# ...
# 3576
#
#  2023-06-13 18:10:23.248543  - random_milliseconds / 1000
# ...
# 3.576
#
#  2023-06-13 18:10:28.575377  - random_milliseconds
# ...
# 2552
#
#  2023-06-13 18:10:28.575377  - random_milliseconds / 1000
# ...
# 2.552
#
#  2023-06-13 18:10:32.915335  - random_milliseconds
# ...
# 3292
#
#  2023-06-13 18:10:32.915335  - random_milliseconds / 1000
# ...
# 3.292
#
#  2023-06-13 18:10:38.473382  - random_milliseconds
# ...
# 2446
#
#  2023-06-13 18:10:38.473382  - random_milliseconds / 1000
# ...
# 2.446
#
#  2023-06-13 18:10:41.654943  - random_milliseconds
# ...
# 3096
#
#  2023-06-13 18:10:41.654943  - random_milliseconds / 1000
# ...
# 3.096
#
#  2023-06-13 18:10:46.543067  - random_milliseconds
# ...
# 3358
#
#  2023-06-13 18:10:46.543067  - random_milliseconds / 1000
# ...
# 3.358
#
#  2023-06-13 18:10:51.630432  - random_milliseconds
# ...
# 3124
#
#  2023-06-13 18:10:51.630432  - random_milliseconds / 1000
# ...
# 3.124
#
#  2023-06-13 18:10:56.554580  - random_milliseconds
# ...
# 3703
#
#  2023-06-13 18:10:56.554580  - random_milliseconds / 1000
# ...
# 3.703
#
#  2023-06-13 18:11:02.125790  - random_milliseconds
# ...
# 3067
#
#  2023-06-13 18:11:02.125790  - random_milliseconds / 1000
# ...
# 3.067
#
#  2023-06-13 18:11:05.893269  - random_milliseconds
# ...
# 3649
#
#  2023-06-13 18:11:05.893269  - random_milliseconds / 1000
# ...
# 3.649
#
#  2023-06-13 18:11:11.311324  - random_milliseconds
# ...
# 3285
#
#  2023-06-13 18:11:11.311324  - random_milliseconds / 1000
# ...
# 3.285
#  2023-06-13 18:11:16.552102  - random_milliseconds
# ...
# 2277
#
#  2023-06-13 18:11:16.552102  - random_milliseconds / 1000
# ...
# 2.277
#
#  2023-06-13 18:11:20.655489  - random_milliseconds
# ...
# 3652
#
#  2023-06-13 18:11:20.655489  - random_milliseconds / 1000
# ...
# 3.652
#
#  2023-06-13 18:11:26.840558  - random_milliseconds
# ...
# 3833
#
#  2023-06-13 18:11:26.840558  - random_milliseconds / 1000
# ...
# 3.833
#
#  2023-06-13 18:11:31.448772  - random_milliseconds
# ...
# 2445
#
#  2023-06-13 18:11:31.448772  - random_milliseconds / 1000
# ...
# 2.445
#
#  2023-06-13 18:11:35.658633  - random_milliseconds
# ...
# 2875
#
#  2023-06-13 18:11:35.658633  - random_milliseconds / 1000
# ...
# 2.875
#
#  2023-06-13 18:11:40.499562  - random_milliseconds
# ...
# 2247
#
#  2023-06-13 18:11:40.499562  - random_milliseconds / 1000
# ...
# 2.247
#
#  2023-06-13 18:11:44.671912  - random_milliseconds
# ...
# 2519
#
#  2023-06-13 18:11:44.672910  - random_milliseconds / 1000
# ...
# 2.519
#
#  2023-06-13 18:11:49.127822  - random_milliseconds
# ...
# 2880
#
#  2023-06-13 18:11:49.127822  - random_milliseconds / 1000
# ...
# 2.88
#
#  2023-06-13 18:11:52.734581  - random_milliseconds
# ...
# 2437
#
#  2023-06-13 18:11:52.734581  - random_milliseconds / 1000
# ...
# 2.437
#
#  2023-06-13 18:11:57.005488  - random_milliseconds
# ...
# 2174
#
#  2023-06-13 18:11:57.005488  - random_milliseconds / 1000
# ...
# 2.174
#
#  2023-06-13 18:12:01.029133  - random_milliseconds
# ...
# 2677
#
#  2023-06-13 18:12:01.030130  - random_milliseconds / 1000
# ...
# 2.677
#
#  2023-06-13 18:12:06.005661  - random_milliseconds
# ...
# 3632
#
#  2023-06-13 18:12:06.005661  - random_milliseconds / 1000
# ...
# 3.632
#
#  2023-06-13 18:12:11.460184  - random_milliseconds
# ...
# 2064
#
#  2023-06-13 18:12:11.460184  - random_milliseconds / 1000
# ...
# 2.064
#
#  2023-06-13 18:12:14.277645  - random_milliseconds
# ...
# 2181
#
#  2023-06-13 18:12:14.277645  - random_milliseconds / 1000
# ...
# 2.181
#
#  2023-06-13 18:12:18.283593  - random_milliseconds
# ...
# 3959
#
#  2023-06-13 18:12:18.283593  - random_milliseconds / 1000
# ...
# 3.959
#
#  2023-06-13 18:12:24.073035  - random_milliseconds
# ...
# 3725
#
#  2023-06-13 18:12:24.074024  - random_milliseconds / 1000
# ...
# 3.725
#
#  2023-06-13 18:12:29.704619  - random_milliseconds
# ...
# 3711
#
#  2023-06-13 18:12:29.704619  - random_milliseconds / 1000
# ...
# 3.711
#
#  2023-06-13 18:12:35.534599  - random_milliseconds
# ...
# 2251
#
#  2023-06-13 18:12:35.535596  - random_milliseconds / 1000
# ...
# 2.251
#
#  2023-06-13 18:12:38.573185  - random_milliseconds
# ...
# 3352
#
#  2023-06-13 18:12:38.573185  - random_milliseconds / 1000
# ...
# 3.352
#
#  2023-06-13 18:12:43.729483  - random_milliseconds
# ...
# 3286
#
#  2023-06-13 18:12:43.729483  - random_milliseconds / 1000
# ...
# 3.286
#
#  2023-06-13 18:12:49.262950  - random_milliseconds
# ...
# 3085
#
#  2023-06-13 18:12:49.262950  - random_milliseconds / 1000
# ...
# 3.085
#
#  2023-06-13 18:12:54.293478  - random_milliseconds
# ...
# 2931
#
#  2023-06-13 18:12:54.293478  - random_milliseconds / 1000
# ...
# 2.931
#
#  2023-06-13 18:12:58.995640  - random_milliseconds
# ...
# 2604
#
#  2023-06-13 18:12:58.995640  - random_milliseconds / 1000
# ...
# 2.604
#
#  2023-06-13 18:13:02.323223  - random_milliseconds
# ...
# 2068
#
#  2023-06-13 18:13:02.324225  - random_milliseconds / 1000
# ...
# 2.068
#
#  2023-06-13 18:13:06.209415  - random_milliseconds
# ...
# 3174
#
#  2023-06-13 18:13:06.209415  - random_milliseconds / 1000
# ...
# 3.174
#
#  2023-06-13 18:13:11.209906  - random_milliseconds
# ...
# 3019
#
#  2023-06-13 18:13:11.209906  - random_milliseconds / 1000
# ...
# 3.019
#
#  2023-06-13 18:13:16.082259  - random_milliseconds
# ...
# 2527
#
#  2023-06-13 18:13:16.082259  - random_milliseconds / 1000
# ...
# 2.527
#
#  2023-06-13 18:13:20.397192  - random_milliseconds
# ...
# 3459
#
#  2023-06-13 18:13:20.397192  - random_milliseconds / 1000
# ...
# 3.459
#
#  2023-06-13 18:13:24.640892  - random_milliseconds
# ...
# 3897
#
#  2023-06-13 18:13:24.640892  - random_milliseconds / 1000
# ...
# 3.897
#
#  2023-06-13 18:13:30.297256  - random_milliseconds
# ...
# 2133
#
#  2023-06-13 18:13:30.297256  - random_milliseconds / 1000
# ...
# 2.133
#
#  2023-06-13 18:13:34.881143  - random_milliseconds
# ...
# 2279
#
#  2023-06-13 18:13:34.881143  - random_milliseconds / 1000
# ...
# 2.279
#
#  2023-06-13 18:13:39.118584  - random_milliseconds
# ...
# 3676
#
#  2023-06-13 18:13:39.118584  - random_milliseconds / 1000
# ...
# 3.676
#
#  2023-06-13 18:13:44.682553  - random_milliseconds
# ...
# 2703
#
#  2023-06-13 18:13:44.682553  - random_milliseconds / 1000
# ...
# 2.703
#
#  2023-06-13 18:13:48.181461  - random_milliseconds
# ...
# 2712
#
#  2023-06-13 18:13:48.181461  - random_milliseconds / 1000
# ...
# 2.712
#
#  2023-06-13 18:13:52.688594  - random_milliseconds
# ...
# 2610
#
#  2023-06-13 18:13:52.688594  - random_milliseconds / 1000
# ...
# 2.61
#
#  2023-06-13 18:13:57.105575  - random_milliseconds
# ...
# 3734
#
#  2023-06-13 18:13:57.105575  - random_milliseconds / 1000
# ...
# 3.734
#
#  2023-06-13 18:14:02.690642  - random_milliseconds
# ...
# 3861
#
#  2023-06-13 18:14:02.690642  - random_milliseconds / 1000
# ...
# 3.861
#
#  2023-06-13 18:14:08.954048  - random_milliseconds
# ...
# 2918
#
#  2023-06-13 18:14:08.954048  - random_milliseconds / 1000
# ...
# 2.918
#
#  2023-06-13 18:14:12.705313  - random_milliseconds
# ...
# 2619
#
#  2023-06-13 18:14:12.705313  - random_milliseconds / 1000
# ...
# 2.619
#
#  2023-06-13 18:14:17.163669  - random_milliseconds
# ...
# 2011
#
#  2023-06-13 18:14:17.163669  - random_milliseconds / 1000
# ...
# 2.011
#
#  2023-06-13 18:14:20.959043  - random_milliseconds
# ...
# 2610
#
#  2023-06-13 18:14:20.959043  - random_milliseconds / 1000
# ...
# 2.61
#
#  2023-06-13 18:14:25.571455  - random_milliseconds
# ...
# 3025
#
#  2023-06-13 18:14:25.571455  - random_milliseconds / 1000
# ...
# 3.025
#
#  2023-06-13 18:14:30.441191  - random_milliseconds
# ...
# 2633
#
#  2023-06-13 18:14:30.441191  - random_milliseconds / 1000
# ...
# 2.633
#
#  2023-06-13 18:14:33.769176  - random_milliseconds
# ...
# 3742
#
#  2023-06-13 18:14:33.769176  - random_milliseconds / 1000
# ...
# 3.742
#
#  2023-06-13 18:14:39.327407  - random_milliseconds
# ...
# 2092
#
#  2023-06-13 18:14:39.327407  - random_milliseconds / 1000
# ...
# 2.092
#
#  2023-06-13 18:14:43.440402  - random_milliseconds
# ...
# 3979
#
#  2023-06-13 18:14:43.440402  - random_milliseconds / 1000
# ...
# 3.979
#
#  2023-06-13 18:14:49.932422  - random_milliseconds
# ...
# 2922
#
#  2023-06-13 18:14:49.932422  - random_milliseconds / 1000
# ...
# 2.922
#
#  2023-06-13 18:14:54.816881  - random_milliseconds
# ...
# 2792
#
#  2023-06-13 18:14:54.816881  - random_milliseconds / 1000
# ...
# 2.792
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4384\2492558543.py in <module>
#     162 #     attaquer_village('3466', '3275', 'data/village.txt')
#     163 #     attaquer_village('3466', '3172', 'data/village.txt')
# --> 164     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
#     165     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
#     166     delay_with_random_seconds()
#
# ~\AppData\Local\Temp\ipykernel_4384\2492558543.py in attaquer_village(troupes_file)
#      79
#      80         bouton = firefox.child_window(auto_id='troop_confirm_submit')
# ---> 81         bouton.click()
#      82         delay_with_random_seconds()
#      83
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     377         if len(self.criteria) >= 2:  # FIXME - this is surprising
#     378
# --> 379             ctrls = self.__resolve_control(self.criteria)
#     380
#     381             try:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     220                 if 'backend' not in ctrl_criteria:
#     221                     ctrl_criteria['backend'] = self.backend.name
# --> 222                 ctrl = self.backend.generic_wrapper_class(findwindows.find_element(**ctrl_criteria))
#     223                 previous_parent = ctrl.element_info
#     224                 ctrls.append(ctrl)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'auto_id': 'troop_confirm_submit', 'top_level_only': False, 'parent': <uia_element_info.UIAElementInfo - 'M81----1 (556|484) - Guerre Tribale - Monde 81 — Mozilla Firefox', MozillaWindowClass, 117440744>, 'backend': 'uia'}
