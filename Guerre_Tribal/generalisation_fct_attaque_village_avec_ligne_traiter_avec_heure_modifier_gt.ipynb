# %%
from pywinauto.application import Application
import psutil
import time
import random
import requests
import csv
import datetime
import fileinput

def delay_with_random_seconds():
#     # Génère un délai aléatoire entre 1 et 5 secondes
#     random_seconds = random.randint(2, 4)
# #     print(random_seconds)
    
#     # Pause l'exécution du programme pendant le délai aléatoire
#     time.sleep(random_seconds)
    random_milliseconds = random.randint(2000, 4000)  # Générer un nombre aléatoire en millisecondes entre 2000 et 4000
    print('\n', datetime.datetime.now(),' - random_milliseconds \n...')   
    print(random_milliseconds)
    print('\n', datetime.datetime.now(),' - random_milliseconds / 1000 \n...')   
    print(random_milliseconds / 1000)
    time.sleep(random_milliseconds / 1000)  # Utiliser la valeur en millisecondes dans time.sleep()
 #     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()

def attaquer_village(troupes_file):
    lines = []

    # Lire le fichier et stocker les lignes dans une liste
    with open(troupes_file, 'r') as file:
        lines = file.readlines()

    # Exclure la première ligne (en-têtes)
    headers = lines[0].strip().split(',')
    lines = lines[1:]

    # Trier les lignes par heure_attaque la plus ancienne
    lines = sorted(lines, key=lambda x: datetime.datetime.strptime(x.strip().split(',')[headers.index('heure_attaque')], "%Y-%m-%d %H:%M:%S"))

    # Parcourir les lignes triées
    for i, line in enumerate(lines):
        data = line.strip().split(',')
        village_depart = data[headers.index('village_depart')]
        village_attaquer = data[headers.index('village_attaquer')]

        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_attaquer}"
        firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()

        # Saisir les champs pour chaque type de troupe
        for header in headers:
            if header not in ['heure_attaque', 'village_depart', 'village_attaquer']:
                value = int(data[headers.index(header)])
                if value > 0:
                    zone = firefox.child_window(auto_id=header)
                    zone.type_keys(str(value))
                    delay_with_random_seconds()

        # Mettre à jour la colonne heure_attaque avec l'heure actuelle
        heure_attaque_index = headers.index('heure_attaque')
        heure_attaque = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        data[heure_attaque_index] = heure_attaque

        # Modifier la ligne dans la liste
        lines[i] = ','.join(data) + '\n'

        bouton = firefox.child_window(auto_id='target_attack')
        bouton.click()
        delay_with_random_seconds()

        bouton = firefox.child_window(auto_id='troop_confirm_submit')
        bouton.click()
        delay_with_random_seconds()

    # Réécrire le fichier avec les lignes modifiées
    with open(troupes_file, 'w') as file:
        file.write(','.join(headers) + '\n')  # Réécrire les en-têtes
        file.writelines(lines)  # Réécrire les lignes modifiées


# Vérifier si Firefox est en cours d'exécution
firefox_running = False
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_running = True
        firefox_pid = process.pid
        break

# Fermer Firefox si c'est le cas
if firefox_running:
    process = psutil.Process(firefox_pid)
    process.terminate()
#     time.sleep(5)
# Ouvrir Firefox
time.sleep(2)

app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Ouvrir Firefox
# app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Trouver le PID de Firefox
firefox_pid = None
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_pid = process.pid
        break

# Vérifier si Firefox est en cours d'exécution
if firefox_pid is None:
    print("Firefox n'est pas en cours d'exécution.")
else:
    # Attacher Pywinauto à la fenêtre Firefox
    app = Application(backend='uia').connect(process=firefox_pid)

    # Ouvrir une page web
#     firefox = app.window(title_re='.*Nouvel onglet*')
    firefox = app.window( class_name='MozillaWindowClass')

    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     time.sleep(5)

#     # Saisir les champs
#     zone1 = firefox.window(title='user')
#     zone1.type_keys('*test1')
#     zone1 = firefox.child_window(control_type="Edit", found_index=0, automation_id="user")
    zone1 = firefox.child_window(auto_id='user')

    zone1.type_keys('arion1')
    delay_with_random_seconds()

    zone2 = firefox.child_window(auto_id='password')
    zone2.type_keys('MiMa5158**')
    delay_with_random_seconds()
    # Cliquer sur le bouton
#     bouton = firefox.window(title='Connexion')
# #     bouton = firefox.child_window(auto_id='btn-login')
#     bouton = firefox.child_window(title='Connexion')
#     bouton.click()!
    bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
    bouton.invoke()
#     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
#     bouton.invoke()
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    
#     attaquer_village('3466', '3275', 'data/village.txt')
#     attaquer_village('3466', '3172', 'data/village.txt')
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
    delay_with_random_seconds()    
    # Fermer Firefox 
#     firefox.close()
# Out:
#  2023-06-08 20:26:20.906705  - random_milliseconds
# ...
# 2364
#
#  2023-06-08 20:26:20.906705  - random_milliseconds / 1000
# ...
# 2.364
#
#  2023-06-08 20:26:24.130674  - random_milliseconds
# ...
# 3932
#
#  2023-06-08 20:26:24.131706  - random_milliseconds / 1000
# ...
# 3.932
#
#  2023-06-08 20:26:28.635237  - random_milliseconds
# ...
# 2587
#
#  2023-06-08 20:26:28.635237  - random_milliseconds / 1000
# ...
# 2.587
#
#  2023-06-08 20:26:33.043638  - random_milliseconds
# ...
# 2324
#
#  2023-06-08 20:26:33.043638  - random_milliseconds / 1000
# ...
# 2.324
#
#  2023-06-08 20:26:37.710648  - random_milliseconds
# ...
# 3901
#
#  2023-06-08 20:26:37.710648  - random_milliseconds / 1000
# ...
# 3.901
#
#  2023-06-08 20:26:43.928179  - random_milliseconds
# ...
# 2885
#
#  2023-06-08 20:26:43.929176  - random_milliseconds / 1000
# ...
# 2.885
#
#  2023-06-08 20:26:48.101188  - random_milliseconds
# ...
# 3179
#
#  2023-06-08 20:26:48.101188  - random_milliseconds / 1000
# ...
# 3.179
#
#  2023-06-08 20:26:52.613759  - random_milliseconds
# ...
# 3372
#
#  2023-06-08 20:26:52.613759  - random_milliseconds / 1000
# ...
# 3.372
#
#  2023-06-08 20:26:57.326473  - random_milliseconds
# ...
# 3892
#
#  2023-06-08 20:26:57.326473  - random_milliseconds / 1000
# ...
# 3.892
#
#  2023-06-08 20:27:02.522176  - random_milliseconds
# ...
# 3725
#
#  2023-06-08 20:27:02.522176  - random_milliseconds / 1000
# ...
# 3.725
#
#  2023-06-08 20:27:08.339577  - random_milliseconds
# ...
# 3769
#
#  2023-06-08 20:27:08.339577  - random_milliseconds / 1000
# ...
# 3.769
#
#  2023-06-08 20:27:13.200072  - random_milliseconds
# ...
# 3911
#
#  2023-06-08 20:27:13.200072  - random_milliseconds / 1000
# ...
# 3.911
#
#  2023-06-08 20:27:18.322740  - random_milliseconds
# ...
# 3525
#
#  2023-06-08 20:27:18.323737  - random_milliseconds / 1000
# ...
# 3.525
#
#  2023-06-08 20:27:23.206961  - random_milliseconds
# ...
# 2868
#
#  2023-06-08 20:27:23.207959  - random_milliseconds / 1000
# ...
# 2.868
#
#  2023-06-08 20:27:27.276503  - random_milliseconds
# ...
# 3477
#
#  2023-06-08 20:27:27.276503  - random_milliseconds / 1000
# ...
# 3.477
#
#  2023-06-08 20:27:32.982145  - random_milliseconds
# ...
# 3064
#
#  2023-06-08 20:27:32.982145  - random_milliseconds / 1000
# ...
# 3.064
#
#  2023-06-08 20:27:37.419299  - random_milliseconds
# ...
# 3059
#
#  2023-06-08 20:27:37.419299  - random_milliseconds / 1000
# ...
# 3.059
#
#  2023-06-08 20:27:41.916408  - random_milliseconds
# ...
# 2895
#
#  2023-06-08 20:27:41.917415  - random_milliseconds / 1000
# ...
# 2.895
#
#  2023-06-08 20:27:46.306087  - random_milliseconds
# ...
# 2365
#
#  2023-06-08 20:27:46.306087  - random_milliseconds / 1000
# ...
# 2.365
#
#  2023-06-08 20:27:49.700936  - random_milliseconds
# ...
# 3296
#
#  2023-06-08 20:27:49.700936  - random_milliseconds / 1000
# ...
# 3.296
#
#  2023-06-08 20:27:55.319906  - random_milliseconds
# ...
# 3436
#
#  2023-06-08 20:27:55.319906  - random_milliseconds / 1000
# ...
# 3.436
#
#  2023-06-08 20:28:00.413651  - random_milliseconds
# ...
# 2810
#
#  2023-06-08 20:28:00.413651  - random_milliseconds / 1000
# ...
# 2.81
#
#  2023-06-08 20:28:04.435452  - random_milliseconds
# ...
# 3423
#
#  2023-06-08 20:28:04.435452  - random_milliseconds / 1000
# ...
# 3.423
#
#  2023-06-08 20:28:09.326625  - random_milliseconds
# ...
# 3700
#
#  2023-06-08 20:28:09.326625  - random_milliseconds / 1000
# ...
# 3.7
#
#  2023-06-08 20:28:14.174247  - random_milliseconds
# ...
# 3112
#
#  2023-06-08 20:28:14.174247  - random_milliseconds / 1000
# ...
# 3.112
#
#  2023-06-08 20:28:19.611084  - random_milliseconds
# ...
# 3313
#
#  2023-06-08 20:28:19.611084  - random_milliseconds / 1000
# ...
# 3.313
#
#  2023-06-08 20:28:24.288191  - random_milliseconds
# ...
# 2361
#
#  2023-06-08 20:28:24.288191  - random_milliseconds / 1000
# ...
# 2.361
#
#  2023-06-08 20:28:27.996427  - random_milliseconds
# ...
# 3913
#
#  2023-06-08 20:28:27.996427  - random_milliseconds / 1000
# ...
# 3.913
#
#  2023-06-08 20:28:33.240614  - random_milliseconds
# ...
# 2066
#
#  2023-06-08 20:28:33.240614  - random_milliseconds / 1000
# ...
# 2.066
#
#  2023-06-08 20:28:36.373820  - random_milliseconds
# ...
# 3007
#
#  2023-06-08 20:28:36.373820  - random_milliseconds / 1000
# ...
# 3.007
#
#  2023-06-08 20:28:41.792292  - random_milliseconds
# ...
# 2147
#
#  2023-06-08 20:28:41.792292  - random_milliseconds / 1000
# ...
# 2.147
#
#  2023-06-08 20:28:45.176725  - random_milliseconds
# ...
# 2493
#
#  2023-06-08 20:28:45.176725  - random_milliseconds / 1000
# ...
# 2.493
#
#  2023-06-08 20:28:49.082677  - random_milliseconds
# ...
# 3700
#
#  2023-06-08 20:28:49.082677  - random_milliseconds / 1000
# ...
# 3.7
#
#  2023-06-08 20:28:53.894948  - random_milliseconds
# ...
# 2263
#
#  2023-06-08 20:28:53.894948  - random_milliseconds / 1000
# ...
# 2.263
#
#  2023-06-08 20:28:57.342096  - random_milliseconds
# ...
# 3017
#
#  2023-06-08 20:28:57.342096  - random_milliseconds / 1000
# ...
# 3.017
#
#  2023-06-08 20:29:02.758655  - random_milliseconds
# ...
# 3316
#
#  2023-06-08 20:29:02.758655  - random_milliseconds / 1000
# ...
# 3.316
#
#  2023-06-08 20:29:07.507332  - random_milliseconds
# ...
# 3128
#
#  2023-06-08 20:29:07.507332  - random_milliseconds / 1000
# ...
# 3.128
#
#  2023-06-08 20:29:12.038979  - random_milliseconds
# ...
# 3125
#
#  2023-06-08 20:29:12.039977  - random_milliseconds / 1000
# ...
# 3.125
#
#  2023-06-08 20:29:16.514196  - random_milliseconds
# ...
# 3743
#
#  2023-06-08 20:29:16.514196  - random_milliseconds / 1000
# ...
# 3.743
#
#  2023-06-08 20:29:21.423850  - random_milliseconds
# ...
# 3460
#
#  2023-06-08 20:29:21.423850  - random_milliseconds / 1000
# ...
# 3.46
#
#  2023-06-08 20:29:27.208468  - random_milliseconds
# ...
# 3492
#
#  2023-06-08 20:29:27.208468  - random_milliseconds / 1000
# ...
# 3.492
#
#  2023-06-08 20:29:32.068073  - random_milliseconds
# ...
# 2662
#
#  2023-06-08 20:29:32.068073  - random_milliseconds / 1000
# ...
# 2.662
#
#  2023-06-08 20:29:36.252858  - random_milliseconds
# ...
# 3131
#
#  2023-06-08 20:29:36.252858  - random_milliseconds / 1000
# ...
# 3.131
#
#  2023-06-08 20:29:40.573415  - random_milliseconds
# ...
# 3331
#
#  2023-06-08 20:29:40.573415  - random_milliseconds / 1000
# ...
# 3.331
#
#  2023-06-08 20:29:45.124591  - random_milliseconds
# ...
# 2368
#
#  2023-06-08 20:29:45.124591  - random_milliseconds / 1000
# ...
# 2.368
#
#  2023-06-08 20:29:50.154657  - random_milliseconds
# ...
# 3296
#
#  2023-06-08 20:29:50.154657  - random_milliseconds / 1000
# ...
# 3.296
#
#  2023-06-08 20:29:54.818976  - random_milliseconds
# ...
# 3588
#
#  2023-06-08 20:29:54.818976  - random_milliseconds / 1000
# ...
# 3.588
#
#  2023-06-08 20:30:00.145547  - random_milliseconds
# ...
# 2258
#
#  2023-06-08 20:30:00.145547  - random_milliseconds / 1000
# ...
# 2.258
#
#  2023-06-08 20:30:03.835665  - random_milliseconds
# ...
# 3832
#
#  2023-06-08 20:30:03.835665  - random_milliseconds / 1000
# ...
# 3.832
#
#  2023-06-08 20:30:08.846179  - random_milliseconds
# ...
# 2721
#
#  2023-06-08 20:30:08.846179  - random_milliseconds / 1000
# ...
# 2.721
#
#  2023-06-08 20:30:13.621358  - random_milliseconds
# ...
# 2560
#
#  2023-06-08 20:30:13.621358  - random_milliseconds / 1000
# ...
# 2.56
#
#  2023-06-08 20:30:17.593951  - random_milliseconds
# ...
# 2373
#
#  2023-06-08 20:30:17.593951  - random_milliseconds / 1000
# ...
# 2.373
#
#  2023-06-08 20:30:21.398476  - random_milliseconds
# ...
# 3743
#
#  2023-06-08 20:30:21.398476  - random_milliseconds / 1000
# ...
# 3.743
#
#  2023-06-08 20:30:26.501475  - random_milliseconds
# ...
# 2490
#
#  2023-06-08 20:30:26.502471  - random_milliseconds / 1000
# ...
# 2.49
#
#  2023-06-08 20:30:30.086591  - random_milliseconds
# ...
# 3843
#
#  2023-06-08 20:30:30.086591  - random_milliseconds / 1000
# ...
# 3.843
#
#  2023-06-08 20:30:36.448528  - random_milliseconds
# ...
# 2465
#
#  2023-06-08 20:30:36.448528  - random_milliseconds / 1000
# ...
# 2.465
#
#  2023-06-08 20:30:40.236807  - random_milliseconds
# ...
# 2642
#
#  2023-06-08 20:30:40.236807  - random_milliseconds / 1000
# ...
# 2.642
#
#  2023-06-08 20:30:44.358276  - random_milliseconds
# ...
# 3055
#
#  2023-06-08 20:30:44.358276  - random_milliseconds / 1000
# ...
# 3.055
#
#  2023-06-08 20:30:48.957910  - random_milliseconds
# ...
# 2982
#
#  2023-06-08 20:30:48.957910  - random_milliseconds / 1000
# ...
# 2.982
#
#  2023-06-08 20:30:53.123367  - random_milliseconds
# ...
# 3663
#
#  2023-06-08 20:30:53.123367  - random_milliseconds / 1000
# ...
# 3.663
#
#  2023-06-08 20:30:59.331872  - random_milliseconds
# ...
# 3603
#
#  2023-06-08 20:30:59.331872  - random_milliseconds / 1000
# ...
# 3.603
#
#  2023-06-08 20:31:04.331107  - random_milliseconds
# ...
# 2246
#
#  2023-06-08 20:31:04.331107  - random_milliseconds / 1000
# ...
# 2.246
#
#  2023-06-08 20:31:07.982530  - random_milliseconds
# ...
# 3200
#
#  2023-06-08 20:31:07.982530  - random_milliseconds / 1000
# ...
# 3.2
#  2023-06-08 20:31:12.678792  - random_milliseconds
# ...
# 3941
#
#  2023-06-08 20:31:12.678792  - random_milliseconds / 1000
# ...
# 3.941
#
#  2023-06-08 20:31:17.569532  - random_milliseconds
# ...
# 2136
#
#  2023-06-08 20:31:17.569532  - random_milliseconds / 1000
# ...
# 2.136
#
#  2023-06-08 20:31:22.346552  - random_milliseconds
# ...
# 2470
#
#  2023-06-08 20:31:22.346552  - random_milliseconds / 1000
# ...
# 2.47
#
#  2023-06-08 20:31:26.240534  - random_milliseconds
# ...
# 3774
#
#  2023-06-08 20:31:26.240534  - random_milliseconds / 1000
# ...
# 3.774
#
#  2023-06-08 20:31:31.964655  - random_milliseconds
# ...
# 3006
#
#  2023-06-08 20:31:31.964655  - random_milliseconds / 1000
# ...
# 3.006
#
#  2023-06-08 20:31:36.364643  - random_milliseconds
# ...
# 3729
#
#  2023-06-08 20:31:36.364643  - random_milliseconds / 1000
# ...
# 3.729
#
#  2023-06-08 20:31:41.312391  - random_milliseconds
# ...
# 2670
#
#  2023-06-08 20:31:41.312391  - random_milliseconds / 1000
# ...
# 2.67
#
#  2023-06-08 20:31:46.585578  - random_milliseconds
# ...
# 3537
#
#  2023-06-08 20:31:46.585578  - random_milliseconds / 1000
# ...
# 3.537
#
#  2023-06-08 20:31:51.409341  - random_milliseconds
# ...
# 2992
#
#  2023-06-08 20:31:51.409341  - random_milliseconds / 1000
# ...
# 2.992
#
#  2023-06-08 20:31:55.937007  - random_milliseconds
# ...
# 2991
#
#  2023-06-08 20:31:55.937007  - random_milliseconds / 1000
# ...
# 2.991
#
#  2023-06-08 20:32:00.394864  - random_milliseconds
# ...
# 2279
#
#  2023-06-08 20:32:00.394864  - random_milliseconds / 1000
# ...
# 2.279
#
#  2023-06-08 20:32:03.968389  - random_milliseconds
# ...
# 3963
#
#  2023-06-08 20:32:03.968389  - random_milliseconds / 1000
# ...
# 3.963
#
#  2023-06-08 20:32:10.422007  - random_milliseconds
# ...
# 2300
#
#  2023-06-08 20:32:10.422007  - random_milliseconds / 1000
# ...
# 2.3
#
#  2023-06-08 20:32:14.187147  - random_milliseconds
# ...
# 3243
#
#  2023-06-08 20:32:14.187147  - random_milliseconds / 1000
# ...
# 3.243
#
#  2023-06-08 20:32:18.816015  - random_milliseconds
# ...
# 3749
#
#  2023-06-08 20:32:18.816369  - random_milliseconds / 1000
# ...
# 3.749
#
#  2023-06-08 20:32:24.088376  - random_milliseconds
# ...
# 2711
#
#  2023-06-08 20:32:24.089374  - random_milliseconds / 1000
# ...
# 2.711
#
#  2023-06-08 20:32:28.046595  - random_milliseconds
# ...
# 2911
#
#  2023-06-08 20:32:28.046595  - random_milliseconds / 1000
# ...
# 2.911
#
#  2023-06-08 20:32:33.362103  - random_milliseconds
# ...
# 2961
#
#  2023-06-08 20:32:33.362103  - random_milliseconds / 1000
# ...
# 2.961
#
#  2023-06-08 20:32:37.669762  - random_milliseconds
# ...
# 3172
#
#  2023-06-08 20:32:37.669762  - random_milliseconds / 1000
# ...
# 3.172
#
#  2023-06-08 20:32:42.336235  - random_milliseconds
# ...
# 3920
#
#  2023-06-08 20:32:42.336235  - random_milliseconds / 1000
# ...
# 3.92
#
#  2023-06-08 20:32:47.983393  - random_milliseconds
# ...
# 2875
#
#  2023-06-08 20:32:47.983393  - random_milliseconds / 1000
# ...
# 2.875
#
#  2023-06-08 20:32:52.134577  - random_milliseconds
# ...
# 2550
#
#  2023-06-08 20:32:52.134577  - random_milliseconds / 1000
# ...
# 2.55
#
#  2023-06-08 20:32:57.294783  - random_milliseconds
# ...
# 3993
#
#  2023-06-08 20:32:57.295780  - random_milliseconds / 1000
# ...
# 3.993
#
#  2023-06-08 20:33:02.858921  - random_milliseconds
# ...
# 2984
#
#  2023-06-08 20:33:02.858921  - random_milliseconds / 1000
# ...
# 2.984
#
#  2023-06-08 20:33:07.704108  - random_milliseconds
# ...
# 2189
#
#  2023-06-08 20:33:07.704108  - random_milliseconds / 1000
# ...
# 2.189
#
#  2023-06-08 20:33:11.386279  - random_milliseconds
# ...
# 3918
#
#  2023-06-08 20:33:11.386279  - random_milliseconds / 1000
# ...
# 3.918
#
#  2023-06-08 20:33:16.616020  - random_milliseconds
# ...
# 2073
#
#  2023-06-08 20:33:16.616020  - random_milliseconds / 1000
# ...
# 2.073
#
#  2023-06-08 20:33:21.003322  - random_milliseconds
# ...
# 3318
#
#  2023-06-08 20:33:21.003322  - random_milliseconds / 1000
# ...
# 3.318
#
#  2023-06-08 20:33:25.617683  - random_milliseconds
# ...
# 2791
#
#  2023-06-08 20:33:25.617683  - random_milliseconds / 1000
# ...
# 2.791
#
#  2023-06-08 20:33:29.900655  - random_milliseconds
# ...
# 3562
#
#  2023-06-08 20:33:29.900655  - random_milliseconds / 1000
# ...
# 3.562
#
#  2023-06-08 20:33:35.070581  - random_milliseconds
# ...
# 2914
#
#  2023-06-08 20:33:35.070581  - random_milliseconds / 1000
# ...
# 2.914
#
#  2023-06-08 20:33:39.187902  - random_milliseconds
# ...
# 2089
#
#  2023-06-08 20:33:39.187902  - random_milliseconds / 1000
# ...
# 2.089
#
#  2023-06-08 20:33:43.429684  - random_milliseconds
# ...
# 3721
#
#  2023-06-08 20:33:43.429875  - random_milliseconds / 1000
# ...
# 3.721
#
#  2023-06-08 20:33:48.578983  - random_milliseconds
# ...
# 2394
#
#  2023-06-08 20:33:48.578983  - random_milliseconds / 1000
# ...
# 2.394
#
#  2023-06-08 20:33:52.505643  - random_milliseconds
# ...
# 3387
#
#  2023-06-08 20:33:52.505643  - random_milliseconds / 1000
# ...
# 3.387
#
#  2023-06-08 20:33:57.210742  - random_milliseconds
# ...
# 3325
#
#  2023-06-08 20:33:57.210742  - random_milliseconds / 1000
# ...
# 3.325
#
#  2023-06-08 20:34:01.702621  - random_milliseconds
# ...
# 3054
#
#  2023-06-08 20:34:01.702621  - random_milliseconds / 1000
# ...
# 3.054
#
#  2023-06-08 20:34:07.255914  - random_milliseconds
# ...
# 3756
#
#  2023-06-08 20:34:07.255914  - random_milliseconds / 1000
# ...
# 3.756
#
#  2023-06-08 20:34:12.531104  - random_milliseconds
# ...
# 2868
#
#  2023-06-08 20:34:12.531104  - random_milliseconds / 1000
# ...
# 2.868
#
#  2023-06-08 20:34:16.965713  - random_milliseconds
# ...
# 2225
#
#  2023-06-08 20:34:16.966712  - random_milliseconds / 1000
# ...
# 2.225
#
#  2023-06-08 20:34:20.796763  - random_milliseconds
# ...
# 2816
#
#  2023-06-08 20:34:20.796763  - random_milliseconds / 1000
# ...
# 2.816
#
#  2023-06-08 20:34:24.746869  - random_milliseconds
# ...
# 3618
#
#  2023-06-08 20:34:24.746869  - random_milliseconds / 1000
# ...
# 3.618
#
#  2023-06-08 20:34:30.321282  - random_milliseconds
# ...
# 3819
#
#  2023-06-08 20:34:30.321282  - random_milliseconds / 1000
# ...
# 3.819
#
#  2023-06-08 20:34:35.894576  - random_milliseconds
# ...
# 2538
#
#  2023-06-08 20:34:35.894576  - random_milliseconds / 1000
# ...
# 2.538
#
#  2023-06-08 20:34:39.927627  - random_milliseconds
# ...
# 3577
#
#  2023-06-08 20:34:39.928626  - random_milliseconds / 1000
# ...
# 3.577
#
#  2023-06-08 20:34:44.875791  - random_milliseconds
# ...
# 3784
#
#  2023-06-08 20:34:44.875791  - random_milliseconds / 1000
# ...
# 3.784
#
#  2023-06-08 20:34:49.855502  - random_milliseconds
# ...
# 3848
#
#  2023-06-08 20:34:49.855502  - random_milliseconds / 1000
# ...
# 3.848
#
#  2023-06-08 20:34:56.051855  - random_milliseconds
# ...
# 2253
#
#  2023-06-08 20:34:56.051855  - random_milliseconds / 1000
# ...
# 2.253
#
#  2023-06-08 20:34:59.826715  - random_milliseconds
# ...
# 3301
#
#  2023-06-08 20:34:59.826715  - random_milliseconds / 1000
# ...
# 3.301
#
#  2023-06-08 20:35:04.664604  - random_milliseconds
# ...
# 3826
#
#  2023-06-08 20:35:04.664604  - random_milliseconds / 1000
# ...
# 3.826
#
#  2023-06-08 20:35:10.083777  - random_milliseconds
# ...
# 3818
#
#  2023-06-08 20:35:10.083777  - random_milliseconds / 1000
# ...
# 3.818
#
#  2023-06-08 20:35:15.314974  - random_milliseconds
# ...
# 2013
#
#  2023-06-08 20:35:15.314974  - random_milliseconds / 1000
# ...
# 2.013
#
#  2023-06-08 20:35:19.677390  - random_milliseconds
# ...
# 2305
#
#  2023-06-08 20:35:19.677390  - random_milliseconds / 1000
# ...
# 2.305
#
#  2023-06-08 20:35:23.616924  - random_milliseconds
# ...
# 3796
#
#  2023-06-08 20:35:23.616924  - random_milliseconds / 1000
# ...
# 3.796
#
#  2023-06-08 20:35:28.821313  - random_milliseconds
# ...
# 2257
#
#  2023-06-08 20:35:28.821313  - random_milliseconds / 1000
# ...
# 2.257
#
#  2023-06-08 20:35:32.690876  - random_milliseconds
# ...
# 3903
#
#  2023-06-08 20:35:32.690876  - random_milliseconds / 1000
# ...
# 3.903
#
#  2023-06-08 20:35:37.789383  - random_milliseconds
# ...
# 2748
#
#  2023-06-08 20:35:37.789383  - random_milliseconds / 1000
# ...
# 2.748
#
#  2023-06-08 20:35:43.007718  - random_milliseconds
# ...
# 2674
#
#  2023-06-08 20:35:43.007718  - random_milliseconds / 1000
# ...
# 2.674
#
#  2023-06-08 20:35:47.283182  - random_milliseconds
# ...
# 2526
#
#  2023-06-08 20:35:47.283182  - random_milliseconds / 1000
# ...
# 2.526
#
#  2023-06-08 20:35:51.371628  - random_milliseconds
# ...
# 3270
#
#  2023-06-08 20:35:51.371628  - random_milliseconds / 1000
# ...
# 3.27
#
#  2023-06-08 20:35:56.633411  - random_milliseconds
# ...
# 2098
#
#  2023-06-08 20:35:56.633411  - random_milliseconds / 1000
# ...
# 2.098
#
#  2023-06-08 20:35:59.971238  - random_milliseconds
# ...
# 3388
#
#  2023-06-08 20:35:59.971238  - random_milliseconds / 1000
# ...
# 3.388
#
#  2023-06-08 20:36:05.582245  - random_milliseconds
# ...
# 2721
#
#  2023-06-08 20:36:05.582245  - random_milliseconds / 1000
# ...
# 2.721
#  2023-06-08 20:36:09.957829  - random_milliseconds
# ...
# 3463
#
#  2023-06-08 20:36:09.957829  - random_milliseconds / 1000
# ...
# 3.463
#
#  2023-06-08 20:36:15.159186  - random_milliseconds
# ...
# 2086
#
#  2023-06-08 20:36:15.160183  - random_milliseconds / 1000
# ...
# 2.086
#
#  2023-06-08 20:36:18.844493  - random_milliseconds
# ...
# 3316
#
#  2023-06-08 20:36:18.844493  - random_milliseconds / 1000
# ...
# 3.316
#
#  2023-06-08 20:36:23.205075  - random_milliseconds
# ...
# 3046
#
#  2023-06-08 20:36:23.206076  - random_milliseconds / 1000
# ...
# 3.046
#
#  2023-06-08 20:36:28.724363  - random_milliseconds
# ...
# 2396
#
#  2023-06-08 20:36:28.724363  - random_milliseconds / 1000
# ...
# 2.396
#
#  2023-06-08 20:36:32.705288  - random_milliseconds
# ...
# 2774
#
#  2023-06-08 20:36:32.705288  - random_milliseconds / 1000
# ...
# 2.774
#
#  2023-06-08 20:36:36.868488  - random_milliseconds
# ...
# 2499
#
#  2023-06-08 20:36:36.868488  - random_milliseconds / 1000
# ...
# 2.499
#
#  2023-06-08 20:36:41.094298  - random_milliseconds
# ...
# 2890
#
#  2023-06-08 20:36:41.095338  - random_milliseconds / 1000
# ...
# 2.89
#
#  2023-06-08 20:36:45.135782  - random_milliseconds
# ...
# 2409
#
#  2023-06-08 20:36:45.135782  - random_milliseconds / 1000
# ...
# 2.409
#
#  2023-06-08 20:36:50.125917  - random_milliseconds
# ...
# 3034
#
#  2023-06-08 20:36:50.125917  - random_milliseconds / 1000
# ...
# 3.034
#
#  2023-06-08 20:36:54.573476  - random_milliseconds
# ...
# 2955
#
#  2023-06-08 20:36:54.573476  - random_milliseconds / 1000
# ...
# 2.955
#
#  2023-06-08 20:36:59.216681  - random_milliseconds
# ...
# 3870
#
#  2023-06-08 20:36:59.216681  - random_milliseconds / 1000
# ...
# 3.87
#
#  2023-06-08 20:37:04.793365  - random_milliseconds
# ...
# 3775
#
#  2023-06-08 20:37:04.793365  - random_milliseconds / 1000
# ...
# 3.775
#
#  2023-06-08 20:37:09.564579  - random_milliseconds
# ...
# 2458
#
#  2023-06-08 20:37:09.564579  - random_milliseconds / 1000
# ...
# 2.458
#
#  2023-06-08 20:37:14.356739  - random_milliseconds
# ...
# 3593
#
#  2023-06-08 20:37:14.356739  - random_milliseconds / 1000
# ...
# 3.593
#
#  2023-06-08 20:37:20.053340  - random_milliseconds
# ...
# 2892
#
#  2023-06-08 20:37:20.053340  - random_milliseconds / 1000
# ...
# 2.892
#
#  2023-06-08 20:37:24.651734  - random_milliseconds
# ...
# 3767
#
#  2023-06-08 20:37:24.651734  - random_milliseconds / 1000
# ...
# 3.767
#
#  2023-06-08 20:37:30.254828  - random_milliseconds
# ...
# 3965
#
#  2023-06-08 20:37:30.254828  - random_milliseconds / 1000
# ...
# 3.965
#
#  2023-06-08 20:37:35.426013  - random_milliseconds
# ...
# 2442
#
#  2023-06-08 20:37:35.426013  - random_milliseconds / 1000
# ...
# 2.442
#
#  2023-06-08 20:37:40.133233  - random_milliseconds
# ...
# 3823
#
#  2023-06-08 20:37:40.133233  - random_milliseconds / 1000
# ...
# 3.823
#
#  2023-06-08 20:37:45.768289  - random_milliseconds
# ...
# 3899
#
#  2023-06-08 20:37:45.768289  - random_milliseconds / 1000
# ...
# 3.899
#
#  2023-06-08 20:37:51.466388  - random_milliseconds
# ...
# 2576
#
#  2023-06-08 20:37:51.466388  - random_milliseconds / 1000
# ...
# 2.576
#
#  2023-06-08 20:37:55.767438  - random_milliseconds
# ...
# 3981
#
#  2023-06-08 20:37:55.767438  - random_milliseconds / 1000
# ...
# 3.981
#
#  2023-06-08 20:38:00.990832  - random_milliseconds
# ...
# 3234
#
#  2023-06-08 20:38:00.990832  - random_milliseconds / 1000
# ...
# 3.234
#
#  2023-06-08 20:38:06.809335  - random_milliseconds
# ...
# 2078
#
#  2023-06-08 20:38:06.810333  - random_milliseconds / 1000
# ...
# 2.078
#
#  2023-06-08 20:38:10.567686  - random_milliseconds
# ...
# 3619
#
#  2023-06-08 20:38:10.567686  - random_milliseconds / 1000
# ...
# 3.619
#
#  2023-06-08 20:38:15.955818  - random_milliseconds
# ...
# 3842
#
#  2023-06-08 20:38:15.955818  - random_milliseconds / 1000
# ...
# 3.842
#
#  2023-06-08 20:38:21.682795  - random_milliseconds
# ...
# 2275
#
#  2023-06-08 20:38:21.683804  - random_milliseconds / 1000
# ...
# 2.275
#
#  2023-06-08 20:38:25.123443  - random_milliseconds
# ...
# 3674
#
#  2023-06-08 20:38:25.123443  - random_milliseconds / 1000
# ...
# 3.674
#
#  2023-06-08 20:38:30.989913  - random_milliseconds
# ...
# 2350
#
#  2023-06-08 20:38:30.990856  - random_milliseconds / 1000
# ...
# 2.35
#
#  2023-06-08 20:38:35.251250  - random_milliseconds
# ...
# 2482
#
#  2023-06-08 20:38:35.251250  - random_milliseconds / 1000
# ...
# 2.482
#
#  2023-06-08 20:38:39.536280  - random_milliseconds
# ...
# 2803
#
#  2023-06-08 20:38:39.536280  - random_milliseconds / 1000
# ...
# 2.803
#
#  2023-06-08 20:38:43.953909  - random_milliseconds
# ...
# 3525
#
#  2023-06-08 20:38:43.953909  - random_milliseconds / 1000
# ...
# 3.525
#
#  2023-06-08 20:38:48.635544  - random_milliseconds
# ...
# 3199
#
#  2023-06-08 20:38:48.635544  - random_milliseconds / 1000
# ...
# 3.199
#
#  2023-06-08 20:38:54.191041  - random_milliseconds
# ...
# 2443
#
#  2023-06-08 20:38:54.191041  - random_milliseconds / 1000
# ...
# 2.443
#
#  2023-06-08 20:38:58.182542  - random_milliseconds
# ...
# 3563
#
#  2023-06-08 20:38:58.182542  - random_milliseconds / 1000
# ...
# 3.563
#
#  2023-06-08 20:39:03.440326  - random_milliseconds
# ...
# 2408
#
#  2023-06-08 20:39:03.440326  - random_milliseconds / 1000
# ...
# 2.408
#
#  2023-06-08 20:39:07.624145  - random_milliseconds
# ...
# 3942
#
#  2023-06-08 20:39:07.624193  - random_milliseconds / 1000
# ...
# 3.942
#
#  2023-06-08 20:39:12.846496  - random_milliseconds
# ...
# 3069
#
#  2023-06-08 20:39:12.846496  - random_milliseconds / 1000
# ...
# 3.069
#
#  2023-06-08 20:39:18.045717  - random_milliseconds
# ...
# 3461
#
#  2023-06-08 20:39:18.045717  - random_milliseconds / 1000
# ...
# 3.461
#
#  2023-06-08 20:39:23.251284  - random_milliseconds
# ...
# 2814
#
#  2023-06-08 20:39:23.251284  - random_milliseconds / 1000
# ...
# 2.814
#
#  2023-06-08 20:39:27.789835  - random_milliseconds
# ...
# 2479
#
#  2023-06-08 20:39:27.789835  - random_milliseconds / 1000
# ...
# 2.479
#
#  2023-06-08 20:39:32.063769  - random_milliseconds
# ...
# 3152
#
#  2023-06-08 20:39:32.063769  - random_milliseconds / 1000
# ...
# 3.152
#
#  2023-06-08 20:39:36.312142  - random_milliseconds
# ...
# 3473
#
#  2023-06-08 20:39:36.312142  - random_milliseconds / 1000
# ...
# 3.473
#
#  2023-06-08 20:39:42.362514  - random_milliseconds
# ...
# 3062
#
#  2023-06-08 20:39:42.363068  - random_milliseconds / 1000
# ...
# 3.062
#
#  2023-06-08 20:39:47.308890  - random_milliseconds
# ...
# 3097
#
#  2023-06-08 20:39:47.308890  - random_milliseconds / 1000
# ...
# 3.097
#
#  2023-06-08 20:39:52.611871  - random_milliseconds
# ...
# 2912
#
#  2023-06-08 20:39:52.611871  - random_milliseconds / 1000
# ...
# 2.912
#
#  2023-06-08 20:39:57.244647  - random_milliseconds
# ...
# 3175
#
#  2023-06-08 20:39:57.244647  - random_milliseconds / 1000
# ...
# 3.175
#
#  2023-06-08 20:40:01.569519  - random_milliseconds
# ...
# 2017
#
#  2023-06-08 20:40:01.569519  - random_milliseconds / 1000
# ...
# 2.017
#
#  2023-06-08 20:40:05.496205  - random_milliseconds
# ...
# 2494
#
#  2023-06-08 20:40:05.496205  - random_milliseconds / 1000
# ...
# 2.494
#
#  2023-06-08 20:40:09.756877  - random_milliseconds
# ...
# 3814
#
#  2023-06-08 20:40:09.756877  - random_milliseconds / 1000
# ...
# 3.814
#
#  2023-06-08 20:40:15.379002  - random_milliseconds
# ...
# 2419
#
#  2023-06-08 20:40:15.379002  - random_milliseconds / 1000
# ...
# 2.419
#
#  2023-06-08 20:40:19.710856  - random_milliseconds
# ...
# 2404
#
#  2023-06-08 20:40:19.710856  - random_milliseconds / 1000
# ...
# 2.404
#
#  2023-06-08 20:40:23.176463  - random_milliseconds
# ...
# 2732
#
#  2023-06-08 20:40:23.176463  - random_milliseconds / 1000
# ...
# 2.732
#
#  2023-06-08 20:40:28.429303  - random_milliseconds
# ...
# 2309
#
#  2023-06-08 20:40:28.429303  - random_milliseconds / 1000
# ...
# 2.309
#
#  2023-06-08 20:40:32.458536  - random_milliseconds
# ...
# 2607
#
#  2023-06-08 20:40:32.458536  - random_milliseconds / 1000
# ...
# 2.607
#
#  2023-06-08 20:40:36.744538  - random_milliseconds
# ...
# 3961
#
#  2023-06-08 20:40:36.744538  - random_milliseconds / 1000
# ...
# 3.961
#
#  2023-06-08 20:40:42.359988  - random_milliseconds
# ...
# 3199
#
#  2023-06-08 20:40:42.359988  - random_milliseconds / 1000
# ...
# 3.199
#
#  2023-06-08 20:40:46.716217  - random_milliseconds
# ...
# 3554
#
#  2023-06-08 20:40:46.716217  - random_milliseconds / 1000
# ...
# 3.554
#
#  2023-06-08 20:40:52.798150  - random_milliseconds
# ...
# 3955
#
#  2023-06-08 20:40:52.798150  - random_milliseconds / 1000
# ...
# 3.955
#
#  2023-06-08 20:40:58.488560  - random_milliseconds
# ...
# 3503
#
#  2023-06-08 20:40:58.488560  - random_milliseconds / 1000
# ...
# 3.503
#
#  2023-06-08 20:41:04.429601  - random_milliseconds
# ...
# 3163
#
#  2023-06-08 20:41:04.429601  - random_milliseconds / 1000
# ...
# 3.163
#
#  2023-06-08 20:41:09.181853  - random_milliseconds
# ...
# 2882
#
#  2023-06-08 20:41:09.181853  - random_milliseconds / 1000
# ...
# 2.882
#  2023-06-08 20:41:13.274613  - random_milliseconds
# ...
# 3781
#
#  2023-06-08 20:41:13.274613  - random_milliseconds / 1000
# ...
# 3.781
#
#  2023-06-08 20:41:19.400532  - random_milliseconds
# ...
# 2725
#
#  2023-06-08 20:41:19.400532  - random_milliseconds / 1000
# ...
# 2.725
#
#  2023-06-08 20:41:23.909463  - random_milliseconds
# ...
# 2607
#
#  2023-06-08 20:41:23.909463  - random_milliseconds / 1000
# ...
# 2.607
#
#  2023-06-08 20:41:28.309479  - random_milliseconds
# ...
# 2532
#
#  2023-06-08 20:41:28.309479  - random_milliseconds / 1000
# ...
# 2.532
#
#  2023-06-08 20:41:32.623890  - random_milliseconds
# ...
# 3650
#
#  2023-06-08 20:41:32.623890  - random_milliseconds / 1000
# ...
# 3.65
#
#  2023-06-08 20:41:37.504501  - random_milliseconds
# ...
# 3400
#
#  2023-06-08 20:41:37.504501  - random_milliseconds / 1000
# ...
# 3.4
#
#  2023-06-08 20:41:42.961860  - random_milliseconds
# ...
# 2227
#
#  2023-06-08 20:41:42.961860  - random_milliseconds / 1000
# ...
# 2.227
#
#  2023-06-08 20:41:46.941335  - random_milliseconds
# ...
# 2159
#
#  2023-06-08 20:41:46.941959  - random_milliseconds / 1000
# ...
# 2.159
#
#  2023-06-08 20:41:50.996494  - random_milliseconds
# ...
# 2467
#
#  2023-06-08 20:41:50.996494  - random_milliseconds / 1000
# ...
# 2.467
#
#  2023-06-08 20:41:55.297808  - random_milliseconds
# ...
# 2944
#
#  2023-06-08 20:41:55.298805  - random_milliseconds / 1000
# ...
# 2.944
#
#  2023-06-08 20:41:59.371143  - random_milliseconds
# ...
# 2199
#
#  2023-06-08 20:41:59.371143  - random_milliseconds / 1000
# ...
# 2.199
#
#  2023-06-08 20:42:03.985929  - random_milliseconds
# ...
# 2843
#
#  2023-06-08 20:42:03.985929  - random_milliseconds / 1000
# ...
# 2.843
#
#  2023-06-08 20:42:08.957247  - random_milliseconds
# ...
# 2681
#
#  2023-06-08 20:42:08.957247  - random_milliseconds / 1000
# ...
# 2.681
#
#  2023-06-08 20:42:13.273581  - random_milliseconds
# ...
# 2792
#
#  2023-06-08 20:42:13.273581  - random_milliseconds / 1000
# ...
# 2.792
#
#  2023-06-08 20:42:17.869078  - random_milliseconds
# ...
# 2914
#
#  2023-06-08 20:42:17.869078  - random_milliseconds / 1000
# ...
# 2.914
#
#  2023-06-08 20:42:22.085421  - random_milliseconds
# ...
# 3431
#
#  2023-06-08 20:42:22.085421  - random_milliseconds / 1000
# ...
# 3.431
#
#  2023-06-08 20:42:27.874618  - random_milliseconds
# ...
# 2532
#
#  2023-06-08 20:42:27.874618  - random_milliseconds / 1000
# ...
# 2.532
#
#  2023-06-08 20:42:32.095079  - random_milliseconds
# ...
# 3664
#
#  2023-06-08 20:42:32.095079  - random_milliseconds / 1000
# ...
# 3.664
#
#  2023-06-08 20:42:37.721049  - random_milliseconds
# ...
# 3645
#
#  2023-06-08 20:42:37.721049  - random_milliseconds / 1000
# ...
# 3.645
#
#  2023-06-08 20:42:43.227203  - random_milliseconds
# ...
# 2115
#
#  2023-06-08 20:42:43.227203  - random_milliseconds / 1000
# ...
# 2.115
#
#  2023-06-08 20:42:46.410805  - random_milliseconds
# ...
# 3215
#
#  2023-06-08 20:42:46.410805  - random_milliseconds / 1000
# ...
# 3.215
#
#  2023-06-08 20:42:52.199187  - random_milliseconds
# ...
# 2480
#
#  2023-06-08 20:42:52.199187  - random_milliseconds / 1000
# ...
# 2.48
#
#  2023-06-08 20:42:56.528442  - random_milliseconds
# ...
# 2594
#
#  2023-06-08 20:42:56.528741  - random_milliseconds / 1000
# ...
# 2.594
#
#  2023-06-08 20:43:01.036104  - random_milliseconds
# ...
# 3337
#
#  2023-06-08 20:43:01.036104  - random_milliseconds / 1000
# ...
# 3.337
#
#  2023-06-08 20:43:06.296718  - random_milliseconds
# ...
# 2936
#
#  2023-06-08 20:43:06.296718  - random_milliseconds / 1000
# ...
# 2.936
#
#  2023-06-08 20:43:10.328459  - random_milliseconds
# ...
# 2576
#
#  2023-06-08 20:43:10.328459  - random_milliseconds / 1000
# ...
# 2.576
#
#  2023-06-08 20:43:15.505664  - random_milliseconds
# ...
# 3377
#
#  2023-06-08 20:43:15.505664  - random_milliseconds / 1000
# ...
# 3.377
#
#  2023-06-08 20:43:21.065059  - random_milliseconds
# ...
# 2802
#
#  2023-06-08 20:43:21.065059  - random_milliseconds / 1000
# ...
# 2.802
#
#  2023-06-08 20:43:25.677899  - random_milliseconds
# ...
# 2617
#
#  2023-06-08 20:43:25.677899  - random_milliseconds / 1000
# ...
# 2.617
#
#  2023-06-08 20:43:30.378321  - random_milliseconds
# ...
# 2969
#
#  2023-06-08 20:43:30.378321  - random_milliseconds / 1000
# ...
# 2.969
#
#  2023-06-08 20:43:34.387303  - random_milliseconds
# ...
# 3834
#
#  2023-06-08 20:43:34.387303  - random_milliseconds / 1000
# ...
# 3.834
#
#  2023-06-08 20:43:40.776736  - random_milliseconds
# ...
# 3920
#
#  2023-06-08 20:43:40.776736  - random_milliseconds / 1000
# ...
# 3.92
#
#  2023-06-08 20:43:46.489765  - random_milliseconds
# ...
# 3117
#
#  2023-06-08 20:43:46.490765  - random_milliseconds / 1000
# ...
# 3.117
#
#  2023-06-08 20:43:51.360642  - random_milliseconds
# ...
# 3690
#
#  2023-06-08 20:43:51.360642  - random_milliseconds / 1000
# ...
# 3.69
#
#  2023-06-08 20:43:56.923860  - random_milliseconds
# ...
# 3093
#
#  2023-06-08 20:43:56.923860  - random_milliseconds / 1000
# ...
# 3.093
#
#  2023-06-08 20:44:01.208199  - random_milliseconds
# ...
# 2965
#
#  2023-06-08 20:44:01.208199  - random_milliseconds / 1000
# ...
# 2.965
#
#  2023-06-08 20:44:06.208574  - random_milliseconds
# ...
# 3724
#
#  2023-06-08 20:44:06.208574  - random_milliseconds / 1000
# ...
# 3.724
#
#  2023-06-08 20:44:11.807126  - random_milliseconds
# ...
# 2856
#
#  2023-06-08 20:44:11.807126  - random_milliseconds / 1000
# ...
# 2.856
#
#  2023-06-08 20:44:16.532060  - random_milliseconds
# ...
# 2537
#
#  2023-06-08 20:44:16.532060  - random_milliseconds / 1000
# ...
# 2.537
#
#  2023-06-08 20:44:20.994690  - random_milliseconds
# ...
# 3243
#
#  2023-06-08 20:44:20.994690  - random_milliseconds / 1000
# ...
# 3.243
#
#  2023-06-08 20:44:25.523671  - random_milliseconds
# ...
# 2776
#
#  2023-06-08 20:44:25.523671  - random_milliseconds / 1000
# ...
# 2.776
#
#  2023-06-08 20:44:30.824249  - random_milliseconds
# ...
# 3372
#
#  2023-06-08 20:44:30.825426  - random_milliseconds / 1000
# ...
# 3.372
#
#  2023-06-08 20:44:36.299221  - random_milliseconds
# ...
# 2021
#
#  2023-06-08 20:44:36.299221  - random_milliseconds / 1000
# ...
# 2.021
#
#  2023-06-08 20:44:40.104559  - random_milliseconds
# ...
# 3416
#
#  2023-06-08 20:44:40.104559  - random_milliseconds / 1000
# ...
# 3.416
#
#  2023-06-08 20:44:45.593801  - random_milliseconds
# ...
# 3666
#
#  2023-06-08 20:44:45.593801  - random_milliseconds / 1000
# ...
# 3.666
#
#  2023-06-08 20:44:50.433554  - random_milliseconds
# ...
# 2697
#
#  2023-06-08 20:44:50.433554  - random_milliseconds / 1000
# ...
# 2.697
#
#  2023-06-08 20:44:55.434928  - random_milliseconds
# ...
# 3010
#
#  2023-06-08 20:44:55.434928  - random_milliseconds / 1000
# ...
# 3.01
#
#  2023-06-08 20:45:00.278830  - random_milliseconds
# ...
# 2088
#
#  2023-06-08 20:45:00.278830  - random_milliseconds / 1000
# ...
# 2.088
#
#  2023-06-08 20:45:04.284531  - random_milliseconds
# ...
# 3662
#
#  2023-06-08 20:45:04.284531  - random_milliseconds / 1000
# ...
# 3.662
#
#  2023-06-08 20:45:09.719717  - random_milliseconds
# ...
# 2252
#
#  2023-06-08 20:45:09.719717  - random_milliseconds / 1000
# ...
# 2.252
#
#  2023-06-08 20:45:13.202411  - random_milliseconds
# ...
# 3664
#
#  2023-06-08 20:45:13.202411  - random_milliseconds / 1000
# ...
# 3.664
#
#  2023-06-08 20:45:19.353346  - random_milliseconds
# ...
# 3041
#
#  2023-06-08 20:45:19.353346  - random_milliseconds / 1000
# ...
# 3.041
#
#  2023-06-08 20:45:24.212544  - random_milliseconds
# ...
# 2167
#
#  2023-06-08 20:45:24.212544  - random_milliseconds / 1000
# ...
# 2.167
#
#  2023-06-08 20:45:28.115819  - random_milliseconds
# ...
# 3630
#
#  2023-06-08 20:45:28.115819  - random_milliseconds / 1000
# ...
# 3.63
#
#  2023-06-08 20:45:33.906996  - random_milliseconds
# ...
# 3865
#
#  2023-06-08 20:45:33.906996  - random_milliseconds / 1000
# ...
# 3.865
#
#  2023-06-08 20:45:38.988995  - random_milliseconds
# ...
# 2132
#
#  2023-06-08 20:45:38.988995  - random_milliseconds / 1000
# ...
# 2.132
#
#  2023-06-08 20:45:43.211972  - random_milliseconds
# ...
# 3728
#
#  2023-06-08 20:45:43.211972  - random_milliseconds / 1000
# ...
# 3.728
#
#  2023-06-08 20:45:48.894170  - random_milliseconds
# ...
# 2390
#
#  2023-06-08 20:45:48.895166  - random_milliseconds / 1000
# ...
# 2.39
#
#  2023-06-08 20:45:53.256221  - random_milliseconds
# ...
# 2453
#
#  2023-06-08 20:45:53.256221  - random_milliseconds / 1000
# ...
# 2.453
#
#  2023-06-08 20:45:57.485325  - random_milliseconds
# ...
# 2593
#
#  2023-06-08 20:45:57.485325  - random_milliseconds / 1000
# ...
# 2.593
#
#  2023-06-08 20:46:01.184384  - random_milliseconds
# ...
# 3654
#
#  2023-06-08 20:46:01.184384  - random_milliseconds / 1000
# ...
# 3.654
#
#  2023-06-08 20:46:07.207478  - random_milliseconds
# ...
# 2126
#
#  2023-06-08 20:46:07.207478  - random_milliseconds / 1000
# ...
# 2.126
#
#  2023-06-08 20:46:11.271822  - random_milliseconds
# ...
# 3561
#
#  2023-06-08 20:46:11.271822  - random_milliseconds / 1000
# ...
# 3.561
#  2023-06-08 20:46:16.890761  - random_milliseconds
# ...
# 3338
#
#  2023-06-08 20:46:16.890761  - random_milliseconds / 1000
# ...
# 3.338
#
#  2023-06-08 20:46:22.219373  - random_milliseconds
# ...
# 2366
#
#  2023-06-08 20:46:22.219373  - random_milliseconds / 1000
# ...
# 2.366
#
#  2023-06-08 20:46:25.737978  - random_milliseconds
# ...
# 3204
#
#  2023-06-08 20:46:25.737978  - random_milliseconds / 1000
# ...
# 3.204
#
#  2023-06-08 20:46:30.955219  - random_milliseconds
# ...
# 3869
#
#  2023-06-08 20:46:30.955219  - random_milliseconds / 1000
# ...
# 3.869
#
#  2023-06-08 20:46:36.816865  - random_milliseconds
# ...
# 3483
#
#  2023-06-08 20:46:36.816865  - random_milliseconds / 1000
# ...
# 3.483
#
#  2023-06-08 20:46:42.702670  - random_milliseconds
# ...
# 2427
#
#  2023-06-08 20:46:42.702670  - random_milliseconds / 1000
# ...
# 2.427
#
#  2023-06-08 20:46:46.875888  - random_milliseconds
# ...
# 2616
#
#  2023-06-08 20:46:46.875888  - random_milliseconds / 1000
# ...
# 2.616
#
#  2023-06-08 20:46:50.646606  - random_milliseconds
# ...
# 2644
#
#  2023-06-08 20:46:50.646606  - random_milliseconds / 1000
# ...
# 2.644
#
#  2023-06-08 20:46:55.958176  - random_milliseconds
# ...
# 3747
#
#  2023-06-08 20:46:55.958176  - random_milliseconds / 1000
# ...
# 3.747
#
#  2023-06-08 20:47:01.414067  - random_milliseconds
# ...
# 3949
#
#  2023-06-08 20:47:01.414067  - random_milliseconds / 1000
# ...
# 3.949
#
#  2023-06-08 20:47:07.510867  - random_milliseconds
# ...
# 2494
#
#  2023-06-08 20:47:07.510867  - random_milliseconds / 1000
# ...
# 2.494
#
#  2023-06-08 20:47:11.936815  - random_milliseconds
# ...
# 2515
#
#  2023-06-08 20:47:11.936815  - random_milliseconds / 1000
# ...
# 2.515
#
#  2023-06-08 20:47:15.832277  - random_milliseconds
# ...
# 2493
#
#  2023-06-08 20:47:15.832277  - random_milliseconds / 1000
# ...
# 2.493
#
#  2023-06-08 20:47:20.803803  - random_milliseconds
# ...
# 2606
#
#  2023-06-08 20:47:20.803803  - random_milliseconds / 1000
# ...
# 2.606
#
#  2023-06-08 20:47:25.234601  - random_milliseconds
# ...
# 2693
#
#  2023-06-08 20:47:25.234601  - random_milliseconds / 1000
# ...
# 2.693
#
#  2023-06-08 20:47:29.896424  - random_milliseconds
# ...
# 3417
#
#  2023-06-08 20:47:29.896424  - random_milliseconds / 1000
# ...
# 3.417
#
#  2023-06-08 20:47:35.307874  - random_milliseconds
# ...
# 2982
#
#  2023-06-08 20:47:35.307874  - random_milliseconds / 1000
# ...
# 2.982
#
#  2023-06-08 20:47:39.530879  - random_milliseconds
# ...
# 3456
#
#  2023-06-08 20:47:39.530879  - random_milliseconds / 1000
# ...
# 3.456
#
#  2023-06-08 20:47:45.460348  - random_milliseconds
# ...
# 3084
#
#  2023-06-08 20:47:45.460433  - random_milliseconds / 1000
# ...
# 3.084
#
#  2023-06-08 20:47:50.734725  - random_milliseconds
# ...
# 2874
#
#  2023-06-08 20:47:50.734725  - random_milliseconds / 1000
# ...
# 2.874
#
#  2023-06-08 20:47:55.738384  - random_milliseconds
# ...
# 2652
#
#  2023-06-08 20:47:55.738384  - random_milliseconds / 1000
# ...
# 2.652
#
#  2023-06-08 20:48:00.284870  - random_milliseconds
# ...
# 3797
#
#  2023-06-08 20:48:00.284870  - random_milliseconds / 1000
# ...
# 3.797
#
#  2023-06-08 20:48:04.992423  - random_milliseconds
# ...
# 3389
#
#  2023-06-08 20:48:04.992423  - random_milliseconds / 1000
# ...
# 3.389
#
#  2023-06-08 20:48:10.741091  - random_milliseconds
# ...
# 2113
#
#  2023-06-08 20:48:10.741091  - random_milliseconds / 1000
# ...
# 2.113
#
#  2023-06-08 20:48:14.808668  - random_milliseconds
# ...
# 2922
#
#  2023-06-08 20:48:14.808668  - random_milliseconds / 1000
# ...
# 2.922
#
#  2023-06-08 20:48:19.724873  - random_milliseconds
# ...
# 2206
#
#  2023-06-08 20:48:19.724873  - random_milliseconds / 1000
# ...
# 2.206
#
#  2023-06-08 20:48:23.838962  - random_milliseconds
# ...
# 3621
#
#  2023-06-08 20:48:23.838962  - random_milliseconds / 1000
# ...
# 3.621
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22416\3447074465.py in <module>
#     158 #     attaquer_village('3466', '3275', 'data/village.txt')
#     159 #     attaquer_village('3466', '3172', 'data/village.txt')
# --> 160     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
#     161     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
#     162     delay_with_random_seconds()
#
# ~\AppData\Local\Temp\ipykernel_22416\3447074465.py in attaquer_village(troupes_file)
#      75
#      76         bouton = firefox.child_window(auto_id='troop_confirm_submit')
# ---> 77         bouton.click()
#      78         delay_with_random_seconds()
#      79
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     377         if len(self.criteria) >= 2:  # FIXME - this is surprising
#     378
# --> 379             ctrls = self.__resolve_control(self.criteria)
#     380
#     381             try:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     220                 if 'backend' not in ctrl_criteria:
#     221                     ctrl_criteria['backend'] = self.backend.name
# --> 222                 ctrl = self.backend.generic_wrapper_class(findwindows.find_element(**ctrl_criteria))
#     223                 previous_parent = ctrl.element_info
#     224                 ctrls.append(ctrl)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'auto_id': 'troop_confirm_submit', 'top_level_only': False, 'parent': <uia_element_info.UIAElementInfo - 'arion1 (556|484) - Guerre Tribale - Monde 81 — Mozilla Firefox', MozillaWindowClass, 20451476>, 'backend': 'uia'}
