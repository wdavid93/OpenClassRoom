# %%
from pywinauto.application import Application
import psutil
import time
import random
import requests
import csv
import datetime
import fileinput

def delay_with_random_seconds():
#     # Génère un délai aléatoire entre 1 et 5 secondes
#     random_seconds = random.randint(2, 4)
# #     print(random_seconds)
    
#     # Pause l'exécution du programme pendant le délai aléatoire
#     time.sleep(random_seconds)
    random_milliseconds = random.randint(2000, 4000)  # Générer un nombre aléatoire en millisecondes entre 2000 et 4000
    print('\n', datetime.datetime.now(),' - random_milliseconds \n...')   
    print(random_milliseconds)
    print('\n', datetime.datetime.now(),' - random_milliseconds / 1000 \n...')   
    print(random_milliseconds / 1000)
    time.sleep(random_milliseconds / 1000)  # Utiliser la valeur en millisecondes dans time.sleep()
 #     # Reprise de l'exécution du programme après le délai
#     print("Délai de", random_seconds, "secondes terminé.")

# for proc in psutil.process_iter():
#     if proc.name() == "firefox.exe":
#         proc.kill()

def attaquer_village(troupes_file):
    lines = []

    # Lire le fichier et stocker les lignes dans une liste
    with open(troupes_file, 'r') as file:
        lines = file.readlines()

    # Exclure la première ligne (en-têtes)
    headers = lines[0].strip().split(',')
    lines = lines[1:]

    # Trier les lignes par heure_attaque la plus ancienne
    lines = sorted(lines, key=lambda x: datetime.datetime.strptime(x.strip().split(',')[headers.index('heure_attaque')], "%Y-%m-%d %H:%M:%S"))

    # Parcourir les lignes triées
    for i, line in enumerate(lines):
        data = line.strip().split(',')
        village_depart = data[headers.index('village_depart')]
        village_attaquer = data[headers.index('village_attaquer')]

        firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
        url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_attaquer}"
        firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
        delay_with_random_seconds()

        # Saisir les champs pour chaque type de troupe
        for header in headers:
            if header not in ['heure_attaque', 'village_depart', 'village_attaquer']:
                value = int(data[headers.index(header)])
                if value > 0:
                    zone = firefox.child_window(auto_id=header)
                    zone.type_keys(str(value))
                    delay_with_random_seconds()

        # Mettre à jour la colonne heure_attaque avec l'heure actuelle
        heure_attaque_index = headers.index('heure_attaque')
        heure_attaque = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        data[heure_attaque_index] = heure_attaque

        # Modifier la ligne dans la liste
        lines[i] = ','.join(data) + '\n'

        bouton = firefox.child_window(auto_id='target_attack')
        bouton.click()
        delay_with_random_seconds()

        bouton = firefox.child_window(auto_id='troop_confirm_submit')
        bouton.click()
        delay_with_random_seconds()

    # Réécrire le fichier avec les lignes modifiées
    with open(troupes_file, 'w') as file:
        file.write(','.join(headers) + '\n')  # Réécrire les en-têtes
        file.writelines(lines)  # Réécrire les lignes modifiées


# Vérifier si Firefox est en cours d'exécution
firefox_running = False
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_running = True
        firefox_pid = process.pid
        break

# Fermer Firefox si c'est le cas
if firefox_running:
    process = psutil.Process(firefox_pid)
    process.terminate()
#     time.sleep(5)
# Ouvrir Firefox
time.sleep(2)

app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Ouvrir Firefox
# app = Application(backend='uia').start('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

# Trouver le PID de Firefox
firefox_pid = None
for process in psutil.process_iter():
    if process.name() == "firefox.exe":
        firefox_pid = process.pid
        break

# Vérifier si Firefox est en cours d'exécution
if firefox_pid is None:
    print("Firefox n'est pas en cours d'exécution.")
else:
    # Attacher Pywinauto à la fenêtre Firefox
    app = Application(backend='uia').connect(process=firefox_pid)

    # Ouvrir une page web
#     firefox = app.window(title_re='.*Nouvel onglet*')
    firefox = app.window( class_name='MozillaWindowClass')

    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#     time.sleep(5)

#     # Saisir les champs
#     zone1 = firefox.window(title='user')
#     zone1.type_keys('*test1')
#     zone1 = firefox.child_window(control_type="Edit", found_index=0, automation_id="user")
    zone1 = firefox.child_window(auto_id='user')

    zone1.type_keys('arion1')
    delay_with_random_seconds()

    zone2 = firefox.child_window(auto_id='password')
    zone2.type_keys('MiMa5158**')
    delay_with_random_seconds()
    # Cliquer sur le bouton
#     bouton = firefox.window(title='Connexion')
# #     bouton = firefox.child_window(auto_id='btn-login')
#     bouton = firefox.child_window(title='Connexion')
#     bouton.click()!
    bouton = firefox.child_window(title='Connexion', control_type='Hyperlink')
    bouton.invoke()
#     bouton = firefox.child_window(title='Monde 80', control_type='Hyperlink')
#     bouton.invoke()
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://www.guerretribale.fr/page/play/fr81{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
    firefox.type_keys('https://fr81.guerretribale.fr/game.php?village=3466&screen=map#556;484{ENTER}')  # Entrer l'URL et appuyer sur Entrée
    delay_with_random_seconds()
    
#     attaquer_village('3466', '3275', 'data/village.txt')
#     attaquer_village('3466', '3172', 'data/village.txt')
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
    attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
    delay_with_random_seconds()    
    # Fermer Firefox 
#     firefox.close()
# Out:
#  2023-06-06 21:08:13.837854  - random_milliseconds
# ...
# 3161
#
#  2023-06-06 21:08:13.837854  - random_milliseconds / 1000
# ...
# 3.161
#
#  2023-06-06 21:08:17.693189  - random_milliseconds
# ...
# 3253
#
#  2023-06-06 21:08:17.693189  - random_milliseconds / 1000
# ...
# 3.253
#
#  2023-06-06 21:08:21.406227  - random_milliseconds
# ...
# 3181
#
#  2023-06-06 21:08:21.406227  - random_milliseconds / 1000
# ...
# 3.181
#
#  2023-06-06 21:08:25.878028  - random_milliseconds
# ...
# 2141
#
#  2023-06-06 21:08:25.878028  - random_milliseconds / 1000
# ...
# 2.141
#
#  2023-06-06 21:08:29.757824  - random_milliseconds
# ...
# 2902
#
#  2023-06-06 21:08:29.757824  - random_milliseconds / 1000
# ...
# 2.902
#
#  2023-06-06 21:08:34.462085  - random_milliseconds
# ...
# 3212
#
#  2023-06-06 21:08:34.462085  - random_milliseconds / 1000
# ...
# 3.212
#
#  2023-06-06 21:08:38.626019  - random_milliseconds
# ...
# 2026
#
#  2023-06-06 21:08:38.626019  - random_milliseconds / 1000
# ...
# 2.026
#
#  2023-06-06 21:08:41.617428  - random_milliseconds
# ...
# 2690
#
#  2023-06-06 21:08:41.617428  - random_milliseconds / 1000
# ...
# 2.69
#
#  2023-06-06 21:08:45.252975  - random_milliseconds
# ...
# 2641
#
#  2023-06-06 21:08:45.252975  - random_milliseconds / 1000
# ...
# 2.641
#
#  2023-06-06 21:08:48.676698  - random_milliseconds
# ...
# 2376
#
#  2023-06-06 21:08:48.676698  - random_milliseconds / 1000
# ...
# 2.376
#
#  2023-06-06 21:08:52.828338  - random_milliseconds
# ...
# 2286
#
#  2023-06-06 21:08:52.828338  - random_milliseconds / 1000
# ...
# 2.286
#
#  2023-06-06 21:08:56.040916  - random_milliseconds
# ...
# 3892
#
#  2023-06-06 21:08:56.040916  - random_milliseconds / 1000
# ...
# 3.892
#
#  2023-06-06 21:09:01.433478  - random_milliseconds
# ...
# 2084
#
#  2023-06-06 21:09:01.433478  - random_milliseconds / 1000
# ...
# 2.084
#
#  2023-06-06 21:09:04.553136  - random_milliseconds
# ...
# 2267
#
#  2023-06-06 21:09:04.553136  - random_milliseconds / 1000
# ...
# 2.267
#
#  2023-06-06 21:09:07.542272  - random_milliseconds
# ...
# 2577
#
#  2023-06-06 21:09:07.542272  - random_milliseconds / 1000
# ...
# 2.577
#
#  2023-06-06 21:09:11.901863  - random_milliseconds
# ...
# 3232
#
#  2023-06-06 21:09:11.901863  - random_milliseconds / 1000
# ...
# 3.232
#
#  2023-06-06 21:09:16.047857  - random_milliseconds
# ...
# 3949
#
#  2023-06-06 21:09:16.047857  - random_milliseconds / 1000
# ...
# 3.949
#
#  2023-06-06 21:09:21.010946  - random_milliseconds
# ...
# 2208
#
#  2023-06-06 21:09:21.010946  - random_milliseconds / 1000
# ...
# 2.208
#
#  2023-06-06 21:09:24.193046  - random_milliseconds
# ...
# 2033
#
#  2023-06-06 21:09:24.193046  - random_milliseconds / 1000
# ...
# 2.033
#
#  2023-06-06 21:09:27.001486  - random_milliseconds
# ...
# 3303
#
#  2023-06-06 21:09:27.001486  - random_milliseconds / 1000
# ...
# 3.303
#
#  2023-06-06 21:09:32.068909  - random_milliseconds
# ...
# 3880
#
#  2023-06-06 21:09:32.068909  - random_milliseconds / 1000
# ...
# 3.88
#
#  2023-06-06 21:09:36.919037  - random_milliseconds
# ...
# 3592
#
#  2023-06-06 21:09:36.919037  - random_milliseconds / 1000
# ...
# 3.592
#
#  2023-06-06 21:09:41.472820  - random_milliseconds
# ...
# 3367
#
#  2023-06-06 21:09:41.473817  - random_milliseconds / 1000
# ...
# 3.367
#
#  2023-06-06 21:09:45.801043  - random_milliseconds
# ...
# 2033
#
#  2023-06-06 21:09:45.801043  - random_milliseconds / 1000
# ...
# 2.033
#
#  2023-06-06 21:09:48.608577  - random_milliseconds
# ...
# 3539
#
#  2023-06-06 21:09:48.608577  - random_milliseconds / 1000
# ...
# 3.539
#
#  2023-06-06 21:09:53.906047  - random_milliseconds
# ...
# 3034
#
#  2023-06-06 21:09:53.906047  - random_milliseconds / 1000
# ...
# 3.034
#
#  2023-06-06 21:09:57.871206  - random_milliseconds
# ...
# 2368
#
#  2023-06-06 21:09:57.871206  - random_milliseconds / 1000
# ...
# 2.368
#
#  2023-06-06 21:10:01.268702  - random_milliseconds
# ...
# 3477
#
#  2023-06-06 21:10:01.268702  - random_milliseconds / 1000
# ...
# 3.477
#
#  2023-06-06 21:10:05.749985  - random_milliseconds
# ...
# 2215
#
#  2023-06-06 21:10:05.749985  - random_milliseconds / 1000
# ...
# 2.215
#
#  2023-06-06 21:10:08.744640  - random_milliseconds
# ...
# 2371
#
#  2023-06-06 21:10:08.744640  - random_milliseconds / 1000
# ...
# 2.371
#
#  2023-06-06 21:10:12.904447  - random_milliseconds
# ...
# 2316
#
#  2023-06-06 21:10:12.904447  - random_milliseconds / 1000
# ...
# 2.316
#
#  2023-06-06 21:10:16.163967  - random_milliseconds
# ...
# 2042
#
#  2023-06-06 21:10:16.163967  - random_milliseconds / 1000
# ...
# 2.042
#
#  2023-06-06 21:10:19.515733  - random_milliseconds
# ...
# 2352
#
#  2023-06-06 21:10:19.515733  - random_milliseconds / 1000
# ...
# 2.352
#
#  2023-06-06 21:10:22.868398  - random_milliseconds
# ...
# 2088
#
#  2023-06-06 21:10:22.869380  - random_milliseconds / 1000
# ...
# 2.088
#
#  2023-06-06 21:10:25.703363  - random_milliseconds
# ...
# 2214
#
#  2023-06-06 21:10:25.703363  - random_milliseconds / 1000
# ...
# 2.214
#
#  2023-06-06 21:10:29.698002  - random_milliseconds
# ...
# 3908
#
#  2023-06-06 21:10:29.698002  - random_milliseconds / 1000
# ...
# 3.908
#
#  2023-06-06 21:10:34.616106  - random_milliseconds
# ...
# 2335
#
#  2023-06-06 21:10:34.616106  - random_milliseconds / 1000
# ...
# 2.335
#
#  2023-06-06 21:10:37.943960  - random_milliseconds
# ...
# 2181
#
#  2023-06-06 21:10:37.944952  - random_milliseconds / 1000
# ...
# 2.181
#
#  2023-06-06 21:10:41.185024  - random_milliseconds
# ...
# 2858
#
#  2023-06-06 21:10:41.185024  - random_milliseconds / 1000
# ...
# 2.858
#
#  2023-06-06 21:10:44.840090  - random_milliseconds
# ...
# 3022
#
#  2023-06-06 21:10:44.840090  - random_milliseconds / 1000
# ...
# 3.022
#
#  2023-06-06 21:10:49.638506  - random_milliseconds
# ...
# 2850
#
#  2023-06-06 21:10:49.638506  - random_milliseconds / 1000
# ...
# 2.85
#
#  2023-06-06 21:10:53.418127  - random_milliseconds
# ...
# 3151
#
#  2023-06-06 21:10:53.418127  - random_milliseconds / 1000
# ...
# 3.151
#
#  2023-06-06 21:10:57.539594  - random_milliseconds
# ...
# 2537
#
#  2023-06-06 21:10:57.539594  - random_milliseconds / 1000
# ...
# 2.537
#
#  2023-06-06 21:11:01.018727  - random_milliseconds
# ...
# 2149
#
#  2023-06-06 21:11:01.018727  - random_milliseconds / 1000
# ...
# 2.149
#
#  2023-06-06 21:11:03.946413  - random_milliseconds
# ...
# 2787
#
#  2023-06-06 21:11:03.946413  - random_milliseconds / 1000
# ...
# 2.787
#
#  2023-06-06 21:11:08.503468  - random_milliseconds
# ...
# 3648
#
#  2023-06-06 21:11:08.503468  - random_milliseconds / 1000
# ...
# 3.648
#
#  2023-06-06 21:11:13.188593  - random_milliseconds
# ...
# 3345
#
#  2023-06-06 21:11:13.188593  - random_milliseconds / 1000
# ...
# 3.345
#
#  2023-06-06 21:11:17.519559  - random_milliseconds
# ...
# 3558
#
#  2023-06-06 21:11:17.519559  - random_milliseconds / 1000
# ...
# 3.558
#
#  2023-06-06 21:11:22.294424  - random_milliseconds
# ...
# 3661
#
#  2023-06-06 21:11:22.294424  - random_milliseconds / 1000
# ...
# 3.661
#
#  2023-06-06 21:11:26.689453  - random_milliseconds
# ...
# 2843
#
#  2023-06-06 21:11:26.689453  - random_milliseconds / 1000
# ...
# 2.843
#
#  2023-06-06 21:11:31.350091  - random_milliseconds
# ...
# 2754
#
#  2023-06-06 21:11:31.350091  - random_milliseconds / 1000
# ...
# 2.754
#
#  2023-06-06 21:11:35.153070  - random_milliseconds
# ...
# 3412
#
#  2023-06-06 21:11:35.153070  - random_milliseconds / 1000
# ...
# 3.412
#
#  2023-06-06 21:11:39.597824  - random_milliseconds
# ...
# 3981
#
#  2023-06-06 21:11:39.597824  - random_milliseconds / 1000
# ...
# 3.981
#
#  2023-06-06 21:11:44.637679  - random_milliseconds
# ...
# 3854
#
#  2023-06-06 21:11:44.638664  - random_milliseconds / 1000
# ...
# 3.854
#
#  2023-06-06 21:11:49.248052  - random_milliseconds
# ...
# 2385
#
#  2023-06-06 21:11:49.248052  - random_milliseconds / 1000
# ...
# 2.385
#
#  2023-06-06 21:11:53.422915  - random_milliseconds
# ...
# 3278
#
#  2023-06-06 21:11:53.423913  - random_milliseconds / 1000
# ...
# 3.278
#
#  2023-06-06 21:11:57.672322  - random_milliseconds
# ...
# 3261
#
#  2023-06-06 21:11:57.672322  - random_milliseconds / 1000
# ...
# 3.261
#
#  2023-06-06 21:12:01.944715  - random_milliseconds
# ...
# 3055
#
#  2023-06-06 21:12:01.944715  - random_milliseconds / 1000
# ...
# 3.055
#
#  2023-06-06 21:12:05.972143  - random_milliseconds
# ...
# 3920
#
#  2023-06-06 21:12:05.972143  - random_milliseconds / 1000
# ...
# 3.92
#
#  2023-06-06 21:12:10.638760  - random_milliseconds
# ...
# 3636
#
#  2023-06-06 21:12:10.638760  - random_milliseconds / 1000
# ...
# 3.636
#
#  2023-06-06 21:12:16.028513  - random_milliseconds
# ...
# 2966
#
#  2023-06-06 21:12:16.028513  - random_milliseconds / 1000
# ...
# 2.966
#
#  2023-06-06 21:12:19.973426  - random_milliseconds
# ...
# 3464
#
#  2023-06-06 21:12:19.973426  - random_milliseconds / 1000
# ...
# 3.464
#
#  2023-06-06 21:12:24.464261  - random_milliseconds
# ...
# 2692
#
#  2023-06-06 21:12:24.464261  - random_milliseconds / 1000
# ...
# 2.692
#  2023-06-06 21:12:28.163434  - random_milliseconds
# ...
# 3888
#
#  2023-06-06 21:12:28.163434  - random_milliseconds / 1000
# ...
# 3.888
#
#  2023-06-06 21:12:32.832228  - random_milliseconds
# ...
# 2387
#
#  2023-06-06 21:12:32.832228  - random_milliseconds / 1000
# ...
# 2.387
#
#  2023-06-06 21:12:37.021423  - random_milliseconds
# ...
# 2716
#
#  2023-06-06 21:12:37.021423  - random_milliseconds / 1000
# ...
# 2.716
#
#  2023-06-06 21:12:41.031000  - random_milliseconds
# ...
# 3606
#
#  2023-06-06 21:12:41.032001  - random_milliseconds / 1000
# ...
# 3.606
#
#  2023-06-06 21:12:45.613503  - random_milliseconds
# ...
# 2342
#
#  2023-06-06 21:12:45.613503  - random_milliseconds / 1000
# ...
# 2.342
#
#  2023-06-06 21:12:49.044922  - random_milliseconds
# ...
# 3608
#
#  2023-06-06 21:12:49.044922  - random_milliseconds / 1000
# ...
# 3.608
#
#  2023-06-06 21:12:53.450636  - random_milliseconds
# ...
# 3906
#
#  2023-06-06 21:12:53.450636  - random_milliseconds / 1000
# ...
# 3.906
#
#  2023-06-06 21:12:59.124027  - random_milliseconds
# ...
# 3411
#
#  2023-06-06 21:12:59.124027  - random_milliseconds / 1000
# ...
# 3.411
#
#  2023-06-06 21:13:03.537203  - random_milliseconds
# ...
# 2609
#
#  2023-06-06 21:13:03.537203  - random_milliseconds / 1000
# ...
# 2.609
#
#  2023-06-06 21:13:07.156961  - random_milliseconds
# ...
# 3867
#
#  2023-06-06 21:13:07.156961  - random_milliseconds / 1000
# ...
# 3.867
#
#  2023-06-06 21:13:12.077147  - random_milliseconds
# ...
# 3949
#
#  2023-06-06 21:13:12.077147  - random_milliseconds / 1000
# ...
# 3.949
#
#  2023-06-06 21:13:16.748627  - random_milliseconds
# ...
# 3426
#
#  2023-06-06 21:13:16.748627  - random_milliseconds / 1000
# ...
# 3.426
#
#  2023-06-06 21:13:22.000498  - random_milliseconds
# ...
# 3926
#
#  2023-06-06 21:13:22.000498  - random_milliseconds / 1000
# ...
# 3.926
#
#  2023-06-06 21:13:27.014847  - random_milliseconds
# ...
# 3527
#
#  2023-06-06 21:13:27.014847  - random_milliseconds / 1000
# ...
# 3.527
#
#  2023-06-06 21:13:31.634578  - random_milliseconds
# ...
# 3909
#
#  2023-06-06 21:13:31.634578  - random_milliseconds / 1000
# ...
# 3.909
#
#  2023-06-06 21:13:36.777058  - random_milliseconds
# ...
# 2598
#
#  2023-06-06 21:13:36.777058  - random_milliseconds / 1000
# ...
# 2.598
#
#  2023-06-06 21:13:40.122812  - random_milliseconds
# ...
# 3947
#
#  2023-06-06 21:13:40.122812  - random_milliseconds / 1000
# ...
# 3.947
#
#  2023-06-06 21:13:45.861310  - random_milliseconds
# ...
# 2730
#
#  2023-06-06 21:13:45.861310  - random_milliseconds / 1000
# ...
# 2.73
#
#  2023-06-06 21:13:49.655244  - random_milliseconds
# ...
# 2859
#
#  2023-06-06 21:13:49.655244  - random_milliseconds / 1000
# ...
# 2.859
#
#  2023-06-06 21:13:53.596949  - random_milliseconds
# ...
# 2091
#
#  2023-06-06 21:13:53.596949  - random_milliseconds / 1000
# ...
# 2.091
#
#  2023-06-06 21:13:57.079081  - random_milliseconds
# ...
# 2831
#
#  2023-06-06 21:13:57.079081  - random_milliseconds / 1000
# ...
# 2.831
#
#  2023-06-06 21:14:00.716314  - random_milliseconds
# ...
# 3959
#
#  2023-06-06 21:14:00.716314  - random_milliseconds / 1000
# ...
# 3.959
#
#  2023-06-06 21:14:06.418283  - random_milliseconds
# ...
# 2999
#
#  2023-06-06 21:14:06.418283  - random_milliseconds / 1000
# ...
# 2.999
#
#  2023-06-06 21:14:10.460968  - random_milliseconds
# ...
# 3598
#
#  2023-06-06 21:14:10.460968  - random_milliseconds / 1000
# ...
# 3.598
#
#  2023-06-06 21:14:15.144516  - random_milliseconds
# ...
# 2444
#
#  2023-06-06 21:14:15.144516  - random_milliseconds / 1000
# ...
# 2.444
#
#  2023-06-06 21:14:18.704155  - random_milliseconds
# ...
# 2957
#
#  2023-06-06 21:14:18.705152  - random_milliseconds / 1000
# ...
# 2.957
#
#  2023-06-06 21:14:22.464675  - random_milliseconds
# ...
# 3144
#
#  2023-06-06 21:14:22.464675  - random_milliseconds / 1000
# ...
# 3.144
#
#  2023-06-06 21:14:27.377310  - random_milliseconds
# ...
# 3408
#
#  2023-06-06 21:14:27.377310  - random_milliseconds / 1000
# ...
# 3.408
#
#  2023-06-06 21:14:31.895272  - random_milliseconds
# ...
# 2756
#
#  2023-06-06 21:14:31.895272  - random_milliseconds / 1000
# ...
# 2.756
#
#  2023-06-06 21:14:35.754474  - random_milliseconds
# ...
# 2918
#
#  2023-06-06 21:14:35.754474  - random_milliseconds / 1000
# ...
# 2.918
#
#  2023-06-06 21:14:39.798904  - random_milliseconds
# ...
# 2507
#
#  2023-06-06 21:14:39.798904  - random_milliseconds / 1000
# ...
# 2.507
#
#  2023-06-06 21:14:43.128461  - random_milliseconds
# ...
# 3914
#
#  2023-06-06 21:14:43.128461  - random_milliseconds / 1000
# ...
# 3.914
#
#  2023-06-06 21:14:48.807816  - random_milliseconds
# ...
# 3281
#
#  2023-06-06 21:14:48.807816  - random_milliseconds / 1000
# ...
# 3.281
#
#  2023-06-06 21:14:53.116256  - random_milliseconds
# ...
# 2378
#
#  2023-06-06 21:14:53.116256  - random_milliseconds / 1000
# ...
# 2.378
#
#  2023-06-06 21:14:56.708397  - random_milliseconds
# ...
# 2497
#
#  2023-06-06 21:14:56.708397  - random_milliseconds / 1000
# ...
# 2.497
#
#  2023-06-06 21:15:00.609598  - random_milliseconds
# ...
# 3837
#
#  2023-06-06 21:15:00.609598  - random_milliseconds / 1000
# ...
# 3.837
#
#  2023-06-06 21:15:05.191060  - random_milliseconds
# ...
# 3176
#
#  2023-06-06 21:15:05.191060  - random_milliseconds / 1000
# ...
# 3.176
#
#  2023-06-06 21:15:10.120718  - random_milliseconds
# ...
# 2640
#
#  2023-06-06 21:15:10.120718  - random_milliseconds / 1000
# ...
# 2.64
#
#  2023-06-06 21:15:13.870819  - random_milliseconds
# ...
# 3842
#
#  2023-06-06 21:15:13.870819  - random_milliseconds / 1000
# ...
# 3.842
#
#  2023-06-06 21:15:18.778383  - random_milliseconds
# ...
# 3041
#
#  2023-06-06 21:15:18.778383  - random_milliseconds / 1000
# ...
# 3.041
#
#  2023-06-06 21:15:22.924652  - random_milliseconds
# ...
# 3290
#
#  2023-06-06 21:15:22.924652  - random_milliseconds / 1000
# ...
# 3.29
#
#  2023-06-06 21:15:26.938914  - random_milliseconds
# ...
# 2542
#
#  2023-06-06 21:15:26.939912  - random_milliseconds / 1000
# ...
# 2.542
#
#  2023-06-06 21:15:31.255350  - random_milliseconds
# ...
# 2706
#
#  2023-06-06 21:15:31.255350  - random_milliseconds / 1000
# ...
# 2.706
#
#  2023-06-06 21:15:35.040977  - random_milliseconds
# ...
# 2391
#
#  2023-06-06 21:15:35.040977  - random_milliseconds / 1000
# ...
# 2.391
#
#  2023-06-06 21:15:38.571017  - random_milliseconds
# ...
# 3370
#
#  2023-06-06 21:15:38.571017  - random_milliseconds / 1000
# ...
# 3.37
#
#  2023-06-06 21:15:43.036960  - random_milliseconds
# ...
# 2350
#
#  2023-06-06 21:15:43.036960  - random_milliseconds / 1000
# ...
# 2.35
#
#  2023-06-06 21:15:46.185123  - random_milliseconds
# ...
# 2142
#
#  2023-06-06 21:15:46.185123  - random_milliseconds / 1000
# ...
# 2.142
#
#  2023-06-06 21:15:50.121163  - random_milliseconds
# ...
# 3090
#
#  2023-06-06 21:15:50.121163  - random_milliseconds / 1000
# ...
# 3.09
#
#  2023-06-06 21:15:54.348938  - random_milliseconds
# ...
# 3500
#
#  2023-06-06 21:15:54.348938  - random_milliseconds / 1000
# ...
# 3.5
#
#  2023-06-06 21:15:58.936926  - random_milliseconds
# ...
# 2965
#
#  2023-06-06 21:15:58.937923  - random_milliseconds / 1000
# ...
# 2.965
#
#  2023-06-06 21:16:03.458841  - random_milliseconds
# ...
# 3380
#
#  2023-06-06 21:16:03.459848  - random_milliseconds / 1000
# ...
# 3.38
#
#  2023-06-06 21:16:07.607901  - random_milliseconds
# ...
# 2811
#
#  2023-06-06 21:16:07.607901  - random_milliseconds / 1000
# ...
# 2.811
#
#  2023-06-06 21:16:12.217395  - random_milliseconds
# ...
# 3155
#
#  2023-06-06 21:16:12.217395  - random_milliseconds / 1000
# ...
# 3.155
#
#  2023-06-06 21:16:16.651097  - random_milliseconds
# ...
# 2556
#
#  2023-06-06 21:16:16.651097  - random_milliseconds / 1000
# ...
# 2.556
#
#  2023-06-06 21:16:20.372036  - random_milliseconds
# ...
# 3422
#
#  2023-06-06 21:16:20.372036  - random_milliseconds / 1000
# ...
# 3.422
#
#  2023-06-06 21:16:24.957984  - random_milliseconds
# ...
# 3073
#
#  2023-06-06 21:16:24.958982  - random_milliseconds / 1000
# ...
# 3.073
#
#  2023-06-06 21:16:28.800246  - random_milliseconds
# ...
# 2455
#
#  2023-06-06 21:16:28.801243  - random_milliseconds / 1000
# ...
# 2.455
#
#  2023-06-06 21:16:33.051871  - random_milliseconds
# ...
# 3140
#
#  2023-06-06 21:16:33.051871  - random_milliseconds / 1000
# ...
# 3.14
#
#  2023-06-06 21:16:37.391008  - random_milliseconds
# ...
# 2371
#
#  2023-06-06 21:16:37.391008  - random_milliseconds / 1000
# ...
# 2.371
#
#  2023-06-06 21:16:40.971531  - random_milliseconds
# ...
# 3900
#
#  2023-06-06 21:16:40.971531  - random_milliseconds / 1000
# ...
# 3.9
#
#  2023-06-06 21:16:46.121890  - random_milliseconds
# ...
# 2715
#
#  2023-06-06 21:16:46.121890  - random_milliseconds / 1000
# ...
# 2.715
#
#  2023-06-06 21:16:49.620002  - random_milliseconds
# ...
# 2606
#
#  2023-06-06 21:16:49.620002  - random_milliseconds / 1000
# ...
# 2.606
#
#  2023-06-06 21:16:53.979375  - random_milliseconds
# ...
# 3530
#
#  2023-06-06 21:16:53.979375  - random_milliseconds / 1000
# ...
# 3.53
#  2023-06-06 21:16:58.603943  - random_milliseconds
# ...
# 3246
#
#  2023-06-06 21:16:58.603943  - random_milliseconds / 1000
# ...
# 3.246
#
#  2023-06-06 21:17:02.980792  - random_milliseconds
# ...
# 3469
#
#  2023-06-06 21:17:02.980792  - random_milliseconds / 1000
# ...
# 3.469
#
#  2023-06-06 21:17:07.885672  - random_milliseconds
# ...
# 3845
#
#  2023-06-06 21:17:07.885672  - random_milliseconds / 1000
# ...
# 3.845
#
#  2023-06-06 21:17:12.518694  - random_milliseconds
# ...
# 3952
#
#  2023-06-06 21:17:12.518694  - random_milliseconds / 1000
# ...
# 3.952
#
#  2023-06-06 21:17:18.233307  - random_milliseconds
# ...
# 2064
#
#  2023-06-06 21:17:18.233307  - random_milliseconds / 1000
# ...
# 2.064
#
#  2023-06-06 21:17:21.575090  - random_milliseconds
# ...
# 2841
#
#  2023-06-06 21:17:21.575090  - random_milliseconds / 1000
# ...
# 2.841
#
#  2023-06-06 21:17:25.682969  - random_milliseconds
# ...
# 3858
#
#  2023-06-06 21:17:25.682969  - random_milliseconds / 1000
# ...
# 3.858
#
#  2023-06-06 21:17:30.817284  - random_milliseconds
# ...
# 2647
#
#  2023-06-06 21:17:30.817284  - random_milliseconds / 1000
# ...
# 2.647
#
#  2023-06-06 21:17:34.209844  - random_milliseconds
# ...
# 2940
#
#  2023-06-06 21:17:34.209844  - random_milliseconds / 1000
# ...
# 2.94
#
#  2023-06-06 21:17:38.896008  - random_milliseconds
# ...
# 3545
#
#  2023-06-06 21:17:38.896008  - random_milliseconds / 1000
# ...
# 3.545
#
#  2023-06-06 21:17:43.612718  - random_milliseconds
# ...
# 3674
#
#  2023-06-06 21:17:43.612718  - random_milliseconds / 1000
# ...
# 3.674
#
#  2023-06-06 21:17:48.458882  - random_milliseconds
# ...
# 3122
#
#  2023-06-06 21:17:48.458882  - random_milliseconds / 1000
# ...
# 3.122
#
#  2023-06-06 21:17:52.865062  - random_milliseconds
# ...
# 3394
#
#  2023-06-06 21:17:52.865062  - random_milliseconds / 1000
# ...
# 3.394
#
#  2023-06-06 21:17:57.022827  - random_milliseconds
# ...
# 2281
#
#  2023-06-06 21:17:57.022827  - random_milliseconds / 1000
# ...
# 2.281
#
#  2023-06-06 21:18:01.099272  - random_milliseconds
# ...
# 3236
#
#  2023-06-06 21:18:01.099272  - random_milliseconds / 1000
# ...
# 3.236
#
#  2023-06-06 21:18:05.513025  - random_milliseconds
# ...
# 2727
#
#  2023-06-06 21:18:05.513025  - random_milliseconds / 1000
# ...
# 2.727
#
#  2023-06-06 21:18:09.935838  - random_milliseconds
# ...
# 3274
#
#  2023-06-06 21:18:09.935838  - random_milliseconds / 1000
# ...
# 3.274
#
#  2023-06-06 21:18:14.413336  - random_milliseconds
# ...
# 2574
#
#  2023-06-06 21:18:14.413336  - random_milliseconds / 1000
# ...
# 2.574
#
#  2023-06-06 21:18:17.750299  - random_milliseconds
# ...
# 3698
#
#  2023-06-06 21:18:17.750299  - random_milliseconds / 1000
# ...
# 3.698
#
#  2023-06-06 21:18:23.217932  - random_milliseconds
# ...
# 3067
#
#  2023-06-06 21:18:23.217932  - random_milliseconds / 1000
# ...
# 3.067
#
#  2023-06-06 21:18:27.500909  - random_milliseconds
# ...
# 3470
#
#  2023-06-06 21:18:27.500909  - random_milliseconds / 1000
# ...
# 3.47
#
#  2023-06-06 21:18:32.187201  - random_milliseconds
# ...
# 2723
#
#  2023-06-06 21:18:32.187201  - random_milliseconds / 1000
# ...
# 2.723
#
#  2023-06-06 21:18:36.114751  - random_milliseconds
# ...
# 2618
#
#  2023-06-06 21:18:36.114751  - random_milliseconds / 1000
# ...
# 2.618
#
#  2023-06-06 21:18:39.476624  - random_milliseconds
# ...
# 2495
#
#  2023-06-06 21:18:39.476624  - random_milliseconds / 1000
# ...
# 2.495
#
#  2023-06-06 21:18:43.742276  - random_milliseconds
# ...
# 3188
#
#  2023-06-06 21:18:43.742276  - random_milliseconds / 1000
# ...
# 3.188
#
#  2023-06-06 21:18:48.135383  - random_milliseconds
# ...
# 3457
#
#  2023-06-06 21:18:48.135383  - random_milliseconds / 1000
# ...
# 3.457
#
#  2023-06-06 21:18:52.845560  - random_milliseconds
# ...
# 2235
#
#  2023-06-06 21:18:52.845560  - random_milliseconds / 1000
# ...
# 2.235
#
#  2023-06-06 21:18:56.389928  - random_milliseconds
# ...
# 3040
#
#  2023-06-06 21:18:56.389928  - random_milliseconds / 1000
# ...
# 3.04
#
#  2023-06-06 21:19:00.261198  - random_milliseconds
# ...
# 3159
#
#  2023-06-06 21:19:00.261198  - random_milliseconds / 1000
# ...
# 3.159
#
#  2023-06-06 21:19:05.210083  - random_milliseconds
# ...
# 2615
#
#  2023-06-06 21:19:05.210083  - random_milliseconds / 1000
# ...
# 2.615
#
#  2023-06-06 21:19:09.446197  - random_milliseconds
# ...
# 3748
#
#  2023-06-06 21:19:09.446197  - random_milliseconds / 1000
# ...
# 3.748
#
#  2023-06-06 21:19:14.452813  - random_milliseconds
# ...
# 3557
#
#  2023-06-06 21:19:14.452813  - random_milliseconds / 1000
# ...
# 3.557
#
#  2023-06-06 21:19:19.201746  - random_milliseconds
# ...
# 2893
#
#  2023-06-06 21:19:19.201746  - random_milliseconds / 1000
# ...
# 2.893
#
#  2023-06-06 21:19:22.843606  - random_milliseconds
# ...
# 2484
#
#  2023-06-06 21:19:22.843606  - random_milliseconds / 1000
# ...
# 2.484
#
#  2023-06-06 21:19:27.161215  - random_milliseconds
# ...
# 3634
#
#  2023-06-06 21:19:27.161215  - random_milliseconds / 1000
# ...
# 3.634
#
#  2023-06-06 21:19:31.984638  - random_milliseconds
# ...
# 3543
#
#  2023-06-06 21:19:31.984638  - random_milliseconds / 1000
# ...
# 3.543
#
#  2023-06-06 21:19:36.747873  - random_milliseconds
# ...
# 2760
#
#  2023-06-06 21:19:36.747873  - random_milliseconds / 1000
# ...
# 2.76
#
#  2023-06-06 21:19:40.749827  - random_milliseconds
# ...
# 3303
#
#  2023-06-06 21:19:40.749827  - random_milliseconds / 1000
# ...
# 3.303
#
#  2023-06-06 21:19:44.854681  - random_milliseconds
# ...
# 3448
#
#  2023-06-06 21:19:44.854681  - random_milliseconds / 1000
# ...
# 3.448
#
#  2023-06-06 21:19:50.085225  - random_milliseconds
# ...
# 3202
#
#  2023-06-06 21:19:50.085225  - random_milliseconds / 1000
# ...
# 3.202
#
#  2023-06-06 21:19:54.469625  - random_milliseconds
# ...
# 3640
#
#  2023-06-06 21:19:54.469625  - random_milliseconds / 1000
# ...
# 3.64
#
#  2023-06-06 21:19:59.323362  - random_milliseconds
# ...
# 3553
#
#  2023-06-06 21:19:59.323362  - random_milliseconds / 1000
# ...
# 3.553
#
#  2023-06-06 21:20:04.103951  - random_milliseconds
# ...
# 2100
#
#  2023-06-06 21:20:04.103951  - random_milliseconds / 1000
# ...
# 2.1
#
#  2023-06-06 21:20:07.475615  - random_milliseconds
# ...
# 3286
#
#  2023-06-06 21:20:07.475615  - random_milliseconds / 1000
# ...
# 3.286
#
#  2023-06-06 21:20:12.537501  - random_milliseconds
# ...
# 2802
#
#  2023-06-06 21:20:12.537501  - random_milliseconds / 1000
# ...
# 2.802
#
#  2023-06-06 21:20:16.714069  - random_milliseconds
# ...
# 3986
#
#  2023-06-06 21:20:16.714069  - random_milliseconds / 1000
# ...
# 3.986
#
#  2023-06-06 21:20:22.025559  - random_milliseconds
# ...
# 3677
#
#  2023-06-06 21:20:22.025559  - random_milliseconds / 1000
# ...
# 3.677
#
#  2023-06-06 21:20:26.970403  - random_milliseconds
# ...
# 3485
#
#  2023-06-06 21:20:26.970403  - random_milliseconds / 1000
# ...
# 3.485
#
#  2023-06-06 21:20:31.215719  - random_milliseconds
# ...
# 3392
#
#  2023-06-06 21:20:31.215719  - random_milliseconds / 1000
# ...
# 3.392
#
#  2023-06-06 21:20:36.393428  - random_milliseconds
# ...
# 2524
#
#  2023-06-06 21:20:36.394427  - random_milliseconds / 1000
# ...
# 2.524
#
#  2023-06-06 21:20:40.137322  - random_milliseconds
# ...
# 2949
#
#  2023-06-06 21:20:40.137322  - random_milliseconds / 1000
# ...
# 2.949
#
#  2023-06-06 21:20:44.326827  - random_milliseconds
# ...
# 2066
#
#  2023-06-06 21:20:44.326827  - random_milliseconds / 1000
# ...
# 2.066
#
#  2023-06-06 21:20:47.816566  - random_milliseconds
# ...
# 3628
#
#  2023-06-06 21:20:47.816566  - random_milliseconds / 1000
# ...
# 3.628
#
#  2023-06-06 21:20:52.207329  - random_milliseconds
# ...
# 2122
#
#  2023-06-06 21:20:52.207329  - random_milliseconds / 1000
# ...
# 2.122
#
#  2023-06-06 21:20:56.106658  - random_milliseconds
# ...
# 2614
#
#  2023-06-06 21:20:56.106658  - random_milliseconds / 1000
# ...
# 2.614
#
#  2023-06-06 21:20:59.947548  - random_milliseconds
# ...
# 2095
#
#  2023-06-06 21:20:59.947548  - random_milliseconds / 1000
# ...
# 2.095
#
#  2023-06-06 21:21:03.320349  - random_milliseconds
# ...
# 3748
#
#  2023-06-06 21:21:03.320349  - random_milliseconds / 1000
# ...
# 3.748
#
#  2023-06-06 21:21:08.668561  - random_milliseconds
# ...
# 3574
#
#  2023-06-06 21:21:08.668561  - random_milliseconds / 1000
# ...
# 3.574
#
#  2023-06-06 21:21:13.093468  - random_milliseconds
# ...
# 3239
#
#  2023-06-06 21:21:13.093468  - random_milliseconds / 1000
# ...
# 3.239
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     249         try:
# --> 250             ctrl = wait_until_passes(
#     251                 timeout,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     457                 err.original_exception = e
# --> 458                 raise err
#     459
#
# TimeoutError:
#
# During handling of the above exception, another exception occurred:
#
# ElementNotFoundError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22416\3447074465.py in <module>
#     158 #     attaquer_village('3466', '3275', 'data/village.txt')
#     159 #     attaquer_village('3466', '3172', 'data/village.txt')
# --> 160     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
#     161     attaquer_village("C:\\Users\\Zbook\\OpenClassRoom\\Projet\\Guerre_Tribal\\data\\villages.csv")
#     162     delay_with_random_seconds()
#
# ~\AppData\Local\Temp\ipykernel_22416\3447074465.py in attaquer_village(troupes_file)
#      50         firefox.type_keys('^l')  # Presser la combinaison de touches Ctrl+L pour sélectionner la barre d'adresse
#      51         url = f"https://fr81.guerretribale.fr/game.php?village={village_depart}&screen=place&target={village_attaquer}"
# ---> 52         firefox.type_keys(url + '{ENTER}')  # Entrer l'URL et appuyer sur Entrée
#      53         delay_with_random_seconds()
#      54
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __getattribute__(self, attr_name)
#     394
#     395             if need_to_resolve:
# --> 396                 ctrls = self.__resolve_control(self.criteria)
#     397                 return getattr(ctrls[-1], attr_name)
#     398
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __resolve_control(self, criteria, timeout, retry_interval)
#     259
#     260         except TimeoutError as e:
# --> 261             raise e.original_exception
#     262
#     263         return ctrl
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\timings.py in wait_until_passes(timeout, retry_interval, func, exceptions, *args, **kwargs)
#     434         try:
#     435             # Call the function with any arguments
# --> 436             func_val = func(*args, **kwargs)
#     437
#     438             # if no exception is raised then we are finished
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\application.py in __get_ctrl(self, criteria_)
#     201             criteria[0]['process'] = self.app.process
#     202             del criteria[0]['app']
# --> 203         dialog = self.backend.generic_wrapper_class(findwindows.find_element(**criteria[0]))
#     204
#     205         ctrls = []
#
# ~\AppData\Roaming\Python\Python39\site-packages\pywinauto\findwindows.py in find_element(**kwargs)
#      85
#      86     if not elements:
# ---> 87         raise ElementNotFoundError(kwargs)
#      88
#      89     if len(elements) > 1:
#
# ElementNotFoundError: {'class_name': 'MozillaWindowClass', 'backend': 'uia', 'process': 17100}
