# %%
# Pour déterminer la meilleure défense et la meilleure attaque avec 20 000 hommes, tout en tenant compte du temps de construction, on peut calculer la défense et l'attaque maximales pour chaque unité par homme et par minute. Voici comment procéder :

# 1. Créez une liste pour chaque type d'unité avec le temps de construction, les hommes nécessaires, et les statistiques de combat (attaque et défense).

# ```python
unités = [
    {'nom': 'lancier', 'hommes': 1, 'temps': 4.44, 'attaque': 10, 'défense': 15, 'défense_cavalerie': 45, 'défense_archers': 20},
    {'nom': 'épée', 'hommes': 1, 'temps': 6.58, 'attaque': 25, 'défense': 50, 'défense_cavalerie': 15, 'défense_archers': 40},
    {'nom': 'hache', 'hommes': 1, 'temps': 9.13, 'attaque': 40, 'défense': 10, 'défense_cavalerie': 5, 'défense_archers': 10},
    {'nom': 'archer', 'hommes': 1, 'temps': 8.21, 'attaque': 15, 'défense': 50, 'défense_cavalerie': 40, 'défense_archers': 5},
    {'nom': 'éclaireur', 'hommes': 2, 'temps': 5.56, 'attaque': 0, 'défense': 2, 'défense_cavalerie': 1, 'défense_archers': 2},
    {'nom': 'cavalier', 'hommes': 4, 'temps': 11.51, 'attaque': 130, 'défense': 30, 'défense_cavalerie': 40, 'défense_archers': 30},
    {'nom': 'arché_monté', 'hommes': 5, 'temps': 12.51, 'attaque': 120, 'défense': 40, 'défense_cavalerie': 30, 'défense_archers': 50},
    {'nom': 'cavalier_lourd', 'hommes': 6, 'temps': 18.51, 'attaque': 150, 'défense': 200, 'défense_cavalerie': 80, 'défense_archers': 180}
]
# ```

# 2. Calculez les statistiques maximales pour chaque unité par homme et par minute.

# ```python
pop_max = 20000

for unité in unités:
    unité['attaque_par_homme_minute'] = (unité['attaque'] / unité['hommes']) / unité['temps']
    unité['défense_par_homme_minute'] = (unité['défense'] / unité['hommes']) / unité['temps']

meilleure_attaque = max(unités, key=lambda x: x['attaque_par_homme_minute'])
meilleure_défense = max(unités, key=lambda x: x['défense_par_homme_minute'])
# ```

# 3. Affichez les résultats.

# ```python
print("Meilleure attaque :")
print(meilleure_attaque['nom'], meilleure_attaque['attaque_par_homme_minute'])

print("Meilleure défense :")
print(meilleure_défense['nom'], meilleure_défense['défense_par_homme_minute'])
# Out:
# Meilleure attaque :
# hache 4.381161007667031
# Meilleure défense :
# épée 7.598784194528875

# %%
def calculer_unites(hommes, temps_construction):
    return hommes * 60 / temps_construction

def calculer_force_attaque(nb_unites, force_attaque):
    return nb_unites * force_attaque

def calculer_defense(nb_unites, defense):
    return nb_unites * defense

def determiner_meilleure_combinaison(hommes):
    temps_lancier = 4.44
    temps_epee = 6.58
    temps_hache = 9.13
    temps_archer = 8.21
    temps_eclaireur = 5.56
    temps_cavalier = 11.51
    temps_arche_monte = 12.51
    temps_cavalier_lourd = 18.51

    # Calcul du nombre d'unités construites pour chaque type
    nb_lancier = calculer_unites(hommes, temps_lancier)
    nb_epee = calculer_unites(hommes, temps_epee)
    nb_hache = calculer_unites(hommes, temps_hache)
    nb_archer = calculer_unites(hommes, temps_archer)
    nb_eclaireur = calculer_unites(hommes / 2, temps_eclaireur)  # Divisé par 2 car il faut 2 hommes par éclaireur
    nb_cavalier = calculer_unites(hommes / 4, temps_cavalier)  # Divisé par 4 car il faut 4 hommes par cavalier
    nb_arche_monte = calculer_unites(hommes / 5, temps_arche_monte)  # Divisé par 5 car il faut 5 hommes par arché monté
    nb_cavalier_lourd = calculer_unites(hommes / 6, temps_cavalier_lourd)  # Divisé par 6 car il faut 6 hommes par cavalier lourd

    # Calcul de la force d'attaque et de défense totale pour chaque configuration
    force_attaque_lancier = calculer_force_attaque(nb_lancier, 10)
    force_attaque_epee = calculer_force_attaque(nb_epee, 25)
    force_attaque_hache = calculer_force_attaque(nb_hache, 40)
    force_attaque_archer = calculer_force_attaque(nb_archer, 15)
    force_attaque_eclaireur = calculer_force_attaque(nb_eclaireur, 0)
    force_attaque_cavalier = calculer_force_attaque(nb_cavalier, 130)
    force_attaque_arche_monte = calculer_force_attaque(nb_arche_monte, 120)
    force_attaque_cavalier_lourd = calculer_force_attaque(nb_cavalier_lourd, 150)

    defense_generale_lancier = calculer_defense(nb_lancier, 15)
    defense_generale_epee = calculer_defense(nb_epee, 50)
    defense_generale_hache = calculer_defense(nb_hache, 10)
    defense_generale_archer = calculer_defense(nb_archer, 50)
    defense_generale_eclaireur = calculer_defense(nb_eclaireur, 2)
    defense_generale_cavalier = calculer_defense(nb_cavalier, 30)
    defense_generale_arche_monte = calculer_defense(nb_arche_monte, 40)
    defense_generale_cavalier_lourd = calculer_defense(nb_cavalier_lourd, 200)

    defense_cavalerie_lancier = calculer_defense(nb_lancier, 45)
    defense_cavalerie_epee = calculer_defense(nb_epee, 15)
    defense_cavalerie_hache = calculer_defense(nb_hache, 5)
    defense_cavalerie_archer = calculer_defense(nb_archer, 40)
    defense_cavalerie_cavalier = calculer_defense(nb_cavalier, 40)
    defense_cavalerie_arche_monte = calculer_defense(nb_arche_monte, 30)
    defense_cavalerie_cavalier_lourd = calculer_defense(nb_cavalier_lourd, 80)

    defense_archers_lancier = calculer_defense(nb_lancier, 20)
    defense_archers_epee = calculer_defense(nb_epee, 40)
    defense_archers_hache = calculer_defense(nb_hache, 10)
    defense_archers_archer = calculer_defense(nb_archer, 5)
    defense_archers_eclaireur = calculer_defense(nb_eclaireur, 2)
    defense_archers_cavalier = calculer_defense(nb_cavalier, 30)
    defense_archers_arche_monte = calculer_defense(nb_arche_monte, 50)
    defense_archers_cavalier_lourd = calculer_defense(nb_cavalier_lourd, 180)

    # Trouver la combinaison avec la meilleure force d'attaque
    max_force_attaque = max(force_attaque_lancier, force_attaque_epee, force_attaque_hache,
                            force_attaque_archer, force_attaque_eclaireur, force_attaque_cavalier,
                            force_attaque_arche_monte, force_attaque_cavalier_lourd)

    if max_force_attaque == force_attaque_lancier:
        meilleure_attaque = "Lancier"
    elif max_force_attaque == force_attaque_epee:
        meilleure_attaque = "Épée"
    elif max_force_attaque == force_attaque_hache:
        meilleure_attaque = "Hache"
    elif max_force_attaque == force_attaque_archer:
        meilleure_attaque = "Archer"
    elif max_force_attaque == force_attaque_eclaireur:
        meilleure_attaque = "Éclaireur"
    elif max_force_attaque == force_attaque_cavalier:
        meilleure_attaque = "Cavalier"
    elif max_force_attaque == force_attaque_arche_monte:
        meilleure_attaque = "Arché monté"
    else:
        meilleure_attaque = "Cavalier lourd"

    # Trouver la combinaison avec la meilleure défense
    max_defense = max(defense_generale_lancier + defense_cavalerie_lancier + defense_archers_lancier,
                      defense_generale_epee + defense_cavalerie_epee + defense_archers_epee,
                      defense_generale_hache + defense_cavalerie_hache + defense_archers_hache,
                      defense_generale_archer + defense_cavalerie_archer + defense_archers_archer,
                      defense_generale_eclaireur  + defense_archers_eclaireur,
                      defense_generale_cavalier + defense_cavalerie_cavalier + defense_archers_cavalier,
                      defense_generale_arche_monte + defense_cavalerie_arche_monte + defense_archers_arche_monte,
                      defense_generale_cavalier_lourd + defense_cavalerie_cavalier_lourd + defense_archers_cavalier_lourd)

    if max_defense == defense_generale_lancier + defense_cavalerie_lancier + defense_archers_lancier:
        meilleure_defense = "Lancier"
    elif max_defense == defense_generale_epee + defense_cavalerie_epee + defense_archers_epee:
        meilleure_defense = "Épée"
    elif max_defense == defense_generale_hache + defense_cavalerie_hache + defense_archers_hache:
        meilleure_defense = "Hache"
    elif max_defense == defense_generale_archer + defense_cavalerie_archer + defense_archers_archer:
        meilleure_defense = "Archer"
    elif max_defense == defense_generale_eclaireur + defense_cavalerie_eclaireur + defense_archers_eclaireur:
        meilleure_defense = "Éclaireur"
    elif max_defense == defense_generale_cavalier + defense_cavalerie_cavalier + defense_archers_cavalier:
        meilleure_defense = "Cavalier"
    elif max_defense == defense_generale_arche_monte + defense_cavalerie_arche_monte + defense_archers_arche_monte:
        meilleure_defense = "Arché monté"
    else:
        meilleure_defense = "Cavalier lourd"

    return meilleure_defense, meilleure_attaque

# Exemple d'utilisation
hommes = 20000
meilleure_defense, meilleure_attaque = determiner_meilleure_combinaison(hommes)
print(f"Meilleure défense : {meilleure_defense}")
print(f"Meilleure attaque : {meilleure_attaque}")
# Out:
# Meilleure défense : Lancier
# Meilleure attaque : Hache

# %%
def calculer_unites(hommes, temps_construction):
    return hommes * 60 / temps_construction

def calculer_force_attaque(nb_unites, force_attaque):
    return nb_unites * force_attaque

def calculer_defense(nb_unites, defense_generale, defense_cavalerie, defense_archers):
    return nb_unites * (defense_generale + defense_cavalerie + defense_archers)

def determiner_meilleure_combinaison(hommes):
    temps_lancier = 4.44
    temps_epee = 6.58
    temps_hache = 9.13
    temps_archer = 8.21
    temps_eclaireur = 5.56
    temps_cavalier = 11.51
    temps_arche_monte = 12.51
    temps_cavalier_lourd = 18.51

    # Calcul du nombre maximal d'unités construites pour chaque type
    nb_lancier = calculer_unites(hommes, temps_lancier)
    nb_epee = calculer_unites(hommes, temps_epee)
    nb_hache = calculer_unites(hommes, temps_hache)
    nb_archer = calculer_unites(hommes, temps_archer)
    nb_eclaireur = calculer_unites(hommes / 2, temps_eclaireur)
    nb_cavalier = calculer_unites(hommes / 4, temps_cavalier)
    nb_arche_monte = calculer_unites(hommes / 5, temps_arche_monte)
    nb_cavalier_lourd = calculer_unites(hommes / 6, temps_cavalier_lourd)

    # Calcul de la défense totale pour chaque configuration
    defense_lancier = calculer_defense(nb_lancier, 15, 45, 20)
    defense_epee = calculer_defense(nb_epee, 50, 15, 40)
    defense_hache = calculer_defense(nb_hache, 10, 5, 10)
    defense_archer = calculer_defense(nb_archer, 50, 40, 5)
    defense_eclaireur = calculer_defense(nb_eclaireur, 2, 1, 2)
    defense_cavalier = calculer_defense(nb_cavalier, 30, 40, 30)
    defense_arche_monte = calculer_defense(nb_arche_monte, 40, 30, 50)
    defense_cavalier_lourd = calculer_defense(nb_cavalier_lourd, 200, 80, 180)

    # Calcul de l'attaque totale pour chaque configuration
    attaque_lancier = calculer_force_attaque(nb_lancier, 10)
    attaque_epee = calculer_force_attaque(nb_epee, 25)
    attaque_hache = calculer_force_attaque(nb_hache, 40)
    attaque_archer = calculer_force_attaque(nb_archer, 15)
    attaque_eclaireur = calculer_force_attaque(nb_eclaireur, 0)
    attaque_cavalier = calculer_force_attaque(nb_cavalier, 130)
    attaque_arche_monte = calculer_force_attaque(nb_arche_monte, 120)
    attaque_cavalier_lourd = calculer_force_attaque(nb_cavalier_lourd, 150)

    # Comparaison des combinaisons pour trouver la meilleure défense
    max_defense = max(defense_lancier, defense_epee, defense_hache, defense_archer,
                      defense_eclaireur, defense_cavalier, defense_arche_monte, defense_cavalier_lourd)

    if max_defense == defense_lancier:
        meilleure_defense = "Lancier"
    elif max_defense == defense_epee:
        meilleure_defense = "Épée"
    elif max_defense == defense_hache:
        meilleure_defense = "Hache"
    elif max_defense == defense_archer:
        meilleure_defense = "Archer"
    elif max_defense == defense_eclaireur:
        meilleure_defense = "Éclaireur"
    elif max_defense == defense_cavalier:
        meilleure_defense = "Cavalier"
    elif max_defense == defense_arche_monte:
        meilleure_defense = "Arché monté"
    else:
        meilleure_defense = "Cavalier lourd"

    # Comparaison des combinaisons pour trouver la meilleure attaque
    max_attaque = max(attaque_lancier, attaque_epee, attaque_hache, attaque_archer,
                      attaque_eclaireur, attaque_cavalier, attaque_arche_monte, attaque_cavalier_lourd)

    if max_attaque == attaque_lancier:
        meilleure_attaque = "Lancier"
    elif max_attaque == attaque_epee:
        meilleure_attaque = "Épée"
    elif max_attaque == attaque_hache:
        meilleure_attaque = "Hache"
    elif max_attaque == attaque_archer:
        meilleure_attaque = "Archer"
    elif max_attaque == attaque_eclaireur:
        meilleure_attaque = "Éclaireur"
    elif max_attaque == attaque_cavalier:
        meilleure_attaque = "Cavalier"
    elif max_attaque == attaque_arche_monte:
        meilleure_attaque = "Arché monté"
    else:
        meilleure_attaque = "Cavalier lourd"

    return meilleure_defense, meilleure_attaque

# Exemple d'utilisation
hommes = 20000
meilleure_defense, meilleure_attaque = determiner_meilleure_combinaison(hommes)
print(f"Meilleure défense : {meilleure_defense}")
print(f"Meilleure attaque : {meilleure_attaque}")
# Out:
# Meilleure défense : Lancier
# Meilleure attaque : Hache

# %%
def calculer_force_attaque(nb_unites, force_attaque):
    return nb_unites * force_attaque

def calculer_defense(nb_unites, defense_generale, defense_cavalerie, defense_archers):
    return nb_unites * (defense_generale + defense_cavalerie + defense_archers)

def determiner_meilleure_combinaison(hommes):
    meilleur_defense = 0
    meilleure_attaque = 0
    meilleure_combinaison = {}

    for nb_lancier in range(hommes + 1):
        nb_epee = hommes - nb_lancier

        force_attaque = calculer_force_attaque(nb_lancier, 10) + calculer_force_attaque(nb_epee, 25)
        defense = calculer_defense(nb_lancier, 15, 45, 20) + calculer_defense(nb_epee, 50, 15, 40)

        if defense > meilleur_defense:
            meilleur_defense = defense
            meilleure_combinaison['Lancier'] = nb_lancier
            meilleure_combinaison['Épée'] = nb_epee

        if force_attaque > meilleure_attaque:
            meilleure_attaque = force_attaque

    return meilleure_combinaison, meilleur_defense, meilleure_attaque

# Exemple d'utilisation
hommes = 20000
meilleure_combinaison, meilleure_defense, meilleure_attaque = determiner_meilleure_combinaison(hommes)

print(f"Meilleure combinaison pour la défense : {meilleure_combinaison}")
print(f"Meilleure défense : {meilleure_defense}")
print(f"Meilleure attaque : {meilleure_attaque}")
# Out:
# Meilleure combinaison pour la défense : {'Lancier': 0, 'Épée': 20000}
# Meilleure défense : 2100000
# Meilleure attaque : 500000

# %%
unites = {
    "lancier": {
        "population": 1,
        "temps_construction": 4.44,
        "force_attaque": 10,
        "defense_generale": 15,
        "defense_cavalerie": 45,
        "defense_archers": 20
    },
    "epée": {
        "population": 1,
        "temps_construction": 6.58,
        "force_attaque": 25,
        "defense_generale": 50,
        "defense_cavalerie": 15,
        "defense_archers": 40
    },
    "hache": {
        "population": 1,
        "temps_construction": 9.13,
        "force_attaque": 40,
        "defense_generale": 10,
        "defense_cavalerie": 5,
        "defense_archers": 10
    },
    "archer": {
        "population": 1,
        "temps_construction": 8.21,
        "force_attaque": 15,
        "defense_generale": 50,
        "defense_cavalerie": 40,
        "defense_archers": 5
    },
    "eclaireur": {
        "population": 2,
        "temps_construction": 5.56,
        "force_attaque": 0,
        "defense_generale": 2,
        "defense_cavalerie": 1,
        "defense_archers": 2
    },
    "cavalier": {
        "population": 4,
        "temps_construction": 11.51,
        "force_attaque": 130,
        "defense_generale": 30,
        "defense_cavalerie": 40,
        "defense_archers": 30
    },
    "arché monté": {
        "population": 5,
        "temps_construction": 12.51,
        "force_attaque": 120,
        "defense_generale": 40,
        "defense_cavalerie": 30,
        "defense_archers": 50
    },
    "cavalier lourd": {
        "population": 6,
        "temps_construction": 18.51,
        "force_attaque": 150,
        "defense_generale": 200,
        "defense_cavalerie": 80,
        "defense_archers": 180
    }
}

def calculer_force_attaque(unite, quantite):
    return unite["force_attaque"] * quantite

def calculer_defense(unite, quantite):
    return (unite["defense_generale"] + unite["defense_cavalerie"] + unite["defense_archers"]) * quantite

def trouver_meilleure_combinaison(hommes):
    meilleure_combinaison_defense = ()
    meilleure_defense = 0
    meilleure_combinaison_attaque = ()
    meilleure_attaque = 0

    for nom_unite in unites:
        unite = unites[nom_unite]
        population = unite["population"]
        temps_construction = unite["temps_construction"]
        force_attaque = unite["force_attaque"]
        defense = unite["defense_generale"] + unite["defense_cavalerie"] + unite["defense_archers"]

        quantite_maximale = hommes // population

        for quantite in range(quantite_maximale + 1):
            total_population = quantite * population

            if total_population <= hommes:
                temps_total_construction = quantite * temps_construction
                attaque = calculer_force_attaque(unite, quantite)
                defense_totale = defense * quantite

                if defense_totale > meilleure_defense:
                    meilleure_defense = defense_totale
                    meilleure_combinaison_defense = (nom_unite, quantite)

                if attaque > meilleure_attaque:
                    meilleure_attaque = attaque
                    meilleure_combinaison_attaque = (nom_unite, quantite)

    return meilleure_combinaison_defense, meilleure_defense, meilleure_combinaison_attaque, meilleure_attaque

# Calcul de la meilleure combinaison de défense et attaque
meilleure_combinaison_defense, meilleure_defense, meilleure_combinaison_attaque, meilleure_attaque = trouver_meilleure_combinaison(20000)

def afficher_combinaison_unites(combinaison):
    result = ""
    for unite, quantite in [combinaison]:
        result += f"{quantite} {unite} + "
    result = result[:-3]  # Supprimer le dernier "+"
    return result

print(f"Meilleure combinaison pour la défense : {afficher_combinaison_unites(meilleure_combinaison_defense)}")
print(f"Meilleure défense : {meilleure_defense}")
print(f"Meilleure combinaison pour l'attaque : {afficher_combinaison_unites(meilleure_combinaison_attaque)}")
print(f"Meilleure attaque : {meilleure_attaque}")
# Out:
# Meilleure combinaison pour la défense : 20000 epée
# Meilleure défense : 2100000
# Meilleure combinaison pour l'attaque : 20000 hache
# Meilleure attaque : 800000

# %%
unites = {
    "lancier": {
        "population": 1,
        "temps_construction": 4.44,
        "force_attaque": 10,
        "defense_generale": 15,
        "defense_cavalerie": 45,
        "defense_archers": 20
    },
    "epée": {
        "population": 1,
        "temps_construction": 6.58,
        "force_attaque": 25,
        "defense_generale": 50,
        "defense_cavalerie": 15,
        "defense_archers": 40
    },
    "hache": {
        "population": 1,
        "temps_construction": 9.13,
        "force_attaque": 40,
        "defense_generale": 10,
        "defense_cavalerie": 5,
        "defense_archers": 10
    },
    "archer": {
        "population": 1,
        "temps_construction": 8.21,
        "force_attaque": 15,
        "defense_generale": 50,
        "defense_cavalerie": 40,
        "defense_archers": 5
    },
    "eclaireur": {
        "population": 2,
        "temps_construction": 5.56,
        "force_attaque": 0,
        "defense_generale": 2,
        "defense_cavalerie": 1,
        "defense_archers": 2
    },
    "cavalier": {
        "population": 4,
        "temps_construction": 11.51,
        "force_attaque": 130,
        "defense_generale": 30,
        "defense_cavalerie": 40,
        "defense_archers": 30
    },
    "arché monté": {
        "population": 5,
        "temps_construction": 12.51,
        "force_attaque": 120,
        "defense_generale": 40,
        "defense_cavalerie": 30,
        "defense_archers": 50
    },
    "cavalier lourd": {
        "population": 6,
        "temps_construction": 18.51,
        "force_attaque": 150,
        "defense_generale": 200,
        "defense_cavalerie": 80,
        "defense_archers": 180
    }
}

def calculer_force_attaque(unite, quantite):
    return unite["force_attaque"] * quantite

def calculer_defense(unite, quantite):
    return (unite["defense_generale"] + unite["defense_cavalerie"] + unite["defense_archers"]) * quantite

def trouver_meilleure_combinaison(hommes, combinaisons):
    resultats = []
    
    for combinaison in combinaisons:
        meilleure_combinaison_defense = {}
        meilleure_defense = 0
        meilleure_combinaison_attaque = {}
        meilleure_attaque = 0
        
        for nom_unite, quantite in combinaison.items():
            unite = unites[nom_unite]
            population = unite["population"]
            temps_construction = unite["temps_construction"]
            force_attaque = unite["force_attaque"]
            defense = unite["defense_generale"] + unite["defense_cavalerie"] + unite["defense_archers"]
    
            quantite_maximale = hommes // population
    
            for quantite in range(quantite_maximale + 1):
                total_population = quantite * population
    
                if total_population <= hommes:
                    temps_total_construction = quantite * temps_construction
                    attaque = calculer_force_attaque(unite, quantite)
                    defense_totale = calculer_defense(unite, quantite)
    
                    if defense_totale > meilleure_defense:
                        meilleure_defense = defense_totale
                        meilleure_combinaison_defense = {nom_unite: quantite}
    
                    if attaque > meilleure_attaque:
                        meilleure_attaque = attaque
                        meilleure_combinaison_attaque = {nom_unite: quantite}
        
        resultats.append({
            "combinaison": combinaison,
            "meilleure_combinaison_defense": meilleure_combinaison_defense,
            "meilleure_defense": meilleure_defense,
            "meilleure_combinaison_attaque": meilleure_combinaison_attaque,
            "meilleure_attaque": meilleure_attaque
        })
    
    return resultats

def afficher_combinaison_unites(combinaison):
    result = ""
    for unite, quantite in combinaison.items():
        result += f"{quantite} {unite} + "
    result = result[:-3]  # Supprimer le dernier "+"
    return result

combinaisons = [
    {"lancier": 10000, "cavalier lourd": 3000},
    {"epée": 10000, "archer": 10000}
]

resultats = trouver_meilleure_combinaison(20000, combinaisons)

for i, resultat in enumerate(resultats):
    print(f"Combinaison {i + 1}:")
    print(f"Meilleure combinaison pour la défense : {afficher_combinaison_unites(resultat['meilleure_combinaison_defense'])}")
    print(f"Meilleure défense : {resultat['meilleure_defense']}")
    print(f"Meilleure combinaison pour l'attaque : {afficher_combinaison_unites(resultat['meilleure_combinaison_attaque'])}")
    print(f"Meilleure attaque : {resultat['meilleure_attaque']}")
    print()
# Out:
# Combinaison 1:
# Meilleure combinaison pour la défense : 20000 lancier
# Meilleure défense : 1600000
# Meilleure combinaison pour l'attaque : 3333 cavalier lourd
# Meilleure attaque : 499950
#
# Combinaison 2:
# Meilleure combinaison pour la défense : 20000 epée
# Meilleure défense : 2100000
# Meilleure combinaison pour l'attaque : 20000 epée
# Meilleure attaque : 500000

# %%
unites = {
    "lancier": {
        "population": 1,
        "temps_construction": 4.44,
        "force_attaque": 10,
        "defense_generale": 15,
        "defense_cavalerie": 45,
        "defense_archers": 20
    },
    "epée": {
        "population": 1,
        "temps_construction": 6.58,
        "force_attaque": 25,
        "defense_generale": 50,
        "defense_cavalerie": 15,
        "defense_archers": 40
    },
    "hache": {
        "population": 1,
        "temps_construction": 9.13,
        "force_attaque": 40,
        "defense_generale": 10,
        "defense_cavalerie": 5,
        "defense_archers": 10
    },
    "archer": {
        "population": 1,
        "temps_construction": 8.21,
        "force_attaque": 15,
        "defense_generale": 50,
        "defense_cavalerie": 40,
        "defense_archers": 5
    },
    "eclaireur": {
        "population": 2,
        "temps_construction": 5.56,
        "force_attaque": 0,
        "defense_generale": 2,
        "defense_cavalerie": 1,
        "defense_archers": 2
    },
    "cavalier": {
        "population": 4,
        "temps_construction": 11.51,
        "force_attaque": 130,
        "defense_generale": 30,
        "defense_cavalerie": 40,
        "defense_archers": 30
    },
    "arché monté": {
        "population": 5,
        "temps_construction": 12.51,
        "force_attaque": 120,
        "defense_generale": 40,
        "defense_cavalerie": 30,
        "defense_archers": 50
    },
    "cavalier lourd": {
        "population": 6,
        "temps_construction": 18.51,
        "force_attaque": 150,
        "defense_generale": 200,
        "defense_cavalerie": 80,
        "defense_archers": 180
    }
}

def calculer_force_attaque(unite, quantite):
    return unite["force_attaque"] * quantite

def calculer_defense(unite, quantite):
    return (unite["defense_generale"] + unite["defense_cavalerie"] + unite["defense_archers"]) * quantite

def trouver_meilleure_combinaison(hommes, combinaisons):
    resultats = []
    
    for combinaison in combinaisons:
        meilleure_combinaison_defense = {}
        meilleure_defense = 0
        meilleure_combinaison_attaque = {}
        meilleure_attaque = 0
        
        for nom_unite, quantite in combinaison.items():
            unite = unites[nom_unite]
            population = unite["population"]
            temps_construction = unite["temps_construction"]
            force_attaque = unite["force_attaque"]
            defense = unite["defense_generale"] + unite["defense_cavalerie"] + unite["defense_archers"]
    
            quantite_maximale = hommes // population
    
            for quantite in range(quantite_maximale + 1):
                total_population = quantite * population
    
                if total_population <= hommes and quantite <= combinaison[nom_unite]:
                    temps_total_construction = quantite * temps_construction
                    attaque = calculer_force_attaque(unite, quantite)
                    defense_totale = calculer_defense(unite, quantite)
    
                    if defense_totale > meilleure_defense:
                        meilleure_defense = defense_totale
                        meilleure_combinaison_defense = {nom_unite: quantite}
    
                    if attaque > meilleure_attaque:
                        meilleure_attaque = attaque
                        meilleure_combinaison_attaque = {nom_unite: quantite}
        
        resultats.append({
            "combinaison": combinaison,
            "meilleure_combinaison_defense": meilleure_combinaison_defense,
            "meilleure_defense": meilleure_defense,
            "meilleure_combinaison_attaque": meilleure_combinaison_attaque,
            "meilleure_attaque": meilleure_attaque
        })
    
    return resultats

def afficher_combinaison_unites(combinaison):
    result = ""
    for unite, quantite in combinaison.items():
        result += f"{quantite} {unite} + "
    result = result[:-3]  # Supprimer le dernier "+"
    return result

combinaisons = [
    {"lancier": 10000, "cavalier lourd": 3000},
    {"epée": 10000, "archer": 10000}
]

resultats = trouver_meilleure_combinaison(20000, combinaisons)

for i, resultat in enumerate(resultats):
    print(f"Combinaison {i + 1}:")
    print(f"Meilleure combinaison pour la défense : {afficher_combinaison_unites(resultat['meilleure_combinaison_defense'])}")
    print(f"Meilleure défense : {resultat['meilleure_defense']}")
    print(f"Meilleure combinaison pour l'attaque : {afficher_combinaison_unites(resultat['meilleure_combinaison_attaque'])}")
    print(f"Meilleure attaque : {resultat['meilleure_attaque']}")
    print()
# Out:
# Combinaison 1:
# Meilleure combinaison pour la défense : 3000 cavalier lourd
# Meilleure défense : 1380000
# Meilleure combinaison pour l'attaque : 3000 cavalier lourd
# Meilleure attaque : 450000
#
# Combinaison 2:
# Meilleure combinaison pour la défense : 10000 epée
# Meilleure défense : 1050000
# Meilleure combinaison pour l'attaque : 10000 epée
# Meilleure attaque : 250000

# %%
unites = {
    "lancier": {
        "population": 1,
        "temps_construction": 4.44,
        "force_attaque": 10,
        "defense_generale": 15,
        "defense_cavalerie": 45,
        "defense_archers": 20
    },
    "epée": {
        "population": 1,
        "temps_construction": 6.58,
        "force_attaque": 25,
        "defense_generale": 50,
        "defense_cavalerie": 15,
        "defense_archers": 40
    },
    "hache": {
        "population": 1,
        "temps_construction": 9.13,
        "force_attaque": 40,
        "defense_generale": 10,
        "defense_cavalerie": 5,
        "defense_archers": 10
    },
    "archer": {
        "population": 1,
        "temps_construction": 8.21,
        "force_attaque": 15,
        "defense_generale": 50,
        "defense_cavalerie": 40,
        "defense_archers": 5
    },
    "eclaireur": {
        "population": 2,
        "temps_construction": 5.56,
        "force_attaque": 0,
        "defense_generale": 2,
        "defense_cavalerie": 1,
        "defense_archers": 2
    },
    "cavalier": {
        "population": 4,
        "temps_construction": 11.51,
        "force_attaque": 130,
        "defense_generale": 30,
        "defense_cavalerie": 40,
        "defense_archers": 30
    },
    "arché monté": {
        "population": 5,
        "temps_construction": 12.51,
        "force_attaque": 120,
        "defense_generale": 40,
        "defense_cavalerie": 30,
        "defense_archers": 50
    },
    "cavalier lourd": {
        "population": 6,
        "temps_construction": 18.51,
        "force_attaque": 150,
        "defense_generale": 200,
        "defense_cavalerie": 80,
        "defense_archers": 180
    }
}

def calculer_force_attaque(unite, quantite):
    return unite["force_attaque"] * quantite

def calculer_defense(unite, quantite):
    return (unite["defense_generale"] + unite["defense_cavalerie"] + unite["defense_archers"]) * quantite

def trouver_meilleure_combinaison(hommes, combinaison1, combinaison2):
    meilleure_combinaison_defense = {}
    meilleure_defense = 0
    meilleure_combinaison_attaque = {}
    meilleure_attaque = 0

    for nom_unite, quantite in combinaison1.items():
        unite = unites[nom_unite]
        population = unite["population"]
        temps_construction = unite["temps_construction"]
        force_attaque = unite["force_attaque"]
        defense = unite["defense_generale"] + unite["defense_cavalerie"] + unite["defense_archers"]

        quantite_maximale = hommes // population

        for qte in range(quantite_maximale + 1):
            total_population = quantite * population

            if total_population <= hommes and qte <= combinaison1[nom_unite]:
                temps_total_construction = qte * temps_construction
                attaque = calculer_force_attaque(unite, qte)
                defense_totale = defense * qte

                if defense_totale > meilleure_defense:
                    meilleure_defense = defense_totale
                    meilleure_combinaison_defense = {nom_unite: qte}

                if attaque > meilleure_attaque:
                    meilleure_attaque = attaque
                    meilleure_combinaison_attaque = {nom_unite: qte}

    for nom_unite, quantite in combinaison2.items():
        unite = unites[nom_unite]
        population = unite["population"]
        temps_construction = unite["temps_construction"]
        force_attaque = unite["force_attaque"]
        defense = unite["defense_generale"] + unite["defense_cavalerie"] + unite["defense_archers"]

        quantite_maximale = hommes // population

        for qte in range(quantite_maximale + 1):
            total_population = quantite * population

            if total_population <= hommes and qte <= combinaison2[nom_unite]:
                temps_total_construction = qte * temps_construction
                attaque = calculer_force_attaque(unite, qte)
                defense_totale = defense * qte

                if defense_totale > meilleure_defense:
                    meilleure_defense = defense_totale
                    meilleure_combinaison_defense = {nom_unite: qte}

                if attaque > meilleure_attaque:
                    meilleure_attaque = attaque
                    meilleure_combinaison_attaque = {nom_unite: qte}

    return meilleure_combinaison_defense, meilleure_defense, meilleure_combinaison_attaque, meilleure_attaque

def afficher_combinaison_unites(combinaison):
    result = ""
    for unite, quantite in combinaison.items():
        result += f"{quantite} {unite} + "
    result = result[:-3]  # Supprimer le dernier "+"
    return result

combinaison1 = {"lancier": 10000, "cavalier lourd": 3000}
combinaison2 = {"epée": 10000, "archer": 10000}

meilleure_combinaison_defense, meilleure_defense, meilleure_combinaison_attaque, meilleure_attaque = trouver_meilleure_combinaison(20000, combinaison1, combinaison2)

print("Combinaison 1:")
print(f"Meilleure combinaison pour la défense : {afficher_combinaison_unites(meilleure_combinaison_defense)}")
print(f"Meilleure défense : {meilleure_defense}")
print(f"Meilleure combinaison pour l'attaque : {afficher_combinaison_unites(meilleure_combinaison_attaque)}")
print(f"Meilleure attaque : {meilleure_attaque}")
# Out:
# Combinaison 1:
# Meilleure combinaison pour la défense : 3000 cavalier lourd
# Meilleure défense : 1380000
# Meilleure combinaison pour l'attaque : 3000 cavalier lourd
# Meilleure attaque : 450000

# %%
unites = {
    "lancier": {
        "population": 1,
        "temps_construction": 4.44,
        "force_attaque": 10,
        "defense_generale": 15,
        "defense_cavalerie": 45,
        "defense_archers": 20
    },
    "epée": {
        "population": 1,
        "temps_construction": 6.58,
        "force_attaque": 25,
        "defense_generale": 50,
        "defense_cavalerie": 15,
        "defense_archers": 40
    },
    "hache": {
        "population": 1,
        "temps_construction": 9.13,
        "force_attaque": 40,
        "defense_generale": 10,
        "defense_cavalerie": 5,
        "defense_archers": 10
    },
    "archer": {
        "population": 1,
        "temps_construction": 8.21,
        "force_attaque": 15,
        "defense_generale": 50,
        "defense_cavalerie": 40,
        "defense_archers": 5
    },
    "eclaireur": {
        "population": 2,
        "temps_construction": 5.56,
        "force_attaque": 0,
        "defense_generale": 2,
        "defense_cavalerie": 1,
        "defense_archers": 2
    },
    "cavalier": {
        "population": 4,
        "temps_construction": 11.51,
        "force_attaque": 130,
        "defense_generale": 30,
        "defense_cavalerie": 40,
        "defense_archers": 30
    },
    "arché monté": {
        "population": 5,
        "temps_construction": 12.51,
        "force_attaque": 120,
        "defense_generale": 40,
        "defense_cavalerie": 30,
        "defense_archers": 50
    },
    "cavalier lourd": {
        "population": 6,
        "temps_construction": 18.51,
        "force_attaque": 150,
        "defense_generale": 200,
        "defense_cavalerie": 80,
        "defense_archers": 180
    }
}

def calculer_force_attaque(unite, quantite):
    return unite["force_attaque"] * quantite

def calculer_defense(unite, quantite):
    return (unite["defense_generale"] + unite["defense_cavalerie"] + unite["defense_archers"]) * quantite

def trouver_meilleure_combinaison(hommes, combinaison1, combinaison2):
    meilleure_combinaison_defense = ()
    meilleure_defense = 0
    meilleure_combinaison_attaque = ()
    meilleure_attaque = 0

    for nom_unite in unites:
        unite = unites[nom_unite]
        population = unite["population"]
        temps_construction = unite["temps_construction"]
        force_attaque = unite["force_attaque"]
        defense = unite["defense_generale"] + unite["defense_cavalerie"] + unite["defense_archers"]

        quantite_maximale = hommes // population

        for qte in range(quantite_maximale + 1):
            total_population = qte * population

            if total_population <= hommes:
                temps_total_construction = qte * temps_construction
                attaque = calculer_force_attaque(unite, qte)
                defense_totale = defense * qte

                if defense_totale > meilleure_defense:
                    meilleure_defense = defense_totale
                    meilleure_combinaison_defense = (nom_unite, qte)

                if attaque > meilleure_attaque:
                    meilleure_attaque = attaque
                    meilleure_combinaison_attaque = (nom_unite, qte)

    compte_rendu = {
        "Combinaison 1": {
            "Unités": combinaison1,
            "Meilleure combinaison pour la défense": meilleure_combinaison_defense,
            "Meilleure défense": meilleure_defense,
            "Meilleure combinaison pour l'attaque": meilleure_combinaison_attaque,
            "Meilleure attaque": meilleure_attaque
        }
    }

    # Calcul de la meilleure combinaison pour la deuxième configuration
    meilleure_combinaison_defense, meilleure_defense, meilleure_combinaison_attaque, meilleure_attaque = trouver_meilleure_combinaison(hommes, combinaison2, combinaison1)
    compte_rendu["Combinaison 2"] = {
        "Unités": combinaison2,
        "Meilleure combinaison pour la défense": meilleure_combinaison_defense,
        "Meilleure défense": meilleure_defense,
        "Meilleure combinaison pour l'attaque": meilleure_combinaison_attaque,
        "Meilleure attaque": meilleure_attaque
    }

    return compte_rendu

# Configuration des combinaisons d'unités
combinaison1 = {"lancier": 10000, "cavalier lourd": 3000}
combinaison2 = {"epée": 10000, "archer": 10000}

# Calcul du compte rendu²ii²00
compte_rendu = trouver_meilleure_combinaison(20000, combinaison1, combinaison2)

# Affichage du compte rendu
for combinaison_num, combinaison_data in compte_rendu.items():
    print(f"\n{combinaison_num}:")
    print("Unités:", combinaison_data["Unités"])
    print("Meilleure combinaison pour la défense:", combinaison_data["Meilleure combinaison pour la défense"])
    print("Meilleure défense:", combinaison_data["Meilleure défense"])
    print("Meilleure combinaison pour l'attaque:", combinaison_data["Meilleure combinaison pour l'attaque"])
    print("Meilleure attaque:", combinaison_data["Meilleure attaque"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18780\2265795034.py in <module>
#     130
#     131 # Calcul du compte rendu²ii²00
# --> 132 compte_rendu = trouver_meilleure_combinaison(20000, combinaison1, combinaison2)
#     133
#     134 # # Affichage du compte rendu
#
# ~\AppData\Local\Temp\ipykernel_18780\2265795034.py in trouver_meilleure_combinaison(hommes, combinaison1, combinaison2)
#     114
#     115     # Calcul de la meilleure combinaison pour la deuxième configuration
# --> 116     meilleure_combinaison_defense, meilleure_defense, meilleure_combinaison_attaque, meilleure_attaque = trouver_meilleure_combinaison(hommes, combinaison2, combinaison1)
#     117     compte_rendu["Combinaison 2"] = {
#     118         "Unités": combinaison2,
#
# ...

# %%
unites = {
    "lancier": {
        "population": 1,
        "temps_construction": 4.44,
        "force_attaque": 10,
        "defense_generale": 15,
        "defense_cavalerie": 45,
        "defense_archers": 20
    },
    "epée": {
        "population": 1,
        "temps_construction": 6.58,
        "force_attaque": 25,
        "defense_generale": 50,
        "defense_cavalerie": 15,
        "defense_archers": 40
    },
    "hache": {
        "population": 1,
        "temps_construction": 9.13,
        "force_attaque": 40,
        "defense_generale": 10,
        "defense_cavalerie": 5,
        "defense_archers": 10
    },
    "archer": {
        "population": 1,
        "temps_construction": 8.21,
        "force_attaque": 15,
        "defense_generale": 50,
        "defense_cavalerie": 40,
        "defense_archers": 5
    },
    "eclaireur": {
        "population": 2,
        "temps_construction": 5.56,
        "force_attaque": 0,
        "defense_generale": 2,
        "defense_cavalerie": 1,
        "defense_archers": 2
    },
    "cavalier": {
        "population": 4,
        "temps_construction": 11.51,
        "force_attaque": 130,
        "defense_generale": 30,
        "defense_cavalerie": 40,
        "defense_archers": 30
    },
    "arché monté": {
        "population": 5,
        "temps_construction": 12.51,
        "force_attaque": 120,
        "defense_generale": 40,
        "defense_cavalerie": 30,
        "defense_archers": 50
    },
    "cavalier lourd": {
        "population": 6,
        "temps_construction": 18.51,
        "force_attaque": 150,
        "defense_generale": 200,
        "defense_cavalerie": 80,
        "defense_archers": 180
    }
}

def calculer_force_attaque(unite, quantite):
    return unite["force_attaque"] * quantite

def calculer_defense(unite, quantite):
    return (unite["defense_generale"] + unite["defense_cavalerie"] + unite["defense_archers"]) * quantite

def trouver_meilleure_combinaison(hommes, combinaison_1, combinaison_2):
    meilleure_combinaison_defense_1 = ()
    meilleure_defense_1 = 0
    meilleure_combinaison_attaque_1 = ()
    meilleure_attaque_1 = 0

    meilleure_combinaison_defense_2 = ()
    meilleure_defense_2 = 0
    meilleure_combinaison_attaque_2 = ()
    meilleure_attaque_2 = 0

    for nom_unite in unites:
        unite = unites[nom_unite]
        population = unite["population"]
        temps_construction = unite["temps_construction"]
        force_attaque = unite["force_attaque"]
        defense = unite["defense_generale"] + unite["defense_cavalerie"] + unite["defense_archers"]

        quantite_maximale = hommes // population

        for quantite_1 in range(quantite_maximale + 1):
            quantite_maximale_2 = (hommes - quantite_1 * population) // population
            for quantite_2 in range(quantite_maximale_2 + 1):
                total_population = quantite_1 * population + quantite_2 * population

                if total_population <= hommes:
                    temps_total_construction = quantite_1 * temps_construction + quantite_2 * temps_construction
                    attaque = calculer_force_attaque(unite, quantite_1) + calculer_force_attaque(unite, quantite_2)
                    defense_totale = defense * quantite_1 + defense * quantite_2

                    if defense_totale > meilleure_defense_1:
                        meilleure_defense_1 = defense_totale
                        meilleure_combinaison_defense_1 = (nom_unite, quantite_1, nom_unite, quantite_2)

                    if attaque > meilleure_attaque_1:
                        meilleure_attaque_1 = attaque
                        meilleure_combinaison_attaque_1 = (nom_unite, quantite_1, nom_unite, quantite_2)

                    if (nom_unite == combinaison_1[0] and quantite_1 == combinaison_1[1] and
                            nom_unite == combinaison_2[0] and quantite_2 == combinaison_2[1]):
                        print(f"Combinaison 1:")
                        print(f"Meilleure combinaison pour la défense : {quantite_1} {nom_unite} + {quantite_2} {nom_unite}")
                        print(f"Meilleure défense : {defense_totale}")
                        print(f"Meilleure combinaison pour l'attaque : {quantite_1} {nom_unite} + {quantite_2} {nom_unite}")
                        print(f"Meilleure attaque : {attaque}")
                        print()

                    if defense_totale > meilleure_defense_2:
                        meilleure_defense_2 = defense_totale
                        meilleure_combinaison_defense_2 = (nom_unite, quantite_1, nom_unite, quantite_2)

                    if attaque > meilleure_attaque_2:
                        meilleure_attaque_2 = attaque
                        meilleure_combinaison_attaque_2 = (nom_unite, quantite_1, nom_unite, quantite_2)

    print(f"Combinaison 2:")
    print(f"Meilleure combinaison pour la défense : {meilleure_combinaison_defense_2[1]} {meilleure_combinaison_defense_2[0]} + {meilleure_combinaison_defense_2[3]} {meilleure_combinaison_defense_2[2]}")
    print(f"Meilleure défense : {meilleure_defense_2}")
    print(f"Meilleure combinaison pour l'attaque : {meilleure_combinaison_attaque_2[1]} {meilleure_combinaison_attaque_2[0]} + {meilleure_combinaison_attaque_2[3]} {meilleure_combinaison_attaque_2[2]}")
    print(f"Meilleure attaque : {meilleure_attaque_2}")

hommes = 20000
combinaison_1 = ("lancier", 10000, "cavalier lourd", 3000)
combinaison_2 = ("épée", 10000, "archer", 10000)

trouver_meilleure_combinaison(hommes, combinaison_1, combinaison_2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18780\1357687069.py in <module>
#     137 combinaison_2 = ("épée", 10000, "archer", 10000)
#     138
# --> 139 trouver_meilleure_combinaison(hommes, combinaison_1, combinaison_2)
#
# ~\AppData\Local\Temp\ipykernel_18780\1357687069.py in trouver_meilleure_combinaison(hommes, combinaison_1, combinaison_2)
#     100                     temps_total_construction = quantite_1 * temps_construction + quantite_2 * temps_construction
#     101                     attaque = calculer_force_attaque(unite, quantite_1) + calculer_force_attaque(unite, quantite_2)
# --> 102                     defense_totale = defense * quantite_1 + defense * quantite_2
#     103
#     104                     if defense_totale > meilleure_defense_1:
#
# KeyboardInterrupt:
